# %% [markdown]
# ## Tomato Pollination: Pepper 0

# %%
# def parse_obj_to_input_with_commas(obj_filename):
#     nodes = []
#     edges = []

#     # Read obj file
#     with open(obj_filename, "r") as f:
#         for line in f:
#             parts = line.strip().split()
#             if not parts:
#                 continue
#             if parts[0] == "v":  # Node line
#                 nodes.append([float(x) for x in parts[1:4]])
#             elif parts[0] == "l":  # Edge line
#                 edges.append([int(x) for x in parts[1:]])

#     # Write to input.txt with commas
#     out_filename=obj_filename.replace(".obj", ".txt")
#     with open(out_filename, "w") as f:
#         f.write("*Nodes\n")
#         for (x, y, z) in nodes:
#             f.write(f"{x}, {y}, {z}\n")

#         f.write("*Edges\n")
#         for (n1, n2) in edges:
#             f.write(f"{n1}, {n2}\n")

#     return out_filename

# # Run for all files in the directory
# directory = "../tests/resources/tomato_pollination/plants/"
# import os
# for filename in os.listdir(directory):
#     if filename.endswith(".obj"):
#         parse_obj_to_input_with_commas(os.path.join(directory, filename))

# %%
import numpy as np
import dismech
import os

plant_name = "pepper0"

position = "1"

geom = dismech.GeomParams(
    rod_r0=0.03,
    shell_h=0.0,
)

material = dismech.Material(density=1100,
                            youngs_rod=2.16e7,
                            youngs_shell=0,
                            poisson_rod=0.5,
                            poisson_shell=0)

dyn_sim = dismech.SimParams(static_sim=True,
                                  two_d_sim=True,   # no twisting
                                  use_mid_edge=False,
                                  use_line_search=False,
                                  show_floor=False,
                                  log_data=True,
                                  log_step=1,
                                  dt=1e-2,
                                  max_iter=50,
                                  total_time=5,
                                  plot_step=100,
                                  tol=1e-4,
                                  ftol=1e-4,
                                  dtol=1e-2
                                  )

env = dismech.Environment()
# env.add_force('gravity', g=np.array([0.0, 0.0, -9.81]))
env.add_force('damping', eta=100)

input_txt = os.path.join('../tests/resources/tomato_pollination/plants/', f"{plant_name}.txt")
geo = dismech.Geometry.from_txt(input_txt)

robot = dismech.SoftRobot(geom, material, geo, dyn_sim, env)

# %% [markdown]
# ### Move the stem: Moving BC

# %%
# # --- pick the main grip node robustly ---
# grasping_point = np.array([
#       1.1120794,
#       0.0663341,
#       0.3889156
#     ])

main_grip = [33]

print("Main grip node:", main_grip)
#82

# other_grip_nodes_below = np.array([1, 5, 8, 13], dtype=int)
# other_grip_nodes_above = np.array([57, 47, 44, 33, 28, 21], dtype=int)
other_grip_nodes_below = []
other_grip_nodes_above = []
# Out:
# Main grip node: [33]

# %%
base_nodes = np.where((robot.state.q[robot.node_dof_indices].reshape(-1, 3)[:, 2]) < 0.22)[0] # fixed base
# Fix only main_grip and base nodes
robot = robot.fix_nodes(np.unique(np.r_[main_grip, base_nodes]))

# %%
print(np.unique(np.r_[main_grip, base_nodes]))
# Out:
# [ 0  1  2  3 33]

# %%
# ----- once, before simulation -----
all_grip_nodes = np.r_[main_grip, other_grip_nodes_below, other_grip_nodes_above].astype(int)

xyz0 = robot.state.q[robot.node_dof_indices].reshape(-1, 3).copy()
x0 = xyz0[all_grip_nodes, 0].copy()          # initial x of all prescribed nodes
prev_target_x = x0.copy()                     # last absolute target (starts at initial)

# (Optional) precompute amplitude scalings from *initial* geometry
def build_amps_from_xyz0(xyz0, main_grip, all_grip_nodes, A_main):
    amps = np.empty(all_grip_nodes.size, float)
    amps[0] = A_main  # main_grip
    # below group
    below = np.array(other_grip_nodes_below, dtype=int)
    if below.size:
        ref = below[0]
        L = max(np.linalg.norm(xyz0[main_grip]-xyz0[ref]), 1e-12)
        for j, node in enumerate(below, start=1):  # start=1 because 0 is main_grip
            amps[j] = A_main * (np.linalg.norm(xyz0[ref]-xyz0[node]) / L)
    # above group
    above = np.array(other_grip_nodes_above, dtype=int)
    if above.size:
        ref = above[0]
        offset = 1 + below.size
        L = max(np.linalg.norm(xyz0[main_grip]-xyz0[ref]), 1e-12)
        for j, node in enumerate(above, start=offset):
            amps[j] = A_main * (np.linalg.norm(xyz0[ref]-xyz0[node]) / L)
    return amps

A_main = 0.4094e-2  # m at main_grip
freq   = 1    # Hz
# amps   = build_amps_from_xyz0(xyz0, main_grip, all_grip_nodes, A_main)
amps   = np.array([A_main for _ in all_grip_nodes])
print("Amplitudes (m):", amps)

def shake_distributed(robot, t: float):
    # absolute target centered at initial pose
    target_x = x0 + amps * np.sin(2*np.pi*freq*t)

    # INCREMENT ONLY: avoids velocity spikes and keeps symmetry
    delta_x = target_x - prev_target_x
    prev_target_x[:] = target_x

    return robot.move_nodes(all_grip_nodes, delta_x.reshape(-1,1).flatten(), axis=0)

print("grasping points:", all_grip_nodes)
# Out:
# Amplitudes (m): [0.004094]
# grasping points: [33]

# %%
stepper = dismech.ImplicitEulerTimeStepper(robot)
stepper.before_step = shake_distributed

# %% [markdown]
# ### Simulate

# %%
# simulate
robots = stepper.simulate()

qs = np.stack([robot.state.q for robot in robots])
# Out:
# iter: 1, error: 11425.186
# iter: 2, error: 1038.835
# iter: 3, error: 8.535
# current_time:  0.01
# iter: 1, error: 11402.635
# iter: 2, error: 1037.959
# iter: 3, error: 8.522
# current_time:  0.02
# iter: 1, error: 11338.931
# iter: 2, error: 1022.467
# iter: 3, error: 8.315
# current_time:  0.03
# iter: 1, error: 11231.419
# iter: 2, error: 998.108
# iter: 3, error: 7.972
# current_time:  0.04
# iter: 1, error: 11080.012
# iter: 2, error: 965.635
# iter: 3, error: 7.508
# current_time:  0.05
# iter: 1, error: 10884.931
# iter: 2, error: 925.645
# iter: 3, error: 6.942
# current_time:  0.06
# iter: 1, error: 10646.563
# iter: 2, error: 878.845
# current_time:  0.07
# iter: 1, error: 10363.152
# iter: 2, error: 823.754
# current_time:  0.08
# iter: 1, error: 10040.256
# iter: 2, error: 766.277
# current_time:  0.09
# iter: 1, error: 9676.212
# iter: 2, error: 704.773
# current_time:  0.1
# iter: 1, error: 9272.068
# iter: 2, error: 640.327
# current_time:  0.11
# iter: 1, error: 8829.028
# iter: 2, error: 574.062
# current_time:  0.12
# iter: 1, error: 8348.465
# iter: 2, error: 507.125
# current_time:  0.13
# iter: 1, error: 7831.926
# iter: 2, error: 440.657
# current_time:  0.14
# iter: 1, error: 7281.127
# iter: 2, error: 375.777
# current_time:  0.15
# iter: 1, error: 6697.957
# iter: 2, error: 313.552
# current_time:  0.16
# iter: 1, error: 6084.471
# iter: 2, error: 254.978
# current_time:  0.17
# iter: 1, error: 5442.891
# iter: 2, error: 200.961
# current_time:  0.18
# iter: 1, error: 4775.600
# iter: 2, error: 152.298
# current_time:  0.19
# iter: 1, error: 4085.137
# iter: 2, error: 109.661
# current_time:  0.2
# iter: 1, error: 3374.188
# current_time:  0.21
# iter: 1, error: 2612.645
# current_time:  0.22
# iter: 1, error: 1884.107
# current_time:  0.23
# iter: 1, error: 1137.571
# current_time:  0.24
# iter: 1, error: 380.257
# current_time:  0.25
# iter: 1, error: 385.179
# current_time:  0.26
# iter: 1, error: 1155.734
# current_time:  0.27
# iter: 1, error: 1928.424
# current_time:  0.28
# iter: 1, error: 2700.146
# current_time:  0.29
# iter: 1, error: 3467.728
# current_time:  0.3
# iter: 1, error: 4227.931
# iter: 2, error: 101.084
# current_time:  0.31
# iter: 1, error: 4917.092
# iter: 2, error: 128.834
# current_time:  0.32
# iter: 1, error: 5627.374
# iter: 2, error: 166.023
# current_time:  0.33
# iter: 1, error: 6315.908
# iter: 2, error: 205.946
# current_time:  0.34
# iter: 1, error: 6979.455
# iter: 2, error: 247.811
# current_time:  0.35000000000000003
# iter: 1, error: 7614.928
# iter: 2, error: 290.874
# current_time:  0.36
# iter: 1, error: 8219.368
# iter: 2, error: 334.407
# current_time:  0.37
# iter: 1, error: 8789.970
# iter: 2, error: 377.714
# current_time:  0.38
# iter: 1, error: 9324.093
# iter: 2, error: 420.130
# current_time:  0.39
# iter: 1, error: 9819.281
# iter: 2, error: 461.036
# current_time:  0.4
# iter: 1, error: 10273.281
# iter: 2, error: 499.861
# current_time:  0.41000000000000003
# iter: 1, error: 10684.056
# iter: 2, error: 536.088
# current_time:  0.42
# iter: 1, error: 11049.796
# iter: 2, error: 569.255
# iter: 3, error: 12.676
# current_time:  0.43
# iter: 1, error: 11362.117
# iter: 2, error: 598.421
# iter: 3, error: 14.045
# current_time:  0.44
# iter: 1, error: 11632.578
# iter: 2, error: 624.272
# iter: 3, error: 15.338
# current_time:  0.45
# iter: 1, error: 11854.124
# iter: 2, error: 646.035
# iter: 3, error: 16.482
# current_time:  0.46
# iter: 1, error: 12025.979
# iter: 2, error: 663.483
# iter: 3, error: 17.439
# current_time:  0.47000000000000003
# iter: 1, error: 12147.629
# iter: 2, error: 676.444
# iter: 3, error: 18.179
# current_time:  0.48
# iter: 1, error: 12218.817
# iter: 2, error: 684.795
# iter: 3, error: 18.676
# current_time:  0.49
# iter: 1, error: 12239.543
# iter: 2, error: 688.469
# iter: 3, error: 18.913
# current_time:  0.5
# iter: 1, error: 12210.055
# iter: 2, error: 687.444
# iter: 3, error: 18.884
# current_time:  0.51
# iter: 1, error: 12130.846
# iter: 2, error: 681.749
# iter: 3, error: 18.590
# current_time:  0.52
# iter: 1, error: 12002.643
# iter: 2, error: 671.459
# iter: 3, error: 18.041
# current_time:  0.53
# iter: 1, error: 11826.396
# iter: 2, error: 656.694
# iter: 3, error: 17.256
# current_time:  0.54
# iter: 1, error: 11603.267
# iter: 2, error: 637.622
# iter: 3, error: 16.261
# current_time:  0.55
# iter: 1, error: 11334.615
# iter: 2, error: 614.459
# iter: 3, error: 15.091
# current_time:  0.56
# iter: 1, error: 11021.987
# iter: 2, error: 587.465
# iter: 3, error: 13.784
# current_time:  0.5700000000000001
# iter: 1, error: 10667.098
# iter: 2, error: 556.950
# iter: 3, error: 12.381
# current_time:  0.58
# iter: 1, error: 10271.820
# iter: 2, error: 523.272
# iter: 3, error: 10.925
# current_time:  0.59
# iter: 1, error: 9838.165
# iter: 2, error: 486.838
# current_time:  0.6
# iter: 1, error: 9372.804
# iter: 2, error: 448.467
# current_time:  0.61
# iter: 1, error: 8868.176
# iter: 2, error: 407.871
# current_time:  0.62
# iter: 1, error: 8331.936
# iter: 2, error: 366.025
# current_time:  0.63
# iter: 1, error: 7766.530
# iter: 2, error: 323.515
# current_time:  0.64
# iter: 1, error: 7174.458
# iter: 2, error: 280.970
# current_time:  0.65
# iter: 1, error: 6558.266
# iter: 2, error: 239.044
# current_time:  0.66
# iter: 1, error: 5920.540
# iter: 2, error: 198.417
# current_time:  0.67
# iter: 1, error: 5263.889
# iter: 2, error: 159.783
# current_time:  0.68
# iter: 1, error: 4590.935
# iter: 2, error: 123.836
# current_time:  0.6900000000000001
# iter: 1, error: 3904.308
# current_time:  0.7000000000000001
# iter: 1, error: 3253.579
# current_time:  0.71
# iter: 1, error: 2536.054
# current_time:  0.72
# iter: 1, error: 1809.791
# current_time:  0.73
# iter: 1, error: 1083.931
# current_time:  0.74
# iter: 1, error: 361.174
# current_time:  0.75
# iter: 1, error: 356.274
# current_time:  0.76
# iter: 1, error: 1066.187
# current_time:  0.77
# iter: 1, error: 1766.529
# current_time:  0.78
# iter: 1, error: 2455.272
# current_time:  0.79
# iter: 1, error: 3130.444
# current_time:  0.8
# iter: 1, error: 3790.122
# iter: 2, error: 98.545
# current_time:  0.81
# iter: 1, error: 4468.170
# iter: 2, error: 145.158
# current_time:  0.8200000000000001
# iter: 1, error: 5102.903
# iter: 2, error: 191.840
# current_time:  0.8300000000000001
# iter: 1, error: 5717.417
# iter: 2, error: 243.715
# current_time:  0.84
# iter: 1, error: 6309.627
# iter: 2, error: 300.118
# current_time:  0.85
# iter: 1, error: 6877.551
# iter: 2, error: 360.232
# current_time:  0.86
# iter: 1, error: 7419.281
# iter: 2, error: 423.148
# current_time:  0.87
# iter: 1, error: 7932.981
# iter: 2, error: 487.884
# current_time:  0.88
# iter: 1, error: 8416.899
# iter: 2, error: 553.406
# current_time:  0.89
# iter: 1, error: 8869.361
# iter: 2, error: 618.642
# current_time:  0.9
# iter: 1, error: 9288.783
# iter: 2, error: 682.509
# current_time:  0.91
# iter: 1, error: 9673.671
# iter: 2, error: 743.928
# current_time:  0.92
# iter: 1, error: 10022.623
# iter: 2, error: 801.848
# current_time:  0.93
# iter: 1, error: 10334.339
# iter: 2, error: 855.269
# current_time:  0.9400000000000001
# iter: 1, error: 10607.621
# iter: 2, error: 903.256
# iter: 3, error: 6.200
# current_time:  0.9500000000000001
# iter: 1, error: 10843.478
# iter: 2, error: 947.506
# iter: 3, error: 6.826
# current_time:  0.96
# iter: 1, error: 11036.930
# iter: 2, error: 982.484
# iter: 3, error: 7.360
# current_time:  0.97
# iter: 1, error: 11188.996
# iter: 2, error: 1009.771
# iter: 3, error: 7.800
# current_time:  0.98
# iter: 1, error: 11298.929
# iter: 2, error: 1028.862
# iter: 3, error: 8.128
# current_time:  0.99
# iter: 1, error: 11366.109
# iter: 2, error: 1039.391
# iter: 3, error: 8.332
# current_time:  1.0
# iter: 1, error: 11390.049
# iter: 2, error: 1041.145
# iter: 3, error: 8.401
# current_time:  1.01
# iter: 1, error: 11370.396
# iter: 2, error: 1034.069
# iter: 3, error: 8.333
# current_time:  1.02
# iter: 1, error: 11306.939
# iter: 2, error: 1018.266
# iter: 3, error: 8.127
# current_time:  1.03
# iter: 1, error: 11199.610
# iter: 2, error: 993.999
# iter: 3, error: 7.792
# current_time:  1.04
# iter: 1, error: 11048.491
# iter: 2, error: 961.687
# iter: 3, error: 7.340
# current_time:  1.05
# iter: 1, error: 10853.816
# iter: 2, error: 921.894
# iter: 3, error: 6.788
# current_time:  1.06
# iter: 1, error: 10615.975
# iter: 2, error: 875.323
# current_time:  1.07
# iter: 1, error: 10333.291
# iter: 2, error: 820.528
# current_time:  1.08
# iter: 1, error: 10011.160
# iter: 2, error: 763.319
# current_time:  1.09
# iter: 1, error: 9648.006
# iter: 2, error: 702.096
# current_time:  1.1
# iter: 1, error: 9244.876
# iter: 2, error: 637.940
# current_time:  1.11
# iter: 1, error: 8802.975
# iter: 2, error: 571.966
# current_time:  1.12
# iter: 1, error: 8323.676
# iter: 2, error: 505.314
# current_time:  1.1300000000000001
# iter: 1, error: 7808.523
# iter: 2, error: 439.123
# current_time:  1.1400000000000001
# iter: 1, error: 7259.232
# iter: 2, error: 374.503
# current_time:  1.1500000000000001
# iter: 1, error: 6677.687
# iter: 2, error: 312.520
# current_time:  1.16
# iter: 1, error: 6065.940
# iter: 2, error: 254.165
# current_time:  1.17
# iter: 1, error: 5426.210
# iter: 2, error: 200.342
# current_time:  1.18
# iter: 1, error: 4760.874
# iter: 2, error: 151.845
# current_time:  1.19
# iter: 1, error: 4072.463
# iter: 2, error: 109.348
# current_time:  1.2
# iter: 1, error: 3363.657
# current_time:  1.21
# iter: 1, error: 2604.703
# current_time:  1.22
# iter: 1, error: 1878.288
# current_time:  1.23
# iter: 1, error: 1134.029
# current_time:  1.24
# iter: 1, error: 379.068
# current_time:  1.25
# iter: 1, error: 383.940
# current_time:  1.26
# iter: 1, error: 1152.004
# current_time:  1.27
# iter: 1, error: 1922.149
# current_time:  1.28
# iter: 1, error: 2691.280
# current_time:  1.29
# iter: 1, error: 3456.237
# current_time:  1.3
# iter: 1, error: 4213.794
# iter: 2, error: 100.881
# current_time:  1.31
# iter: 1, error: 4900.883
# iter: 2, error: 128.647
# current_time:  1.32
# iter: 1, error: 5608.753
# iter: 2, error: 165.801
# current_time:  1.33
# iter: 1, error: 6294.934
# iter: 2, error: 205.692
# current_time:  1.34
# iter: 1, error: 6956.200
# iter: 2, error: 247.531
# current_time:  1.35
# iter: 1, error: 7589.475
# iter: 2, error: 290.574
# current_time:  1.36
# iter: 1, error: 8191.816
# iter: 2, error: 334.096
# current_time:  1.37
# iter: 1, error: 8760.428
# iter: 2, error: 377.397
# current_time:  1.3800000000000001
# iter: 1, error: 9292.682
# iter: 2, error: 419.815
# current_time:  1.3900000000000001
# iter: 1, error: 9786.133
# iter: 2, error: 460.728
# current_time:  1.4000000000000001
# iter: 1, error: 10238.538
# iter: 2, error: 499.566
# current_time:  1.41
# iter: 1, error: 10647.870
# iter: 2, error: 535.809
# current_time:  1.42
# iter: 1, error: 11012.328
# iter: 2, error: 568.996
# iter: 3, error: 12.529
# current_time:  1.43
# iter: 1, error: 11323.657
# iter: 2, error: 598.181
# iter: 3, error: 13.883
# current_time:  1.44
# iter: 1, error: 11593.190
# iter: 2, error: 624.053
# iter: 3, error: 15.161
# current_time:  1.45
# iter: 1, error: 11813.987
# iter: 2, error: 645.835
# iter: 3, error: 16.292
# current_time:  1.46
# iter: 1, error: 11985.274
# iter: 2, error: 663.299
# iter: 3, error: 17.239
# current_time:  1.47
# iter: 1, error: 12106.539
# iter: 2, error: 676.272
# iter: 3, error: 17.970
# current_time:  1.48
# iter: 1, error: 12177.527
# iter: 2, error: 684.632
# iter: 3, error: 18.462
# current_time:  1.49
# iter: 1, error: 12198.237
# iter: 2, error: 688.309
# iter: 3, error: 18.697
# current_time:  1.5
# iter: 1, error: 12168.917
# iter: 2, error: 687.283
# iter: 3, error: 18.668
# current_time:  1.51
# iter: 1, error: 12090.056
# iter: 2, error: 681.581
# iter: 3, error: 18.377
# current_time:  1.52
# iter: 1, error: 11962.378
# iter: 2, error: 671.280
# iter: 3, error: 17.833
# current_time:  1.53
# iter: 1, error: 11786.828
# iter: 2, error: 656.500
# iter: 3, error: 17.057
# current_time:  1.54
# iter: 1, error: 11564.561
# iter: 2, error: 637.411
# iter: 3, error: 16.074
# current_time:  1.55
# iter: 1, error: 11296.930
# iter: 2, error: 614.228
# iter: 3, error: 14.917
# current_time:  1.56
# iter: 1, error: 10985.474
# iter: 2, error: 587.214
# iter: 3, error: 13.624
# current_time:  1.57
# iter: 1, error: 10631.900
# iter: 2, error: 556.679
# iter: 3, error: 12.236
# current_time:  1.58
# iter: 1, error: 10238.070
# iter: 2, error: 522.984
# iter: 3, error: 10.797
# current_time:  1.59
# iter: 1, error: 9805.986
# iter: 2, error: 486.536
# current_time:  1.6
# iter: 1, error: 9342.220
# iter: 2, error: 448.155
# current_time:  1.61
# iter: 1, error: 8839.392
# iter: 2, error: 407.555
# current_time:  1.62
# iter: 1, error: 8305.044
# iter: 2, error: 365.709
# current_time:  1.6300000000000001
# iter: 1, error: 7741.609
# iter: 2, error: 323.208
# current_time:  1.6400000000000001
# iter: 1, error: 7151.576
# iter: 2, error: 280.677
# current_time:  1.6500000000000001
# iter: 1, error: 6537.480
# iter: 2, error: 238.772
# current_time:  1.6600000000000001
# iter: 1, error: 5901.895
# iter: 2, error: 198.173
# current_time:  1.67
# iter: 1, error: 5247.420
# iter: 2, error: 159.570
# current_time:  1.68
# iter: 1, error: 4576.667
# iter: 2, error: 123.658
# current_time:  1.69
# iter: 1, error: 3892.256
# current_time:  1.7
# iter: 1, error: 3243.240
# current_time:  1.71
# iter: 1, error: 2528.037
# current_time:  1.72
# iter: 1, error: 1804.136
# current_time:  1.73
# iter: 1, error: 1080.583
# current_time:  1.74
# iter: 1, error: 360.063
# current_time:  1.75
# iter: 1, error: 355.222
# current_time:  1.76
# iter: 1, error: 1063.050
# current_time:  1.77
# iter: 1, error: 1761.389
# current_time:  1.78
# iter: 1, error: 2448.212
# current_time:  1.79
# iter: 1, error: 3121.549
# current_time:  1.8
# iter: 1, error: 3779.478
# iter: 2, error: 98.313
# current_time:  1.81
# iter: 1, error: 4455.395
# iter: 2, error: 144.739
# current_time:  1.82
# iter: 1, error: 5088.389
# iter: 2, error: 191.265
# current_time:  1.83
# iter: 1, error: 5701.234
# iter: 2, error: 242.960
# current_time:  1.84
# iter: 1, error: 6291.850
# iter: 2, error: 299.157
# current_time:  1.85
# iter: 1, error: 6858.255
# iter: 2, error: 359.042
# current_time:  1.86
# iter: 1, error: 7398.543
# iter: 2, error: 421.709
# current_time:  1.87
# iter: 1, error: 7910.883
# iter: 2, error: 486.181
# current_time:  1.8800000000000001
# iter: 1, error: 8393.522
# iter: 2, error: 551.426
# current_time:  1.8900000000000001
# iter: 1, error: 8844.790
# iter: 2, error: 616.379
# current_time:  1.9000000000000001
# iter: 1, error: 9263.103
# iter: 2, error: 679.960
# current_time:  1.9100000000000001
# iter: 1, error: 9646.968
# iter: 2, error: 741.098
# current_time:  1.92
# iter: 1, error: 9994.986
# iter: 2, error: 798.748
# current_time:  1.93
# iter: 1, error: 10305.859
# iter: 2, error: 851.913
# current_time:  1.94
# iter: 1, error: 10578.388
# iter: 2, error: 899.667
# iter: 3, error: 6.061
# current_time:  1.95
# iter: 1, error: 10813.513
# iter: 2, error: 943.664
# iter: 3, error: 6.671
# current_time:  1.96
# iter: 1, error: 11006.396
# iter: 2, error: 978.462
# iter: 3, error: 7.192
# current_time:  1.97
# iter: 1, error: 11157.991
# iter: 2, error: 1005.607
# iter: 3, error: 7.621
# current_time:  1.98
# iter: 1, error: 11267.553
# iter: 2, error: 1024.596
# iter: 3, error: 7.942
# current_time:  1.99
# iter: 1, error: 11334.466
# iter: 2, error: 1035.067
# iter: 3, error: 8.140
# current_time:  2.0
# iter: 1, error: 11358.245
# iter: 2, error: 1036.808
# iter: 3, error: 8.208
# current_time:  2.0100000000000002
# iter: 1, error: 11338.539
# iter: 2, error: 1029.764
# iter: 3, error: 8.141
# current_time:  2.02
# iter: 1, error: 11275.139
# iter: 2, error: 1014.038
# iter: 3, error: 7.941
# current_time:  2.0300000000000002
# iter: 1, error: 11167.981
# iter: 2, error: 989.892
# iter: 3, error: 7.615
# current_time:  2.04
# iter: 1, error: 11017.149
# iter: 2, error: 957.740
# iter: 3, error: 7.174
# current_time:  2.05
# iter: 1, error: 10822.878
# iter: 2, error: 918.144
# iter: 3, error: 6.635
# current_time:  2.06
# iter: 1, error: 10585.561
# iter: 2, error: 871.801
# current_time:  2.07
# iter: 1, error: 10303.599
# iter: 2, error: 817.302
# current_time:  2.08
# iter: 1, error: 9982.227
# iter: 2, error: 760.360
# current_time:  2.09
# iter: 1, error: 9619.957
# iter: 2, error: 699.419
# current_time:  2.1
# iter: 1, error: 9217.835
# iter: 2, error: 635.552
# current_time:  2.11
# iter: 1, error: 8777.065
# iter: 2, error: 569.869
# current_time:  2.12
# iter: 1, error: 8299.021
# iter: 2, error: 503.503
# current_time:  2.13
# iter: 1, error: 7785.246
# iter: 2, error: 437.588
# current_time:  2.14
# iter: 1, error: 7237.452
# iter: 2, error: 373.229
# current_time:  2.15
# iter: 1, error: 6657.523
# iter: 2, error: 311.488
# current_time:  2.16
# iter: 1, error: 6047.506
# iter: 2, error: 253.352
# current_time:  2.17
# iter: 1, error: 5409.615
# iter: 2, error: 199.722
# current_time:  2.18
# iter: 1, error: 4746.222
# iter: 2, error: 151.392
# current_time:  2.19
# iter: 1, error: 4059.852
# iter: 2, error: 109.034
# current_time:  2.2
# iter: 1, error: 3353.178
# current_time:  2.21
# iter: 1, error: 2596.802
# current_time:  2.22
# iter: 1, error: 1872.499
# current_time:  2.23
# iter: 1, error: 1130.504
# current_time:  2.24
# iter: 1, error: 377.886
# current_time:  2.25
# iter: 1, error: 382.707
# current_time:  2.2600000000000002
# iter: 1, error: 1148.291
# current_time:  2.27
# iter: 1, error: 1915.899
# current_time:  2.2800000000000002
# iter: 1, error: 2682.450
# current_time:  2.29
# iter: 1, error: 3444.792
# current_time:  2.3000000000000003
# iter: 1, error: 4199.710
# iter: 2, error: 100.677
# current_time:  2.31
# iter: 1, error: 4884.737
# iter: 2, error: 128.459
# current_time:  2.32
# iter: 1, error: 5590.204
# iter: 2, error: 165.577
# current_time:  2.33
# iter: 1, error: 6274.039
# iter: 2, error: 205.437
# current_time:  2.34
# iter: 1, error: 6933.030
# iter: 2, error: 247.250
# current_time:  2.35
# iter: 1, error: 7564.115
# iter: 2, error: 290.274
# current_time:  2.36
# iter: 1, error: 8164.363
# iter: 2, error: 333.783
# current_time:  2.37
# iter: 1, error: 8730.989
# iter: 2, error: 377.079
# current_time:  2.38
# iter: 1, error: 9261.378
# iter: 2, error: 419.497
# current_time:  2.39
# iter: 1, error: 9753.096
# iter: 2, error: 460.418
# current_time:  2.4
# iter: 1, error: 10203.910
# iter: 2, error: 499.269
# current_time:  2.41
# iter: 1, error: 10611.801
# iter: 2, error: 535.529
# current_time:  2.42
# iter: 1, error: 10974.978
# iter: 2, error: 568.735
# iter: 3, error: 12.382
# current_time:  2.43
# iter: 1, error: 11285.318
# iter: 2, error: 597.939
# iter: 3, error: 13.721
# current_time:  2.44
# iter: 1, error: 11553.925
# iter: 2, error: 623.831
# iter: 3, error: 14.984
# current_time:  2.45
# iter: 1, error: 11773.972
# iter: 2, error: 645.631
# iter: 3, error: 16.103
# current_time:  2.46
# iter: 1, error: 11944.691
# iter: 2, error: 663.112
# iter: 3, error: 17.039
# current_time:  2.47
# iter: 1, error: 12065.571
# iter: 2, error: 676.098
# iter: 3, error: 17.762
# current_time:  2.48
# iter: 1, error: 12136.358
# iter: 2, error: 684.466
# iter: 3, error: 18.248
# current_time:  2.49
# iter: 1, error: 12157.052
# iter: 2, error: 688.147
# iter: 3, error: 18.480
# current_time:  2.5
# iter: 1, error: 12127.898
# iter: 2, error: 687.119
# iter: 3, error: 18.451
# current_time:  2.5100000000000002
# iter: 1, error: 12049.383
# iter: 2, error: 681.411
# iter: 3, error: 18.163
# current_time:  2.52
# iter: 1, error: 11922.228
# iter: 2, error: 671.098
# iter: 3, error: 17.626
# current_time:  2.5300000000000002
# iter: 1, error: 11747.372
# iter: 2, error: 656.304
# iter: 3, error: 16.858
# current_time:  2.54
# iter: 1, error: 11525.964
# iter: 2, error: 637.197
# iter: 3, error: 15.886
# current_time:  2.5500000000000003
# iter: 1, error: 11259.352
# iter: 2, error: 613.994
# iter: 3, error: 14.742
# current_time:  2.56
# iter: 1, error: 10949.065
# iter: 2, error: 586.960
# iter: 3, error: 13.463
# current_time:  2.57
# iter: 1, error: 10596.803
# iter: 2, error: 556.407
# iter: 3, error: 12.092
# current_time:  2.58
# iter: 1, error: 10204.417
# iter: 2, error: 522.695
# iter: 3, error: 10.669
# current_time:  2.59
# iter: 1, error: 9773.900
# iter: 2, error: 486.232
# current_time:  2.6
# iter: 1, error: 9311.725
# iter: 2, error: 447.842
# current_time:  2.61
# iter: 1, error: 8810.694
# iter: 2, error: 407.237
# current_time:  2.62
# iter: 1, error: 8278.233
# iter: 2, error: 365.393
# current_time:  2.63
# iter: 1, error: 7716.765
# iter: 2, error: 322.899
# current_time:  2.64
# iter: 1, error: 7128.765
# iter: 2, error: 280.383
# current_time:  2.65
# iter: 1, error: 6516.760
# iter: 2, error: 238.499
# current_time:  2.66
# iter: 1, error: 5883.311
# iter: 2, error: 197.927
# current_time:  2.67
# iter: 1, error: 5231.006
# iter: 2, error: 159.356
# current_time:  2.68
# iter: 1, error: 4562.448
# iter: 2, error: 123.480
# current_time:  2.69
# iter: 1, error: 3880.245
# current_time:  2.7
# iter: 1, error: 3232.931
# current_time:  2.71
# iter: 1, error: 2520.044
# current_time:  2.72
# iter: 1, error: 1798.500
# current_time:  2.73
# iter: 1, error: 1077.246
# current_time:  2.74
# iter: 1, error: 358.957
# current_time:  2.75
# iter: 1, error: 354.174
# current_time:  2.7600000000000002
# iter: 1, error: 1059.927
# current_time:  2.77
# iter: 1, error: 1756.272
# current_time:  2.7800000000000002
# iter: 1, error: 2441.184
# current_time:  2.79
# iter: 1, error: 3112.697
# current_time:  2.8000000000000003
# iter: 1, error: 3768.888
# iter: 2, error: 98.080
# current_time:  2.81
# iter: 1, error: 4442.681
# iter: 2, error: 144.318
# current_time:  2.82
# iter: 1, error: 5073.947
# iter: 2, error: 190.689
# current_time:  2.83
# iter: 1, error: 5685.133
# iter: 2, error: 242.201
# current_time:  2.84
# iter: 1, error: 6274.164
# iter: 2, error: 298.192
# current_time:  2.85
# iter: 1, error: 6839.060
# iter: 2, error: 357.848
# current_time:  2.86
# iter: 1, error: 7377.917
# iter: 2, error: 420.267
# current_time:  2.87
# iter: 1, error: 7888.906
# iter: 2, error: 484.474
# current_time:  2.88
# iter: 1, error: 8370.276
# iter: 2, error: 549.442
# current_time:  2.89
# iter: 1, error: 8820.358
# iter: 2, error: 614.111
# current_time:  2.9
# iter: 1, error: 9237.569
# iter: 2, error: 677.407
# current_time:  2.91
# iter: 1, error: 9620.420
# iter: 2, error: 738.263
# current_time:  2.92
# iter: 1, error: 9967.512
# iter: 2, error: 795.641
# current_time:  2.93
# iter: 1, error: 10277.547
# iter: 2, error: 848.552
# current_time:  2.94
# iter: 1, error: 10549.331
# iter: 2, error: 896.073
# iter: 3, error: 5.923
# current_time:  2.95
# iter: 1, error: 10783.730
# iter: 2, error: 939.817
# iter: 3, error: 6.518
# current_time:  2.96
# iter: 1, error: 10976.048
# iter: 2, error: 974.436
# iter: 3, error: 7.026
# current_time:  2.97
# iter: 1, error: 11127.176
# iter: 2, error: 1001.438
# iter: 3, error: 7.444
# current_time:  2.98
# iter: 1, error: 11236.371
# iter: 2, error: 1020.326
# iter: 3, error: 7.757
# current_time:  2.99
# iter: 1, error: 11303.019
# iter: 2, error: 1030.739
# iter: 3, error: 7.951
# current_time:  3.0
# iter: 1, error: 11326.637
# iter: 2, error: 1032.468
# iter: 3, error: 8.017
# current_time:  3.0100000000000002
# iter: 1, error: 11306.878
# iter: 2, error: 1025.457
# iter: 3, error: 7.952
# current_time:  3.02
# iter: 1, error: 11243.536
# iter: 2, error: 1009.809
# iter: 3, error: 7.757
# current_time:  3.0300000000000002
# iter: 1, error: 11136.547
# iter: 2, error: 985.783
# iter: 3, error: 7.439
# current_time:  3.04
# iter: 1, error: 10985.999
# iter: 2, error: 953.792
# iter: 3, error: 7.009
# current_time:  3.0500000000000003
# iter: 1, error: 10792.129
# iter: 2, error: 914.393
# iter: 3, error: 6.484
# current_time:  3.06
# iter: 1, error: 10555.331
# iter: 2, error: 868.279
# current_time:  3.0700000000000003
# iter: 1, error: 10274.084
# iter: 2, error: 814.074
# current_time:  3.08
# iter: 1, error: 9953.467
# iter: 2, error: 757.401
# current_time:  3.09
# iter: 1, error: 9592.073
# iter: 2, error: 696.742
# current_time:  3.1
# iter: 1, error: 9190.951
# iter: 2, error: 633.164
# current_time:  3.11
# iter: 1, error: 8751.305
# iter: 2, error: 567.771
# current_time:  3.12
# iter: 1, error: 8274.507
# iter: 2, error: 501.692
# current_time:  3.13
# iter: 1, error: 7762.099
# iter: 2, error: 436.052
# current_time:  3.14
# iter: 1, error: 7215.793
# iter: 2, error: 371.955
# current_time:  3.15
# iter: 1, error: 6637.469
# iter: 2, error: 310.455
# current_time:  3.16
# iter: 1, error: 6029.171
# iter: 2, error: 252.538
# current_time:  3.17
# iter: 1, error: 5393.108
# iter: 2, error: 199.102
# current_time:  3.18
# iter: 1, error: 4731.646
# iter: 2, error: 150.939
# current_time:  3.19
# iter: 1, error: 4047.306
# iter: 2, error: 108.720
# current_time:  3.2
# iter: 1, error: 3342.751
# current_time:  3.21
# iter: 1, error: 2588.945
# current_time:  3.22
# iter: 1, error: 1866.741
# current_time:  3.23
# iter: 1, error: 1126.997
# current_time:  3.24
# iter: 1, error: 376.709
# current_time:  3.25
# iter: 1, error: 381.480
# current_time:  3.2600000000000002
# iter: 1, error: 1144.594
# current_time:  3.27
# iter: 1, error: 1909.678
# current_time:  3.2800000000000002
# iter: 1, error: 2673.657
# current_time:  3.29
# iter: 1, error: 3433.393
# current_time:  3.3000000000000003
# iter: 1, error: 4185.682
# iter: 2, error: 100.473
# current_time:  3.31
# iter: 1, error: 4868.659
# iter: 2, error: 128.271
# current_time:  3.3200000000000003
# iter: 1, error: 5571.731
# iter: 2, error: 165.353
# current_time:  3.33
# iter: 1, error: 6253.228
# iter: 2, error: 205.182
# current_time:  3.34
# iter: 1, error: 6909.952
# iter: 2, error: 246.969
# current_time:  3.35
# iter: 1, error: 7538.853
# iter: 2, error: 289.973
# current_time:  3.36
# iter: 1, error: 8137.013
# iter: 2, error: 333.469
# current_time:  3.37
# iter: 1, error: 8701.660
# iter: 2, error: 376.759
# current_time:  3.38
# iter: 1, error: 9230.189
# iter: 2, error: 419.178
# current_time:  3.39
# iter: 1, error: 9720.178
# iter: 2, error: 460.106
# current_time:  3.4
# iter: 1, error: 10169.404
# iter: 2, error: 498.969
# current_time:  3.41
# iter: 1, error: 10575.858
# iter: 2, error: 535.246
# current_time:  3.42
# iter: 1, error: 10937.756
# iter: 2, error: 568.471
# iter: 3, error: 12.235
# current_time:  3.43
# iter: 1, error: 11247.108
# iter: 2, error: 597.695
# iter: 3, error: 13.558
# current_time:  3.44
# iter: 1, error: 11514.789
# iter: 2, error: 623.606
# iter: 3, error: 14.807
# current_time:  3.45
# iter: 1, error: 11734.088
# iter: 2, error: 645.425
# iter: 3, error: 15.913
# current_time:  3.46
# iter: 1, error: 11904.239
# iter: 2, error: 662.922
# iter: 3, error: 16.838
# current_time:  3.47
# iter: 1, error: 12024.734
# iter: 2, error: 675.920
# iter: 3, error: 17.553
# current_time:  3.48
# iter: 1, error: 12095.320
# iter: 2, error: 684.297
# iter: 3, error: 18.033
# current_time:  3.49
# iter: 1, error: 12115.995
# iter: 2, error: 687.981
# iter: 3, error: 18.263
# current_time:  3.5
# iter: 1, error: 12087.006
# iter: 2, error: 686.952
# iter: 3, error: 18.234
# current_time:  3.5100000000000002
# iter: 1, error: 12008.836
# iter: 2, error: 681.237
# iter: 3, error: 17.949
# current_time:  3.52
# iter: 1, error: 11882.201
# iter: 2, error: 670.914
# iter: 3, error: 17.418
# current_time:  3.5300000000000002
# iter: 1, error: 11708.037
# iter: 2, error: 656.105
# iter: 3, error: 16.658
# current_time:  3.54
# iter: 1, error: 11487.486
# iter: 2, error: 636.980
# iter: 3, error: 15.697
# current_time:  3.5500000000000003
# iter: 1, error: 11221.889
# iter: 2, error: 613.759
# iter: 3, error: 14.566
# current_time:  3.56
# iter: 1, error: 10912.768
# iter: 2, error: 586.705
# iter: 3, error: 13.303
# current_time:  3.5700000000000003
# iter: 1, error: 10561.814
# iter: 2, error: 556.132
# iter: 3, error: 11.947
# current_time:  3.58
# iter: 1, error: 10170.869
# iter: 2, error: 522.403
# iter: 3, error: 10.541
# current_time:  3.59
# iter: 1, error: 9741.916
# iter: 2, error: 485.927
# current_time:  3.6
# iter: 1, error: 9281.327
# iter: 2, error: 447.527
# current_time:  3.61
# iter: 1, error: 8782.088
# iter: 2, error: 406.917
# current_time:  3.62
# iter: 1, error: 8251.509
# iter: 2, error: 365.075
# current_time:  3.63
# iter: 1, error: 7692.002
# iter: 2, error: 322.590
# current_time:  3.64
# iter: 1, error: 7106.031
# iter: 2, error: 280.088
# current_time:  3.65
# iter: 1, error: 6496.110
# iter: 2, error: 238.225
# current_time:  3.66
# iter: 1, error: 5864.791
# iter: 2, error: 197.680
# current_time:  3.67
# iter: 1, error: 5214.650
# iter: 2, error: 159.141
# current_time:  3.68
# iter: 1, error: 4548.280
# iter: 2, error: 123.300
# current_time:  3.69
# iter: 1, error: 3868.279
# current_time:  3.7
# iter: 1, error: 3222.654
# current_time:  3.71
# iter: 1, error: 2512.077
# current_time:  3.72
# iter: 1, error: 1792.884
# current_time:  3.73
# iter: 1, error: 1073.922
# current_time:  3.74
# iter: 1, error: 357.854
# current_time:  3.75
# iter: 1, error: 353.130
# current_time:  3.7600000000000002
# iter: 1, error: 1056.817
# current_time:  3.77
# iter: 1, error: 1751.178
# current_time:  3.7800000000000002
# iter: 1, error: 2434.192
# current_time:  3.79
# iter: 1, error: 3103.891
# current_time:  3.8000000000000003
# iter: 1, error: 3758.355
# iter: 2, error: 97.846
# current_time:  3.81
# iter: 1, error: 4430.031
# iter: 2, error: 143.896
# current_time:  3.8200000000000003
# iter: 1, error: 5059.580
# iter: 2, error: 190.110
# current_time:  3.83
# iter: 1, error: 5669.118
# iter: 2, error: 241.441
# current_time:  3.84
# iter: 1, error: 6256.574
# iter: 2, error: 297.225
# current_time:  3.85
# iter: 1, error: 6819.972
# iter: 2, error: 356.651
# current_time:  3.86
# iter: 1, error: 7357.408
# iter: 2, error: 418.821
# current_time:  3.87
# iter: 1, error: 7867.056
# iter: 2, error: 482.762
# current_time:  3.88
# iter: 1, error: 8347.166
# iter: 2, error: 547.453
# current_time:  3.89
# iter: 1, error: 8796.071
# iter: 2, error: 611.838
# current_time:  3.9
# iter: 1, error: 9212.191
# iter: 2, error: 674.848
# current_time:  3.91
# iter: 1, error: 9594.035
# iter: 2, error: 735.423
# current_time:  3.92
# iter: 1, error: 9940.208
# iter: 2, error: 792.530
# current_time:  3.93
# iter: 1, error: 10249.413
# iter: 2, error: 845.186
# current_time:  3.94
# iter: 1, error: 10520.458
# iter: 2, error: 892.474
# iter: 3, error: 5.788
# current_time:  3.95
# iter: 1, error: 10754.137
# iter: 2, error: 935.966
# iter: 3, error: 6.367
# current_time:  3.96
# iter: 1, error: 10945.895
# iter: 2, error: 970.406
# iter: 3, error: 6.861
# current_time:  3.97
# iter: 1, error: 11096.559
# iter: 2, error: 997.267
# iter: 3, error: 7.269
# current_time:  3.98
# iter: 1, error: 11205.390
# iter: 2, error: 1016.054
# iter: 3, error: 7.574
# current_time:  3.99
# iter: 1, error: 11271.775
# iter: 2, error: 1026.410
# iter: 3, error: 7.764
# current_time:  4.0
# iter: 1, error: 11295.234
# iter: 2, error: 1028.126
# iter: 3, error: 7.829
# current_time:  4.01
# iter: 1, error: 11275.422
# iter: 2, error: 1021.148
# iter: 3, error: 7.765
# current_time:  4.0200000000000005
# iter: 1, error: 11212.136
# iter: 2, error: 1005.579
# iter: 3, error: 7.576
# current_time:  4.03
# iter: 1, error: 11105.315
# iter: 2, error: 981.674
# iter: 3, error: 7.265
# current_time:  4.04
# iter: 1, error: 10955.048
# iter: 2, error: 949.844
# iter: 3, error: 6.846
# current_time:  4.05
# iter: 1, error: 10761.575
# iter: 2, error: 910.642
# iter: 3, error: 6.334
# current_time:  4.0600000000000005
# iter: 1, error: 10525.293
# iter: 2, error: 864.757
# current_time:  4.07
# iter: 1, error: 10244.753
# iter: 2, error: 810.847
# current_time:  4.08
# iter: 1, error: 9924.884
# iter: 2, error: 754.441
# current_time:  4.09
# iter: 1, error: 9564.360
# iter: 2, error: 694.064
# current_time:  4.1
# iter: 1, error: 9164.231
# iter: 2, error: 630.775
# current_time:  4.11
# iter: 1, error: 8725.699
# iter: 2, error: 565.673
# current_time:  4.12
# iter: 1, error: 8250.138
# iter: 2, error: 499.880
# current_time:  4.13
# iter: 1, error: 7739.089
# iter: 2, error: 434.517
# current_time:  4.14
# iter: 1, error: 7194.260
# iter: 2, error: 370.680
# current_time:  4.15
# iter: 1, error: 6617.530
# iter: 2, error: 309.422
# current_time:  4.16
# iter: 1, error: 6010.939
# iter: 2, error: 251.724
# current_time:  4.17
# iter: 1, error: 5376.692
# iter: 2, error: 198.482
# current_time:  4.18
# iter: 1, error: 4717.150
# iter: 2, error: 150.486
# current_time:  4.19
# iter: 1, error: 4034.827
# iter: 2, error: 108.406
# current_time:  4.2
# iter: 1, error: 3332.380
# current_time:  4.21
# iter: 1, error: 2581.132
# current_time:  4.22
# iter: 1, error: 1861.015
# current_time:  4.23
# iter: 1, error: 1123.510
# current_time:  4.24
# iter: 1, error: 375.539
# current_time:  4.25
# iter: 1, error: 380.259
# current_time:  4.26
# iter: 1, error: 1140.915
# current_time:  4.2700000000000005
# iter: 1, error: 1903.485
# current_time:  4.28
# iter: 1, error: 2664.904
# current_time:  4.29
# iter: 1, error: 3422.043
# current_time:  4.3
# iter: 1, error: 4171.712
# iter: 2, error: 100.269
# current_time:  4.3100000000000005
# iter: 1, error: 4852.651
# iter: 2, error: 128.083
# current_time:  4.32
# iter: 1, error: 5553.337
# iter: 2, error: 165.129
# current_time:  4.33
# iter: 1, error: 6232.504
# iter: 2, error: 204.925
# current_time:  4.34
# iter: 1, error: 6886.968
# iter: 2, error: 246.686
# current_time:  4.3500000000000005
# iter: 1, error: 7513.693
# iter: 2, error: 289.671
# current_time:  4.36
# iter: 1, error: 8109.772
# iter: 2, error: 333.154
# current_time:  4.37
# iter: 1, error: 8672.445
# iter: 2, error: 376.438
# current_time:  4.38
# iter: 1, error: 9199.120
# iter: 2, error: 418.858
# current_time:  4.39
# iter: 1, error: 9687.385
# iter: 2, error: 459.793
# current_time:  4.4
# iter: 1, error: 10135.027
# iter: 2, error: 498.668
# current_time:  4.41
# iter: 1, error: 10540.047
# iter: 2, error: 534.960
# current_time:  4.42
# iter: 1, error: 10900.670
# iter: 2, error: 568.205
# iter: 3, error: 12.088
# current_time:  4.43
# iter: 1, error: 11209.035
# iter: 2, error: 597.448
# iter: 3, error: 13.396
# current_time:  4.44
# iter: 1, error: 11475.792
# iter: 2, error: 623.379
# iter: 3, error: 14.630
# current_time:  4.45
# iter: 1, error: 11694.343
# iter: 2, error: 645.216
# iter: 3, error: 15.723
# current_time:  4.46
# iter: 1, error: 11863.926
# iter: 2, error: 662.729
# iter: 3, error: 16.638
# current_time:  4.47
# iter: 1, error: 11984.036
# iter: 2, error: 675.740
# iter: 3, error: 17.344
# current_time:  4.48
# iter: 1, error: 12054.420
# iter: 2, error: 684.125
# iter: 3, error: 17.819
# current_time:  4.49
# iter: 1, error: 12075.077
# iter: 2, error: 687.813
# iter: 3, error: 18.045
# current_time:  4.5
# iter: 1, error: 12046.251
# iter: 2, error: 686.782
# iter: 3, error: 18.017
# current_time:  4.51
# iter: 1, error: 11968.424
# iter: 2, error: 681.061
# iter: 3, error: 17.735
# current_time:  4.5200000000000005
# iter: 1, error: 11842.307
# iter: 2, error: 670.727
# iter: 3, error: 17.209
# current_time:  4.53
# iter: 1, error: 11668.832
# iter: 2, error: 655.904
# iter: 3, error: 16.459
# current_time:  4.54
# iter: 1, error: 11449.135
# iter: 2, error: 636.762
# iter: 3, error: 15.508
# current_time:  4.55
# iter: 1, error: 11184.551
# iter: 2, error: 613.521
# iter: 3, error: 14.391
# current_time:  4.5600000000000005
# iter: 1, error: 10876.592
# iter: 2, error: 586.447
# iter: 3, error: 13.142
# current_time:  4.57
# iter: 1, error: 10526.941
# iter: 2, error: 555.856
# iter: 3, error: 11.802
# current_time:  4.58
# iter: 1, error: 10137.433
# iter: 2, error: 522.110
# iter: 3, error: 10.413
# current_time:  4.59
# iter: 1, error: 9710.039
# iter: 2, error: 485.620
# current_time:  4.6000000000000005
# iter: 1, error: 9251.033
# iter: 2, error: 447.210
# current_time:  4.61
# iter: 1, error: 8753.581
# iter: 2, error: 406.596
# current_time:  4.62
# iter: 1, error: 8224.879
# iter: 2, error: 364.755
# current_time:  4.63
# iter: 1, error: 7667.328
# iter: 2, error: 322.278
# current_time:  4.64
# iter: 1, error: 7083.379
# iter: 2, error: 279.791
# current_time:  4.65
# iter: 1, error: 6475.537
# iter: 2, error: 237.950
# current_time:  4.66
# iter: 1, error: 5846.341
# iter: 2, error: 197.432
# current_time:  4.67
# iter: 1, error: 5198.357
# iter: 2, error: 158.925
# current_time:  4.68
# iter: 1, error: 4534.168
# iter: 2, error: 123.120
# current_time:  4.69
# iter: 1, error: 3856.362
# current_time:  4.7
# iter: 1, error: 3212.414
# current_time:  4.71
# iter: 1, error: 2504.140
# current_time:  4.72
# iter: 1, error: 1787.289
# current_time:  4.73
# iter: 1, error: 1070.611
# current_time:  4.74
# iter: 1, error: 356.756
# current_time:  4.75
# iter: 1, error: 352.092
# current_time:  4.76
# iter: 1, error: 1053.722
# current_time:  4.7700000000000005
# iter: 1, error: 1746.110
# current_time:  4.78
# iter: 1, error: 2427.236
# current_time:  4.79
# iter: 1, error: 3095.134
# current_time:  4.8
# iter: 1, error: 3747.883
# iter: 2, error: 97.612
# current_time:  4.8100000000000005
# iter: 1, error: 4417.451
# iter: 2, error: 143.473
# current_time:  4.82
# iter: 1, error: 5045.292
# iter: 2, error: 189.530
# current_time:  4.83
# iter: 1, error: 5653.194
# iter: 2, error: 240.678
# current_time:  4.84
# iter: 1, error: 6239.086
# iter: 2, error: 296.255
# current_time:  4.8500000000000005
# iter: 1, error: 6800.996
# iter: 2, error: 355.452
# current_time:  4.86
# iter: 1, error: 7337.022
# iter: 2, error: 417.371
# current_time:  4.87
# iter: 1, error: 7845.339
# iter: 2, error: 481.047
# current_time:  4.88
# iter: 1, error: 8324.199
# iter: 2, error: 545.460
# current_time:  4.89
# iter: 1, error: 8771.937
# iter: 2, error: 609.561
# current_time:  4.9
# iter: 1, error: 9186.973
# iter: 2, error: 672.285
# current_time:  4.91
# iter: 1, error: 9567.819
# iter: 2, error: 732.579
# current_time:  4.92
# iter: 1, error: 9913.081
# iter: 2, error: 789.415
# current_time:  4.93
# iter: 1, error: 10221.463
# iter: 2, error: 841.816
# current_time:  4.94
# iter: 1, error: 10491.775
# iter: 2, error: 888.872
# iter: 3, error: 5.654
# current_time:  4.95
# iter: 1, error: 10724.742
# iter: 2, error: 932.112
# iter: 3, error: 6.218
# current_time:  4.96
# iter: 1, error: 10915.945
# iter: 2, error: 966.373
# iter: 3, error: 6.700
# current_time:  4.97
# iter: 1, error: 11066.149
# iter: 2, error: 993.093
# iter: 3, error: 7.097
# current_time:  4.98
# iter: 1, error: 11174.619
# iter: 2, error: 1011.779
# iter: 3, error: 7.394
# current_time:  4.99
# iter: 1, error: 11240.743
# iter: 2, error: 1022.078
# iter: 3, error: 7.579
# current_time:  5.0

# %% [markdown]
# ### Plotting

# %%
t = np.arange(robot.sim_params.total_time, step=robot.sim_params.dt)
options = dismech.AnimationOptions(title=plant_name, plot_step=10)

fig = dismech.get_interactive_animation_plotly(robot, t, qs , options)
fig.show()

# %%
# save gif
ani = dismech.get_animation(robot, t, qs, options)
save_path = os.path.join("tomato_results", f"{plant_name}_{position}.gif")
ani.save(save_path)
# Out:
# 51

# %%
# plot the trajectory of the flower location
flower_node = 143  # pick a node at the flower
# flower_node = main_grip  # pick a node at the flower

import matplotlib.pyplot as plt

# Extract the DOF indices (x, y, z) of the node you want to track
flower_node_dofs = robot.map_node_to_dof(flower_node)  # e.g., [ix, iy, iz]

# Extract position of that node across all timesteps
logged = qs[:, flower_node_dofs].squeeze()  # shape (n_timesteps, 3)

# remove value at t=0
logged -= robot.nodes[flower_node]

# Plot x, y, z over time
t = np.arange(qs.shape[0]) * robot.sim_params.dt

plt.figure(figsize=(10, 4))
plt.plot(t, logged[:, 0], label='x')
plt.plot(t, logged[:, 1], label='y')
plt.plot(t, logged[:, 2], label='z')
plt.xlabel('Time (s)')
plt.ylabel('Position')
plt.title(f'Position of Node {flower_node} Over Time')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
from scipy.signal import hilbert, detrend, find_peaks

def avg_cycle_amplitude_hilbert(x: np.ndarray) -> float:
    """
    Robust average oscillation amplitude using the analytic-signal envelope.
    Returns the median envelope value (less sensitive to outliers).
    """
    x = np.asarray(x).ravel()
    x = detrend(x)  # remove slow drift
    envelope = np.abs(hilbert(x))
    # Use median to resist occasional spikes; mean is also fine.
    return float(np.median(envelope))
# amplitude of flower node motion
amp_x_flower_hilbert = avg_cycle_amplitude_hilbert(logged[:, 0]) # hilbert-based amplitude
amp_x_flower_peak = (np.max(logged[:, 0]) - np.min(logged[:, 0])) / 2.0 # peak-to-peak amplitude
print(f"Amplitude of flower node {flower_node} motion in x (peak-to-peak): {amp_x_flower_peak:.4f} m")
print(f"Amplitude of flower node {flower_node} motion in x (hilbert): {amp_x_flower_hilbert:.4f} m")
# Out:
# Amplitude of flower node 143 motion in x (peak-to-peak): 0.0048 m
# Amplitude of flower node 143 motion in x (hilbert): 0.0047 m

# %% [markdown]
# ### Save data for rendering

# %%
# from dismech.logging import logDataForRendering
# from dismech.logging import export_rod_shell_data, export_parachute_data

# rod_data, shell_data = logDataForRendering(qs, t.reshape(-1, 1), robot, len(t), robot.sim_params.static_sim, robot.map_node_to_dof, log_step=10)

# js_file = os.path.join("tomato_results", f"{plant_name}_{position}.js")

# export_parachute_data(qs, geo.rod_edges, robot,
#                           rod_js=js_file,
#                           scaleFactor=100)

# %% [markdown]
# ### Estimated values of parameters

# %%
# L = 0.292 # m
# r0 = 0.0059 # m

# delta = 0.054 # m # delta = PL^3/(3EI)
# P = 0.02*9.81 # N

# K = P/delta # effective stiffness

# I = np.pi * r0**4 / 4
# E = P*(L**3) / (3 * I * delta)

# print("E:", E)

# f = 1.38 # Hz
# TP = 0.725 # s

# omega = 2 * np.pi * f
# m_eff = K / omega**2
# print("m_eff:", m_eff)

# # estimate density
# V = np.pi * r0**2 * L
# rho = m_eff / V
# print("rho:", rho)
