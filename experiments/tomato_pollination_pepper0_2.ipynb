# %% [markdown]
# ## Tomato Pollination: Pepper 0

# %%
import numpy as np
import dismech
import os

plant_name = "pepper0"

position = "2"

geom = dismech.GeomParams(
    rod_r0=0.03,
    shell_h=0.0,
)

material = dismech.Material(density=1100,
                            youngs_rod=2.16e7,
                            youngs_shell=0,
                            poisson_rod=0.5,
                            poisson_shell=0)

dyn_sim = dismech.SimParams(static_sim=False,
                                  two_d_sim=True,   # no twisting
                                  use_mid_edge=False,
                                  use_line_search=False,
                                  show_floor=False,
                                  log_data=True,
                                  log_step=1,
                                  dt=1e-2,
                                  max_iter=50,
                                  total_time=5,
                                  plot_step=10,
                                  tol=1e-4,
                                  ftol=1e-4,
                                  dtol=1e-2
                                  )

env = dismech.Environment()
env.add_force('gravity', g=np.array([0.0, 0.0, -9.81]))
env.add_force('damping', eta=100)

input_txt = os.path.join('../tests/resources/tomato_pollination/plants/', f"{plant_name}.txt")
geo = dismech.Geometry.from_txt(input_txt)

robot = dismech.SoftRobot(geom, material, geo, dyn_sim, env)

# %% [markdown]
# ### Move the stem: Moving BC

# %%
# # --- pick the main grip node robustly ---
# grasping_point = np.array([
#       1.1120794,
#       0.0663341,
#       0.3889156
#     ])

main_grip = [57]

print("Main grip node:", main_grip)


other_grip_nodes_below = np.array([33, 44, 47], dtype=int)
other_grip_nodes_above = np.array([79, 77, 76, 71, 69, 65], dtype=int)
# Out:
# Main grip node: [57]

# %%
base_nodes = np.where((robot.state.q[robot.node_dof_indices].reshape(-1, 3)[:, 2]) < 0.22)[0] # fixed base
# Fix only main_grip and base nodes
robot = robot.fix_nodes(np.unique(np.r_[main_grip, base_nodes]))

# %%
# ----- once, before simulation -----
all_grip_nodes = np.r_[main_grip, other_grip_nodes_below, other_grip_nodes_above].astype(int)

xyz0 = robot.state.q[robot.node_dof_indices].reshape(-1, 3).copy()
x0 = xyz0[all_grip_nodes, 0].copy()          # initial x of all prescribed nodes
prev_target_x = x0.copy()                     # last absolute target (starts at initial)

# (Optional) precompute amplitude scalings from *initial* geometry
def build_amps_from_xyz0(xyz0, main_grip, all_grip_nodes, A_main):
    amps = np.empty(all_grip_nodes.size, float)
    amps[0] = A_main  # main_grip
    # below group
    below = np.array(other_grip_nodes_below, dtype=int)
    if below.size:
        ref = below[0]
        L = max(np.linalg.norm(xyz0[main_grip]-xyz0[ref]), 1e-12)
        for j, node in enumerate(below, start=1):  # start=1 because 0 is main_grip
            amps[j] = A_main * (np.linalg.norm(xyz0[ref]-xyz0[node]) / L)
    # above group
    above = np.array(other_grip_nodes_above, dtype=int)
    if above.size:
        ref = above[0]
        offset = 1 + below.size
        L = max(np.linalg.norm(xyz0[main_grip]-xyz0[ref]), 1e-12)
        for j, node in enumerate(above, start=offset):
            amps[j] = A_main * (np.linalg.norm(xyz0[ref]-xyz0[node]) / L)
    return amps

A_main = 0.4094e-2   # m at main_grip
freq   = 1.3    # Hz
amps   = build_amps_from_xyz0(xyz0, main_grip, all_grip_nodes, A_main)

print("Amplitudes (m):", amps)

def shake_distributed(robot, t: float):
    # absolute target centered at initial pose
    target_x = x0 + amps * np.sin(2*np.pi*freq*t)

    # INCREMENT ONLY: avoids velocity spikes and keeps symmetry
    delta_x = target_x - prev_target_x
    prev_target_x[:] = target_x

    return robot.move_nodes(all_grip_nodes, delta_x.reshape(-1,1).flatten(), axis=0)

print("grasping points:", all_grip_nodes)
# Out:
# Amplitudes (m): [0.004094   0.         0.00144745 0.002047   0.         0.00051175
#  0.0010235  0.00153525 0.00217117 0.00260942]
# grasping points: [57 33 44 47 79 77 76 71 69 65]

# %%
stepper = dismech.ImplicitEulerTimeStepper(robot)
stepper.before_step = shake_distributed

# %% [markdown]
# ### Simulate

# %%
# simulate
robots = stepper.simulate()

qs = np.stack([robot.state.q for robot in robots])
# Out:
# iter: 1, error: 31786.343
# iter: 2, error: 663.842
# current_time:  0.01
# iter: 1, error: 31583.839
# iter: 2, error: 664.591
# current_time:  0.02
# iter: 1, error: 31177.605
# iter: 2, error: 649.573
# current_time:  0.03
# iter: 1, error: 30564.532
# iter: 2, error: 618.067
# current_time:  0.04
# iter: 1, error: 29748.443
# iter: 2, error: 578.294
# current_time:  0.05
# iter: 1, error: 28734.343
# iter: 2, error: 534.872
# current_time:  0.06
# iter: 1, error: 27528.482
# iter: 2, error: 487.071
# current_time:  0.07
# iter: 1, error: 26138.314
# iter: 2, error: 434.894
# current_time:  0.08
# iter: 1, error: 24572.489
# iter: 2, error: 380.174
# current_time:  0.09
# iter: 1, error: 22840.856
# iter: 2, error: 324.691
# current_time:  0.1
# iter: 1, error: 20954.427
# iter: 2, error: 269.964
# current_time:  0.11
# iter: 1, error: 18925.291
# iter: 2, error: 217.445
# current_time:  0.12
# iter: 1, error: 16766.518
# iter: 2, error: 168.476
# current_time:  0.13
# iter: 1, error: 14492.068
# iter: 2, error: 124.225
# current_time:  0.14
# iter: 1, error: 12116.714
# iter: 2, error: 85.686
# current_time:  0.15
# iter: 1, error: 9655.962
# iter: 2, error: 53.682
# current_time:  0.16
# iter: 1, error: 7125.962
# current_time:  0.17
# iter: 1, error: 4524.422
# current_time:  0.18
# iter: 1, error: 1918.789
# current_time:  0.19
# iter: 1, error: 711.633
# current_time:  0.2
# iter: 1, error: 3346.729
# current_time:  0.21
# iter: 1, error: 5969.241
# current_time:  0.22
# iter: 1, error: 8561.760
# iter: 2, error: 39.165
# current_time:  0.23
# iter: 1, error: 11078.366
# iter: 2, error: 63.935
# current_time:  0.24
# iter: 1, error: 13538.092
# iter: 2, error: 94.530
# current_time:  0.25
# iter: 1, error: 15910.408
# iter: 2, error: 129.370
# current_time:  0.26
# iter: 1, error: 18178.820
# iter: 2, error: 167.476
# current_time:  0.27
# iter: 1, error: 20327.486
# iter: 2, error: 207.817
# current_time:  0.28
# iter: 1, error: 22341.333
# iter: 2, error: 249.322
# current_time:  0.29
# iter: 1, error: 24206.183
# iter: 2, error: 290.906
# current_time:  0.3
# iter: 1, error: 25908.872
# iter: 2, error: 331.490
# current_time:  0.31
# iter: 1, error: 27437.360
# iter: 2, error: 370.026
# current_time:  0.32
# iter: 1, error: 28780.842
# iter: 2, error: 405.521
# current_time:  0.33
# iter: 1, error: 29929.841
# iter: 2, error: 437.064
# current_time:  0.34
# iter: 1, error: 30876.291
# iter: 2, error: 463.845
# current_time:  0.35000000000000003
# iter: 1, error: 31613.610
# iter: 2, error: 485.180
# current_time:  0.36
# iter: 1, error: 32136.751
# iter: 2, error: 500.527
# current_time:  0.37
# iter: 1, error: 32442.239
# iter: 2, error: 509.501
# current_time:  0.38
# iter: 1, error: 32528.193
# iter: 2, error: 511.883
# current_time:  0.39
# iter: 1, error: 32394.334
# iter: 2, error: 507.624
# current_time:  0.4
# iter: 1, error: 32041.964
# iter: 2, error: 496.845
# current_time:  0.41000000000000003
# iter: 1, error: 31473.954
# iter: 2, error: 479.834
# current_time:  0.42
# iter: 1, error: 30694.698
# iter: 2, error: 457.038
# current_time:  0.43
# iter: 1, error: 29710.074
# iter: 2, error: 429.051
# current_time:  0.44
# iter: 1, error: 28527.379
# iter: 2, error: 396.598
# current_time:  0.45
# iter: 1, error: 27155.264
# iter: 2, error: 360.515
# current_time:  0.46
# iter: 1, error: 25603.651
# iter: 2, error: 321.728
# current_time:  0.47000000000000003
# iter: 1, error: 23883.649
# iter: 2, error: 281.225
# current_time:  0.48
# iter: 1, error: 22007.448
# iter: 2, error: 240.039
# current_time:  0.49
# iter: 1, error: 19988.220
# iter: 2, error: 199.213
# current_time:  0.5
# iter: 1, error: 17840.010
# iter: 2, error: 159.787
# current_time:  0.51
# iter: 1, error: 15577.620
# iter: 2, error: 122.774
# current_time:  0.52
# iter: 1, error: 13216.500
# iter: 2, error: 89.138
# current_time:  0.53
# iter: 1, error: 10772.634
# iter: 2, error: 59.783
# current_time:  0.54
# iter: 1, error: 8262.430
# iter: 2, error: 35.531
# current_time:  0.55
# iter: 1, error: 5702.609
# current_time:  0.56
# iter: 1, error: 3120.950
# current_time:  0.5700000000000001
# iter: 1, error: 505.638
# current_time:  0.58
# iter: 1, error: 2104.738
# current_time:  0.59
# iter: 1, error: 4691.829
# current_time:  0.6
# iter: 1, error: 7239.420
# iter: 2, error: 29.068
# current_time:  0.61
# iter: 1, error: 9748.563
# iter: 2, error: 54.193
# current_time:  0.62
# iter: 1, error: 12182.806
# iter: 2, error: 85.861
# current_time:  0.63
# iter: 1, error: 14533.819
# iter: 2, error: 123.956
# current_time:  0.64
# iter: 1, error: 16786.532
# iter: 2, error: 167.708
# current_time:  0.65
# iter: 1, error: 18926.525
# iter: 2, error: 216.142
# current_time:  0.66
# iter: 1, error: 20940.098
# iter: 2, error: 268.102
# current_time:  0.67
# iter: 1, error: 22814.353
# iter: 2, error: 322.266
# current_time:  0.68
# iter: 1, error: 24537.275
# iter: 2, error: 377.188
# current_time:  0.6900000000000001
# iter: 1, error: 26097.800
# iter: 2, error: 431.332
# current_time:  0.7000000000000001
# iter: 1, error: 27485.883
# iter: 2, error: 483.127
# current_time:  0.71
# iter: 1, error: 28692.563
# iter: 2, error: 531.019
# current_time:  0.72
# iter: 1, error: 29710.015
# iter: 2, error: 573.530
# current_time:  0.73
# iter: 1, error: 30531.601
# iter: 2, error: 609.318
# current_time:  0.74
# iter: 1, error: 31151.911
# iter: 2, error: 637.231
# current_time:  0.75
# iter: 1, error: 31566.800
# iter: 2, error: 656.357
# current_time:  0.76
# iter: 1, error: 31773.414
# iter: 2, error: 666.062
# current_time:  0.77
# iter: 1, error: 31770.210
# iter: 2, error: 666.021
# current_time:  0.78
# iter: 1, error: 31556.971
# iter: 2, error: 656.230
# current_time:  0.79
# iter: 1, error: 31134.809
# iter: 2, error: 637.004
# current_time:  0.8
# iter: 1, error: 30506.166
# iter: 2, error: 608.969
# current_time:  0.81
# iter: 1, error: 29674.807
# iter: 2, error: 573.028
# current_time:  0.8200000000000001
# iter: 1, error: 28645.799
# iter: 2, error: 530.325
# current_time:  0.8300000000000001
# iter: 1, error: 27425.491
# iter: 2, error: 482.199
# current_time:  0.84
# iter: 1, error: 26021.482
# iter: 2, error: 430.127
# current_time:  0.85
# iter: 1, error: 24442.582
# iter: 2, error: 375.668
# current_time:  0.86
# iter: 1, error: 22698.767
# iter: 2, error: 320.409
# current_time:  0.87
# iter: 1, error: 20801.121
# iter: 2, error: 265.906
# current_time:  0.88
# iter: 1, error: 18761.776
# iter: 2, error: 213.636
# current_time:  0.89
# iter: 1, error: 16593.844
# iter: 2, error: 164.956
# current_time:  0.9
# iter: 1, error: 14311.338
# iter: 2, error: 121.063
# current_time:  0.91
# iter: 1, error: 11929.091
# iter: 2, error: 82.972
# current_time:  0.92
# iter: 1, error: 9462.669
# iter: 2, error: 51.493
# current_time:  0.93
# iter: 1, error: 6928.271
# current_time:  0.9400000000000001
# iter: 1, error: 4324.689
# current_time:  0.9500000000000001
# iter: 1, error: 1716.836
# current_time:  0.96
# iter: 1, error: 914.293
# current_time:  0.97
# iter: 1, error: 3548.774
# current_time:  0.98
# iter: 1, error: 6169.334
# current_time:  0.99
# iter: 1, error: 8758.565
# iter: 2, error: 40.983
# current_time:  1.0
# iter: 1, error: 11269.170
# iter: 2, error: 66.114
# current_time:  1.01
# iter: 1, error: 13722.529
# iter: 2, error: 97.068
# current_time:  1.02
# iter: 1, error: 16087.201
# iter: 2, error: 132.195
# current_time:  1.03
# iter: 1, error: 18346.740
# iter: 2, error: 170.512
# current_time:  1.04
# iter: 1, error: 20485.359
# iter: 2, error: 210.983
# current_time:  1.05
# iter: 1, error: 22488.052
# iter: 2, error: 252.536
# current_time:  1.06
# iter: 1, error: 24340.715
# iter: 2, error: 294.085
# current_time:  1.07
# iter: 1, error: 26030.266
# iter: 2, error: 334.552
# current_time:  1.08
# iter: 1, error: 27544.760
# iter: 2, error: 372.892
# current_time:  1.09
# iter: 1, error: 28873.491
# iter: 2, error: 408.118
# current_time:  1.1
# iter: 1, error: 30007.088
# iter: 2, error: 439.324
# current_time:  1.11
# iter: 1, error: 30937.598
# iter: 2, error: 465.710
# current_time:  1.12
# iter: 1, error: 31658.554
# iter: 2, error: 486.603
# current_time:  1.1300000000000001
# iter: 1, error: 32165.030
# iter: 2, error: 501.473
# current_time:  1.1400000000000001
# iter: 1, error: 32453.672
# iter: 2, error: 509.947
# current_time:  1.1500000000000001
# iter: 1, error: 32522.723
# iter: 2, error: 511.818
# current_time:  1.16
# iter: 1, error: 32372.024
# iter: 2, error: 507.052
# current_time:  1.17
# iter: 1, error: 32003.000
# iter: 2, error: 495.781
# current_time:  1.18
# iter: 1, error: 31418.637
# iter: 2, error: 478.306
# current_time:  1.19
# iter: 1, error: 30623.446
# iter: 2, error: 455.087
# current_time:  1.2
# iter: 1, error: 29623.415
# iter: 2, error: 426.728
# current_time:  1.21
# iter: 1, error: 28425.946
# iter: 2, error: 393.963
# current_time:  1.22
# iter: 1, error: 27039.790
# iter: 2, error: 357.636
# current_time:  1.23
# iter: 1, error: 25474.964
# iter: 2, error: 318.678
# current_time:  1.24
# iter: 1, error: 23742.661
# iter: 2, error: 278.084
# current_time:  1.25
# iter: 1, error: 21855.150
# iter: 2, error: 236.884
# current_time:  1.26
# iter: 1, error: 19825.673
# iter: 2, error: 196.127
# current_time:  1.27
# iter: 1, error: 17668.336
# iter: 2, error: 156.849
# current_time:  1.28
# iter: 1, error: 15397.993
# iter: 2, error: 120.060
# current_time:  1.29
# iter: 1, error: 13030.138
# iter: 2, error: 86.720
# current_time:  1.3
# iter: 1, error: 10580.792
# iter: 2, error: 57.728
# current_time:  1.31
# iter: 1, error: 8066.388
# iter: 2, error: 33.899
# current_time:  1.32
# iter: 1, error: 5503.666
# current_time:  1.33
# iter: 1, error: 2919.673
# current_time:  1.34
# iter: 1, error: 304.368
# current_time:  1.35
# iter: 1, error: 2304.587
# current_time:  1.36
# iter: 1, error: 4888.993
# current_time:  1.37
# iter: 1, error: 7432.671
# iter: 2, error: 30.654
# current_time:  1.3800000000000001
# iter: 1, error: 9937.579
# iter: 2, error: 56.385
# current_time:  1.3900000000000001
# iter: 1, error: 12365.761
# iter: 2, error: 88.568
# current_time:  1.4000000000000001
# iter: 1, error: 14709.538
# iter: 2, error: 127.127
# current_time:  1.41
# iter: 1, error: 16953.890
# iter: 2, error: 171.273
# current_time:  1.42
# iter: 1, error: 19084.448
# iter: 2, error: 220.019
# current_time:  1.43
# iter: 1, error: 21087.573
# iter: 2, error: 272.193
# current_time:  1.44
# iter: 1, error: 22950.435
# iter: 2, error: 326.465
# current_time:  1.45
# iter: 1, error: 24661.088
# iter: 2, error: 381.378
# current_time:  1.46
# iter: 1, error: 26208.545
# iter: 2, error: 435.393
# current_time:  1.47
# iter: 1, error: 27582.846
# iter: 2, error: 486.938
# current_time:  1.48
# iter: 1, error: 28775.113
# iter: 2, error: 534.463
# current_time:  1.49
# iter: 1, error: 29777.614
# iter: 2, error: 576.499
# current_time:  1.5
# iter: 1, error: 30583.804
# iter: 2, error: 611.716
# current_time:  1.51
# iter: 1, error: 31188.370
# iter: 2, error: 638.980
# current_time:  1.52
# iter: 1, error: 31587.268
# iter: 2, error: 657.398
# current_time:  1.53
# iter: 1, error: 31777.742
# iter: 2, error: 666.360
# current_time:  1.54
# iter: 1, error: 31758.353
# iter: 2, error: 665.564
# current_time:  1.55
# iter: 1, error: 31528.987
# iter: 2, error: 655.032
# current_time:  1.56
# iter: 1, error: 31090.858
# iter: 2, error: 635.103
# current_time:  1.57
# iter: 1, error: 30446.511
# iter: 2, error: 606.426
# current_time:  1.58
# iter: 1, error: 29599.811
# iter: 2, error: 569.923
# current_time:  1.59
# iter: 1, error: 28555.926
# iter: 2, error: 526.756
# current_time:  1.6
# iter: 1, error: 27321.301
# iter: 2, error: 478.276
# current_time:  1.61
# iter: 1, error: 25903.631
# iter: 2, error: 425.968
# current_time:  1.62
# iter: 1, error: 24311.816
# iter: 2, error: 371.396
# current_time:  1.6300000000000001
# iter: 1, error: 22555.917
# iter: 2, error: 316.145
# current_time:  1.6400000000000001
# iter: 1, error: 20647.102
# iter: 2, error: 261.767
# current_time:  1.6500000000000001
# iter: 1, error: 18597.580
# iter: 2, error: 209.732
# current_time:  1.6600000000000001
# iter: 1, error: 16420.532
# iter: 2, error: 161.384
# current_time:  1.67
# iter: 1, error: 14130.037
# iter: 2, error: 117.907
# current_time:  1.68
# iter: 1, error: 11740.986
# iter: 2, error: 80.301
# current_time:  1.69
# iter: 1, error: 9268.995
# iter: 2, error: 49.361
# current_time:  1.7
# iter: 1, error: 6730.307
# current_time:  1.71
# iter: 1, error: 4124.760
# current_time:  1.72
# iter: 1, error: 1514.801
# current_time:  1.73
# iter: 1, error: 1116.932
# current_time:  1.74
# iter: 1, error: 3750.695
# current_time:  1.75
# iter: 1, error: 6369.203
# current_time:  1.76
# iter: 1, error: 8955.043
# iter: 2, error: 42.840
# current_time:  1.77
# iter: 1, error: 11459.514
# iter: 2, error: 68.325
# current_time:  1.78
# iter: 1, error: 13906.407
# iter: 2, error: 99.634
# current_time:  1.79
# iter: 1, error: 16263.339
# iter: 2, error: 135.042
# current_time:  1.8
# iter: 1, error: 18513.912
# iter: 2, error: 173.564
# current_time:  1.81
# iter: 1, error: 20642.397
# iter: 2, error: 214.159
# current_time:  1.82
# iter: 1, error: 22633.852
# iter: 2, error: 255.753
# current_time:  1.83
# iter: 1, error: 24474.252
# iter: 2, error: 297.259
# current_time:  1.84
# iter: 1, error: 26150.598
# iter: 2, error: 337.601
# current_time:  1.85
# iter: 1, error: 27651.038
# iter: 2, error: 375.738
# current_time:  1.86
# iter: 1, error: 28964.966
# iter: 2, error: 410.688
# current_time:  1.87
# iter: 1, error: 30083.118
# iter: 2, error: 441.553
# current_time:  1.8800000000000001
# iter: 1, error: 30997.653
# iter: 2, error: 467.542
# current_time:  1.8900000000000001
# iter: 1, error: 31702.221
# iter: 2, error: 487.991
# current_time:  1.9000000000000001
# iter: 1, error: 32192.016
# iter: 2, error: 502.381
# current_time:  1.9100000000000001
# iter: 1, error: 32463.805
# iter: 2, error: 510.354
# current_time:  1.92
# iter: 1, error: 32515.955
# iter: 2, error: 511.715
# current_time:  1.93
# iter: 1, error: 32348.427
# iter: 2, error: 506.441
# current_time:  1.94
# iter: 1, error: 31962.768
# iter: 2, error: 494.680
# current_time:  1.95
# iter: 1, error: 31362.082
# iter: 2, error: 476.745
# current_time:  1.96
# iter: 1, error: 30550.994
# iter: 2, error: 453.107
# current_time:  1.97
# iter: 1, error: 29535.602
# iter: 2, error: 424.379
# current_time:  1.98
# iter: 1, error: 28323.414
# iter: 2, error: 391.307
# current_time:  1.99
# iter: 1, error: 26923.279
# iter: 2, error: 354.741
# current_time:  2.0
# iter: 1, error: 25345.308
# iter: 2, error: 315.619
# current_time:  2.0100000000000002
# iter: 1, error: 23600.779
# iter: 2, error: 274.938
# current_time:  2.02
# iter: 1, error: 21702.038
# iter: 2, error: 233.732
# current_time:  2.0300000000000002
# iter: 1, error: 19662.397
# iter: 2, error: 193.049
# current_time:  2.04
# iter: 1, error: 17496.022
# iter: 2, error: 153.925
# current_time:  2.05
# iter: 1, error: 15217.819
# iter: 2, error: 117.365
# current_time:  2.06
# iter: 1, error: 12843.326
# iter: 2, error: 84.328
# current_time:  2.07
# iter: 1, error: 10388.597
# iter: 2, error: 55.703
# current_time:  2.08
# iter: 1, error: 7870.092
# iter: 2, error: 32.303
# current_time:  2.09
# iter: 1, error: 5304.571
# current_time:  2.1
# iter: 1, error: 2718.371
# current_time:  2.11
# iter: 1, error: 103.200
# current_time:  2.12
# iter: 1, error: 2504.257
# current_time:  2.13
# iter: 1, error: 5085.883
# current_time:  2.14
# iter: 1, error: 7625.555
# iter: 2, error: 32.279
# current_time:  2.15
# iter: 1, error: 10126.154
# iter: 2, error: 58.618
# current_time:  2.16
# iter: 1, error: 12548.183
# iter: 2, error: 91.314
# current_time:  2.17
# iter: 1, error: 14884.637
# iter: 2, error: 130.330
# current_time:  2.18
# iter: 1, error: 17120.543
# iter: 2, error: 174.866
# current_time:  2.19
# iter: 1, error: 19241.587
# iter: 2, error: 223.916
# current_time:  2.2
# iter: 1, error: 21234.191
# iter: 2, error: 276.297
# current_time:  2.21
# iter: 1, error: 23085.588
# iter: 2, error: 330.667
# current_time:  2.22
# iter: 1, error: 24783.909
# iter: 2, error: 385.561
# current_time:  2.23
# iter: 1, error: 26318.242
# iter: 2, error: 439.438
# current_time:  2.24
# iter: 1, error: 27678.709
# iter: 2, error: 490.724
# current_time:  2.25
# iter: 1, error: 28856.520
# iter: 2, error: 537.874
# current_time:  2.2600000000000002
# iter: 1, error: 29844.033
# iter: 2, error: 579.427
# current_time:  2.27
# iter: 1, error: 30634.798
# iter: 2, error: 614.067
# current_time:  2.2800000000000002
# iter: 1, error: 31223.600
# iter: 2, error: 640.676
# current_time:  2.29
# iter: 1, error: 31606.492
# iter: 2, error: 658.382
# current_time:  2.3000000000000003
# iter: 1, error: 31780.821
# iter: 2, error: 666.599
# current_time:  2.31
# iter: 1, error: 31745.249
# iter: 2, error: 665.049
# current_time:  2.32
# iter: 1, error: 31499.766
# iter: 2, error: 653.777
# current_time:  2.33
# iter: 1, error: 31045.688
# iter: 2, error: 633.150
# current_time:  2.34
# iter: 1, error: 30385.663
# iter: 2, error: 603.836
# current_time:  2.35
# iter: 1, error: 29523.657
# iter: 2, error: 566.779
# current_time:  2.36
# iter: 1, error: 28464.936
# iter: 2, error: 523.156
# current_time:  2.37
# iter: 1, error: 27216.043
# iter: 2, error: 474.331
# current_time:  2.38
# iter: 1, error: 25784.767
# iter: 2, error: 421.797
# current_time:  2.39
# iter: 1, error: 24180.099
# iter: 2, error: 367.121
# current_time:  2.4
# iter: 1, error: 22412.186
# iter: 2, error: 311.887
# current_time:  2.41
# iter: 1, error: 20492.277
# iter: 2, error: 257.643
# current_time:  2.42
# iter: 1, error: 18432.657
# iter: 2, error: 205.850
# current_time:  2.43
# iter: 1, error: 16246.580
# iter: 2, error: 157.841
# current_time:  2.44
# iter: 1, error: 13948.187
# iter: 2, error: 114.786
# current_time:  2.45
# iter: 1, error: 11552.426
# iter: 2, error: 77.671
# current_time:  2.46
# iter: 1, error: 9074.964
# iter: 2, error: 47.272
# current_time:  2.47
# iter: 1, error: 6532.086
# current_time:  2.48
# iter: 1, error: 3924.649
# current_time:  2.49
# iter: 1, error: 1312.693
# current_time:  2.5
# iter: 1, error: 1319.544
# current_time:  2.5100000000000002
# iter: 1, error: 3952.486
# current_time:  2.52
# iter: 1, error: 6568.838
# current_time:  2.5300000000000002
# iter: 1, error: 9151.185
# iter: 2, error: 44.734
# current_time:  2.54
# iter: 1, error: 11649.387
# iter: 2, error: 70.566
# current_time:  2.5500000000000003
# iter: 1, error: 14089.715
# iter: 2, error: 102.223
# current_time:  2.56
# iter: 1, error: 16438.812
# iter: 2, error: 137.908
# current_time:  2.57
# iter: 1, error: 18680.328
# iter: 2, error: 176.628
# current_time:  2.58
# iter: 1, error: 20798.592
# iter: 2, error: 217.340
# current_time:  2.59
# iter: 1, error: 22778.730
# iter: 2, error: 258.968
# current_time:  2.6
# iter: 1, error: 24606.793
# iter: 2, error: 300.425
# current_time:  2.61
# iter: 1, error: 26269.867
# iter: 2, error: 340.637
# current_time:  2.62
# iter: 1, error: 27756.193
# iter: 2, error: 378.566
# current_time:  2.63
# iter: 1, error: 29055.266
# iter: 2, error: 413.235
# current_time:  2.64
# iter: 1, error: 30157.930
# iter: 2, error: 443.754
# current_time:  2.65
# iter: 1, error: 31056.455
# iter: 2, error: 469.341
# current_time:  2.66
# iter: 1, error: 31744.610
# iter: 2, error: 489.342
# current_time:  2.67
# iter: 1, error: 32217.707
# iter: 2, error: 503.252
# current_time:  2.68
# iter: 1, error: 32472.638
# iter: 2, error: 510.722
# current_time:  2.69
# iter: 1, error: 32507.889
# iter: 2, error: 511.572
# current_time:  2.7
# iter: 1, error: 32323.545
# iter: 2, error: 505.793
# current_time:  2.71
# iter: 1, error: 31921.273
# iter: 2, error: 493.543
# current_time:  2.72
# iter: 1, error: 31304.294
# iter: 2, error: 475.150
# current_time:  2.73
# iter: 1, error: 30477.347
# iter: 2, error: 451.095
# current_time:  2.74
# iter: 1, error: 29446.641
# iter: 2, error: 422.004
# current_time:  2.75
# iter: 1, error: 28219.788
# iter: 2, error: 388.629
# current_time:  2.7600000000000002
# iter: 1, error: 26805.737
# iter: 2, error: 351.830
# current_time:  2.77
# iter: 1, error: 25214.690
# iter: 2, error: 312.549
# current_time:  2.7800000000000002
# iter: 1, error: 23458.009
# iter: 2, error: 271.788
# current_time:  2.79
# iter: 1, error: 21548.119
# iter: 2, error: 230.583
# current_time:  2.8000000000000003
# iter: 1, error: 19498.399
# iter: 2, error: 189.981
# current_time:  2.81
# iter: 1, error: 17323.075
# iter: 2, error: 151.016
# current_time:  2.82
# iter: 1, error: 15037.105
# iter: 2, error: 114.692
# current_time:  2.83
# iter: 1, error: 12656.070
# iter: 2, error: 81.961
# current_time:  2.84
# iter: 1, error: 10196.057
# iter: 2, error: 53.710
# current_time:  2.85
# iter: 1, error: 7673.552
# iter: 2, error: 30.741
# current_time:  2.86
# iter: 1, error: 5105.331
# current_time:  2.87
# iter: 1, error: 2517.051
# current_time:  2.88
# iter: 1, error: 97.982
# current_time:  2.89
# iter: 1, error: 2703.740
# current_time:  2.9
# iter: 1, error: 5282.491
# current_time:  2.91
# iter: 1, error: 7818.063
# iter: 2, error: 33.944
# current_time:  2.92
# iter: 1, error: 10314.282
# iter: 2, error: 60.892
# current_time:  2.93
# iter: 1, error: 12730.067
# iter: 2, error: 94.097
# current_time:  2.94
# iter: 1, error: 15059.110
# iter: 2, error: 133.566
# current_time:  2.95
# iter: 1, error: 17286.486
# iter: 2, error: 178.484
# current_time:  2.96
# iter: 1, error: 19397.937
# iter: 2, error: 227.832
# current_time:  2.97
# iter: 1, error: 21379.944
# iter: 2, error: 280.411
# current_time:  2.98
# iter: 1, error: 23219.810
# iter: 2, error: 334.871
# current_time:  2.99
# iter: 1, error: 24905.734
# iter: 2, error: 389.738
# current_time:  3.0
# iter: 1, error: 26426.887
# iter: 2, error: 443.467
# current_time:  3.0100000000000002
# iter: 1, error: 27773.470
# iter: 2, error: 494.485
# current_time:  3.02
# iter: 1, error: 28936.782
# iter: 2, error: 541.250
# current_time:  3.0300000000000002
# iter: 1, error: 29909.272
# iter: 2, error: 582.313
# current_time:  3.04
# iter: 1, error: 30684.584
# iter: 2, error: 616.369
# current_time:  3.0500000000000003
# iter: 1, error: 31257.600
# iter: 2, error: 642.318
# current_time:  3.06
# iter: 1, error: 31624.472
# iter: 2, error: 659.310
# current_time:  3.0700000000000003
# iter: 1, error: 31782.651
# iter: 2, error: 666.780
# current_time:  3.08
# iter: 1, error: 31730.900
# iter: 2, error: 664.475
# current_time:  3.09
# iter: 1, error: 31469.310
# iter: 2, error: 652.467
# current_time:  3.1
# iter: 1, error: 30999.302
# iter: 2, error: 631.145
# current_time:  3.11
# iter: 1, error: 30323.626
# iter: 2, error: 601.200
# current_time:  3.12
# iter: 1, error: 29446.347
# iter: 2, error: 563.596
# current_time:  3.13
# iter: 1, error: 28372.832
# iter: 2, error: 519.525
# current_time:  3.14
# iter: 1, error: 27109.721
# iter: 2, error: 470.364
# current_time:  3.15
# iter: 1, error: 25664.896
# iter: 2, error: 417.613
# current_time:  3.16
# iter: 1, error: 24047.437
# iter: 2, error: 362.842
# current_time:  3.17
# iter: 1, error: 22267.579
# iter: 2, error: 307.635
# current_time:  3.18
# iter: 1, error: 20336.652
# iter: 2, error: 253.534
# current_time:  3.19
# iter: 1, error: 18267.017
# iter: 2, error: 201.991
# current_time:  3.2
# iter: 1, error: 16071.995
# iter: 2, error: 154.328
# current_time:  3.21
# iter: 1, error: 13765.794
# iter: 2, error: 111.702
# current_time:  3.22
# iter: 1, error: 11363.419
# iter: 2, error: 75.080
# current_time:  3.23
# iter: 1, error: 8880.584
# iter: 2, error: 45.227
# current_time:  3.24
# iter: 1, error: 6333.617
# current_time:  3.25
# iter: 1, error: 3724.363
# current_time:  3.2600000000000002
# iter: 1, error: 1110.520
# current_time:  3.27
# iter: 1, error: 1522.119
# current_time:  3.2800000000000002
# iter: 1, error: 4154.139
# current_time:  3.29
# iter: 1, error: 6768.231
# current_time:  3.3000000000000003
# iter: 1, error: 9346.982
# iter: 2, error: 46.666
# current_time:  3.31
# iter: 1, error: 11838.782
# iter: 2, error: 72.836
# current_time:  3.3200000000000003
# iter: 1, error: 14272.446
# iter: 2, error: 104.837
# current_time:  3.33
# iter: 1, error: 16613.614
# iter: 2, error: 140.792
# current_time:  3.34
# iter: 1, error: 18845.982
# iter: 2, error: 179.705
# current_time:  3.35
# iter: 1, error: 20953.940
# iter: 2, error: 220.528
# current_time:  3.36
# iter: 1, error: 22922.681
# iter: 2, error: 262.184
# current_time:  3.37
# iter: 1, error: 24738.332
# iter: 2, error: 303.585
# current_time:  3.38
# iter: 1, error: 26388.067
# iter: 2, error: 343.660
# current_time:  3.39
# iter: 1, error: 27860.220
# iter: 2, error: 381.375
# current_time:  3.4
# iter: 1, error: 29144.388
# iter: 2, error: 415.758
# current_time:  3.41
# iter: 1, error: 30231.520
# iter: 2, error: 445.927
# current_time:  3.42
# iter: 1, error: 31114.003
# iter: 2, error: 471.108
# current_time:  3.43
# iter: 1, error: 31785.720
# iter: 2, error: 490.658
# current_time:  3.44
# iter: 1, error: 32242.105
# iter: 2, error: 504.085
# current_time:  3.45
# iter: 1, error: 32480.171
# iter: 2, error: 511.051
# current_time:  3.46
# iter: 1, error: 32498.527
# iter: 2, error: 511.390
# current_time:  3.47
# iter: 1, error: 32297.380
# iter: 2, error: 505.105
# current_time:  3.48
# iter: 1, error: 31878.516
# iter: 2, error: 492.370
# current_time:  3.49
# iter: 1, error: 31245.274
# iter: 2, error: 473.521
# current_time:  3.5
# iter: 1, error: 30402.509
# iter: 2, error: 449.054
# current_time:  3.5100000000000002
# iter: 1, error: 29356.536
# iter: 2, error: 419.603
# current_time:  3.52
# iter: 1, error: 28115.073
# iter: 2, error: 385.931
# current_time:  3.5300000000000002
# iter: 1, error: 26687.168
# iter: 2, error: 348.904
# current_time:  3.54
# iter: 1, error: 25083.114
# iter: 2, error: 309.471
# current_time:  3.5500000000000003
# iter: 1, error: 23314.358
# iter: 2, error: 268.635
# current_time:  3.56
# iter: 1, error: 21393.399
# iter: 2, error: 227.437
# current_time:  3.5700000000000003
# iter: 1, error: 19333.686
# iter: 2, error: 186.921
# current_time:  3.58
# iter: 1, error: 17149.504
# iter: 2, error: 148.122
# current_time:  3.59
# iter: 1, error: 14855.860
# iter: 2, error: 112.039
# current_time:  3.6
# iter: 1, error: 12468.378
# iter: 2, error: 79.621
# current_time:  3.61
# iter: 1, error: 10003.179
# iter: 2, error: 51.747
# current_time:  3.62
# iter: 1, error: 7476.774
# iter: 2, error: 29.214
# current_time:  3.63
# iter: 1, error: 4905.954
# current_time:  3.64
# iter: 1, error: 2315.722
# current_time:  3.65
# iter: 1, error: 298.963
# current_time:  3.66
# iter: 1, error: 2903.030
# current_time:  3.67
# iter: 1, error: 5478.811
# current_time:  3.68
# iter: 1, error: 8010.190
# iter: 2, error: 35.648
# current_time:  3.69
# iter: 1, error: 10501.957
# iter: 2, error: 63.206
# current_time:  3.7
# iter: 1, error: 12911.405
# iter: 2, error: 96.916
# current_time:  3.71
# iter: 1, error: 15232.950
# iter: 2, error: 136.834
# current_time:  3.72
# iter: 1, error: 17451.714
# iter: 2, error: 182.129
# current_time:  3.73
# iter: 1, error: 19553.493
# iter: 2, error: 231.766
# current_time:  3.74
# iter: 1, error: 21524.829
# iter: 2, error: 284.536
# current_time:  3.75
# iter: 1, error: 23353.095
# iter: 2, error: 339.076
# current_time:  3.7600000000000002
# iter: 1, error: 25026.561
# iter: 2, error: 393.907
# current_time:  3.77
# iter: 1, error: 26534.476
# iter: 2, error: 447.479
# current_time:  3.7800000000000002
# iter: 1, error: 27867.126
# iter: 2, error: 498.219
# current_time:  3.79
# iter: 1, error: 29015.897
# iter: 2, error: 544.592
# current_time:  3.8000000000000003
# iter: 1, error: 29973.328
# iter: 2, error: 585.156
# current_time:  3.81
# iter: 1, error: 30733.158
# iter: 2, error: 618.622
# current_time:  3.8200000000000003
# iter: 1, error: 31290.368
# iter: 2, error: 643.907
# current_time:  3.83
# iter: 1, error: 31641.210
# iter: 2, error: 660.180
# current_time:  3.84
# iter: 1, error: 31783.234
# iter: 2, error: 666.902
# current_time:  3.85
# iter: 1, error: 31715.307
# iter: 2, error: 663.844
# current_time:  3.86
# iter: 1, error: 31437.622
# iter: 2, error: 651.102
# current_time:  3.87
# iter: 1, error: 30951.703
# iter: 2, error: 629.089
# current_time:  3.88
# iter: 1, error: 30260.402
# iter: 2, error: 598.519
# current_time:  3.89
# iter: 1, error: 29367.886
# iter: 2, error: 560.374
# current_time:  3.9
# iter: 1, error: 28279.620
# iter: 2, error: 515.865
# current_time:  3.91
# iter: 1, error: 27002.340
# iter: 2, error: 466.376
# current_time:  3.92
# iter: 1, error: 25544.022
# iter: 2, error: 413.418
# current_time:  3.93
# iter: 1, error: 23913.837
# iter: 2, error: 358.562
# current_time:  3.94
# iter: 1, error: 22122.104
# iter: 2, error: 303.391
# current_time:  3.95
# iter: 1, error: 20180.234
# iter: 2, error: 249.441
# current_time:  3.96
# iter: 1, error: 18100.664
# iter: 2, error: 198.156
# current_time:  3.97
# iter: 1, error: 15896.786
# iter: 2, error: 150.845
# current_time:  3.98
# iter: 1, error: 13582.868
# iter: 2, error: 108.653
# current_time:  3.99
# iter: 1, error: 11173.972
# iter: 2, error: 72.531
# current_time:  4.0
# iter: 1, error: 8685.862
# iter: 2, error: 43.225
# current_time:  4.01
# iter: 1, error: 6134.906
# current_time:  4.0200000000000005
# iter: 1, error: 3523.912
# current_time:  4.03
# iter: 1, error: 908.290
# current_time:  4.04
# iter: 1, error: 1724.650
# current_time:  4.05
# iter: 1, error: 4355.644
# current_time:  4.0600000000000005
# iter: 1, error: 6967.376
# current_time:  4.07
# iter: 1, error: 9542.429
# iter: 2, error: 48.635
# current_time:  4.08
# iter: 1, error: 12027.692
# iter: 2, error: 75.135
# current_time:  4.09
# iter: 1, error: 14454.594
# iter: 2, error: 107.474
# current_time:  4.1
# iter: 1, error: 16787.738
# iter: 2, error: 143.694
# current_time:  4.11
# iter: 1, error: 19010.868
# iter: 2, error: 182.793
# current_time:  4.12
# iter: 1, error: 21108.434
# iter: 2, error: 223.721
# current_time:  4.13
# iter: 1, error: 23065.698
# iter: 2, error: 265.398
# current_time:  4.14
# iter: 1, error: 24868.865
# iter: 2, error: 306.738
# current_time:  4.15
# iter: 1, error: 26505.195
# iter: 2, error: 346.670
# current_time:  4.16
# iter: 1, error: 27963.117
# iter: 2, error: 384.164
# current_time:  4.17
# iter: 1, error: 29232.329
# iter: 2, error: 418.256
# current_time:  4.18
# iter: 1, error: 30303.889
# iter: 2, error: 448.070
# current_time:  4.19
# iter: 1, error: 31170.295
# iter: 2, error: 472.841
# current_time:  4.2
# iter: 1, error: 31825.551
# iter: 2, error: 491.938
# current_time:  4.21
# iter: 1, error: 32265.209
# iter: 2, error: 504.879
# current_time:  4.22
# iter: 1, error: 32486.404
# iter: 2, error: 511.341
# current_time:  4.23
# iter: 1, error: 32487.870
# iter: 2, error: 511.169
# current_time:  4.24
# iter: 1, error: 32269.934
# iter: 2, error: 504.380
# current_time:  4.25
# iter: 1, error: 31834.501
# iter: 2, error: 491.160
# current_time:  4.26
# iter: 1, error: 31185.028
# iter: 2, error: 471.859
# current_time:  4.2700000000000005
# iter: 1, error: 30326.484
# iter: 2, error: 446.982
# current_time:  4.28
# iter: 1, error: 29265.292
# iter: 2, error: 417.177
# current_time:  4.29
# iter: 1, error: 28009.276
# iter: 2, error: 383.213
# current_time:  4.3
# iter: 1, error: 26567.580
# iter: 2, error: 345.964
# current_time:  4.3100000000000005
# iter: 1, error: 24950.589
# iter: 2, error: 306.383
# current_time:  4.32
# iter: 1, error: 23169.832
# iter: 2, error: 265.480
# current_time:  4.33
# iter: 1, error: 21237.886
# iter: 2, error: 224.294
# current_time:  4.34
# iter: 1, error: 19168.266
# iter: 2, error: 183.871
# current_time:  4.3500000000000005
# iter: 1, error: 16975.315
# iter: 2, error: 145.244
# current_time:  4.36
# iter: 1, error: 14674.091
# iter: 2, error: 109.408
# current_time:  4.37
# iter: 1, error: 12280.259
# iter: 2, error: 77.307
# current_time:  4.38
# iter: 1, error: 9809.972
# iter: 2, error: 49.816
# current_time:  4.39
# iter: 1, error: 7279.766
# iter: 2, error: 27.723
# current_time:  4.4
# iter: 1, error: 4706.449
# current_time:  4.41
# iter: 1, error: 2114.391
# current_time:  4.42
# iter: 1, error: 499.862
# current_time:  4.43
# iter: 1, error: 3102.118
# current_time:  4.44
# iter: 1, error: 5674.834
# current_time:  4.45
# iter: 1, error: 8201.929
# iter: 2, error: 37.390
# current_time:  4.46
# iter: 1, error: 10689.170
# iter: 2, error: 65.561
# current_time:  4.47
# iter: 1, error: 13092.192
# iter: 2, error: 99.772
# current_time:  4.48
# iter: 1, error: 15406.152
# iter: 2, error: 140.134
# current_time:  4.49
# iter: 1, error: 17616.220
# iter: 2, error: 185.799
# current_time:  4.5
# iter: 1, error: 19708.248
# iter: 2, error: 235.719
# current_time:  4.51
# iter: 1, error: 21668.841
# iter: 2, error: 288.671
# current_time:  4.5200000000000005
# iter: 1, error: 23485.438
# iter: 2, error: 343.283
# current_time:  4.53
# iter: 1, error: 25146.385
# iter: 2, error: 398.068
# current_time:  4.54
# iter: 1, error: 26641.007
# iter: 2, error: 451.474
# current_time:  4.55
# iter: 1, error: 27959.675
# iter: 2, error: 501.927
# current_time:  4.5600000000000005
# iter: 1, error: 29093.862
# iter: 2, error: 547.899
# current_time:  4.57
# iter: 1, error: 30036.199
# iter: 2, error: 587.957
# current_time:  4.58
# iter: 1, error: 30780.521
# iter: 2, error: 620.826
# current_time:  4.59
# iter: 1, error: 31321.906
# iter: 2, error: 645.441
# current_time:  4.6000000000000005
# iter: 1, error: 31656.705
# iter: 2, error: 660.993
# current_time:  4.61
# iter: 1, error: 31782.570
# iter: 2, error: 666.965
# current_time:  4.62
# iter: 1, error: 31698.471
# iter: 2, error: 663.155
# current_time:  4.63
# iter: 1, error: 31404.703
# iter: 2, error: 649.681
# current_time:  4.64
# iter: 1, error: 30902.894
# iter: 2, error: 626.981
# current_time:  4.65
# iter: 1, error: 30195.996
# iter: 2, error: 595.793
# current_time:  4.66
# iter: 1, error: 29288.278
# iter: 2, error: 557.115
# current_time:  4.67
# iter: 1, error: 28185.303
# iter: 2, error: 512.175
# current_time:  4.68
# iter: 1, error: 26893.905
# iter: 2, error: 462.368
# current_time:  4.69
# iter: 1, error: 25422.152
# iter: 2, error: 409.212
# current_time:  4.7
# iter: 1, error: 23779.304
# iter: 2, error: 354.281
# current_time:  4.71
# iter: 1, error: 21975.766
# iter: 2, error: 299.155
# current_time:  4.72
# iter: 1, error: 20023.030
# iter: 2, error: 245.365
# current_time:  4.73
# iter: 1, error: 17933.607
# iter: 2, error: 194.345
# current_time:  4.74
# iter: 1, error: 15720.958
# iter: 2, error: 147.394
# current_time:  4.75
# iter: 1, error: 13399.414
# iter: 2, error: 105.641
# current_time:  4.76
# iter: 1, error: 10984.093
# iter: 2, error: 70.022
# current_time:  4.7700000000000005
# iter: 1, error: 8490.806
# iter: 2, error: 41.268
# current_time:  4.78
# iter: 1, error: 5935.964
# current_time:  4.79
# iter: 1, error: 3323.302
# current_time:  4.8
# iter: 1, error: 706.010
# current_time:  4.8100000000000005
# iter: 1, error: 1927.130
# current_time:  4.82
# iter: 1, error: 4556.995
# current_time:  4.83
# iter: 1, error: 7166.263
# current_time:  4.84
# iter: 1, error: 9737.516
# iter: 2, error: 50.641
# current_time:  4.8500000000000005
# iter: 1, error: 12216.109
# iter: 2, error: 77.463
# current_time:  4.86
# iter: 1, error: 14636.151
# iter: 2, error: 110.134
# current_time:  4.87
# iter: 1, error: 16961.176
# iter: 2, error: 146.614
# current_time:  4.88
# iter: 1, error: 19174.979
# iter: 2, error: 185.892
# current_time:  4.89
# iter: 1, error: 21262.068
# iter: 2, error: 226.918
# current_time:  4.9
# iter: 1, error: 23207.777
# iter: 2, error: 268.610
# current_time:  4.91
# iter: 1, error: 24998.387
# iter: 2, error: 309.882
# current_time:  4.92
# iter: 1, error: 26621.247
# iter: 2, error: 349.665
# current_time:  4.93
# iter: 1, error: 28064.880
# iter: 2, error: 386.934
# current_time:  4.94
# iter: 1, error: 29319.086
# iter: 2, error: 420.729
# current_time:  4.95
# iter: 1, error: 30375.032
# iter: 2, error: 450.183
# current_time:  4.96
# iter: 1, error: 31225.331
# iter: 2, error: 474.541
# current_time:  4.97
# iter: 1, error: 31864.102
# iter: 2, error: 493.182
# current_time:  4.98
# iter: 1, error: 32287.019
# iter: 2, error: 505.635
# current_time:  4.99
# iter: 1, error: 32491.340
# iter: 2, error: 511.591
# current_time:  5.0

# %% [markdown]
# ### Plotting

# %%
t = np.arange(robot.sim_params.total_time, step=robot.sim_params.dt)
options = dismech.AnimationOptions(title=plant_name, plot_step=10)

fig = dismech.get_interactive_animation_plotly(robot, t, qs , options)
fig.show()

# %%
# # save gif
# ani = dismech.get_animation(robot, t, qs, options)
# save_path = os.path.join("tomato_results", f"{plant_name}_{position}.gif")
# ani.save(save_path)

# %%
# plot the trajectory of the flower location
flower_node = 143  # pick a node at the flower
# flower_node = main_grip  # pick a node at the flower

import matplotlib.pyplot as plt

# Extract the DOF indices (x, y, z) of the node you want to track
flower_node_dofs = robot.map_node_to_dof(flower_node)  # e.g., [ix, iy, iz]

# Extract position of that node across all timesteps
logged = qs[:, flower_node_dofs].squeeze()  # shape (n_timesteps, 3)

# remove value at t=0
logged -= robot.nodes[flower_node]

# Plot x, y, z over time
t = np.arange(qs.shape[0]) * robot.sim_params.dt

plt.figure(figsize=(10, 4))
plt.plot(t, logged[:, 0], label='x')
plt.plot(t, logged[:, 1], label='y')
plt.plot(t, logged[:, 2], label='z')
plt.xlabel('Time (s)')
plt.ylabel('Position')
plt.title(f'Position of Node {flower_node} Over Time')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
from scipy.signal import hilbert, detrend, find_peaks

def avg_cycle_amplitude_hilbert(x: np.ndarray) -> float:
    """
    Robust average oscillation amplitude using the analytic-signal envelope.
    Returns the median envelope value (less sensitive to outliers).
    """
    x = np.asarray(x).ravel()
    x = detrend(x)  # remove slow drift
    envelope = np.abs(hilbert(x))
    # Use median to resist occasional spikes; mean is also fine.
    return float(np.median(envelope))
# amplitude of flower node motion
amp_x_flower_hilbert = avg_cycle_amplitude_hilbert(logged[:, 0]) # hilbert-based amplitude
amp_x_flower_peak = (np.max(logged[:, 0]) - np.min(logged[:, 0])) / 2.0 # peak-to-peak amplitude
print(f"Amplitude of flower node {flower_node} motion in x (peak-to-peak): {amp_x_flower_peak:.4f} m")
print(f"Amplitude of flower node {flower_node} motion in x (hilbert): {amp_x_flower_hilbert:.4f} m")
# Out:
# Amplitude of flower node 143 motion in x (peak-to-peak): 0.0044 m
# Amplitude of flower node 143 motion in x (hilbert): 0.0042 m

# %% [markdown]
# ### Save data for rendering

# %%
# from dismech.logging import logDataForRendering
# from dismech.logging import export_rod_shell_data, export_parachute_data

# rod_data, shell_data = logDataForRendering(qs, t.reshape(-1, 1), robot, len(t), robot.sim_params.static_sim, robot.map_node_to_dof)

# js_file = os.path.join("tomato_results", f"{plant_name}_{position}.js")

# export_parachute_data(qs, geo.rod_edges, robot,
#                           rod_js=js_file,
#                           scaleFactor=100)

# %% [markdown]
# ### Estimated values of parameters

# %%
# L = 0.292 # m
# r0 = 0.0059 # m

# delta = 0.054 # m # delta = PL^3/(3EI)
# P = 0.02*9.81 # N

# K = P/delta # effective stiffness

# I = np.pi * r0**4 / 4
# E = P*(L**3) / (3 * I * delta)

# print("E:", E)

# f = 1.38 # Hz
# TP = 0.725 # s

# omega = 2 * np.pi * f
# m_eff = K / omega**2
# print("m_eff:", m_eff)

# # estimate density
# V = np.pi * r0**2 * L
# rho = m_eff / V
# print("rho:", rho)
