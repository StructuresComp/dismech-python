# %% [markdown]
# ## Tomato Pollination: Pepper 0

# %%
# def parse_obj_to_input_with_commas(obj_filename):
#     nodes = []
#     edges = []

#     # Read obj file
#     with open(obj_filename, "r") as f:
#         for line in f:
#             parts = line.strip().split()
#             if not parts:
#                 continue
#             if parts[0] == "v":  # Node line
#                 nodes.append([float(x) for x in parts[1:4]])
#             elif parts[0] == "l":  # Edge line
#                 edges.append([int(x) for x in parts[1:]])

#     # Write to input.txt with commas
#     out_filename=obj_filename.replace(".obj", ".txt")
#     with open(out_filename, "w") as f:
#         f.write("*Nodes\n")
#         for (x, y, z) in nodes:
#             f.write(f"{x}, {y}, {z}\n")

#         f.write("*Edges\n")
#         for (n1, n2) in edges:
#             f.write(f"{n1}, {n2}\n")

#     return out_filename

# # Run for all files in the directory
# directory = "../tests/resources/tomato_pollination/plants/"
# import os
# for filename in os.listdir(directory):
#     if filename.endswith(".obj"):
#         parse_obj_to_input_with_commas(os.path.join(directory, filename))

# %%
import numpy as np
import dismech
import os

plant_name = "pepper0"

position = "4"

geom = dismech.GeomParams(
    rod_r0=0.03,
    shell_h=0.0,
)

material = dismech.Material(density=1100,
                            youngs_rod=2.16e7,
                            youngs_shell=0,
                            poisson_rod=0.5,
                            poisson_shell=0)

dyn_sim = dismech.SimParams(static_sim=False,
                                  two_d_sim=True,   # no twisting
                                  use_mid_edge=False,
                                  use_line_search=False,
                                  show_floor=False,
                                  log_data=True,
                                  log_step=1,
                                  dt=1e-2,
                                  max_iter=50,
                                  total_time=5,
                                  plot_step=100,
                                  tol=1e-4,
                                  ftol=1e-4,
                                  dtol=1e-2
                                  )

env = dismech.Environment()
env.add_force('gravity', g=np.array([0.0, 0.0, -9.81]))
env.add_force('damping', eta=100)

input_txt = os.path.join('../tests/resources/tomato_pollination/plants/', f"{plant_name}.txt")
geo = dismech.Geometry.from_txt(input_txt)

robot = dismech.SoftRobot(geom, material, geo, dyn_sim, env)

# %%
# height of the plant
node_positions = robot.nodes
plant_height = np.max(node_positions[:, 2]) - np.min(node_positions[:, 2])
print("Plant height:", plant_height)
# Out:
# Plant height: 0.36

# %% [markdown]
# ### Move the stem: Moving BC

# %%
# # --- pick the main grip node robustly ---
# grasping_point = np.array([
#       1.1120794,
#       0.0663341,
#       0.3889156
#     ])

main_grip = [87]

print("Main grip node:", main_grip)
#82

# other_grip_nodes_below = np.array([1, 5, 8, 13], dtype=int)
# other_grip_nodes_above = np.array([57, 47, 44, 33, 28, 21], dtype=int)
other_grip_nodes_below = []
other_grip_nodes_above = []
# Out:
# Main grip node: [87]

# %%
base_nodes = np.where((robot.state.q[robot.node_dof_indices].reshape(-1, 3)[:, 2]) < 0.22)[0] # fixed base
# Fix only main_grip and base nodes
robot = robot.fix_nodes(np.unique(np.r_[main_grip, base_nodes]))

# %%
print(np.unique(np.r_[main_grip, base_nodes]))
# Out:
# [ 0  1  2  3 87]

# %%
# ----- once, before simulation -----
all_grip_nodes = np.r_[main_grip, other_grip_nodes_below, other_grip_nodes_above].astype(int)

xyz0 = robot.state.q[robot.node_dof_indices].reshape(-1, 3).copy()
x0 = xyz0[all_grip_nodes, 0].copy()          # initial x of all prescribed nodes
prev_target_x = x0.copy()                     # last absolute target (starts at initial)

# (Optional) precompute amplitude scalings from *initial* geometry
def build_amps_from_xyz0(xyz0, main_grip, all_grip_nodes, A_main):
    amps = np.empty(all_grip_nodes.size, float)
    amps[0] = A_main  # main_grip
    # below group
    below = np.array(other_grip_nodes_below, dtype=int)
    if below.size:
        ref = below[0]
        L = max(np.linalg.norm(xyz0[main_grip]-xyz0[ref]), 1e-12)
        for j, node in enumerate(below, start=1):  # start=1 because 0 is main_grip
            amps[j] = A_main * (np.linalg.norm(xyz0[ref]-xyz0[node]) / L)
    # above group
    above = np.array(other_grip_nodes_above, dtype=int)
    if above.size:
        ref = above[0]
        offset = 1 + below.size
        L = max(np.linalg.norm(xyz0[main_grip]-xyz0[ref]), 1e-12)
        for j, node in enumerate(above, start=offset):
            amps[j] = A_main * (np.linalg.norm(xyz0[ref]-xyz0[node]) / L)
    return amps

A_main = 0.4094e-2  # m at main_grip
freq   = 1    # Hz
# amps   = build_amps_from_xyz0(xyz0, main_grip, all_grip_nodes, A_main)
amps   = np.array([A_main for _ in all_grip_nodes])
print("Amplitudes (m):", amps)

def shake_distributed(robot, t: float):
    # absolute target centered at initial pose
    target_x = x0 + amps * np.sin(2*np.pi*freq*t)

    # INCREMENT ONLY: avoids velocity spikes and keeps symmetry
    delta_x = target_x - prev_target_x
    prev_target_x[:] = target_x

    return robot.move_nodes(all_grip_nodes, delta_x.reshape(-1,1).flatten(), axis=0)

print("grasping points:", all_grip_nodes)
# Out:
# Amplitudes (m): [0.004094]
# grasping points: [87]

# %%
stepper = dismech.ImplicitEulerTimeStepper(robot)
stepper.before_step = shake_distributed

# %% [markdown]
# ### Simulate

# %%
# simulate
robots = stepper.simulate()

qs = np.stack([robot.state.q for robot in robots])
# Out:
# iter: 1, error: 9385.495
# iter: 2, error: 120.478
# current_time:  0.01
# iter: 1, error: 9347.609
# iter: 2, error: 144.007
# current_time:  0.02
# iter: 1, error: 9272.579
# iter: 2, error: 171.808
# current_time:  0.03
# iter: 1, error: 9161.631
# iter: 2, error: 171.890
# current_time:  0.04
# iter: 1, error: 9014.882
# iter: 2, error: 145.697
# current_time:  0.05
# iter: 1, error: 8832.844
# iter: 2, error: 115.712
# current_time:  0.06
# iter: 1, error: 8616.197
# iter: 2, error: 99.838
# current_time:  0.07
# iter: 1, error: 8365.759
# iter: 2, error: 92.576
# current_time:  0.08
# iter: 1, error: 8082.485
# iter: 2, error: 86.133
# current_time:  0.09
# iter: 1, error: 7767.467
# iter: 2, error: 79.308
# current_time:  0.1
# iter: 1, error: 7421.916
# iter: 2, error: 72.185
# current_time:  0.11
# iter: 1, error: 7047.157
# iter: 2, error: 64.854
# current_time:  0.12
# iter: 1, error: 6644.625
# iter: 2, error: 57.452
# current_time:  0.13
# iter: 1, error: 6215.857
# iter: 2, error: 50.093
# current_time:  0.14
# iter: 1, error: 5762.491
# iter: 2, error: 42.906
# current_time:  0.15
# iter: 1, error: 5286.261
# iter: 2, error: 36.010
# current_time:  0.16
# iter: 1, error: 4788.990
# iter: 2, error: 29.471
# current_time:  0.17
# iter: 1, error: 4272.586
# iter: 2, error: 23.361
# current_time:  0.18
# iter: 1, error: 3739.030
# iter: 2, error: 17.793
# current_time:  0.19
# iter: 1, error: 3190.378
# iter: 2, error: 12.879
# current_time:  0.2
# iter: 1, error: 2628.745
# current_time:  0.21
# iter: 1, error: 2051.031
# current_time:  0.22
# iter: 1, error: 1472.219
# current_time:  0.23
# iter: 1, error: 886.322
# current_time:  0.24
# iter: 1, error: 295.922
# current_time:  0.25
# iter: 1, error: 296.706
# current_time:  0.26
# iter: 1, error: 889.262
# current_time:  0.27
# iter: 1, error: 1479.435
# current_time:  0.28
# iter: 1, error: 2064.910
# current_time:  0.29
# iter: 1, error: 2643.379
# current_time:  0.3
# iter: 1, error: 3212.543
# current_time:  0.31
# iter: 1, error: 3770.128
# iter: 2, error: 17.214
# current_time:  0.32
# iter: 1, error: 4302.559
# iter: 2, error: 22.044
# current_time:  0.33
# iter: 1, error: 4826.664
# iter: 2, error: 27.639
# current_time:  0.34
# iter: 1, error: 5332.195
# iter: 2, error: 33.611
# current_time:  0.35000000000000003
# iter: 1, error: 5817.104
# iter: 2, error: 39.867
# current_time:  0.36
# iter: 1, error: 6279.428
# iter: 2, error: 46.309
# current_time:  0.37
# iter: 1, error: 6717.292
# iter: 2, error: 52.835
# current_time:  0.38
# iter: 1, error: 7128.912
# iter: 2, error: 59.344
# current_time:  0.39
# iter: 1, error: 7512.608
# iter: 2, error: 65.736
# current_time:  0.4
# iter: 1, error: 7866.806
# iter: 2, error: 71.913
# current_time:  0.41000000000000003
# iter: 1, error: 8190.051
# iter: 2, error: 77.780
# current_time:  0.42
# iter: 1, error: 8481.009
# iter: 2, error: 83.247
# current_time:  0.43
# iter: 1, error: 8738.475
# iter: 2, error: 88.231
# current_time:  0.44
# iter: 1, error: 8961.380
# iter: 2, error: 92.657
# current_time:  0.45
# iter: 1, error: 9148.796
# iter: 2, error: 96.455
# current_time:  0.46
# iter: 1, error: 9299.936
# iter: 2, error: 99.569
# current_time:  0.47000000000000003
# iter: 1, error: 9414.163
# iter: 2, error: 101.951
# current_time:  0.48
# iter: 1, error: 9490.994
# iter: 2, error: 103.565
# current_time:  0.49
# iter: 1, error: 9530.096
# iter: 2, error: 104.385
# current_time:  0.5
# iter: 1, error: 9531.294
# iter: 2, error: 104.400
# current_time:  0.51
# iter: 1, error: 9494.569
# iter: 2, error: 103.608
# current_time:  0.52
# iter: 1, error: 9420.058
# iter: 2, error: 102.022
# current_time:  0.53
# iter: 1, error: 9308.058
# iter: 2, error: 99.666
# current_time:  0.54
# iter: 1, error: 9159.018
# iter: 2, error: 96.576
# current_time:  0.55
# iter: 1, error: 8973.540
# iter: 2, error: 92.798
# current_time:  0.56
# iter: 1, error: 8752.381
# iter: 2, error: 88.390
# current_time:  0.5700000000000001
# iter: 1, error: 8496.441
# iter: 2, error: 83.420
# current_time:  0.58
# iter: 1, error: 8206.766
# iter: 2, error: 77.962
# current_time:  0.59
# iter: 1, error: 7884.539
# iter: 2, error: 72.101
# current_time:  0.6
# iter: 1, error: 7531.079
# iter: 2, error: 65.925
# current_time:  0.61
# iter: 1, error: 7147.828
# iter: 2, error: 59.530
# current_time:  0.62
# iter: 1, error: 6736.354
# iter: 2, error: 53.014
# current_time:  0.63
# iter: 1, error: 6298.334
# iter: 2, error: 46.478
# current_time:  0.64
# iter: 1, error: 5835.556
# iter: 2, error: 40.024
# current_time:  0.65
# iter: 1, error: 5349.901
# iter: 2, error: 33.751
# current_time:  0.66
# iter: 1, error: 4843.345
# iter: 2, error: 27.761
# current_time:  0.67
# iter: 1, error: 4317.942
# iter: 2, error: 22.148
# current_time:  0.68
# iter: 1, error: 3775.819
# iter: 2, error: 17.002
# current_time:  0.6900000000000001
# iter: 1, error: 3219.167
# current_time:  0.7000000000000001
# iter: 1, error: 2658.111
# current_time:  0.71
# iter: 1, error: 2076.952
# current_time:  0.72
# iter: 1, error: 1488.117
# current_time:  0.73
# iter: 1, error: 894.490
# current_time:  0.74
# iter: 1, error: 298.458
# current_time:  0.75
# iter: 1, error: 297.612
# current_time:  0.76
# iter: 1, error: 891.365
# current_time:  0.77
# iter: 1, error: 1480.471
# current_time:  0.78
# iter: 1, error: 2062.631
# current_time:  0.79
# iter: 1, error: 2635.585
# current_time:  0.8
# iter: 1, error: 3197.122
# current_time:  0.81
# iter: 1, error: 3745.086
# iter: 2, error: 17.487
# current_time:  0.8200000000000001
# iter: 1, error: 4287.556
# iter: 2, error: 23.380
# current_time:  0.8300000000000001
# iter: 1, error: 4805.130
# iter: 2, error: 29.503
# current_time:  0.84
# iter: 1, error: 5303.305
# iter: 2, error: 36.098
# current_time:  0.85
# iter: 1, error: 5780.147
# iter: 2, error: 43.066
# current_time:  0.86
# iter: 1, error: 6233.820
# iter: 2, error: 50.297
# current_time:  0.87
# iter: 1, error: 6662.585
# iter: 2, error: 57.680
# current_time:  0.88
# iter: 1, error: 7064.801
# iter: 2, error: 65.095
# current_time:  0.89
# iter: 1, error: 7438.935
# iter: 2, error: 72.423
# current_time:  0.9
# iter: 1, error: 7783.564
# iter: 2, error: 79.545
# current_time:  0.91
# iter: 1, error: 8097.383
# iter: 2, error: 86.343
# current_time:  0.92
# iter: 1, error: 8379.205
# iter: 2, error: 92.706
# current_time:  0.93
# iter: 1, error: 8627.972
# iter: 2, error: 98.526
# current_time:  0.9400000000000001
# iter: 1, error: 8842.749
# iter: 2, error: 103.708
# current_time:  0.9500000000000001
# iter: 1, error: 9022.736
# iter: 2, error: 108.163
# current_time:  0.96
# iter: 1, error: 9167.264
# iter: 2, error: 111.816
# current_time:  0.97
# iter: 1, error: 9275.800
# iter: 2, error: 114.605
# current_time:  0.98
# iter: 1, error: 9347.948
# iter: 2, error: 116.484
# current_time:  0.99
# iter: 1, error: 9383.451
# iter: 2, error: 117.420
# current_time:  1.0
# iter: 1, error: 9382.189
# iter: 2, error: 117.398
# current_time:  1.01
# iter: 1, error: 9344.183
# iter: 2, error: 116.418
# current_time:  1.02
# iter: 1, error: 9269.590
# iter: 2, error: 114.498
# current_time:  1.03
# iter: 1, error: 9158.707
# iter: 2, error: 111.669
# current_time:  1.04
# iter: 1, error: 9011.965
# iter: 2, error: 107.982
# current_time:  1.05
# iter: 1, error: 8829.933
# iter: 2, error: 103.498
# current_time:  1.06
# iter: 1, error: 8613.310
# iter: 2, error: 98.293
# current_time:  1.07
# iter: 1, error: 8362.927
# iter: 2, error: 92.456
# current_time:  1.08
# iter: 1, error: 8079.743
# iter: 2, error: 86.083
# current_time:  1.09
# iter: 1, error: 7764.839
# iter: 2, error: 79.282
# current_time:  1.1
# iter: 1, error: 7419.418
# iter: 2, error: 72.163
# current_time:  1.11
# iter: 1, error: 7044.799
# iter: 2, error: 64.845
# current_time:  1.12
# iter: 1, error: 6642.410
# iter: 2, error: 57.445
# current_time:  1.1300000000000001
# iter: 1, error: 6213.791
# iter: 2, error: 50.082
# current_time:  1.1400000000000001
# iter: 1, error: 5760.578
# iter: 2, error: 42.873
# current_time:  1.1500000000000001
# iter: 1, error: 5284.506
# iter: 2, error: 35.931
# current_time:  1.16
# iter: 1, error: 4787.398
# iter: 2, error: 29.363
# current_time:  1.17
# iter: 1, error: 4271.162
# iter: 2, error: 23.269
# current_time:  1.18
# iter: 1, error: 3737.782
# iter: 2, error: 17.740
# current_time:  1.19
# iter: 1, error: 3189.310
# current_time:  1.2
# iter: 1, error: 2620.114
# current_time:  1.21
# iter: 1, error: 2050.679
# current_time:  1.22
# iter: 1, error: 1471.727
# current_time:  1.23
# iter: 1, error: 886.026
# current_time:  1.24
# iter: 1, error: 295.822
# current_time:  1.25
# iter: 1, error: 296.606
# current_time:  1.26
# iter: 1, error: 888.961
# current_time:  1.27
# iter: 1, error: 1478.934
# current_time:  1.28
# iter: 1, error: 2064.209
# current_time:  1.29
# iter: 1, error: 2642.479
# current_time:  1.3
# iter: 1, error: 3211.446
# current_time:  1.31
# iter: 1, error: 3768.836
# iter: 2, error: 17.205
# current_time:  1.32
# iter: 1, error: 4301.090
# iter: 2, error: 22.032
# current_time:  1.33
# iter: 1, error: 4825.014
# iter: 2, error: 27.623
# current_time:  1.34
# iter: 1, error: 5330.369
# iter: 2, error: 33.592
# current_time:  1.35
# iter: 1, error: 5815.107
# iter: 2, error: 39.844
# current_time:  1.36
# iter: 1, error: 6277.269
# iter: 2, error: 46.282
# current_time:  1.37
# iter: 1, error: 6714.977
# iter: 2, error: 52.804
# current_time:  1.3800000000000001
# iter: 1, error: 7126.451
# iter: 2, error: 59.310
# current_time:  1.3900000000000001
# iter: 1, error: 7510.010
# iter: 2, error: 65.698
# current_time:  1.4000000000000001
# iter: 1, error: 7864.080
# iter: 2, error: 71.872
# current_time:  1.41
# iter: 1, error: 8187.208
# iter: 2, error: 77.735
# current_time:  1.42
# iter: 1, error: 8478.059
# iter: 2, error: 83.199
# current_time:  1.43
# iter: 1, error: 8735.431
# iter: 2, error: 88.181
# current_time:  1.44
# iter: 1, error: 8958.253
# iter: 2, error: 92.603
# current_time:  1.45
# iter: 1, error: 9145.598
# iter: 2, error: 96.399
# current_time:  1.46
# iter: 1, error: 9296.680
# iter: 2, error: 99.511
# current_time:  1.47
# iter: 1, error: 9410.863
# iter: 2, error: 101.892
# current_time:  1.48
# iter: 1, error: 9487.661
# iter: 2, error: 103.504
# current_time:  1.49
# iter: 1, error: 9526.745
# iter: 2, error: 104.324
# current_time:  1.5
# iter: 1, error: 9527.939
# iter: 2, error: 104.338
# current_time:  1.51
# iter: 1, error: 9491.222
# iter: 2, error: 103.547
# current_time:  1.52
# iter: 1, error: 9416.735
# iter: 2, error: 101.962
# current_time:  1.53
# iter: 1, error: 9304.771
# iter: 2, error: 99.608
# current_time:  1.54
# iter: 1, error: 9155.780
# iter: 2, error: 96.519
# current_time:  1.55
# iter: 1, error: 8970.367
# iter: 2, error: 92.744
# current_time:  1.56
# iter: 1, error: 8749.283
# iter: 2, error: 88.339
# current_time:  1.57
# iter: 1, error: 8493.432
# iter: 2, error: 83.371
# current_time:  1.58
# iter: 1, error: 8203.859
# iter: 2, error: 77.917
# current_time:  1.59
# iter: 1, error: 7881.745
# iter: 2, error: 72.059
# current_time:  1.6
# iter: 1, error: 7528.410
# iter: 2, error: 65.887
# current_time:  1.61
# iter: 1, error: 7145.295
# iter: 2, error: 59.496
# current_time:  1.62
# iter: 1, error: 6733.966
# iter: 2, error: 52.984
# current_time:  1.6300000000000001
# iter: 1, error: 6296.103
# iter: 2, error: 46.452
# current_time:  1.6400000000000001
# iter: 1, error: 5833.489
# iter: 2, error: 40.001
# current_time:  1.6500000000000001
# iter: 1, error: 5348.007
# iter: 2, error: 33.732
# current_time:  1.6600000000000001
# iter: 1, error: 4841.631
# iter: 2, error: 27.745
# current_time:  1.67
# iter: 1, error: 4316.415
# iter: 2, error: 22.135
# current_time:  1.68
# iter: 1, error: 3774.485
# iter: 2, error: 16.993
# current_time:  1.69
# iter: 1, error: 3218.030
# current_time:  1.7
# iter: 1, error: 2657.165
# current_time:  1.71
# iter: 1, error: 2076.215
# current_time:  1.72
# iter: 1, error: 1487.590
# current_time:  1.73
# iter: 1, error: 894.174
# current_time:  1.74
# iter: 1, error: 298.353
# current_time:  1.75
# iter: 1, error: 297.508
# current_time:  1.76
# iter: 1, error: 891.053
# current_time:  1.77
# iter: 1, error: 1479.954
# current_time:  1.78
# iter: 1, error: 2061.912
# current_time:  1.79
# iter: 1, error: 2634.670
# current_time:  1.8
# iter: 1, error: 3196.015
# current_time:  1.81
# iter: 1, error: 3743.794
# iter: 2, error: 17.477
# current_time:  1.82
# iter: 1, error: 4286.069
# iter: 2, error: 23.367
# current_time:  1.83
# iter: 1, error: 4803.467
# iter: 2, error: 29.487
# current_time:  1.84
# iter: 1, error: 5301.473
# iter: 2, error: 36.078
# current_time:  1.85
# iter: 1, error: 5778.154
# iter: 2, error: 43.042
# current_time:  1.86
# iter: 1, error: 6231.675
# iter: 2, error: 50.269
# current_time:  1.87
# iter: 1, error: 6660.296
# iter: 2, error: 57.648
# current_time:  1.8800000000000001
# iter: 1, error: 7062.379
# iter: 2, error: 65.059
# current_time:  1.8900000000000001
# iter: 1, error: 7436.389
# iter: 2, error: 72.383
# current_time:  1.9000000000000001
# iter: 1, error: 7780.905
# iter: 2, error: 79.500
# current_time:  1.9100000000000001
# iter: 1, error: 8094.621
# iter: 2, error: 86.295
# current_time:  1.92
# iter: 1, error: 8376.353
# iter: 2, error: 92.654
# current_time:  1.93
# iter: 1, error: 8625.039
# iter: 2, error: 98.471
# current_time:  1.94
# iter: 1, error: 8839.749
# iter: 2, error: 103.650
# current_time:  1.95
# iter: 1, error: 9019.679
# iter: 2, error: 108.102
# current_time:  1.96
# iter: 1, error: 9164.163
# iter: 2, error: 111.753
# current_time:  1.97
# iter: 1, error: 9272.667
# iter: 2, error: 114.541
# current_time:  1.98
# iter: 1, error: 9344.795
# iter: 2, error: 116.419
# current_time:  1.99
# iter: 1, error: 9380.291
# iter: 2, error: 117.354
# current_time:  2.0
# iter: 1, error: 9379.034
# iter: 2, error: 117.332
# current_time:  2.0100000000000002
# iter: 1, error: 9341.044
# iter: 2, error: 116.353
# current_time:  2.02
# iter: 1, error: 9266.479
# iter: 2, error: 114.433
# current_time:  2.0300000000000002
# iter: 1, error: 9155.636
# iter: 2, error: 111.607
# current_time:  2.04
# iter: 1, error: 9008.946
# iter: 2, error: 107.921
# current_time:  2.05
# iter: 1, error: 8826.977
# iter: 2, error: 103.440
# current_time:  2.06
# iter: 1, error: 8610.429
# iter: 2, error: 98.238
# current_time:  2.07
# iter: 1, error: 8360.131
# iter: 2, error: 92.404
# current_time:  2.08
# iter: 1, error: 8077.043
# iter: 2, error: 86.035
# current_time:  2.09
# iter: 1, error: 7762.245
# iter: 2, error: 79.237
# current_time:  2.1
# iter: 1, error: 7416.940
# iter: 2, error: 72.123
# current_time:  2.11
# iter: 1, error: 7042.446
# iter: 2, error: 64.809
# current_time:  2.12
# iter: 1, error: 6640.192
# iter: 2, error: 57.413
# current_time:  2.13
# iter: 1, error: 6211.715
# iter: 2, error: 50.054
# current_time:  2.14
# iter: 1, error: 5758.653
# iter: 2, error: 42.849
# current_time:  2.15
# iter: 1, error: 5282.739
# iter: 2, error: 35.911
# current_time:  2.16
# iter: 1, error: 4785.797
# iter: 2, error: 29.347
# current_time:  2.17
# iter: 1, error: 4269.732
# iter: 2, error: 23.256
# current_time:  2.18
# iter: 1, error: 3736.530
# iter: 2, error: 17.730
# current_time:  2.19
# iter: 1, error: 3188.241
# current_time:  2.2
# iter: 1, error: 2619.242
# current_time:  2.21
# iter: 1, error: 2049.996
# current_time:  2.22
# iter: 1, error: 1471.236
# current_time:  2.23
# iter: 1, error: 885.729
# current_time:  2.24
# iter: 1, error: 295.723
# current_time:  2.25
# iter: 1, error: 296.506
# current_time:  2.2600000000000002
# iter: 1, error: 888.660
# current_time:  2.27
# iter: 1, error: 1478.432
# current_time:  2.2800000000000002
# iter: 1, error: 2063.507
# current_time:  2.29
# iter: 1, error: 2641.577
# current_time:  2.3000000000000003
# iter: 1, error: 3210.346
# current_time:  2.31
# iter: 1, error: 3767.541
# iter: 2, error: 17.196
# current_time:  2.32
# iter: 1, error: 4299.620
# iter: 2, error: 22.020
# current_time:  2.33
# iter: 1, error: 4823.361
# iter: 2, error: 27.607
# current_time:  2.34
# iter: 1, error: 5328.539
# iter: 2, error: 33.573
# current_time:  2.35
# iter: 1, error: 5813.107
# iter: 2, error: 39.822
# current_time:  2.36
# iter: 1, error: 6275.105
# iter: 2, error: 46.256
# current_time:  2.37
# iter: 1, error: 6712.659
# iter: 2, error: 52.774
# current_time:  2.38
# iter: 1, error: 7123.986
# iter: 2, error: 59.276
# current_time:  2.39
# iter: 1, error: 7507.406
# iter: 2, error: 65.661
# current_time:  2.4
# iter: 1, error: 7861.349
# iter: 2, error: 71.830
# current_time:  2.41
# iter: 1, error: 8184.359
# iter: 2, error: 77.690
# current_time:  2.42
# iter: 1, error: 8475.104
# iter: 2, error: 83.151
# current_time:  2.43
# iter: 1, error: 8732.381
# iter: 2, error: 88.130
# current_time:  2.44
# iter: 1, error: 8955.120
# iter: 2, error: 92.549
# current_time:  2.45
# iter: 1, error: 9142.394
# iter: 2, error: 96.343
# current_time:  2.46
# iter: 1, error: 9293.418
# iter: 2, error: 99.453
# current_time:  2.47
# iter: 1, error: 9407.556
# iter: 2, error: 101.832
# current_time:  2.48
# iter: 1, error: 9484.323
# iter: 2, error: 103.444
# current_time:  2.49
# iter: 1, error: 9523.389
# iter: 2, error: 104.263
# current_time:  2.5
# iter: 1, error: 9524.577
# iter: 2, error: 104.277
# current_time:  2.5100000000000002
# iter: 1, error: 9487.870
# iter: 2, error: 103.487
# current_time:  2.52
# iter: 1, error: 9413.406
# iter: 2, error: 101.903
# current_time:  2.5300000000000002
# iter: 1, error: 9301.478
# iter: 2, error: 99.550
# current_time:  2.54
# iter: 1, error: 9152.538
# iter: 2, error: 96.463
# current_time:  2.5500000000000003
# iter: 1, error: 8967.187
# iter: 2, error: 92.690
# current_time:  2.56
# iter: 1, error: 8746.180
# iter: 2, error: 88.288
# current_time:  2.57
# iter: 1, error: 8490.419
# iter: 2, error: 83.323
# current_time:  2.58
# iter: 1, error: 8200.947
# iter: 2, error: 77.872
# current_time:  2.59
# iter: 1, error: 7878.947
# iter: 2, error: 72.018
# current_time:  2.6
# iter: 1, error: 7525.736
# iter: 2, error: 65.849
# current_time:  2.61
# iter: 1, error: 7142.757
# iter: 2, error: 59.462
# current_time:  2.62
# iter: 1, error: 6731.575
# iter: 2, error: 52.954
# current_time:  2.63
# iter: 1, error: 6293.867
# iter: 2, error: 46.425
# current_time:  2.64
# iter: 1, error: 5831.418
# iter: 2, error: 39.978
# current_time:  2.65
# iter: 1, error: 5346.110
# iter: 2, error: 33.713
# current_time:  2.66
# iter: 1, error: 4839.914
# iter: 2, error: 27.729
# current_time:  2.67
# iter: 1, error: 4314.885
# iter: 2, error: 22.123
# current_time:  2.68
# iter: 1, error: 3773.148
# iter: 2, error: 16.983
# current_time:  2.69
# iter: 1, error: 3216.892
# current_time:  2.7
# iter: 1, error: 2656.218
# current_time:  2.71
# iter: 1, error: 2075.476
# current_time:  2.72
# iter: 1, error: 1487.062
# current_time:  2.73
# iter: 1, error: 893.857
# current_time:  2.74
# iter: 1, error: 298.247
# current_time:  2.75
# iter: 1, error: 297.403
# current_time:  2.7600000000000002
# iter: 1, error: 890.740
# current_time:  2.77
# iter: 1, error: 1479.436
# current_time:  2.7800000000000002
# iter: 1, error: 2061.193
# current_time:  2.79
# iter: 1, error: 2633.753
# current_time:  2.8000000000000003
# iter: 1, error: 3194.907
# current_time:  2.81
# iter: 1, error: 3742.499
# iter: 2, error: 17.468
# current_time:  2.82
# iter: 1, error: 4284.580
# iter: 2, error: 23.354
# current_time:  2.83
# iter: 1, error: 4801.801
# iter: 2, error: 29.470
# current_time:  2.84
# iter: 1, error: 5299.637
# iter: 2, error: 36.058
# current_time:  2.85
# iter: 1, error: 5776.157
# iter: 2, error: 43.018
# current_time:  2.86
# iter: 1, error: 6229.525
# iter: 2, error: 50.241
# current_time:  2.87
# iter: 1, error: 6658.003
# iter: 2, error: 57.615
# current_time:  2.88
# iter: 1, error: 7059.952
# iter: 2, error: 65.022
# current_time:  2.89
# iter: 1, error: 7433.838
# iter: 2, error: 72.342
# current_time:  2.9
# iter: 1, error: 7778.241
# iter: 2, error: 79.456
# current_time:  2.91
# iter: 1, error: 8091.854
# iter: 2, error: 86.247
# current_time:  2.92
# iter: 1, error: 8373.495
# iter: 2, error: 92.602
# current_time:  2.93
# iter: 1, error: 8622.102
# iter: 2, error: 98.416
# current_time:  2.94
# iter: 1, error: 8836.743
# iter: 2, error: 103.592
# current_time:  2.95
# iter: 1, error: 9016.617
# iter: 2, error: 108.041
# current_time:  2.96
# iter: 1, error: 9161.057
# iter: 2, error: 111.690
# current_time:  2.97
# iter: 1, error: 9269.529
# iter: 2, error: 114.477
# current_time:  2.98
# iter: 1, error: 9341.637
# iter: 2, error: 116.353
# current_time:  2.99
# iter: 1, error: 9377.125
# iter: 2, error: 117.288
# current_time:  3.0
# iter: 1, error: 9375.872
# iter: 2, error: 117.266
# current_time:  3.0100000000000002
# iter: 1, error: 9337.899
# iter: 2, error: 116.287
# current_time:  3.02
# iter: 1, error: 9263.363
# iter: 2, error: 114.369
# current_time:  3.0300000000000002
# iter: 1, error: 9152.559
# iter: 2, error: 111.544
# current_time:  3.04
# iter: 1, error: 9005.922
# iter: 2, error: 107.860
# current_time:  3.0500000000000003
# iter: 1, error: 8824.016
# iter: 2, error: 103.382
# current_time:  3.06
# iter: 1, error: 8607.542
# iter: 2, error: 98.183
# current_time:  3.0700000000000003
# iter: 1, error: 8357.330
# iter: 2, error: 92.352
# current_time:  3.08
# iter: 1, error: 8074.338
# iter: 2, error: 85.987
# current_time:  3.09
# iter: 1, error: 7759.646
# iter: 2, error: 79.193
# current_time:  3.1
# iter: 1, error: 7414.457
# iter: 2, error: 72.083
# current_time:  3.11
# iter: 1, error: 7040.088
# iter: 2, error: 64.772
# current_time:  3.12
# iter: 1, error: 6637.969
# iter: 2, error: 57.380
# current_time:  3.13
# iter: 1, error: 6209.635
# iter: 2, error: 50.026
# current_time:  3.14
# iter: 1, error: 5756.724
# iter: 2, error: 42.825
# current_time:  3.15
# iter: 1, error: 5280.969
# iter: 2, error: 35.891
# current_time:  3.16
# iter: 1, error: 4784.192
# iter: 2, error: 29.330
# current_time:  3.17
# iter: 1, error: 4268.300
# iter: 2, error: 23.243
# current_time:  3.18
# iter: 1, error: 3735.275
# iter: 2, error: 17.721
# current_time:  3.19
# iter: 1, error: 3187.170
# current_time:  3.2
# iter: 1, error: 2618.370
# current_time:  3.21
# iter: 1, error: 2049.311
# current_time:  3.22
# iter: 1, error: 1470.743
# current_time:  3.23
# iter: 1, error: 885.432
# current_time:  3.24
# iter: 1, error: 295.624
# current_time:  3.25
# iter: 1, error: 296.405
# current_time:  3.2600000000000002
# iter: 1, error: 888.359
# current_time:  3.27
# iter: 1, error: 1477.929
# current_time:  3.2800000000000002
# iter: 1, error: 2062.803
# current_time:  3.29
# iter: 1, error: 2640.673
# current_time:  3.3000000000000003
# iter: 1, error: 3209.244
# current_time:  3.31
# iter: 1, error: 3766.244
# iter: 2, error: 17.186
# current_time:  3.3200000000000003
# iter: 1, error: 4298.146
# iter: 2, error: 22.008
# current_time:  3.33
# iter: 1, error: 4821.705
# iter: 2, error: 27.592
# current_time:  3.34
# iter: 1, error: 5326.706
# iter: 2, error: 33.554
# current_time:  3.35
# iter: 1, error: 5811.104
# iter: 2, error: 39.799
# current_time:  3.36
# iter: 1, error: 6272.938
# iter: 2, error: 46.230
# current_time:  3.37
# iter: 1, error: 6710.336
# iter: 2, error: 52.744
# current_time:  3.38
# iter: 1, error: 7121.516
# iter: 2, error: 59.242
# current_time:  3.39
# iter: 1, error: 7504.799
# iter: 2, error: 65.623
# current_time:  3.4
# iter: 1, error: 7858.614
# iter: 2, error: 71.789
# current_time:  3.41
# iter: 1, error: 8181.506
# iter: 2, error: 77.646
# current_time:  3.42
# iter: 1, error: 8472.144
# iter: 2, error: 83.103
# current_time:  3.43
# iter: 1, error: 8729.325
# iter: 2, error: 88.079
# current_time:  3.44
# iter: 1, error: 8951.982
# iter: 2, error: 92.496
# current_time:  3.45
# iter: 1, error: 9139.185
# iter: 2, error: 96.287
# current_time:  3.46
# iter: 1, error: 9290.150
# iter: 2, error: 99.395
# current_time:  3.47
# iter: 1, error: 9404.243
# iter: 2, error: 101.773
# current_time:  3.48
# iter: 1, error: 9480.979
# iter: 2, error: 103.383
# current_time:  3.49
# iter: 1, error: 9520.026
# iter: 2, error: 104.202
# current_time:  3.5
# iter: 1, error: 9521.211
# iter: 2, error: 104.216
# current_time:  3.5100000000000002
# iter: 1, error: 9484.513
# iter: 2, error: 103.426
# current_time:  3.52
# iter: 1, error: 9410.071
# iter: 2, error: 101.843
# current_time:  3.5300000000000002
# iter: 1, error: 9298.180
# iter: 2, error: 99.492
# current_time:  3.54
# iter: 1, error: 9149.290
# iter: 2, error: 96.407
# current_time:  3.5500000000000003
# iter: 1, error: 8964.003
# iter: 2, error: 92.636
# current_time:  3.56
# iter: 1, error: 8743.072
# iter: 2, error: 88.236
# current_time:  3.5700000000000003
# iter: 1, error: 8487.400
# iter: 2, error: 83.275
# current_time:  3.58
# iter: 1, error: 8198.030
# iter: 2, error: 77.827
# current_time:  3.59
# iter: 1, error: 7876.144
# iter: 2, error: 71.976
# current_time:  3.6
# iter: 1, error: 7523.058
# iter: 2, error: 65.812
# current_time:  3.61
# iter: 1, error: 7140.216
# iter: 2, error: 59.428
# current_time:  3.62
# iter: 1, error: 6729.180
# iter: 2, error: 52.924
# current_time:  3.63
# iter: 1, error: 6291.628
# iter: 2, error: 46.399
# current_time:  3.64
# iter: 1, error: 5829.344
# iter: 2, error: 39.955
# current_time:  3.65
# iter: 1, error: 5344.209
# iter: 2, error: 33.694
# current_time:  3.66
# iter: 1, error: 4838.194
# iter: 2, error: 27.714
# current_time:  3.67
# iter: 1, error: 4313.353
# iter: 2, error: 22.110
# current_time:  3.68
# iter: 1, error: 3771.809
# iter: 2, error: 16.974
# current_time:  3.69
# iter: 1, error: 3215.751
# current_time:  3.7
# iter: 1, error: 2655.269
# current_time:  3.71
# iter: 1, error: 2074.736
# current_time:  3.72
# iter: 1, error: 1486.533
# current_time:  3.73
# iter: 1, error: 893.540
# current_time:  3.74
# iter: 1, error: 298.141
# current_time:  3.75
# iter: 1, error: 297.298
# current_time:  3.7600000000000002
# iter: 1, error: 890.427
# current_time:  3.77
# iter: 1, error: 1478.917
# current_time:  3.7800000000000002
# iter: 1, error: 2060.472
# current_time:  3.79
# iter: 1, error: 2632.835
# current_time:  3.8000000000000003
# iter: 1, error: 3193.796
# current_time:  3.81
# iter: 1, error: 3741.202
# iter: 2, error: 17.458
# current_time:  3.8200000000000003
# iter: 1, error: 4283.088
# iter: 2, error: 23.341
# current_time:  3.83
# iter: 1, error: 4800.133
# iter: 2, error: 29.454
# current_time:  3.84
# iter: 1, error: 5297.799
# iter: 2, error: 36.038
# current_time:  3.85
# iter: 1, error: 5774.157
# iter: 2, error: 42.994
# current_time:  3.86
# iter: 1, error: 6227.372
# iter: 2, error: 50.213
# current_time:  3.87
# iter: 1, error: 6655.706
# iter: 2, error: 57.583
# current_time:  3.88
# iter: 1, error: 7057.520
# iter: 2, error: 64.986
# current_time:  3.89
# iter: 1, error: 7431.283
# iter: 2, error: 72.302
# current_time:  3.9
# iter: 1, error: 7775.572
# iter: 2, error: 79.412
# current_time:  3.91
# iter: 1, error: 8089.083
# iter: 2, error: 86.198
# current_time:  3.92
# iter: 1, error: 8370.632
# iter: 2, error: 92.550
# current_time:  3.93
# iter: 1, error: 8619.159
# iter: 2, error: 98.361
# current_time:  3.94
# iter: 1, error: 8833.732
# iter: 2, error: 103.533
# current_time:  3.95
# iter: 1, error: 9013.550
# iter: 2, error: 107.981
# current_time:  3.96
# iter: 1, error: 9157.945
# iter: 2, error: 111.628
# current_time:  3.97
# iter: 1, error: 9266.385
# iter: 2, error: 114.412
# current_time:  3.98
# iter: 1, error: 9338.473
# iter: 2, error: 116.288
# current_time:  3.99
# iter: 1, error: 9373.953
# iter: 2, error: 117.222
# current_time:  4.0
# iter: 1, error: 9372.705
# iter: 2, error: 117.200
# current_time:  4.01
# iter: 1, error: 9334.748
# iter: 2, error: 116.222
# current_time:  4.0200000000000005
# iter: 1, error: 9260.240
# iter: 2, error: 114.304
# current_time:  4.03
# iter: 1, error: 9149.477
# iter: 2, error: 111.481
# current_time:  4.04
# iter: 1, error: 9002.891
# iter: 2, error: 107.800
# current_time:  4.05
# iter: 1, error: 8821.049
# iter: 2, error: 103.323
# current_time:  4.0600000000000005
# iter: 1, error: 8604.650
# iter: 2, error: 98.128
# current_time:  4.07
# iter: 1, error: 8354.524
# iter: 2, error: 92.300
# current_time:  4.08
# iter: 1, error: 8071.628
# iter: 2, error: 85.939
# current_time:  4.09
# iter: 1, error: 7757.042
# iter: 2, error: 79.149
# current_time:  4.1
# iter: 1, error: 7411.969
# iter: 2, error: 72.042
# current_time:  4.11
# iter: 1, error: 7037.726
# iter: 2, error: 64.736
# current_time:  4.12
# iter: 1, error: 6635.742
# iter: 2, error: 57.348
# current_time:  4.13
# iter: 1, error: 6207.551
# iter: 2, error: 49.998
# current_time:  4.14
# iter: 1, error: 5754.792
# iter: 2, error: 42.801
# current_time:  4.15
# iter: 1, error: 5279.195
# iter: 2, error: 35.871
# current_time:  4.16
# iter: 1, error: 4782.585
# iter: 2, error: 29.314
# current_time:  4.17
# iter: 1, error: 4266.865
# iter: 2, error: 23.230
# current_time:  4.18
# iter: 1, error: 3734.018
# iter: 2, error: 17.711
# current_time:  4.19
# iter: 1, error: 3186.096
# current_time:  4.2
# iter: 1, error: 2617.495
# current_time:  4.21
# iter: 1, error: 2048.625
# current_time:  4.22
# iter: 1, error: 1470.250
# current_time:  4.23
# iter: 1, error: 885.134
# current_time:  4.24
# iter: 1, error: 295.524
# current_time:  4.25
# iter: 1, error: 296.305
# current_time:  4.26
# iter: 1, error: 888.057
# current_time:  4.2700000000000005
# iter: 1, error: 1477.425
# current_time:  4.28
# iter: 1, error: 2062.098
# current_time:  4.29
# iter: 1, error: 2639.768
# current_time:  4.3
# iter: 1, error: 3208.141
# current_time:  4.3100000000000005
# iter: 1, error: 3764.945
# iter: 2, error: 17.176
# current_time:  4.32
# iter: 1, error: 4296.670
# iter: 2, error: 21.995
# current_time:  4.33
# iter: 1, error: 4820.046
# iter: 2, error: 27.576
# current_time:  4.34
# iter: 1, error: 5324.869
# iter: 2, error: 33.535
# current_time:  4.3500000000000005
# iter: 1, error: 5809.096
# iter: 2, error: 39.777
# current_time:  4.36
# iter: 1, error: 6270.767
# iter: 2, error: 46.203
# current_time:  4.37
# iter: 1, error: 6708.009
# iter: 2, error: 52.714
# current_time:  4.38
# iter: 1, error: 7119.042
# iter: 2, error: 59.208
# current_time:  4.39
# iter: 1, error: 7502.186
# iter: 2, error: 65.586
# current_time:  4.4
# iter: 1, error: 7855.873
# iter: 2, error: 71.748
# current_time:  4.41
# iter: 1, error: 8178.648
# iter: 2, error: 77.601
# current_time:  4.42
# iter: 1, error: 8469.179
# iter: 2, error: 83.055
# current_time:  4.43
# iter: 1, error: 8726.265
# iter: 2, error: 88.028
# current_time:  4.44
# iter: 1, error: 8948.838
# iter: 2, error: 92.442
# current_time:  4.45
# iter: 1, error: 9135.970
# iter: 2, error: 96.231
# current_time:  4.46
# iter: 1, error: 9286.877
# iter: 2, error: 99.337
# current_time:  4.47
# iter: 1, error: 9400.925
# iter: 2, error: 101.713
# current_time:  4.48
# iter: 1, error: 9477.629
# iter: 2, error: 103.323
# current_time:  4.49
# iter: 1, error: 9516.658
# iter: 2, error: 104.141
# current_time:  4.5
# iter: 1, error: 9517.838
# iter: 2, error: 104.155
# current_time:  4.51
# iter: 1, error: 9481.150
# iter: 2, error: 103.366
# current_time:  4.5200000000000005
# iter: 1, error: 9406.731
# iter: 2, error: 101.784
# current_time:  4.53
# iter: 1, error: 9294.877
# iter: 2, error: 99.433
# current_time:  4.54
# iter: 1, error: 9146.036
# iter: 2, error: 96.351
# current_time:  4.55
# iter: 1, error: 8960.813
# iter: 2, error: 92.582
# current_time:  4.5600000000000005
# iter: 1, error: 8739.959
# iter: 2, error: 88.185
# current_time:  4.57
# iter: 1, error: 8484.376
# iter: 2, error: 83.226
# current_time:  4.58
# iter: 1, error: 8195.108
# iter: 2, error: 77.782
# current_time:  4.59
# iter: 1, error: 7873.336
# iter: 2, error: 71.935
# current_time:  4.6000000000000005
# iter: 1, error: 7520.376
# iter: 2, error: 65.774
# current_time:  4.61
# iter: 1, error: 7137.670
# iter: 2, error: 59.394
# current_time:  4.62
# iter: 1, error: 6726.781
# iter: 2, error: 52.893
# current_time:  4.63
# iter: 1, error: 6289.385
# iter: 2, error: 46.372
# current_time:  4.64
# iter: 1, error: 5827.267
# iter: 2, error: 39.933
# current_time:  4.65
# iter: 1, error: 5342.305
# iter: 2, error: 33.675
# current_time:  4.66
# iter: 1, error: 4836.472
# iter: 2, error: 27.698
# current_time:  4.67
# iter: 1, error: 4311.818
# iter: 2, error: 22.098
# current_time:  4.68
# iter: 1, error: 3770.468
# iter: 2, error: 16.964
# current_time:  4.69
# iter: 1, error: 3214.609
# current_time:  4.7
# iter: 1, error: 2654.318
# current_time:  4.71
# iter: 1, error: 2073.995
# current_time:  4.72
# iter: 1, error: 1486.004
# current_time:  4.73
# iter: 1, error: 893.222
# current_time:  4.74
# iter: 1, error: 298.035
# current_time:  4.75
# iter: 1, error: 297.194
# current_time:  4.76
# iter: 1, error: 890.113
# current_time:  4.7700000000000005
# iter: 1, error: 1478.398
# current_time:  4.78
# iter: 1, error: 2059.750
# current_time:  4.79
# iter: 1, error: 2631.915
# current_time:  4.8
# iter: 1, error: 3192.684
# current_time:  4.8100000000000005
# iter: 1, error: 3739.903
# iter: 2, error: 17.449
# current_time:  4.82
# iter: 1, error: 4281.594
# iter: 2, error: 23.328
# current_time:  4.83
# iter: 1, error: 4798.461
# iter: 2, error: 29.437
# current_time:  4.84
# iter: 1, error: 5295.957
# iter: 2, error: 36.018
# current_time:  4.8500000000000005
# iter: 1, error: 5772.153
# iter: 2, error: 42.970
# current_time:  4.86
# iter: 1, error: 6225.216
# iter: 2, error: 50.185
# current_time:  4.87
# iter: 1, error: 6653.405
# iter: 2, error: 57.551
# current_time:  4.88
# iter: 1, error: 7055.085
# iter: 2, error: 64.950
# current_time:  4.89
# iter: 1, error: 7428.723
# iter: 2, error: 72.261
# current_time:  4.9
# iter: 1, error: 7772.898
# iter: 2, error: 79.367
# current_time:  4.91
# iter: 1, error: 8086.307
# iter: 2, error: 86.150
# current_time:  4.92
# iter: 1, error: 8367.764
# iter: 2, error: 92.498
# current_time:  4.93
# iter: 1, error: 8616.211
# iter: 2, error: 98.306
# current_time:  4.94
# iter: 1, error: 8830.715
# iter: 2, error: 103.475
# current_time:  4.95
# iter: 1, error: 9010.477
# iter: 2, error: 107.920
# current_time:  4.96
# iter: 1, error: 9154.828
# iter: 2, error: 111.565
# current_time:  4.97
# iter: 1, error: 9263.235
# iter: 2, error: 114.348
# current_time:  4.98
# iter: 1, error: 9335.304
# iter: 2, error: 116.222
# current_time:  4.99
# iter: 1, error: 9370.775
# iter: 2, error: 117.156
# current_time:  5.0

# %% [markdown]
# ### Plotting

# %%
t = np.arange(robot.sim_params.total_time, step=robot.sim_params.dt)
options = dismech.AnimationOptions(title=plant_name, plot_step=10)

fig = dismech.get_interactive_animation_plotly(robot, t, qs , options)
fig.show()

# %%
# save gif
ani = dismech.get_animation(robot, t, qs, options)
save_path = os.path.join("tomato_results", f"{plant_name}_{position}.gif")
ani.save(save_path)
# Out:
# 51

# %%
# plot the trajectory of the flower location
flower_node = 143  # pick a node at the flower
# flower_node = main_grip  # pick a node at the flower

import matplotlib.pyplot as plt

# Extract the DOF indices (x, y, z) of the node you want to track
flower_node_dofs = robot.map_node_to_dof(flower_node)  # e.g., [ix, iy, iz]

# Extract position of that node across all timesteps
logged = qs[:, flower_node_dofs].squeeze()  # shape (n_timesteps, 3)

# remove value at t=0
logged -= robot.nodes[flower_node]

# Plot x, y, z over time
t = np.arange(qs.shape[0]) * robot.sim_params.dt

plt.figure(figsize=(10, 4))
plt.plot(t, logged[:, 0], label='x')
plt.plot(t, logged[:, 1], label='y')
plt.plot(t, logged[:, 2], label='z')
plt.xlabel('Time (s)')
plt.ylabel('Position')
plt.title(f'Position of Node {flower_node} Over Time')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
from scipy.signal import hilbert, detrend, find_peaks

def avg_cycle_amplitude_hilbert(x: np.ndarray) -> float:
    """
    Robust average oscillation amplitude using the analytic-signal envelope.
    Returns the median envelope value (less sensitive to outliers).
    """
    x = np.asarray(x).ravel()
    x = detrend(x)  # remove slow drift
    envelope = np.abs(hilbert(x))
    # Use median to resist occasional spikes; mean is also fine.
    return float(np.median(envelope))
# amplitude of flower node motion
amp_x_flower_hilbert = avg_cycle_amplitude_hilbert(logged[:, 0]) # hilbert-based amplitude
amp_x_flower_peak = (np.max(logged[:, 0]) - np.min(logged[:, 0])) / 2.0 # peak-to-peak amplitude
print(f"Amplitude of flower node {flower_node} motion in x (peak-to-peak): {amp_x_flower_peak:.4f} m")
print(f"Amplitude of flower node {flower_node} motion in x (hilbert): {amp_x_flower_hilbert:.4f} m")
# Out:
# Amplitude of flower node 143 motion in x (peak-to-peak): 0.0044 m
# Amplitude of flower node 143 motion in x (hilbert): 0.0044 m

# %% [markdown]
# ### Save data for rendering

# %%
# from dismech.logging import logDataForRendering
# from dismech.logging import export_rod_shell_data, export_parachute_data

# rod_data, shell_data = logDataForRendering(qs, t.reshape(-1, 1), robot, len(t), robot.sim_params.static_sim, robot.map_node_to_dof, log_step=10)

# js_file = os.path.join("tomato_results", f"{plant_name}_{position}.js")

# export_parachute_data(qs, geo.rod_edges, robot,
#                           rod_js=js_file,
#                           scaleFactor=100)

# %% [markdown]
# ### Estimated values of parameters

# %%
# L = 0.292 # m
# r0 = 0.0059 # m

# delta = 0.054 # m # delta = PL^3/(3EI)
# P = 0.02*9.81 # N

# K = P/delta # effective stiffness

# I = np.pi * r0**4 / 4
# E = P*(L**3) / (3 * I * delta)

# print("E:", E)

# f = 1.38 # Hz
# TP = 0.725 # s

# omega = 2 * np.pi * f
# m_eff = K / omega**2
# print("m_eff:", m_eff)

# # estimate density
# V = np.pi * r0**2 * L
# rho = m_eff / V
# print("rho:", rho)
