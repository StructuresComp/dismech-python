# %% [markdown]
# ## Tomato Pollination: Pepper 0

# %%
import numpy as np
import dismech
import os

plant_name = "pepper0"

position = "4"

geom = dismech.GeomParams(
    rod_r0=0.03,
    shell_h=0.0,
)

material = dismech.Material(density=1100,
                            youngs_rod=2.16e7,
                            youngs_shell=0,
                            poisson_rod=0.5,
                            poisson_shell=0)

dyn_sim = dismech.SimParams(static_sim=False,
                                  two_d_sim=True,   # no twisting
                                  use_mid_edge=False,
                                  use_line_search=False,
                                  show_floor=False,
                                  log_data=True,
                                  log_step=1,
                                  dt=1e-2,
                                  max_iter=50,
                                  total_time=5,
                                  plot_step=10,
                                  tol=1e-4,
                                  ftol=1e-4,
                                  dtol=1e-2
                                  )

env = dismech.Environment()
env.add_force('gravity', g=np.array([0.0, 0.0, -9.81]))
env.add_force('damping', eta=100)

input_txt = os.path.join('../tests/resources/tomato_pollination/plants/', f"{plant_name}.txt")
geo = dismech.Geometry.from_txt(input_txt)

robot = dismech.SoftRobot(geom, material, geo, dyn_sim, env)

# %% [markdown]
# ### Move the stem: Moving BC

# %%
# # --- pick the main grip node robustly ---
# grasping_point = np.array([
#       1.1120794,
#       0.0663341,
#       0.3889156
#     ])

main_grip = [83]

print("Main grip node:", main_grip)


other_grip_nodes_below = np.array([69, 71, 76, 77, 79, 81], dtype=int)
other_grip_nodes_above = np.array([94, 91, 87, 84], dtype=int)
# Out:
# Main grip node: [83]

# %%
base_nodes = np.where((robot.state.q[robot.node_dof_indices].reshape(-1, 3)[:, 2]) < 0.22)[0] # fixed base
# Fix only main_grip and base nodes
robot = robot.fix_nodes(np.unique(np.r_[main_grip, base_nodes]))

# %%
# ----- once, before simulation -----
all_grip_nodes = np.r_[main_grip, other_grip_nodes_below, other_grip_nodes_above].astype(int)

xyz0 = robot.state.q[robot.node_dof_indices].reshape(-1, 3).copy()
x0 = xyz0[all_grip_nodes, 0].copy()          # initial x of all prescribed nodes
prev_target_x = x0.copy()                     # last absolute target (starts at initial)

# (Optional) precompute amplitude scalings from *initial* geometry
def build_amps_from_xyz0(xyz0, main_grip, all_grip_nodes, A_main):
    amps = np.empty(all_grip_nodes.size, float)
    amps[0] = A_main  # main_grip
    # below group
    below = np.array(other_grip_nodes_below, dtype=int)
    if below.size:
        ref = below[0]
        L = max(np.linalg.norm(xyz0[main_grip]-xyz0[ref]), 1e-12)
        for j, node in enumerate(below, start=1):  # start=1 because 0 is main_grip
            amps[j] = A_main * (np.linalg.norm(xyz0[ref]-xyz0[node]) / L)
    # above group
    above = np.array(other_grip_nodes_above, dtype=int)
    if above.size:
        ref = above[0]
        offset = 1 + below.size
        L = max(np.linalg.norm(xyz0[main_grip]-xyz0[ref]), 1e-12)
        for j, node in enumerate(above, start=offset):
            amps[j] = A_main * (np.linalg.norm(xyz0[ref]-xyz0[node]) / L)
    return amps

A_main = 0.4094e-2   # m at main_grip
freq   = 1.3    # Hz
amps   = build_amps_from_xyz0(xyz0, main_grip, all_grip_nodes, A_main)

print("Amplitudes (m):", amps)

def shake_distributed(robot, t: float):
    # absolute target centered at initial pose
    target_x = x0 + amps * np.sin(2*np.pi*freq*t)

    # INCREMENT ONLY: avoids velocity spikes and keeps symmetry
    delta_x = target_x - prev_target_x
    prev_target_x[:] = target_x

    return robot.move_nodes(all_grip_nodes, delta_x.reshape(-1,1).flatten(), axis=0)

print("grasping points:", all_grip_nodes)
# Out:
# Amplitudes (m): [0.004094   0.         0.00101301 0.0014326  0.00193975 0.00248134
#  0.00320339 0.         0.00106901 0.00222532 0.00354551]
# grasping points: [83 69 71 76 77 79 81 94 91 87 84]

# %%
stepper = dismech.ImplicitEulerTimeStepper(robot)
stepper.before_step = shake_distributed

# %% [markdown]
# ### Simulate

# %%
# simulate
robots = stepper.simulate()

qs = np.stack([robot.state.q for robot in robots])
# Out:
# iter: 1, error: 5230.029
# iter: 2, error: 62.501
# current_time:  0.01
# iter: 1, error: 5195.476
# iter: 2, error: 105.443
# current_time:  0.02
# iter: 1, error: 5122.550
# iter: 2, error: 152.119
# current_time:  0.03
# iter: 1, error: 5015.343
# iter: 2, error: 162.912
# current_time:  0.04
# iter: 1, error: 4875.074
# iter: 2, error: 134.338
# current_time:  0.05
# iter: 1, error: 4702.587
# iter: 2, error: 87.331
# current_time:  0.06
# iter: 1, error: 4498.973
# iter: 2, error: 53.861
# current_time:  0.07
# iter: 1, error: 4265.626
# iter: 2, error: 42.192
# current_time:  0.08
# iter: 1, error: 4004.171
# iter: 2, error: 36.874
# current_time:  0.09
# iter: 1, error: 3716.411
# iter: 2, error: 31.804
# current_time:  0.1
# iter: 1, error: 3404.310
# iter: 2, error: 26.768
# current_time:  0.11
# iter: 1, error: 3069.978
# iter: 2, error: 21.842
# current_time:  0.12
# iter: 1, error: 2715.660
# iter: 2, error: 17.158
# current_time:  0.13
# iter: 1, error: 2343.726
# iter: 2, error: 12.866
# current_time:  0.14
# iter: 1, error: 1956.649
# iter: 2, error: 9.170
# current_time:  0.15
# iter: 1, error: 1556.993
# iter: 2, error: 6.120
# current_time:  0.16
# iter: 1, error: 1147.394
# iter: 2, error: 3.603
# current_time:  0.17
# iter: 1, error: 730.548
# iter: 2, error: 1.643
# current_time:  0.18
# iter: 1, error: 309.186
# current_time:  0.19
# iter: 1, error: 113.861
# current_time:  0.2
# iter: 1, error: 536.037
# current_time:  0.21
# iter: 1, error: 954.191
# current_time:  0.22
# iter: 1, error: 1365.615
# iter: 2, error: 4.489
# current_time:  0.23
# iter: 1, error: 1769.003
# iter: 2, error: 7.592
# current_time:  0.24
# iter: 1, error: 2159.947
# iter: 2, error: 11.348
# current_time:  0.25
# iter: 1, error: 2536.576
# iter: 2, error: 15.690
# current_time:  0.26
# iter: 1, error: 2896.439
# iter: 2, error: 20.508
# current_time:  0.27
# iter: 1, error: 3237.191
# iter: 2, error: 25.681
# current_time:  0.28
# iter: 1, error: 3556.609
# iter: 2, error: 31.072
# current_time:  0.29
# iter: 1, error: 3852.605
# iter: 2, error: 36.539
# current_time:  0.3
# iter: 1, error: 4123.235
# iter: 2, error: 41.935
# current_time:  0.31
# iter: 1, error: 4366.717
# iter: 2, error: 47.112
# current_time:  0.32
# iter: 1, error: 4581.436
# iter: 2, error: 51.930
# current_time:  0.33
# iter: 1, error: 4765.960
# iter: 2, error: 56.256
# current_time:  0.34
# iter: 1, error: 4919.048
# iter: 2, error: 59.970
# current_time:  0.35000000000000003
# iter: 1, error: 5039.656
# iter: 2, error: 62.971
# current_time:  0.36
# iter: 1, error: 5126.946
# iter: 2, error: 65.174
# current_time:  0.37
# iter: 1, error: 5180.294
# iter: 2, error: 66.519
# current_time:  0.38
# iter: 1, error: 5199.294
# iter: 2, error: 66.969
# current_time:  0.39
# iter: 1, error: 5183.760
# iter: 2, error: 66.509
# current_time:  0.4
# iter: 1, error: 5133.733
# iter: 2, error: 65.154
# current_time:  0.41000000000000003
# iter: 1, error: 5049.479
# iter: 2, error: 62.939
# current_time:  0.42
# iter: 1, error: 4931.490
# iter: 2, error: 59.925
# current_time:  0.43
# iter: 1, error: 4780.483
# iter: 2, error: 56.196
# current_time:  0.44
# iter: 1, error: 4597.395
# iter: 2, error: 51.854
# current_time:  0.45
# iter: 1, error: 4383.384
# iter: 2, error: 47.019
# current_time:  0.46
# iter: 1, error: 4139.816
# iter: 2, error: 41.823
# current_time:  0.47000000000000003
# iter: 1, error: 3868.262
# iter: 2, error: 36.409
# current_time:  0.48
# iter: 1, error: 3570.489
# iter: 2, error: 30.924
# current_time:  0.49
# iter: 1, error: 3248.448
# iter: 2, error: 25.515
# current_time:  0.5
# iter: 1, error: 2904.260
# iter: 2, error: 20.328
# current_time:  0.51
# iter: 1, error: 2540.209
# iter: 2, error: 15.502
# current_time:  0.52
# iter: 1, error: 2158.719
# iter: 2, error: 11.162
# current_time:  0.53
# iter: 1, error: 1762.346
# iter: 2, error: 7.421
# current_time:  0.54
# iter: 1, error: 1353.754
# iter: 2, error: 4.374
# current_time:  0.55
# iter: 1, error: 935.700
# current_time:  0.56
# iter: 1, error: 510.347
# current_time:  0.5700000000000001
# iter: 1, error: 82.386
# current_time:  0.58
# iter: 1, error: 346.696
# current_time:  0.59
# iter: 1, error: 773.958
# current_time:  0.6
# iter: 1, error: 1196.493
# current_time:  0.61
# iter: 1, error: 1611.416
# iter: 2, error: 6.005
# current_time:  0.62
# iter: 1, error: 2013.842
# iter: 2, error: 9.289
# current_time:  0.63
# iter: 1, error: 2403.890
# iter: 2, error: 13.195
# current_time:  0.64
# iter: 1, error: 2777.785
# iter: 2, error: 17.574
# current_time:  0.65
# iter: 1, error: 3132.970
# iter: 2, error: 22.305
# current_time:  0.66
# iter: 1, error: 3467.025
# iter: 2, error: 27.259
# current_time:  0.67
# iter: 1, error: 3777.676
# iter: 2, error: 32.305
# current_time:  0.68
# iter: 1, error: 4062.817
# iter: 2, error: 37.311
# current_time:  0.6900000000000001
# iter: 1, error: 4320.520
# iter: 2, error: 42.146
# current_time:  0.7000000000000001
# iter: 1, error: 4549.055
# iter: 2, error: 46.685
# current_time:  0.71
# iter: 1, error: 4746.894
# iter: 2, error: 50.810
# current_time:  0.72
# iter: 1, error: 4912.728
# iter: 2, error: 54.416
# current_time:  0.73
# iter: 1, error: 5045.470
# iter: 2, error: 57.410
# current_time:  0.74
# iter: 1, error: 5144.267
# iter: 2, error: 59.714
# current_time:  0.75
# iter: 1, error: 5208.501
# iter: 2, error: 61.269
# current_time:  0.76
# iter: 1, error: 5237.791
# iter: 2, error: 62.035
# current_time:  0.77
# iter: 1, error: 5232.001
# iter: 2, error: 61.991
# current_time:  0.78
# iter: 1, error: 5191.230
# iter: 2, error: 61.136
# current_time:  0.79
# iter: 1, error: 5115.818
# iter: 2, error: 59.492
# current_time:  0.8
# iter: 1, error: 5006.335
# iter: 2, error: 57.100
# current_time:  0.81
# iter: 1, error: 4863.582
# iter: 2, error: 54.022
# current_time:  0.8200000000000001
# iter: 1, error: 4688.579
# iter: 2, error: 50.336
# current_time:  0.8300000000000001
# iter: 1, error: 4482.557
# iter: 2, error: 46.140
# current_time:  0.84
# iter: 1, error: 4246.950
# iter: 2, error: 41.541
# current_time:  0.85
# iter: 1, error: 3983.383
# iter: 2, error: 36.661
# current_time:  0.86
# iter: 1, error: 3693.658
# iter: 2, error: 31.628
# current_time:  0.87
# iter: 1, error: 3379.744
# iter: 2, error: 26.574
# current_time:  0.88
# iter: 1, error: 3043.762
# iter: 2, error: 21.633
# current_time:  0.89
# iter: 1, error: 2687.967
# iter: 2, error: 16.938
# current_time:  0.9
# iter: 1, error: 2314.737
# iter: 2, error: 12.613
# current_time:  0.91
# iter: 1, error: 1926.554
# iter: 2, error: 8.777
# current_time:  0.92
# iter: 1, error: 1525.989
# iter: 2, error: 5.535
# current_time:  0.93
# iter: 1, error: 1115.686
# iter: 2, error: 2.978
# current_time:  0.9400000000000001
# iter: 1, error: 698.344
# current_time:  0.9500000000000001
# iter: 1, error: 277.067
# current_time:  0.96
# iter: 1, error: 146.431
# current_time:  0.97
# iter: 1, error: 568.447
# current_time:  0.98
# iter: 1, error: 986.230
# current_time:  0.99
# iter: 1, error: 1397.074
# iter: 2, error: 4.679
# current_time:  1.0
# iter: 1, error: 1799.741
# iter: 2, error: 7.838
# current_time:  1.01
# iter: 1, error: 2189.720
# iter: 2, error: 11.648
# current_time:  1.02
# iter: 1, error: 2565.189
# iter: 2, error: 16.038
# current_time:  1.03
# iter: 1, error: 2923.706
# iter: 2, error: 20.895
# current_time:  1.04
# iter: 1, error: 3262.935
# iter: 2, error: 26.095
# current_time:  1.05
# iter: 1, error: 3580.661
# iter: 2, error: 31.499
# current_time:  1.06
# iter: 1, error: 3874.807
# iter: 2, error: 36.966
# current_time:  1.07
# iter: 1, error: 4143.441
# iter: 2, error: 42.347
# current_time:  1.08
# iter: 1, error: 4384.793
# iter: 2, error: 47.498
# current_time:  1.09
# iter: 1, error: 4597.262
# iter: 2, error: 52.278
# current_time:  1.1
# iter: 1, error: 4779.431
# iter: 2, error: 56.558
# current_time:  1.11
# iter: 1, error: 4930.071
# iter: 2, error: 60.219
# current_time:  1.12
# iter: 1, error: 5048.156
# iter: 2, error: 63.160
# current_time:  1.1300000000000001
# iter: 1, error: 5132.864
# iter: 2, error: 65.299
# current_time:  1.1400000000000001
# iter: 1, error: 5183.586
# iter: 2, error: 66.577
# current_time:  1.1500000000000001
# iter: 1, error: 5199.934
# iter: 2, error: 66.958
# current_time:  1.16
# iter: 1, error: 5181.740
# iter: 2, error: 66.430
# current_time:  1.17
# iter: 1, error: 5129.060
# iter: 2, error: 65.007
# current_time:  1.18
# iter: 1, error: 5042.180
# iter: 2, error: 62.729
# current_time:  1.19
# iter: 1, error: 4921.607
# iter: 2, error: 59.657
# current_time:  1.2
# iter: 1, error: 4768.077
# iter: 2, error: 55.877
# current_time:  1.21
# iter: 1, error: 4582.545
# iter: 2, error: 51.493
# current_time:  1.22
# iter: 1, error: 4366.183
# iter: 2, error: 46.626
# current_time:  1.23
# iter: 1, error: 4120.374
# iter: 2, error: 41.408
# current_time:  1.24
# iter: 1, error: 3846.707
# iter: 2, error: 35.984
# current_time:  1.25
# iter: 1, error: 3546.960
# iter: 2, error: 30.499
# current_time:  1.26
# iter: 1, error: 3223.100
# iter: 2, error: 25.103
# current_time:  1.27
# iter: 1, error: 2877.261
# iter: 2, error: 19.940
# current_time:  1.28
# iter: 1, error: 2511.738
# iter: 2, error: 15.147
# current_time:  1.29
# iter: 1, error: 2128.968
# iter: 2, error: 10.850
# current_time:  1.3
# iter: 1, error: 1731.513
# iter: 2, error: 7.160
# current_time:  1.31
# iter: 1, error: 1322.047
# iter: 2, error: 4.170
# current_time:  1.32
# iter: 1, error: 903.333
# current_time:  1.33
# iter: 1, error: 477.586
# current_time:  1.34
# iter: 1, error: 49.388
# current_time:  1.35
# iter: 1, error: 379.707
# current_time:  1.36
# iter: 1, error: 806.758
# current_time:  1.37
# iter: 1, error: 1228.857
# current_time:  1.3800000000000001
# iter: 1, error: 1643.124
# iter: 2, error: 6.242
# current_time:  1.3900000000000001
# iter: 1, error: 2044.593
# iter: 2, error: 9.569
# current_time:  1.4000000000000001
# iter: 1, error: 2433.536
# iter: 2, error: 13.515
# current_time:  1.41
# iter: 1, error: 2806.123
# iter: 2, error: 17.924
# current_time:  1.42
# iter: 1, error: 3159.809
# iter: 2, error: 22.676
# current_time:  1.43
# iter: 1, error: 3492.180
# iter: 2, error: 27.641
# current_time:  1.44
# iter: 1, error: 3800.977
# iter: 2, error: 32.688
# current_time:  1.45
# iter: 1, error: 4084.107
# iter: 2, error: 37.685
# current_time:  1.46
# iter: 1, error: 4339.656
# iter: 2, error: 42.500
# current_time:  1.47
# iter: 1, error: 4565.908
# iter: 2, error: 47.010
# current_time:  1.48
# iter: 1, error: 4761.352
# iter: 2, error: 51.099
# current_time:  1.49
# iter: 1, error: 4924.696
# iter: 2, error: 54.660
# current_time:  1.5
# iter: 1, error: 5054.870
# iter: 2, error: 57.602
# current_time:  1.51
# iter: 1, error: 5151.040
# iter: 2, error: 59.851
# current_time:  1.52
# iter: 1, error: 5212.604
# iter: 2, error: 61.346
# current_time:  1.53
# iter: 1, error: 5239.202
# iter: 2, error: 62.050
# current_time:  1.54
# iter: 1, error: 5230.714
# iter: 2, error: 61.944
# current_time:  1.55
# iter: 1, error: 5187.260
# iter: 2, error: 61.028
# current_time:  1.56
# iter: 1, error: 5109.195
# iter: 2, error: 59.325
# current_time:  1.57
# iter: 1, error: 4997.110
# iter: 2, error: 56.879
# current_time:  1.58
# iter: 1, error: 4851.822
# iter: 2, error: 53.751
# current_time:  1.59
# iter: 1, error: 4674.366
# iter: 2, error: 50.024
# current_time:  1.6
# iter: 1, error: 4465.991
# iter: 2, error: 45.793
# current_time:  1.61
# iter: 1, error: 4228.146
# iter: 2, error: 41.169
# current_time:  1.62
# iter: 1, error: 3962.469
# iter: 2, error: 36.273
# current_time:  1.6300000000000001
# iter: 1, error: 3670.778
# iter: 2, error: 31.234
# current_time:  1.6400000000000001
# iter: 1, error: 3355.053
# iter: 2, error: 26.185
# current_time:  1.6500000000000001
# iter: 1, error: 3017.425
# iter: 2, error: 21.259
# current_time:  1.6600000000000001
# iter: 1, error: 2660.161
# iter: 2, error: 16.588
# current_time:  1.67
# iter: 1, error: 2285.647
# iter: 2, error: 12.298
# current_time:  1.68
# iter: 1, error: 1896.373
# iter: 2, error: 8.504
# current_time:  1.69
# iter: 1, error: 1494.917
# iter: 2, error: 5.312
# current_time:  1.7
# iter: 1, error: 1083.927
# current_time:  1.71
# iter: 1, error: 666.995
# current_time:  1.72
# iter: 1, error: 244.542
# current_time:  1.73
# iter: 1, error: 179.003
# current_time:  1.74
# iter: 1, error: 600.841
# current_time:  1.75
# iter: 1, error: 1018.235
# current_time:  1.76
# iter: 1, error: 1428.483
# iter: 2, error: 4.890
# current_time:  1.77
# iter: 1, error: 1830.416
# iter: 2, error: 8.107
# current_time:  1.78
# iter: 1, error: 2219.413
# iter: 2, error: 11.965
# current_time:  1.79
# iter: 1, error: 2593.709
# iter: 2, error: 16.394
# current_time:  1.8
# iter: 1, error: 2950.866
# iter: 2, error: 21.282
# current_time:  1.81
# iter: 1, error: 3288.557
# iter: 2, error: 26.502
# current_time:  1.82
# iter: 1, error: 3604.578
# iter: 2, error: 31.917
# current_time:  1.83
# iter: 1, error: 3896.862
# iter: 2, error: 37.381
# current_time:  1.84
# iter: 1, error: 4163.490
# iter: 2, error: 42.749
# current_time:  1.85
# iter: 1, error: 4402.702
# iter: 2, error: 47.876
# current_time:  1.86
# iter: 1, error: 4612.912
# iter: 2, error: 52.622
# current_time:  1.87
# iter: 1, error: 4792.717
# iter: 2, error: 56.857
# current_time:  1.8800000000000001
# iter: 1, error: 4940.904
# iter: 2, error: 60.466
# current_time:  1.8900000000000001
# iter: 1, error: 5056.460
# iter: 2, error: 63.348
# current_time:  1.9000000000000001
# iter: 1, error: 5138.581
# iter: 2, error: 65.422
# current_time:  1.9100000000000001
# iter: 1, error: 5186.675
# iter: 2, error: 66.632
# current_time:  1.92
# iter: 1, error: 5200.369
# iter: 2, error: 66.943
# current_time:  1.93
# iter: 1, error: 5179.514
# iter: 2, error: 66.345
# current_time:  1.94
# iter: 1, error: 5124.183
# iter: 2, error: 64.855
# current_time:  1.95
# iter: 1, error: 5034.678
# iter: 2, error: 62.513
# current_time:  1.96
# iter: 1, error: 4911.526
# iter: 2, error: 59.384
# current_time:  1.97
# iter: 1, error: 4755.479
# iter: 2, error: 55.554
# current_time:  1.98
# iter: 1, error: 4567.508
# iter: 2, error: 51.129
# current_time:  1.99
# iter: 1, error: 4348.803
# iter: 2, error: 46.230
# current_time:  2.0
# iter: 1, error: 4100.763
# iter: 2, error: 40.992
# current_time:  2.0100000000000002
# iter: 1, error: 3824.991
# iter: 2, error: 35.558
# current_time:  2.02
# iter: 1, error: 3523.282
# iter: 2, error: 30.075
# current_time:  2.0300000000000002
# iter: 1, error: 3197.615
# iter: 2, error: 24.693
# current_time:  2.04
# iter: 1, error: 2850.139
# iter: 2, error: 19.554
# current_time:  2.05
# iter: 1, error: 2483.159
# iter: 2, error: 14.795
# current_time:  2.06
# iter: 1, error: 2099.122
# iter: 2, error: 10.542
# current_time:  2.07
# iter: 1, error: 1700.601
# iter: 2, error: 6.903
# current_time:  2.08
# iter: 1, error: 1290.278
# current_time:  2.09
# iter: 1, error: 869.660
# current_time:  2.1
# iter: 1, error: 444.819
# current_time:  2.11
# iter: 1, error: 16.381
# current_time:  2.12
# iter: 1, error: 412.714
# current_time:  2.13
# iter: 1, error: 839.535
# current_time:  2.14
# iter: 1, error: 1261.182
# current_time:  2.15
# iter: 1, error: 1674.775
# iter: 2, error: 6.483
# current_time:  2.16
# iter: 1, error: 2075.269
# iter: 2, error: 9.853
# current_time:  2.17
# iter: 1, error: 2463.091
# iter: 2, error: 13.837
# current_time:  2.18
# iter: 1, error: 2834.356
# iter: 2, error: 18.276
# current_time:  2.19
# iter: 1, error: 3186.527
# iter: 2, error: 23.048
# current_time:  2.2
# iter: 1, error: 3517.201
# iter: 2, error: 28.023
# current_time:  2.21
# iter: 1, error: 3824.132
# iter: 2, error: 33.071
# current_time:  2.22
# iter: 1, error: 4105.238
# iter: 2, error: 38.057
# current_time:  2.23
# iter: 1, error: 4358.622
# iter: 2, error: 42.853
# current_time:  2.24
# iter: 1, error: 4582.581
# iter: 2, error: 47.334
# current_time:  2.25
# iter: 1, error: 4775.623
# iter: 2, error: 51.384
# current_time:  2.2600000000000002
# iter: 1, error: 4936.469
# iter: 2, error: 54.900
# current_time:  2.27
# iter: 1, error: 5064.071
# iter: 2, error: 57.791
# current_time:  2.2800000000000002
# iter: 1, error: 5157.608
# iter: 2, error: 59.983
# current_time:  2.29
# iter: 1, error: 5216.500
# iter: 2, error: 61.419
# current_time:  2.3000000000000003
# iter: 1, error: 5240.405
# iter: 2, error: 62.061
# current_time:  2.31
# iter: 1, error: 5229.220
# iter: 2, error: 61.892
# current_time:  2.32
# iter: 1, error: 5183.083
# iter: 2, error: 60.914
# current_time:  2.33
# iter: 1, error: 5102.369
# iter: 2, error: 59.153
# current_time:  2.34
# iter: 1, error: 4987.686
# iter: 2, error: 56.653
# current_time:  2.35
# iter: 1, error: 4839.867
# iter: 2, error: 53.477
# current_time:  2.36
# iter: 1, error: 4659.966
# iter: 2, error: 49.708
# current_time:  2.37
# iter: 1, error: 4449.246
# iter: 2, error: 45.444
# current_time:  2.38
# iter: 1, error: 4209.172
# iter: 2, error: 40.795
# current_time:  2.39
# iter: 1, error: 3941.397
# iter: 2, error: 35.885
# current_time:  2.4
# iter: 1, error: 3647.750
# iter: 2, error: 30.841
# current_time:  2.41
# iter: 1, error: 3330.226
# iter: 2, error: 25.797
# current_time:  2.42
# iter: 1, error: 2990.966
# iter: 2, error: 20.887
# current_time:  2.43
# iter: 1, error: 2632.246
# iter: 2, error: 16.242
# current_time:  2.44
# iter: 1, error: 2256.463
# iter: 2, error: 11.986
# current_time:  2.45
# iter: 1, error: 1866.113
# iter: 2, error: 8.235
# current_time:  2.46
# iter: 1, error: 1463.781
# iter: 2, error: 5.094
# current_time:  2.47
# iter: 1, error: 1052.120
# current_time:  2.48
# iter: 1, error: 634.674
# current_time:  2.49
# iter: 1, error: 211.989
# current_time:  2.5
# iter: 1, error: 211.573
# current_time:  2.5100000000000002
# iter: 1, error: 633.216
# current_time:  2.52
# iter: 1, error: 1050.205
# current_time:  2.5300000000000002
# iter: 1, error: 1459.843
# iter: 2, error: 5.106
# current_time:  2.54
# iter: 1, error: 1861.025
# iter: 2, error: 8.380
# current_time:  2.5500000000000003
# iter: 1, error: 2249.026
# iter: 2, error: 12.286
# current_time:  2.56
# iter: 1, error: 2622.133
# iter: 2, error: 16.754
# current_time:  2.57
# iter: 1, error: 2977.916
# iter: 2, error: 21.672
# current_time:  2.58
# iter: 1, error: 3314.056
# iter: 2, error: 26.911
# current_time:  2.59
# iter: 1, error: 3628.360
# iter: 2, error: 32.334
# current_time:  2.6
# iter: 1, error: 3918.771
# iter: 2, error: 37.796
# current_time:  2.61
# iter: 1, error: 4183.380
# iter: 2, error: 43.150
# current_time:  2.62
# iter: 1, error: 4420.443
# iter: 2, error: 48.252
# current_time:  2.63
# iter: 1, error: 4628.386
# iter: 2, error: 52.962
# current_time:  2.64
# iter: 1, error: 4805.819
# iter: 2, error: 57.153
# current_time:  2.65
# iter: 1, error: 4951.545
# iter: 2, error: 60.709
# current_time:  2.66
# iter: 1, error: 5064.568
# iter: 2, error: 63.531
# current_time:  2.67
# iter: 1, error: 5144.098
# iter: 2, error: 65.541
# current_time:  2.68
# iter: 1, error: 5189.560
# iter: 2, error: 66.682
# current_time:  2.69
# iter: 1, error: 5200.599
# iter: 2, error: 66.923
# current_time:  2.7
# iter: 1, error: 5177.083
# iter: 2, error: 66.255
# current_time:  2.71
# iter: 1, error: 5119.102
# iter: 2, error: 64.698
# current_time:  2.72
# iter: 1, error: 5026.975
# iter: 2, error: 62.293
# current_time:  2.73
# iter: 1, error: 4901.248
# iter: 2, error: 59.107
# current_time:  2.74
# iter: 1, error: 4742.688
# iter: 2, error: 55.227
# current_time:  2.75
# iter: 1, error: 4552.285
# iter: 2, error: 50.761
# current_time:  2.7600000000000002
# iter: 1, error: 4331.244
# iter: 2, error: 45.832
# current_time:  2.77
# iter: 1, error: 4080.982
# iter: 2, error: 40.574
# current_time:  2.7800000000000002
# iter: 1, error: 3803.116
# iter: 2, error: 35.131
# current_time:  2.79
# iter: 1, error: 3499.457
# iter: 2, error: 29.652
# current_time:  2.8000000000000003
# iter: 1, error: 3171.995
# iter: 2, error: 24.284
# current_time:  2.81
# iter: 1, error: 2822.895
# iter: 2, error: 19.170
# current_time:  2.82
# iter: 1, error: 2454.471
# iter: 2, error: 14.447
# current_time:  2.83
# iter: 1, error: 2069.183
# iter: 2, error: 10.237
# current_time:  2.84
# iter: 1, error: 1669.613
# iter: 2, error: 6.650
# current_time:  2.85
# iter: 1, error: 1258.448
# current_time:  2.86
# iter: 1, error: 837.266
# current_time:  2.87
# iter: 1, error: 411.997
# current_time:  2.88
# iter: 1, error: 16.654
# current_time:  2.89
# iter: 1, error: 445.715
# current_time:  2.9
# iter: 1, error: 872.289
# current_time:  2.91
# iter: 1, error: 1293.466
# current_time:  2.92
# iter: 1, error: 1706.369
# iter: 2, error: 6.727
# current_time:  2.93
# iter: 1, error: 2105.870
# iter: 2, error: 10.140
# current_time:  2.94
# iter: 1, error: 2492.555
# iter: 2, error: 14.161
# current_time:  2.95
# iter: 1, error: 2862.482
# iter: 2, error: 18.630
# current_time:  2.96
# iter: 1, error: 3213.123
# iter: 2, error: 23.422
# current_time:  2.97
# iter: 1, error: 3542.087
# iter: 2, error: 28.406
# current_time:  2.98
# iter: 1, error: 3847.138
# iter: 2, error: 33.452
# current_time:  2.99
# iter: 1, error: 4126.209
# iter: 2, error: 38.428
# current_time:  3.0
# iter: 1, error: 4377.417
# iter: 2, error: 43.203
# current_time:  3.0100000000000002
# iter: 1, error: 4599.075
# iter: 2, error: 47.654
# current_time:  3.02
# iter: 1, error: 4789.705
# iter: 2, error: 51.666
# current_time:  3.0300000000000002
# iter: 1, error: 4948.049
# iter: 2, error: 55.136
# current_time:  3.04
# iter: 1, error: 5073.071
# iter: 2, error: 57.975
# current_time:  3.0500000000000003
# iter: 1, error: 5163.973
# iter: 2, error: 60.111
# current_time:  3.06
# iter: 1, error: 5220.190
# iter: 2, error: 61.486
# current_time:  3.0700000000000003
# iter: 1, error: 5241.400
# iter: 2, error: 62.066
# current_time:  3.08
# iter: 1, error: 5227.518
# iter: 2, error: 61.835
# current_time:  3.09
# iter: 1, error: 5178.701
# iter: 2, error: 60.797
# current_time:  3.1
# iter: 1, error: 5095.341
# iter: 2, error: 58.978
# current_time:  3.11
# iter: 1, error: 4978.063
# iter: 2, error: 56.423
# current_time:  3.12
# iter: 1, error: 4827.720
# iter: 2, error: 53.199
# current_time:  3.13
# iter: 1, error: 4645.380
# iter: 2, error: 49.389
# current_time:  3.14
# iter: 1, error: 4432.323
# iter: 2, error: 45.092
# current_time:  3.15
# iter: 1, error: 4190.029
# iter: 2, error: 40.420
# current_time:  3.16
# iter: 1, error: 3920.166
# iter: 2, error: 35.495
# current_time:  3.17
# iter: 1, error: 3624.575
# iter: 2, error: 30.448
# current_time:  3.18
# iter: 1, error: 3305.264
# iter: 2, error: 25.410
# current_time:  3.19
# iter: 1, error: 2964.384
# iter: 2, error: 20.516
# current_time:  3.2
# iter: 1, error: 2604.223
# iter: 2, error: 15.897
# current_time:  3.21
# iter: 1, error: 2227.185
# iter: 2, error: 11.677
# current_time:  3.22
# iter: 1, error: 1835.774
# iter: 2, error: 7.970
# current_time:  3.23
# iter: 1, error: 1432.582
# iter: 2, error: 4.880
# current_time:  3.24
# iter: 1, error: 1020.267
# current_time:  3.25
# iter: 1, error: 602.324
# current_time:  3.2600000000000002
# iter: 1, error: 179.423
# current_time:  3.27
# iter: 1, error: 244.139
# current_time:  3.2800000000000002
# iter: 1, error: 665.571
# current_time:  3.29
# iter: 1, error: 1082.140
# current_time:  3.3000000000000003
# iter: 1, error: 1491.150
# iter: 2, error: 5.326
# current_time:  3.31
# iter: 1, error: 1891.569
# iter: 2, error: 8.657
# current_time:  3.3200000000000003
# iter: 1, error: 2278.558
# iter: 2, error: 12.609
# current_time:  3.33
# iter: 1, error: 2650.461
# iter: 2, error: 17.116
# current_time:  3.34
# iter: 1, error: 3004.855
# iter: 2, error: 22.063
# current_time:  3.35
# iter: 1, error: 3339.432
# iter: 2, error: 27.321
# current_time:  3.36
# iter: 1, error: 3652.006
# iter: 2, error: 32.751
# current_time:  3.37
# iter: 1, error: 3940.531
# iter: 2, error: 38.210
# current_time:  3.38
# iter: 1, error: 4203.112
# iter: 2, error: 43.549
# current_time:  3.39
# iter: 1, error: 4438.015
# iter: 2, error: 48.625
# current_time:  3.4
# iter: 1, error: 4643.682
# iter: 2, error: 53.300
# current_time:  3.41
# iter: 1, error: 4818.736
# iter: 2, error: 57.445
# current_time:  3.42
# iter: 1, error: 4961.995
# iter: 2, error: 60.947
# current_time:  3.43
# iter: 1, error: 5072.478
# iter: 2, error: 63.709
# current_time:  3.44
# iter: 1, error: 5149.413
# iter: 2, error: 65.653
# current_time:  3.45
# iter: 1, error: 5192.242
# iter: 2, error: 66.726
# current_time:  3.46
# iter: 1, error: 5200.624
# iter: 2, error: 66.897
# current_time:  3.47
# iter: 1, error: 5174.446
# iter: 2, error: 66.160
# current_time:  3.48
# iter: 1, error: 5113.816
# iter: 2, error: 64.535
# current_time:  3.49
# iter: 1, error: 5019.071
# iter: 2, error: 62.068
# current_time:  3.5
# iter: 1, error: 4890.772
# iter: 2, error: 58.825
# current_time:  3.5100000000000002
# iter: 1, error: 4729.705
# iter: 2, error: 54.897
# current_time:  3.52
# iter: 1, error: 4536.876
# iter: 2, error: 50.391
# current_time:  3.5300000000000002
# iter: 1, error: 4313.508
# iter: 2, error: 45.432
# current_time:  3.54
# iter: 1, error: 4061.033
# iter: 2, error: 40.155
# current_time:  3.5500000000000003
# iter: 1, error: 3781.083
# iter: 2, error: 34.705
# current_time:  3.56
# iter: 1, error: 3475.484
# iter: 2, error: 29.230
# current_time:  3.5700000000000003
# iter: 1, error: 3146.241
# iter: 2, error: 23.876
# current_time:  3.58
# iter: 1, error: 2795.529
# iter: 2, error: 18.789
# current_time:  3.59
# iter: 1, error: 2425.677
# iter: 2, error: 14.101
# current_time:  3.6
# iter: 1, error: 2039.153
# iter: 2, error: 9.936
# current_time:  3.61
# iter: 1, error: 1638.548
# iter: 2, error: 6.402
# current_time:  3.62
# iter: 1, error: 1226.559
# current_time:  3.63
# iter: 1, error: 804.827
# current_time:  3.64
# iter: 1, error: 379.149
# current_time:  3.65
# iter: 1, error: 49.683
# current_time:  3.66
# iter: 1, error: 478.708
# current_time:  3.67
# iter: 1, error: 905.019
# current_time:  3.68
# iter: 1, error: 1325.709
# current_time:  3.69
# iter: 1, error: 1737.904
# iter: 2, error: 6.976
# current_time:  3.7
# iter: 1, error: 2136.394
# iter: 2, error: 10.430
# current_time:  3.71
# iter: 1, error: 2521.927
# iter: 2, error: 14.489
# current_time:  3.72
# iter: 1, error: 2890.501
# iter: 2, error: 18.986
# current_time:  3.73
# iter: 1, error: 3239.597
# iter: 2, error: 23.796
# current_time:  3.74
# iter: 1, error: 3566.837
# iter: 2, error: 28.789
# current_time:  3.75
# iter: 1, error: 3869.996
# iter: 2, error: 33.834
# current_time:  3.7600000000000002
# iter: 1, error: 4147.021
# iter: 2, error: 38.797
# current_time:  3.77
# iter: 1, error: 4396.042
# iter: 2, error: 43.551
# current_time:  3.7800000000000002
# iter: 1, error: 4615.389
# iter: 2, error: 47.971
# current_time:  3.79
# iter: 1, error: 4803.600
# iter: 2, error: 51.945
# current_time:  3.8000000000000003
# iter: 1, error: 4959.433
# iter: 2, error: 55.369
# current_time:  3.81
# iter: 1, error: 5081.871
# iter: 2, error: 58.156
# current_time:  3.8200000000000003
# iter: 1, error: 5170.133
# iter: 2, error: 60.234
# current_time:  3.83
# iter: 1, error: 5223.674
# iter: 2, error: 61.549
# current_time:  3.84
# iter: 1, error: 5242.187
# iter: 2, error: 62.067
# current_time:  3.85
# iter: 1, error: 5225.608
# iter: 2, error: 61.773
# current_time:  3.86
# iter: 1, error: 5174.112
# iter: 2, error: 60.674
# current_time:  3.87
# iter: 1, error: 5088.109
# iter: 2, error: 58.797
# current_time:  3.88
# iter: 1, error: 4968.242
# iter: 2, error: 56.190
# current_time:  3.89
# iter: 1, error: 4815.380
# iter: 2, error: 52.919
# current_time:  3.9
# iter: 1, error: 4630.608
# iter: 2, error: 49.068
# current_time:  3.91
# iter: 1, error: 4415.223
# iter: 2, error: 44.739
# current_time:  3.92
# iter: 1, error: 4170.719
# iter: 2, error: 40.044
# current_time:  3.93
# iter: 1, error: 3898.777
# iter: 2, error: 35.105
# current_time:  3.94
# iter: 1, error: 3601.254
# iter: 2, error: 30.054
# current_time:  3.95
# iter: 1, error: 3280.168
# iter: 2, error: 25.024
# current_time:  3.96
# iter: 1, error: 2937.682
# iter: 2, error: 20.147
# current_time:  3.97
# iter: 1, error: 2576.094
# iter: 2, error: 15.555
# current_time:  3.98
# iter: 1, error: 2197.815
# iter: 2, error: 11.371
# current_time:  3.99
# iter: 1, error: 1805.359
# iter: 2, error: 7.709
# current_time:  4.0
# iter: 1, error: 1401.322
# iter: 2, error: 4.670
# current_time:  4.01
# iter: 1, error: 988.367
# current_time:  4.0200000000000005
# iter: 1, error: 569.946
# current_time:  4.03
# iter: 1, error: 146.846
# current_time:  4.04
# iter: 1, error: 276.701
# current_time:  4.05
# iter: 1, error: 697.906
# current_time:  4.0600000000000005
# iter: 1, error: 1114.037
# current_time:  4.07
# iter: 1, error: 1522.404
# iter: 2, error: 5.550
# current_time:  4.08
# iter: 1, error: 1922.045
# iter: 2, error: 8.937
# current_time:  4.09
# iter: 1, error: 2308.008
# iter: 2, error: 12.936
# current_time:  4.1
# iter: 1, error: 2678.692
# iter: 2, error: 17.481
# current_time:  4.11
# iter: 1, error: 3031.684
# iter: 2, error: 22.456
# current_time:  4.12
# iter: 1, error: 3364.683
# iter: 2, error: 27.732
# current_time:  4.13
# iter: 1, error: 3675.514
# iter: 2, error: 33.169
# current_time:  4.14
# iter: 1, error: 3962.142
# iter: 2, error: 38.623
# current_time:  4.15
# iter: 1, error: 4222.684
# iter: 2, error: 43.946
# current_time:  4.16
# iter: 1, error: 4455.418
# iter: 2, error: 48.996
# current_time:  4.17
# iter: 1, error: 4658.799
# iter: 2, error: 53.634
# current_time:  4.18
# iter: 1, error: 4831.466
# iter: 2, error: 57.734
# current_time:  4.19
# iter: 1, error: 4972.252
# iter: 2, error: 61.181
# current_time:  4.2
# iter: 1, error: 5080.192
# iter: 2, error: 63.882
# current_time:  4.21
# iter: 1, error: 5154.528
# iter: 2, error: 65.761
# current_time:  4.22
# iter: 1, error: 5194.719
# iter: 2, error: 66.765
# current_time:  4.23
# iter: 1, error: 5200.444
# iter: 2, error: 66.866
# current_time:  4.24
# iter: 1, error: 5171.604
# iter: 2, error: 66.059
# current_time:  4.25
# iter: 1, error: 5108.327
# iter: 2, error: 64.368
# current_time:  4.26
# iter: 1, error: 5010.965
# iter: 2, error: 61.838
# current_time:  4.2700000000000005
# iter: 1, error: 4880.099
# iter: 2, error: 58.540
# current_time:  4.28
# iter: 1, error: 4716.530
# iter: 2, error: 54.563
# current_time:  4.29
# iter: 1, error: 4521.283
# iter: 2, error: 50.018
# current_time:  4.3
# iter: 1, error: 4295.595
# iter: 2, error: 45.030
# current_time:  4.3100000000000005
# iter: 1, error: 4040.916
# iter: 2, error: 39.736
# current_time:  4.32
# iter: 1, error: 3758.893
# iter: 2, error: 34.279
# current_time:  4.33
# iter: 1, error: 3451.366
# iter: 2, error: 28.808
# current_time:  4.34
# iter: 1, error: 3120.354
# iter: 2, error: 23.471
# current_time:  4.3500000000000005
# iter: 1, error: 2768.044
# iter: 2, error: 18.410
# current_time:  4.36
# iter: 1, error: 2396.778
# iter: 2, error: 13.759
# current_time:  4.37
# iter: 1, error: 2009.033
# iter: 2, error: 9.640
# current_time:  4.38
# iter: 1, error: 1607.409
# iter: 2, error: 6.158
# current_time:  4.39
# iter: 1, error: 1194.611
# current_time:  4.4
# iter: 1, error: 772.346
# current_time:  4.41
# iter: 1, error: 346.275
# current_time:  4.42
# iter: 1, error: 82.724
# current_time:  4.43
# iter: 1, error: 511.693
# current_time:  4.44
# iter: 1, error: 937.723
# current_time:  4.45
# iter: 1, error: 1357.909
# current_time:  4.46
# iter: 1, error: 1769.379
# iter: 2, error: 7.229
# current_time:  4.47
# iter: 1, error: 2166.841
# iter: 2, error: 10.723
# current_time:  4.48
# iter: 1, error: 2551.204
# iter: 2, error: 14.819
# current_time:  4.49
# iter: 1, error: 2918.410
# iter: 2, error: 19.344
# current_time:  4.5
# iter: 1, error: 3265.947
# iter: 2, error: 24.171
# current_time:  4.51
# iter: 1, error: 3591.449
# iter: 2, error: 29.173
# current_time:  4.5200000000000005
# iter: 1, error: 3892.704
# iter: 2, error: 34.215
# current_time:  4.53
# iter: 1, error: 4167.670
# iter: 2, error: 39.166
# current_time:  4.54
# iter: 1, error: 4414.495
# iter: 2, error: 43.897
# current_time:  4.55
# iter: 1, error: 4631.522
# iter: 2, error: 48.286
# current_time:  4.5600000000000005
# iter: 1, error: 4817.306
# iter: 2, error: 52.220
# current_time:  4.57
# iter: 1, error: 4970.622
# iter: 2, error: 55.597
# current_time:  4.58
# iter: 1, error: 5090.471
# iter: 2, error: 58.331
# current_time:  4.59
# iter: 1, error: 5176.089
# iter: 2, error: 60.352
# current_time:  4.6000000000000005
# iter: 1, error: 5226.950
# iter: 2, error: 61.607
# current_time:  4.61
# iter: 1, error: 5242.766
# iter: 2, error: 62.063
# current_time:  4.62
# iter: 1, error: 5223.491
# iter: 2, error: 61.707
# current_time:  4.63
# iter: 1, error: 5169.318
# iter: 2, error: 60.548
# current_time:  4.64
# iter: 1, error: 5080.675
# iter: 2, error: 58.613
# current_time:  4.65
# iter: 1, error: 4958.223
# iter: 2, error: 55.953
# current_time:  4.66
# iter: 1, error: 4802.847
# iter: 2, error: 52.634
# current_time:  4.67
# iter: 1, error: 4615.651
# iter: 2, error: 48.744
# current_time:  4.68
# iter: 1, error: 4397.946
# iter: 2, error: 44.383
# current_time:  4.69
# iter: 1, error: 4151.241
# iter: 2, error: 39.666
# current_time:  4.7
# iter: 1, error: 3877.232
# iter: 2, error: 34.715
# current_time:  4.71
# iter: 1, error: 3577.788
# iter: 2, error: 29.662
# current_time:  4.72
# iter: 1, error: 3254.939
# iter: 2, error: 24.639
# current_time:  4.73
# iter: 1, error: 2910.861
# iter: 2, error: 19.780
# current_time:  4.74
# iter: 1, error: 2547.859
# iter: 2, error: 15.216
# current_time:  4.75
# iter: 1, error: 2168.354
# iter: 2, error: 11.068
# current_time:  4.76
# iter: 1, error: 1774.867
# iter: 2, error: 7.451
# current_time:  4.7700000000000005
# iter: 1, error: 1370.001
# iter: 2, error: 4.464
# current_time:  4.78
# iter: 1, error: 956.423
# current_time:  4.79
# iter: 1, error: 537.541
# current_time:  4.8
# iter: 1, error: 114.259
# current_time:  4.8100000000000005
# iter: 1, error: 309.256
# current_time:  4.82
# iter: 1, error: 730.217
# current_time:  4.83
# iter: 1, error: 1145.896
# current_time:  4.84
# iter: 1, error: 1553.604
# iter: 2, error: 5.778
# current_time:  4.8500000000000005
# iter: 1, error: 1952.452
# iter: 2, error: 9.221
# current_time:  4.86
# iter: 1, error: 2337.373
# iter: 2, error: 13.267
# current_time:  4.87
# iter: 1, error: 2706.824
# iter: 2, error: 17.848
# current_time:  4.88
# iter: 1, error: 3058.400
# iter: 2, error: 22.851
# current_time:  4.89
# iter: 1, error: 3389.808
# iter: 2, error: 28.143
# current_time:  4.9
# iter: 1, error: 3698.885
# iter: 2, error: 33.587
# current_time:  4.91
# iter: 1, error: 3983.604
# iter: 2, error: 39.035
# current_time:  4.92
# iter: 1, error: 4242.095
# iter: 2, error: 44.342
# current_time:  4.93
# iter: 1, error: 4472.650
# iter: 2, error: 49.365
# current_time:  4.94
# iter: 1, error: 4673.738
# iter: 2, error: 53.965
# current_time:  4.95
# iter: 1, error: 4844.011
# iter: 2, error: 58.018
# current_time:  4.96
# iter: 1, error: 4982.317
# iter: 2, error: 61.411
# current_time:  4.97
# iter: 1, error: 5087.707
# iter: 2, error: 64.051
# current_time:  4.98
# iter: 1, error: 5159.440
# iter: 2, error: 65.864
# current_time:  4.99
# iter: 1, error: 5196.992
# iter: 2, error: 66.798
# current_time:  5.0

# %% [markdown]
# ### Plotting

# %%
t = np.arange(robot.sim_params.total_time, step=robot.sim_params.dt)
options = dismech.AnimationOptions(title=plant_name, plot_step=robot.sim_params.plot_step)

fig = dismech.get_interactive_animation_plotly(robot, t, qs , options)
fig.show()

# %%
# # save gif
# ani = dismech.get_animation(robot, t, qs, options)
# save_path = os.path.join("tomato_results", f"{plant_name}_{position}.gif")
# ani.save(save_path)

# %%
# plot the trajectory of the flower location
flower_node = 143  # pick a node at the flower
# flower_node = main_grip  # pick a node at the flower

import matplotlib.pyplot as plt

# Extract the DOF indices (x, y, z) of the node you want to track
flower_node_dofs = robot.map_node_to_dof(flower_node)  # e.g., [ix, iy, iz]

# Extract position of that node across all timesteps
logged = qs[:, flower_node_dofs].squeeze()  # shape (n_timesteps, 3)

# remove value at t=0
logged -= robot.nodes[flower_node]

# Plot x, y, z over time
t = np.arange(qs.shape[0]) * robot.sim_params.dt

plt.figure(figsize=(10, 4))
plt.plot(t, logged[:, 0], label='x')
plt.plot(t, logged[:, 1], label='y')
plt.plot(t, logged[:, 2], label='z')
plt.xlabel('Time (s)')
plt.ylabel('Position')
plt.title(f'Position of Node {flower_node} Over Time')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
from scipy.signal import hilbert, detrend, find_peaks

def avg_cycle_amplitude_hilbert(x: np.ndarray) -> float:
    """
    Robust average oscillation amplitude using the analytic-signal envelope.
    Returns the median envelope value (less sensitive to outliers).
    """
    x = np.asarray(x).ravel()
    x = detrend(x)  # remove slow drift
    envelope = np.abs(hilbert(x))
    # Use median to resist occasional spikes; mean is also fine.
    return float(np.median(envelope))
# amplitude of flower node motion
amp_x_flower_hilbert = avg_cycle_amplitude_hilbert(logged[:, 0]) # hilbert-based amplitude
amp_x_flower_peak = (np.max(logged[:, 0]) - np.min(logged[:, 0])) / 2.0 # peak-to-peak amplitude
print(f"Amplitude of flower node {flower_node} motion in x (peak-to-peak): {amp_x_flower_peak:.4f} m")
print(f"Amplitude of flower node {flower_node} motion in x (hilbert): {amp_x_flower_hilbert:.4f} m")
# Out:
# Amplitude of flower node 143 motion in x (peak-to-peak): 0.0045 m
# Amplitude of flower node 143 motion in x (hilbert): 0.0045 m

# %% [markdown]
# ### Save data for rendering

# %%
# from dismech.logging import logDataForRendering
# from dismech.logging import export_rod_shell_data, export_parachute_data

# rod_data, shell_data = logDataForRendering(qs, t.reshape(-1, 1), robot, len(t), robot.sim_params.static_sim, robot.map_node_to_dof, log_step=1)

# js_file = os.path.join("tomato_results", f"{plant_name}_{position}.js")

# export_parachute_data(qs, geo.rod_edges, robot,
#                           rod_js=js_file,
#                           scaleFactor=100)

# %% [markdown]
# ### Estimated values of parameters

# %%
# L = 0.292 # m
# r0 = 0.0059 # m

# delta = 0.054 # m # delta = PL^3/(3EI)
# P = 0.02*9.81 # N

# K = P/delta # effective stiffness

# I = np.pi * r0**4 / 4
# E = P*(L**3) / (3 * I * delta)

# print("E:", E)

# f = 1.38 # Hz
# TP = 0.725 # s

# omega = 2 * np.pi * f
# m_eff = K / omega**2
# print("m_eff:", m_eff)

# # estimate density
# V = np.pi * r0**2 * L
# rho = m_eff / V
# print("rho:", rho)
