# %% [markdown]
# ## Tomato Pollination: Pepper 0

# %%
import numpy as np
import dismech
import os

plant_name = "pepper0"

position = "5"

geom = dismech.GeomParams(
    rod_r0=0.03,
    shell_h=0.0,
)

material = dismech.Material(density=1100,
                            youngs_rod=2.16e7,
                            youngs_shell=0,
                            poisson_rod=0.5,
                            poisson_shell=0)

dyn_sim = dismech.SimParams(static_sim=False,
                                  two_d_sim=True,   # no twisting
                                  use_mid_edge=False,
                                  use_line_search=False,
                                  show_floor=False,
                                  log_data=True,
                                  log_step=1,
                                  dt=1e-2,
                                  max_iter=50,
                                  total_time=5,
                                  plot_step=10,
                                  tol=1e-4,
                                  ftol=1e-4,
                                  dtol=1e-2
                                  )

env = dismech.Environment()
env.add_force('gravity', g=np.array([0.0, 0.0, -9.81]))
env.add_force('damping', eta=100)

input_txt = os.path.join('../tests/resources/tomato_pollination/plants/', f"{plant_name}.txt")
geo = dismech.Geometry.from_txt(input_txt)

robot = dismech.SoftRobot(geom, material, geo, dyn_sim, env)

# %% [markdown]
# ### Move the stem: Moving BC

# %%
# # --- pick the main grip node robustly ---
# grasping_point = np.array([
#       1.1120794,
#       0.0663341,
#       0.3889156
#     ])

main_grip = [108]

print("Main grip node:", main_grip)


other_grip_nodes_below = np.array([87, 91, 94, 99], dtype=int)
other_grip_nodes_above = np.array([130, 125, 123, 121], dtype=int)
# Out:
# Main grip node: [108]

# %%
base_nodes = np.where((robot.state.q[robot.node_dof_indices].reshape(-1, 3)[:, 2]) < 0.22)[0] # fixed base
# Fix only main_grip and base nodes
robot = robot.fix_nodes(np.unique(np.r_[main_grip, base_nodes]))

# %%
# ----- once, before simulation -----
all_grip_nodes = np.r_[main_grip, other_grip_nodes_below, other_grip_nodes_above].astype(int)

xyz0 = robot.state.q[robot.node_dof_indices].reshape(-1, 3).copy()
x0 = xyz0[all_grip_nodes, 0].copy()          # initial x of all prescribed nodes
prev_target_x = x0.copy()                     # last absolute target (starts at initial)

# (Optional) precompute amplitude scalings from *initial* geometry
def build_amps_from_xyz0(xyz0, main_grip, all_grip_nodes, A_main):
    amps = np.empty(all_grip_nodes.size, float)
    amps[0] = A_main  # main_grip
    # below group
    below = np.array(other_grip_nodes_below, dtype=int)
    if below.size:
        ref = below[0]
        L = max(np.linalg.norm(xyz0[main_grip]-xyz0[ref]), 1e-12)
        for j, node in enumerate(below, start=1):  # start=1 because 0 is main_grip
            amps[j] = A_main * (np.linalg.norm(xyz0[ref]-xyz0[node]) / L)
    # above group
    above = np.array(other_grip_nodes_above, dtype=int)
    if above.size:
        ref = above[0]
        offset = 1 + below.size
        L = max(np.linalg.norm(xyz0[main_grip]-xyz0[ref]), 1e-12)
        for j, node in enumerate(above, start=offset):
            amps[j] = A_main * (np.linalg.norm(xyz0[ref]-xyz0[node]) / L)
    return amps

A_main = 0.4094e-2   # m at main_grip
freq   = 1.3    # Hz
amps   = build_amps_from_xyz0(xyz0, main_grip, all_grip_nodes, A_main)

print("Amplitudes (m):", amps)

def shake_distributed(robot, t: float):
    # absolute target centered at initial pose
    target_x = x0 + amps * np.sin(2*np.pi*freq*t)

    # INCREMENT ONLY: avoids velocity spikes and keeps symmetry
    delta_x = target_x - prev_target_x
    prev_target_x[:] = target_x

    return robot.move_nodes(all_grip_nodes, delta_x.reshape(-1,1).flatten(), axis=0)

print("grasping points:", all_grip_nodes)
# Out:
# Amplitudes (m): [0.004094   0.         0.00196669 0.0028949  0.00359068 0.
#  0.00110743 0.00156614 0.00212057]
# grasping points: [108  87  91  94  99 130 125 123 121]

# %%
stepper = dismech.ImplicitEulerTimeStepper(robot)
stepper.before_step = shake_distributed

# %% [markdown]
# ### Simulate

# %%
# simulate
robots = stepper.simulate()

qs = np.stack([robot.state.q for robot in robots])
# Out:
# iter: 1, error: 25204.503
# iter: 2, error: 393.984
# current_time:  0.01
# iter: 1, error: 25037.051
# iter: 2, error: 395.926
# current_time:  0.02
# iter: 1, error: 24702.336
# iter: 2, error: 396.688
# current_time:  0.03
# iter: 1, error: 24204.455
# iter: 2, error: 381.755
# current_time:  0.04
# iter: 1, error: 23545.608
# iter: 2, error: 350.810
# current_time:  0.05
# iter: 1, error: 22729.902
# iter: 2, error: 315.138
# current_time:  0.06
# iter: 1, error: 21762.729
# iter: 2, error: 282.449
# current_time:  0.07
# iter: 1, error: 20650.460
# iter: 2, error: 250.991
# current_time:  0.08
# iter: 1, error: 19400.391
# iter: 2, error: 218.798
# current_time:  0.09
# iter: 1, error: 18020.735
# iter: 2, error: 186.339
# current_time:  0.1
# iter: 1, error: 16520.583
# iter: 2, error: 154.517
# current_time:  0.11
# iter: 1, error: 14909.837
# iter: 2, error: 124.151
# current_time:  0.12
# iter: 1, error: 13199.150
# iter: 2, error: 95.997
# current_time:  0.13
# iter: 1, error: 11399.852
# iter: 2, error: 70.689
# current_time:  0.14
# iter: 1, error: 9523.877
# iter: 2, error: 48.749
# current_time:  0.15
# iter: 1, error: 7583.690
# iter: 2, error: 30.596
# current_time:  0.16
# iter: 1, error: 5592.198
# iter: 2, error: 16.516
# current_time:  0.17
# iter: 1, error: 3562.667
# iter: 2, error: 6.694
# current_time:  0.18
# iter: 1, error: 1508.632
# current_time:  0.19
# iter: 1, error: 556.433
# current_time:  0.2
# iter: 1, error: 2618.050
# current_time:  0.21
# iter: 1, error: 4663.723
# current_time:  0.22
# iter: 1, error: 6679.993
# current_time:  0.23
# iter: 1, error: 8653.731
# iter: 2, error: 38.637
# current_time:  0.24
# iter: 1, error: 10561.326
# iter: 2, error: 58.296
# current_time:  0.25
# iter: 1, error: 12404.525
# iter: 2, error: 81.018
# current_time:  0.26
# iter: 1, error: 14165.293
# iter: 2, error: 106.526
# current_time:  0.27
# iter: 1, error: 15831.772
# iter: 2, error: 134.273
# current_time:  0.28
# iter: 1, error: 17392.760
# iter: 2, error: 163.604
# current_time:  0.29
# iter: 1, error: 18837.764
# iter: 2, error: 193.776
# current_time:  0.3
# iter: 1, error: 20157.071
# iter: 2, error: 223.974
# current_time:  0.31
# iter: 1, error: 21341.820
# iter: 2, error: 253.337
# current_time:  0.32
# iter: 1, error: 22384.056
# iter: 2, error: 280.986
# current_time:  0.33
# iter: 1, error: 23276.792
# iter: 2, error: 306.056
# current_time:  0.34
# iter: 1, error: 24014.050
# iter: 2, error: 327.738
# current_time:  0.35000000000000003
# iter: 1, error: 24590.901
# iter: 2, error: 345.310
# current_time:  0.36
# iter: 1, error: 25003.498
# iter: 2, error: 358.178
# current_time:  0.37
# iter: 1, error: 25249.096
# iter: 2, error: 365.901
# current_time:  0.38
# iter: 1, error: 25326.074
# iter: 2, error: 368.216
# current_time:  0.39
# iter: 1, error: 25233.939
# iter: 2, error: 365.049
# current_time:  0.4
# iter: 1, error: 24973.328
# iter: 2, error: 356.519
# current_time:  0.41000000000000003
# iter: 1, error: 24546.009
# iter: 2, error: 342.934
# current_time:  0.42
# iter: 1, error: 23954.863
# iter: 2, error: 324.767
# current_time:  0.43
# iter: 1, error: 23203.867
# iter: 2, error: 302.639
# current_time:  0.44
# iter: 1, error: 22298.071
# iter: 2, error: 277.282
# current_time:  0.45
# iter: 1, error: 21243.562
# iter: 2, error: 249.508
# current_time:  0.46
# iter: 1, error: 20047.429
# iter: 2, error: 220.170
# current_time:  0.47000000000000003
# iter: 1, error: 18717.712
# iter: 2, error: 190.127
# current_time:  0.48
# iter: 1, error: 17263.347
# iter: 2, error: 160.215
# current_time:  0.49
# iter: 1, error: 15694.114
# iter: 2, error: 131.218
# current_time:  0.5
# iter: 1, error: 14020.559
# iter: 2, error: 103.850
# current_time:  0.51
# iter: 1, error: 12253.929
# iter: 2, error: 78.741
# current_time:  0.52
# iter: 1, error: 10406.091
# iter: 2, error: 56.436
# current_time:  0.53
# iter: 1, error: 8489.448
# iter: 2, error: 37.387
# current_time:  0.54
# iter: 1, error: 6516.855
# current_time:  0.55
# iter: 1, error: 4504.760
# current_time:  0.56
# iter: 1, error: 2460.218
# current_time:  0.5700000000000001
# iter: 1, error: 397.738
# current_time:  0.58
# iter: 1, error: 1665.118
# current_time:  0.59
# iter: 1, error: 3714.968
# current_time:  0.6
# iter: 1, error: 5738.595
# current_time:  0.61
# iter: 1, error: 7722.973
# iter: 2, error: 31.362
# current_time:  0.62
# iter: 1, error: 9658.288
# iter: 2, error: 50.471
# current_time:  0.63
# iter: 1, error: 11526.421
# iter: 2, error: 72.773
# current_time:  0.64
# iter: 1, error: 13317.134
# iter: 2, error: 98.408
# current_time:  0.65
# iter: 1, error: 15018.558
# iter: 2, error: 126.839
# current_time:  0.66
# iter: 1, error: 16619.448
# iter: 2, error: 157.410
# current_time:  0.67
# iter: 1, error: 18109.232
# iter: 2, error: 189.363
# current_time:  0.68
# iter: 1, error: 19478.082
# iter: 2, error: 221.847
# current_time:  0.6900000000000001
# iter: 1, error: 20716.981
# iter: 2, error: 253.946
# current_time:  0.7000000000000001
# iter: 1, error: 21817.775
# iter: 2, error: 284.705
# current_time:  0.71
# iter: 1, error: 22773.229
# iter: 2, error: 313.171
# current_time:  0.72
# iter: 1, error: 23577.068
# iter: 2, error: 338.427
# current_time:  0.73
# iter: 1, error: 24224.020
# iter: 2, error: 359.634
# current_time:  0.74
# iter: 1, error: 24709.843
# iter: 2, error: 376.071
# current_time:  0.75
# iter: 1, error: 25031.351
# iter: 2, error: 387.169
# current_time:  0.76
# iter: 1, error: 25186.435
# iter: 2, error: 392.540
# current_time:  0.77
# iter: 1, error: 25174.073
# iter: 2, error: 391.995
# current_time:  0.78
# iter: 1, error: 24994.334
# iter: 2, error: 385.555
# current_time:  0.79
# iter: 1, error: 24648.381
# iter: 2, error: 373.448
# current_time:  0.8
# iter: 1, error: 24138.462
# iter: 2, error: 356.101
# current_time:  0.81
# iter: 1, error: 23467.899
# iter: 2, error: 334.115
# current_time:  0.8200000000000001
# iter: 1, error: 22641.069
# iter: 2, error: 308.235
# current_time:  0.8300000000000001
# iter: 1, error: 21663.378
# iter: 2, error: 279.319
# current_time:  0.84
# iter: 1, error: 20541.230
# iter: 2, error: 248.291
# current_time:  0.85
# iter: 1, error: 19281.993
# iter: 2, error: 216.107
# current_time:  0.86
# iter: 1, error: 17893.947
# iter: 2, error: 183.714
# current_time:  0.87
# iter: 1, error: 16386.239
# iter: 2, error: 152.012
# current_time:  0.88
# iter: 1, error: 14768.824
# iter: 2, error: 121.830
# current_time:  0.89
# iter: 1, error: 13052.399
# iter: 2, error: 93.903
# current_time:  0.9
# iter: 1, error: 11248.334
# iter: 2, error: 68.856
# current_time:  0.91
# iter: 1, error: 9368.602
# iter: 2, error: 47.201
# current_time:  0.92
# iter: 1, error: 7425.691
# iter: 2, error: 29.337
# current_time:  0.93
# iter: 1, error: 5432.530
# current_time:  0.9400000000000001
# iter: 1, error: 3399.222
# current_time:  0.9500000000000001
# iter: 1, error: 1348.511
# current_time:  0.96
# iter: 1, error: 714.504
# current_time:  0.97
# iter: 1, error: 2773.735
# current_time:  0.98
# iter: 1, error: 4815.836
# current_time:  0.99
# iter: 1, error: 6827.543
# iter: 2, error: 24.108
# current_time:  1.0
# iter: 1, error: 8789.749
# iter: 2, error: 40.256
# current_time:  1.01
# iter: 1, error: 10696.425
# iter: 2, error: 59.977
# current_time:  1.02
# iter: 1, error: 12532.131
# iter: 2, error: 82.930
# current_time:  1.03
# iter: 1, error: 14284.526
# iter: 2, error: 108.644
# current_time:  1.04
# iter: 1, error: 15941.832
# iter: 2, error: 136.551
# current_time:  1.05
# iter: 1, error: 17492.908
# iter: 2, error: 165.984
# current_time:  1.06
# iter: 1, error: 18927.326
# iter: 2, error: 196.194
# current_time:  1.07
# iter: 1, error: 20235.445
# iter: 2, error: 226.362
# current_time:  1.08
# iter: 1, error: 21408.479
# iter: 2, error: 255.626
# current_time:  1.09
# iter: 1, error: 22438.553
# iter: 2, error: 283.105
# current_time:  1.1
# iter: 1, error: 23318.761
# iter: 2, error: 307.939
# current_time:  1.11
# iter: 1, error: 24043.210
# iter: 2, error: 329.325
# current_time:  1.12
# iter: 1, error: 24607.057
# iter: 2, error: 346.550
# current_time:  1.1300000000000001
# iter: 1, error: 25006.543
# iter: 2, error: 359.032
# current_time:  1.1400000000000001
# iter: 1, error: 25239.011
# iter: 2, error: 366.344
# current_time:  1.1500000000000001
# iter: 1, error: 25302.926
# iter: 2, error: 368.237
# current_time:  1.16
# iter: 1, error: 25197.884
# iter: 2, error: 364.653
# current_time:  1.17
# iter: 1, error: 24924.610
# iter: 2, error: 355.725
# current_time:  1.18
# iter: 1, error: 24484.953
# iter: 2, error: 341.772
# current_time:  1.19
# iter: 1, error: 23881.879
# iter: 2, error: 323.282
# current_time:  1.2
# iter: 1, error: 23119.444
# iter: 2, error: 300.883
# current_time:  1.21
# iter: 1, error: 22202.776
# iter: 2, error: 275.314
# current_time:  1.22
# iter: 1, error: 21138.036
# iter: 2, error: 247.390
# current_time:  1.23
# iter: 1, error: 19932.379
# iter: 2, error: 217.965
# current_time:  1.24
# iter: 1, error: 18593.910
# iter: 2, error: 187.898
# current_time:  1.25
# iter: 1, error: 17131.627
# iter: 2, error: 158.022
# current_time:  1.26
# iter: 1, error: 15555.359
# iter: 2, error: 129.115
# current_time:  1.27
# iter: 1, error: 13875.702
# iter: 2, error: 101.888
# current_time:  1.28
# iter: 1, error: 12103.943
# iter: 2, error: 76.964
# current_time:  1.29
# iter: 1, error: 10251.982
# iter: 2, error: 54.881
# current_time:  1.3
# iter: 1, error: 8332.251
# iter: 2, error: 36.089
# current_time:  1.31
# iter: 1, error: 6357.623
# current_time:  1.32
# iter: 1, error: 4344.410
# current_time:  1.33
# iter: 1, error: 2299.871
# current_time:  1.34
# iter: 1, error: 238.694
# current_time:  1.35
# iter: 1, error: 1821.838
# current_time:  1.36
# iter: 1, error: 3868.350
# current_time:  1.37
# iter: 1, error: 5887.654
# current_time:  1.3800000000000001
# iter: 1, error: 7866.750
# iter: 2, error: 32.606
# current_time:  1.3900000000000001
# iter: 1, error: 9795.907
# iter: 2, error: 52.051
# current_time:  1.4000000000000001
# iter: 1, error: 11656.892
# iter: 2, error: 74.613
# current_time:  1.41
# iter: 1, error: 13439.595
# iter: 2, error: 100.466
# current_time:  1.42
# iter: 1, error: 15132.201
# iter: 2, error: 129.061
# current_time:  1.43
# iter: 1, error: 16723.524
# iter: 2, error: 159.735
# current_time:  1.44
# iter: 1, error: 18203.055
# iter: 2, error: 191.721
# current_time:  1.45
# iter: 1, error: 19561.037
# iter: 2, error: 224.166
# current_time:  1.46
# iter: 1, error: 20788.523
# iter: 2, error: 256.150
# current_time:  1.47
# iter: 1, error: 21877.435
# iter: 2, error: 286.720
# current_time:  1.48
# iter: 1, error: 22820.618
# iter: 2, error: 314.924
# current_time:  1.49
# iter: 1, error: 23611.877
# iter: 2, error: 339.853
# current_time:  1.5
# iter: 1, error: 24246.022
# iter: 2, error: 360.679
# current_time:  1.51
# iter: 1, error: 24718.896
# iter: 2, error: 376.694
# current_time:  1.52
# iter: 1, error: 25027.397
# iter: 2, error: 387.342
# current_time:  1.53
# iter: 1, error: 25169.501
# iter: 2, error: 392.252
# current_time:  1.54
# iter: 1, error: 25144.270
# iter: 2, error: 391.251
# current_time:  1.55
# iter: 1, error: 24951.859
# iter: 2, error: 384.376
# current_time:  1.56
# iter: 1, error: 24593.511
# iter: 2, error: 371.870
# current_time:  1.57
# iter: 1, error: 24071.557
# iter: 2, error: 354.174
# current_time:  1.58
# iter: 1, error: 23389.398
# iter: 2, error: 331.898
# current_time:  1.59
# iter: 1, error: 22551.486
# iter: 2, error: 305.798
# current_time:  1.6
# iter: 1, error: 21563.301
# iter: 2, error: 276.732
# current_time:  1.61
# iter: 1, error: 20431.319
# iter: 2, error: 245.629
# current_time:  1.62
# iter: 1, error: 19162.970
# iter: 2, error: 213.442
# current_time:  1.6300000000000001
# iter: 1, error: 17766.599
# iter: 2, error: 181.113
# current_time:  1.6400000000000001
# iter: 1, error: 16251.407
# iter: 2, error: 149.536
# current_time:  1.6500000000000001
# iter: 1, error: 14627.401
# iter: 2, error: 119.534
# current_time:  1.6600000000000001
# iter: 1, error: 12905.323
# iter: 2, error: 91.831
# current_time:  1.67
# iter: 1, error: 11096.582
# iter: 2, error: 67.046
# current_time:  1.68
# iter: 1, error: 9213.182
# iter: 2, error: 45.681
# current_time:  1.69
# iter: 1, error: 7267.640
# iter: 2, error: 28.128
# current_time:  1.7
# iter: 1, error: 5272.901
# current_time:  1.71
# iter: 1, error: 3239.269
# current_time:  1.72
# iter: 1, error: 1188.949
# current_time:  1.73
# iter: 1, error: 872.448
# current_time:  1.74
# iter: 1, error: 2929.037
# current_time:  1.75
# iter: 1, error: 4967.485
# current_time:  1.76
# iter: 1, error: 6974.550
# iter: 2, error: 25.213
# current_time:  1.77
# iter: 1, error: 8930.836
# iter: 2, error: 41.671
# current_time:  1.78
# iter: 1, error: 10830.837
# iter: 2, error: 61.668
# current_time:  1.79
# iter: 1, error: 12658.966
# iter: 2, error: 84.864
# current_time:  1.8
# iter: 1, error: 14402.930
# iter: 2, error: 110.781
# current_time:  1.81
# iter: 1, error: 16051.009
# iter: 2, error: 138.841
# current_time:  1.82
# iter: 1, error: 17592.122
# iter: 2, error: 168.371
# current_time:  1.83
# iter: 1, error: 19015.910
# iter: 2, error: 198.614
# current_time:  1.84
# iter: 1, error: 20312.804
# iter: 2, error: 228.748
# current_time:  1.85
# iter: 1, error: 21474.091
# iter: 2, error: 257.907
# current_time:  1.86
# iter: 1, error: 22491.979
# iter: 2, error: 285.212
# current_time:  1.87
# iter: 1, error: 23359.643
# iter: 2, error: 309.806
# current_time:  1.8800000000000001
# iter: 1, error: 24071.274
# iter: 2, error: 330.891
# current_time:  1.8900000000000001
# iter: 1, error: 24622.116
# iter: 2, error: 347.767
# current_time:  1.9000000000000001
# iter: 1, error: 25008.497
# iter: 2, error: 359.861
# current_time:  1.9100000000000001
# iter: 1, error: 25227.847
# iter: 2, error: 366.760
# current_time:  1.92
# iter: 1, error: 25278.721
# iter: 2, error: 368.231
# current_time:  1.93
# iter: 1, error: 25160.799
# iter: 2, error: 364.230
# current_time:  1.94
# iter: 1, error: 24874.895
# iter: 2, error: 354.906
# current_time:  1.95
# iter: 1, error: 24422.942
# iter: 2, error: 340.589
# current_time:  1.96
# iter: 1, error: 23807.987
# iter: 2, error: 321.779
# current_time:  1.97
# iter: 1, error: 23034.168
# iter: 2, error: 299.113
# current_time:  1.98
# iter: 1, error: 22106.687
# iter: 2, error: 273.335
# current_time:  1.99
# iter: 1, error: 21031.779
# iter: 2, error: 245.266
# current_time:  2.0
# iter: 1, error: 19816.667
# iter: 2, error: 215.759
# current_time:  2.0100000000000002
# iter: 1, error: 18469.521
# iter: 2, error: 185.672
# current_time:  2.02
# iter: 1, error: 16999.396
# iter: 2, error: 155.835
# current_time:  2.0300000000000002
# iter: 1, error: 15416.175
# iter: 2, error: 127.023
# current_time:  2.04
# iter: 1, error: 13730.500
# iter: 2, error: 99.939
# current_time:  2.05
# iter: 1, error: 11953.698
# iter: 2, error: 75.202
# current_time:  2.06
# iter: 1, error: 10097.703
# iter: 2, error: 53.345
# current_time:  2.07
# iter: 1, error: 8174.971
# iter: 2, error: 34.810
# current_time:  2.08
# iter: 1, error: 6198.397
# current_time:  2.09
# iter: 1, error: 4184.160
# current_time:  2.1
# iter: 1, error: 2139.720
# current_time:  2.11
# iter: 1, error: 79.947
# current_time:  2.12
# iter: 1, error: 1978.194
# current_time:  2.13
# iter: 1, error: 4021.289
# current_time:  2.14
# iter: 1, error: 6036.191
# current_time:  2.15
# iter: 1, error: 8009.933
# iter: 2, error: 33.873
# current_time:  2.16
# iter: 1, error: 9932.857
# iter: 2, error: 53.651
# current_time:  2.17
# iter: 1, error: 11786.627
# iter: 2, error: 76.472
# current_time:  2.18
# iter: 1, error: 13561.257
# iter: 2, error: 102.538
# current_time:  2.19
# iter: 1, error: 15244.989
# iter: 2, error: 131.293
# current_time:  2.2
# iter: 1, error: 16826.693
# iter: 2, error: 162.064
# current_time:  2.21
# iter: 1, error: 18295.926
# iter: 2, error: 194.079
# current_time:  2.22
# iter: 1, error: 19643.000
# iter: 2, error: 226.479
# current_time:  2.23
# iter: 1, error: 20859.041
# iter: 2, error: 258.342
# current_time:  2.24
# iter: 1, error: 21936.046
# iter: 2, error: 288.716
# current_time:  2.25
# iter: 1, error: 22866.939
# iter: 2, error: 316.654
# current_time:  2.2600000000000002
# iter: 1, error: 23645.606
# iter: 2, error: 341.253
# current_time:  2.27
# iter: 1, error: 24266.940
# iter: 2, error: 361.695
# current_time:  2.2800000000000002
# iter: 1, error: 24726.866
# iter: 2, error: 377.285
# current_time:  2.29
# iter: 1, error: 25022.370
# iter: 2, error: 387.483
# current_time:  2.3000000000000003
# iter: 1, error: 25151.511
# iter: 2, error: 391.932
# current_time:  2.31
# iter: 1, error: 25113.435
# iter: 2, error: 390.477
# current_time:  2.32
# iter: 1, error: 24908.381
# iter: 2, error: 383.170
# current_time:  2.33
# iter: 1, error: 24537.676
# iter: 2, error: 370.270
# current_time:  2.34
# iter: 1, error: 24003.730
# iter: 2, error: 352.229
# current_time:  2.35
# iter: 1, error: 23310.022
# iter: 2, error: 329.670
# current_time:  2.36
# iter: 1, error: 22461.084
# iter: 2, error: 303.353
# current_time:  2.37
# iter: 1, error: 21462.466
# iter: 2, error: 274.144
# current_time:  2.38
# iter: 1, error: 20320.713
# iter: 2, error: 242.971
# current_time:  2.39
# iter: 1, error: 19043.324
# iter: 2, error: 210.785
# current_time:  2.4
# iter: 1, error: 17638.701
# iter: 2, error: 178.524
# current_time:  2.41
# iter: 1, error: 16116.104
# iter: 2, error: 147.077
# current_time:  2.42
# iter: 1, error: 14485.588
# iter: 2, error: 117.257
# current_time:  2.43
# iter: 1, error: 12757.941
# iter: 2, error: 89.782
# current_time:  2.44
# iter: 1, error: 10944.610
# iter: 2, error: 65.259
# current_time:  2.45
# iter: 1, error: 9057.631
# iter: 2, error: 44.185
# current_time:  2.46
# iter: 1, error: 7109.546
# iter: 2, error: 26.944
# current_time:  2.47
# iter: 1, error: 5113.318
# current_time:  2.48
# iter: 1, error: 3079.445
# current_time:  2.49
# iter: 1, error: 1029.610
# current_time:  2.5
# iter: 1, error: 1030.084
# current_time:  2.5100000000000002
# iter: 1, error: 3083.948
# current_time:  2.52
# iter: 1, error: 5118.663
# current_time:  2.5300000000000002
# iter: 1, error: 7121.008
# iter: 2, error: 26.341
# current_time:  2.54
# iter: 1, error: 9071.292
# iter: 2, error: 43.110
# current_time:  2.5500000000000003
# iter: 1, error: 10964.548
# iter: 2, error: 63.381
# current_time:  2.56
# iter: 1, error: 12785.032
# iter: 2, error: 86.817
# current_time:  2.57
# iter: 1, error: 14520.504
# iter: 2, error: 112.934
# current_time:  2.58
# iter: 1, error: 16159.299
# iter: 2, error: 141.143
# current_time:  2.59
# iter: 1, error: 17690.401
# iter: 2, error: 170.766
# current_time:  2.6
# iter: 1, error: 19103.515
# iter: 2, error: 201.038
# current_time:  2.61
# iter: 1, error: 20389.146
# iter: 2, error: 231.132
# current_time:  2.62
# iter: 1, error: 21538.659
# iter: 2, error: 260.181
# current_time:  2.63
# iter: 1, error: 22544.338
# iter: 2, error: 287.306
# current_time:  2.64
# iter: 1, error: 23399.442
# iter: 2, error: 311.655
# current_time:  2.65
# iter: 1, error: 24098.248
# iter: 2, error: 332.436
# current_time:  2.66
# iter: 1, error: 24636.084
# iter: 2, error: 348.959
# current_time:  2.67
# iter: 1, error: 25009.365
# iter: 2, error: 360.663
# current_time:  2.68
# iter: 1, error: 25215.612
# iter: 2, error: 367.149
# current_time:  2.69
# iter: 1, error: 25253.464
# iter: 2, error: 368.198
# current_time:  2.7
# iter: 1, error: 25122.692
# iter: 2, error: 363.782
# current_time:  2.71
# iter: 1, error: 24824.192
# iter: 2, error: 354.062
# current_time:  2.72
# iter: 1, error: 24359.984
# iter: 2, error: 339.385
# current_time:  2.73
# iter: 1, error: 23733.197
# iter: 2, error: 320.258
# current_time:  2.74
# iter: 1, error: 22948.046
# iter: 2, error: 297.328
# current_time:  2.75
# iter: 1, error: 22009.812
# iter: 2, error: 271.347
# current_time:  2.7600000000000002
# iter: 1, error: 20924.800
# iter: 2, error: 243.136
# current_time:  2.77
# iter: 1, error: 19700.304
# iter: 2, error: 213.551
# current_time:  2.7800000000000002
# iter: 1, error: 18344.555
# iter: 2, error: 183.449
# current_time:  2.79
# iter: 1, error: 16866.666
# iter: 2, error: 153.655
# current_time:  2.8000000000000003
# iter: 1, error: 15276.573
# iter: 2, error: 124.940
# current_time:  2.81
# iter: 1, error: 13584.964
# iter: 2, error: 98.003
# current_time:  2.82
# iter: 1, error: 11803.205
# iter: 2, error: 73.457
# current_time:  2.83
# iter: 1, error: 9943.263
# iter: 2, error: 51.828
# current_time:  2.84
# iter: 1, error: 8017.620
# iter: 2, error: 33.553
# current_time:  2.85
# iter: 1, error: 6039.189
# current_time:  2.86
# iter: 1, error: 4024.019
# current_time:  2.87
# iter: 1, error: 1979.774
# current_time:  2.88
# iter: 1, error: 78.590
# current_time:  2.89
# iter: 1, error: 2134.180
# current_time:  2.9
# iter: 1, error: 4173.778
# current_time:  2.91
# iter: 1, error: 6184.203
# current_time:  2.92
# iter: 1, error: 8152.515
# iter: 2, error: 35.162
# current_time:  2.93
# iter: 1, error: 10069.136
# iter: 2, error: 55.273
# current_time:  2.94
# iter: 1, error: 11915.623
# iter: 2, error: 78.349
# current_time:  2.95
# iter: 1, error: 13682.120
# iter: 2, error: 104.625
# current_time:  2.96
# iter: 1, error: 15356.919
# iter: 2, error: 133.534
# current_time:  2.97
# iter: 1, error: 16928.954
# iter: 2, error: 164.398
# current_time:  2.98
# iter: 1, error: 18387.846
# iter: 2, error: 196.436
# current_time:  2.99
# iter: 1, error: 19723.973
# iter: 2, error: 228.785
# current_time:  3.0
# iter: 1, error: 20928.537
# iter: 2, error: 260.522
# current_time:  3.0100000000000002
# iter: 1, error: 21993.610
# iter: 2, error: 290.695
# current_time:  3.02
# iter: 1, error: 22912.195
# iter: 2, error: 318.361
# current_time:  3.0300000000000002
# iter: 1, error: 23678.259
# iter: 2, error: 342.626
# current_time:  3.04
# iter: 1, error: 24286.777
# iter: 2, error: 362.682
# current_time:  3.0500000000000003
# iter: 1, error: 24733.760
# iter: 2, error: 377.846
# current_time:  3.06
# iter: 1, error: 25016.277
# iter: 2, error: 387.593
# current_time:  3.0700000000000003
# iter: 1, error: 25132.471
# iter: 2, error: 391.582
# current_time:  3.08
# iter: 1, error: 25081.575
# iter: 2, error: 389.674
# current_time:  3.09
# iter: 1, error: 24863.908
# iter: 2, error: 381.938
# current_time:  3.1
# iter: 1, error: 24480.882
# iter: 2, error: 368.648
# current_time:  3.11
# iter: 1, error: 23934.987
# iter: 2, error: 350.268
# current_time:  3.12
# iter: 1, error: 23229.782
# iter: 2, error: 327.430
# current_time:  3.13
# iter: 1, error: 22369.871
# iter: 2, error: 300.903
# current_time:  3.14
# iter: 1, error: 21360.881
# iter: 2, error: 271.555
# current_time:  3.15
# iter: 1, error: 20209.424
# iter: 2, error: 240.317
# current_time:  3.16
# iter: 1, error: 18923.064
# iter: 2, error: 208.137
# current_time:  3.17
# iter: 1, error: 17510.264
# iter: 2, error: 175.949
# current_time:  3.18
# iter: 1, error: 15980.339
# iter: 2, error: 144.635
# current_time:  3.19
# iter: 1, error: 14343.395
# iter: 2, error: 115.000
# current_time:  3.2
# iter: 1, error: 12610.262
# iter: 2, error: 87.754
# current_time:  3.21
# iter: 1, error: 10792.428
# iter: 2, error: 63.496
# current_time:  3.22
# iter: 1, error: 8901.958
# iter: 2, error: 42.714
# current_time:  3.23
# iter: 1, error: 6951.418
# iter: 2, error: 25.786
# current_time:  3.24
# iter: 1, error: 4953.790
# current_time:  3.25
# iter: 1, error: 2919.758
# current_time:  3.2600000000000002
# iter: 1, error: 870.504
# current_time:  3.27
# iter: 1, error: 1187.406
# current_time:  3.2800000000000002
# iter: 1, error: 3238.462
# current_time:  3.29
# iter: 1, error: 5269.365
# current_time:  3.3000000000000003
# iter: 1, error: 7266.914
# iter: 2, error: 27.493
# current_time:  3.31
# iter: 1, error: 9211.112
# iter: 2, error: 44.572
# current_time:  3.3200000000000003
# iter: 1, error: 11097.552
# iter: 2, error: 65.115
# current_time:  3.33
# iter: 1, error: 12910.327
# iter: 2, error: 88.790
# current_time:  3.34
# iter: 1, error: 14637.246
# iter: 2, error: 115.102
# current_time:  3.35
# iter: 1, error: 16266.703
# iter: 2, error: 143.458
# current_time:  3.36
# iter: 1, error: 17787.743
# iter: 2, error: 173.168
# current_time:  3.37
# iter: 1, error: 19190.142
# iter: 2, error: 203.464
# current_time:  3.38
# iter: 1, error: 20464.475
# iter: 2, error: 233.514
# current_time:  3.39
# iter: 1, error: 21602.184
# iter: 2, error: 262.447
# current_time:  3.4
# iter: 1, error: 22595.632
# iter: 2, error: 289.388
# current_time:  3.41
# iter: 1, error: 23438.162
# iter: 2, error: 313.486
# current_time:  3.42
# iter: 1, error: 24124.134
# iter: 2, error: 333.960
# current_time:  3.43
# iter: 1, error: 24648.964
# iter: 2, error: 350.126
# current_time:  3.44
# iter: 1, error: 25009.154
# iter: 2, error: 361.438
# current_time:  3.45
# iter: 1, error: 25202.311
# iter: 2, error: 367.510
# current_time:  3.46
# iter: 1, error: 25227.165
# iter: 2, error: 368.137
# current_time:  3.47
# iter: 1, error: 25083.570
# iter: 2, error: 363.307
# current_time:  3.48
# iter: 1, error: 24772.510
# iter: 2, error: 353.194
# current_time:  3.49
# iter: 1, error: 24296.089
# iter: 2, error: 338.159
# current_time:  3.5
# iter: 1, error: 23657.517
# iter: 2, error: 318.719
# current_time:  3.5100000000000002
# iter: 1, error: 22861.089
# iter: 2, error: 295.530
# current_time:  3.52
# iter: 1, error: 21912.161
# iter: 2, error: 269.349
# current_time:  3.5300000000000002
# iter: 1, error: 20817.111
# iter: 2, error: 241.001
# current_time:  3.54
# iter: 1, error: 19583.300
# iter: 2, error: 211.342
# current_time:  3.5500000000000003
# iter: 1, error: 18219.021
# iter: 2, error: 181.228
# current_time:  3.56
# iter: 1, error: 16733.446
# iter: 2, error: 151.481
# current_time:  3.5700000000000003
# iter: 1, error: 15136.562
# iter: 2, error: 122.868
# current_time:  3.58
# iter: 1, error: 13439.103
# iter: 2, error: 96.081
# current_time:  3.59
# iter: 1, error: 11652.473
# iter: 2, error: 71.728
# current_time:  3.6
# iter: 1, error: 9788.671
# iter: 2, error: 50.329
# current_time:  3.61
# iter: 1, error: 7860.205
# iter: 2, error: 32.316
# current_time:  3.62
# iter: 1, error: 5880.005
# current_time:  3.63
# iter: 1, error: 3863.994
# current_time:  3.64
# iter: 1, error: 1820.041
# current_time:  3.65
# iter: 1, error: 236.753
# current_time:  3.66
# iter: 1, error: 2289.790
# current_time:  3.67
# iter: 1, error: 4325.812
# current_time:  3.68
# iter: 1, error: 6331.683
# current_time:  3.69
# iter: 1, error: 8294.494
# iter: 2, error: 36.473
# current_time:  3.7
# iter: 1, error: 10204.739
# iter: 2, error: 56.917
# current_time:  3.71
# iter: 1, error: 12043.878
# iter: 2, error: 80.243
# current_time:  3.72
# iter: 1, error: 13802.180
# iter: 2, error: 106.725
# current_time:  3.73
# iter: 1, error: 15467.992
# iter: 2, error: 135.784
# current_time:  3.74
# iter: 1, error: 17030.308
# iter: 2, error: 166.735
# current_time:  3.75
# iter: 1, error: 18478.813
# iter: 2, error: 198.791
# current_time:  3.7600000000000002
# iter: 1, error: 19803.958
# iter: 2, error: 231.084
# current_time:  3.77
# iter: 1, error: 20997.013
# iter: 2, error: 262.688
# current_time:  3.7800000000000002
# iter: 1, error: 22050.131
# iter: 2, error: 292.655
# current_time:  3.79
# iter: 1, error: 22956.390
# iter: 2, error: 320.045
# current_time:  3.8000000000000003
# iter: 1, error: 23709.840
# iter: 2, error: 343.973
# current_time:  3.81
# iter: 1, error: 24305.540
# iter: 2, error: 363.639
# current_time:  3.8200000000000003
# iter: 1, error: 24739.584
# iter: 2, error: 378.375
# current_time:  3.83
# iter: 1, error: 25009.123
# iter: 2, error: 387.670
# current_time:  3.84
# iter: 1, error: 25112.389
# iter: 2, error: 391.201
# current_time:  3.85
# iter: 1, error: 25048.696
# iter: 2, error: 388.843
# current_time:  3.86
# iter: 1, error: 24818.448
# iter: 2, error: 380.681
# current_time:  3.87
# iter: 1, error: 24423.139
# iter: 2, error: 367.004
# current_time:  3.88
# iter: 1, error: 23865.339
# iter: 2, error: 348.289
# current_time:  3.89
# iter: 1, error: 23148.685
# iter: 2, error: 325.178
# current_time:  3.9
# iter: 1, error: 22277.858
# iter: 2, error: 298.446
# current_time:  3.91
# iter: 1, error: 21258.556
# iter: 2, error: 268.966
# current_time:  3.92
# iter: 1, error: 20097.461
# iter: 2, error: 237.668
# current_time:  3.93
# iter: 1, error: 18802.200
# iter: 2, error: 205.499
# current_time:  3.94
# iter: 1, error: 17381.298
# iter: 2, error: 173.387
# current_time:  3.95
# iter: 1, error: 15844.123
# iter: 2, error: 142.210
# current_time:  3.96
# iter: 1, error: 14200.832
# iter: 2, error: 112.763
# current_time:  3.97
# iter: 1, error: 12462.298
# iter: 2, error: 85.748
# current_time:  3.98
# iter: 1, error: 10640.045
# iter: 2, error: 61.756
# current_time:  3.99
# iter: 1, error: 8746.171
# iter: 2, error: 41.268
# current_time:  4.0
# iter: 1, error: 6793.264
# iter: 2, error: 24.652
# current_time:  4.01
# iter: 1, error: 4794.325
# current_time:  4.0200000000000005
# iter: 1, error: 2760.217
# current_time:  4.03
# iter: 1, error: 711.636
# current_time:  4.04
# iter: 1, error: 1344.405
# current_time:  4.05
# iter: 1, error: 3392.574
# current_time:  4.0600000000000005
# iter: 1, error: 5419.586
# current_time:  4.07
# iter: 1, error: 7412.262
# iter: 2, error: 28.669
# current_time:  4.08
# iter: 1, error: 9350.292
# iter: 2, error: 46.058
# current_time:  4.09
# iter: 1, error: 11229.846
# iter: 2, error: 66.871
# current_time:  4.1
# iter: 1, error: 13034.847
# iter: 2, error: 90.781
# current_time:  4.11
# iter: 1, error: 14753.154
# iter: 2, error: 117.286
# current_time:  4.12
# iter: 1, error: 16373.218
# iter: 2, error: 145.784
# current_time:  4.13
# iter: 1, error: 17884.150
# iter: 2, error: 175.578
# current_time:  4.14
# iter: 1, error: 19275.792
# iter: 2, error: 205.892
# current_time:  4.15
# iter: 1, error: 20538.792
# iter: 2, error: 235.892
# current_time:  4.16
# iter: 1, error: 21664.668
# iter: 2, error: 264.705
# current_time:  4.17
# iter: 1, error: 22645.865
# iter: 2, error: 291.456
# current_time:  4.18
# iter: 1, error: 23475.807
# iter: 2, error: 315.300
# current_time:  4.19
# iter: 1, error: 24148.939
# iter: 2, error: 335.461
# current_time:  4.2
# iter: 1, error: 24660.763
# iter: 2, error: 351.268
# current_time:  4.21
# iter: 1, error: 25007.870
# iter: 2, error: 362.186
# current_time:  4.22
# iter: 1, error: 25187.953
# iter: 2, error: 367.843
# current_time:  4.23
# iter: 1, error: 25199.829
# iter: 2, error: 368.049
# current_time:  4.24
# iter: 1, error: 25043.441
# iter: 2, error: 362.805
# current_time:  4.25
# iter: 1, error: 24719.857
# iter: 2, error: 352.303
# current_time:  4.26
# iter: 1, error: 24231.265
# iter: 2, error: 336.912
# current_time:  4.2700000000000005
# iter: 1, error: 23580.957
# iter: 2, error: 317.163
# current_time:  4.28
# iter: 1, error: 22773.306
# iter: 2, error: 293.718
# current_time:  4.29
# iter: 1, error: 21813.745
# iter: 2, error: 267.342
# current_time:  4.3
# iter: 1, error: 20708.721
# iter: 2, error: 238.861
# current_time:  4.3100000000000005
# iter: 1, error: 19465.665
# iter: 2, error: 209.133
# current_time:  4.32
# iter: 1, error: 18092.930
# iter: 2, error: 179.011
# current_time:  4.33
# iter: 1, error: 16599.747
# iter: 2, error: 149.315
# current_time:  4.34
# iter: 1, error: 14996.153
# iter: 2, error: 120.806
# current_time:  4.3500000000000005
# iter: 1, error: 13292.927
# iter: 2, error: 94.172
# current_time:  4.36
# iter: 1, error: 11501.511
# iter: 2, error: 70.014
# current_time:  4.37
# iter: 1, error: 9633.937
# iter: 2, error: 48.848
# current_time:  4.38
# iter: 1, error: 7702.736
# iter: 2, error: 31.101
# current_time:  4.39
# iter: 1, error: 5720.856
# current_time:  4.4
# iter: 1, error: 3704.094
# current_time:  4.41
# iter: 1, error: 1660.526
# current_time:  4.42
# iter: 1, error: 394.630
# current_time:  4.43
# iter: 1, error: 2445.016
# current_time:  4.44
# iter: 1, error: 4477.384
# current_time:  4.45
# iter: 1, error: 6478.627
# current_time:  4.46
# iter: 1, error: 8435.866
# iter: 2, error: 37.805
# current_time:  4.47
# iter: 1, error: 10339.663
# iter: 2, error: 58.581
# current_time:  4.48
# iter: 1, error: 12171.388
# iter: 2, error: 82.156
# current_time:  4.49
# iter: 1, error: 13921.435
# iter: 2, error: 108.838
# current_time:  4.5
# iter: 1, error: 15578.205
# iter: 2, error: 138.044
# current_time:  4.51
# iter: 1, error: 17130.753
# iter: 2, error: 169.076
# current_time:  4.5200000000000005
# iter: 1, error: 18568.829
# iter: 2, error: 201.144
# current_time:  4.53
# iter: 1, error: 19882.954
# iter: 2, error: 233.374
# current_time:  4.54
# iter: 1, error: 21064.471
# iter: 2, error: 264.841
# current_time:  4.55
# iter: 1, error: 22105.609
# iter: 2, error: 294.597
# current_time:  4.5600000000000005
# iter: 1, error: 22999.527
# iter: 2, error: 321.707
# current_time:  4.57
# iter: 1, error: 23740.355
# iter: 2, error: 345.292
# current_time:  4.58
# iter: 1, error: 24323.234
# iter: 2, error: 364.567
# current_time:  4.59
# iter: 1, error: 24744.341
# iter: 2, error: 378.873
# current_time:  4.6000000000000005
# iter: 1, error: 25000.916
# iter: 2, error: 387.717
# current_time:  4.61
# iter: 1, error: 25091.271
# iter: 2, error: 390.789
# current_time:  4.62
# iter: 1, error: 25014.806
# iter: 2, error: 387.983
# current_time:  4.63
# iter: 1, error: 24772.009
# iter: 2, error: 379.399
# current_time:  4.64
# iter: 1, error: 24364.454
# iter: 2, error: 365.340
# current_time:  4.65
# iter: 1, error: 23794.794
# iter: 2, error: 346.295
# current_time:  4.66
# iter: 1, error: 23066.742
# iter: 2, error: 322.915
# current_time:  4.67
# iter: 1, error: 22185.054
# iter: 2, error: 295.984
# current_time:  4.68
# iter: 1, error: 21155.501
# iter: 2, error: 266.376
# current_time:  4.69
# iter: 1, error: 19984.833
# iter: 2, error: 235.023
# current_time:  4.7
# iter: 1, error: 18680.742
# iter: 2, error: 202.870
# current_time:  4.71
# iter: 1, error: 17251.812
# iter: 2, error: 170.839
# current_time:  4.72
# iter: 1, error: 15707.466
# iter: 2, error: 139.801
# current_time:  4.73
# iter: 1, error: 14057.908
# iter: 2, error: 110.545
# current_time:  4.74
# iter: 1, error: 12314.057
# iter: 2, error: 83.764
# current_time:  4.75
# iter: 1, error: 10487.471
# iter: 2, error: 60.040
# current_time:  4.76
# iter: 1, error: 8590.279
# iter: 2, error: 39.846
# current_time:  4.7700000000000005
# iter: 1, error: 6635.094
# current_time:  4.78
# iter: 1, error: 4630.167
# current_time:  4.79
# iter: 1, error: 2602.659
# current_time:  4.8
# iter: 1, error: 553.017
# current_time:  4.8100000000000005
# iter: 1, error: 1501.076
# current_time:  4.82
# iter: 1, error: 3546.276
# current_time:  4.83
# iter: 1, error: 5569.319
# current_time:  4.84
# iter: 1, error: 7557.047
# iter: 2, error: 29.868
# current_time:  4.8500000000000005
# iter: 1, error: 9488.828
# iter: 2, error: 47.567
# current_time:  4.86
# iter: 1, error: 11361.428
# iter: 2, error: 68.648
# current_time:  4.87
# iter: 1, error: 13158.590
# iter: 2, error: 92.791
# current_time:  4.88
# iter: 1, error: 14868.226
# iter: 2, error: 119.486
# current_time:  4.89
# iter: 1, error: 16478.845
# iter: 2, error: 148.121
# current_time:  4.9
# iter: 1, error: 17979.621
# iter: 2, error: 177.994
# current_time:  4.91
# iter: 1, error: 19360.465
# iter: 2, error: 208.322
# current_time:  4.92
# iter: 1, error: 20612.098
# iter: 2, error: 238.266
# current_time:  4.93
# iter: 1, error: 21726.115
# iter: 2, error: 266.954
# current_time:  4.94
# iter: 1, error: 22695.040
# iter: 2, error: 293.510
# current_time:  4.95
# iter: 1, error: 23512.381
# iter: 2, error: 317.095
# current_time:  4.96
# iter: 1, error: 24172.666
# iter: 2, error: 336.941
# current_time:  4.97
# iter: 1, error: 24671.487
# iter: 2, error: 352.386
# current_time:  4.98
# iter: 1, error: 25005.518
# iter: 2, error: 362.908
# current_time:  4.99
# iter: 1, error: 25172.543
# iter: 2, error: 368.149
# current_time:  5.0

# %% [markdown]
# ### Plotting

# %%
t = np.arange(robot.sim_params.total_time, step=robot.sim_params.dt)
options = dismech.AnimationOptions(title=plant_name, plot_step=robot.sim_params.plot_step)

fig = dismech.get_interactive_animation_plotly(robot, t, qs , options)
fig.show()

# %%
# # save gif
# ani = dismech.get_animation(robot, t, qs, options)
# save_path = os.path.join("tomato_results", f"{plant_name}_{position}.gif")
# ani.save(save_path)

# %%
# plot the trajectory of the flower location
flower_node = 143  # pick a node at the flower
# flower_node = main_grip  # pick a node at the flower

import matplotlib.pyplot as plt

# Extract the DOF indices (x, y, z) of the node you want to track
flower_node_dofs = robot.map_node_to_dof(flower_node)  # e.g., [ix, iy, iz]

# Extract position of that node across all timesteps
logged = qs[:, flower_node_dofs].squeeze()  # shape (n_timesteps, 3)

# remove value at t=0
logged -= robot.nodes[flower_node]

# Plot x, y, z over time
t = np.arange(qs.shape[0]) * robot.sim_params.dt

plt.figure(figsize=(10, 4))
plt.plot(t, logged[:, 0], label='x')
plt.plot(t, logged[:, 1], label='y')
plt.plot(t, logged[:, 2], label='z')
plt.xlabel('Time (s)')
plt.ylabel('Position')
plt.title(f'Position of Node {flower_node} Over Time')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
from scipy.signal import hilbert, detrend, find_peaks

def avg_cycle_amplitude_hilbert(x: np.ndarray) -> float:
    """
    Robust average oscillation amplitude using the analytic-signal envelope.
    Returns the median envelope value (less sensitive to outliers).
    """
    x = np.asarray(x).ravel()
    x = detrend(x)  # remove slow drift
    envelope = np.abs(hilbert(x))
    # Use median to resist occasional spikes; mean is also fine.
    return float(np.median(envelope))
# amplitude of flower node motion
amp_x_flower_hilbert = avg_cycle_amplitude_hilbert(logged[:, 0]) # hilbert-based amplitude
amp_x_flower_peak = (np.max(logged[:, 0]) - np.min(logged[:, 0])) / 2.0 # peak-to-peak amplitude
print(f"Amplitude of flower node {flower_node} motion in x (peak-to-peak): {amp_x_flower_peak:.4f} m")
print(f"Amplitude of flower node {flower_node} motion in x (hilbert): {amp_x_flower_hilbert:.4f} m")
# Out:
# Amplitude of flower node 143 motion in x (peak-to-peak): 0.0045 m
# Amplitude of flower node 143 motion in x (hilbert): 0.0043 m

# %% [markdown]
# ### Save data for rendering

# %%
# from dismech.logging import logDataForRendering
# from dismech.logging import export_rod_shell_data, export_parachute_data

# rod_data, shell_data = logDataForRendering(qs, t.reshape(-1, 1), robot, len(t), robot.sim_params.static_sim, robot.map_node_to_dof, log_step=1)

# js_file = os.path.join("tomato_results", f"{plant_name}_{position}.js")

# export_parachute_data(qs, geo.rod_edges, robot,
#                           rod_js=js_file,
#                           scaleFactor=100)

# %% [markdown]
# ### Estimated values of parameters

# %%
L = 0.292 # m
r0 = 0.0059 # m

delta = 0.054 # m # delta = PL^3/(3EI)
P = 0.02*9.81 # N

K = P/delta # effective stiffness

I = np.pi * r0**4 / 4
E = P*(L**3) / (3 * I * delta)

print("E:", E)

f = 1.38 # Hz
TP = 0.725 # s

omega = 2 * np.pi * f
m_eff = K / omega**2
print("m_eff:", m_eff)

# estimate density
V = np.pi * r0**2 * L
rho = m_eff / V
print("rho:", rho)
# Out:
# E: 31683606.79586816
# m_eff: 0.048326721526529885
# rho: 1513.389046285066
