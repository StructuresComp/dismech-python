# %% [markdown]
# ## Tomato Pollination: Tomato 2

# %%
import numpy as np
import dismech
import os

plant_name = "tomato2"

position = "2"

geom = dismech.GeomParams(
    rod_r0=0.03,
    shell_h=0.0,
)

material = dismech.Material(density=1100,
                            youngs_rod=2.16e7,
                            youngs_shell=0,
                            poisson_rod=0.5,
                            poisson_shell=0)

dyn_sim = dismech.SimParams(static_sim=False,
                                  two_d_sim=True,   # no twisting
                                  use_mid_edge=False,
                                  use_line_search=False,
                                  show_floor=False,
                                  log_data=True,
                                  log_step=1,
                                  dt=1e-2,
                                  max_iter=50,
                                  total_time=5,
                                  plot_step=10,
                                  tol=1e-4,
                                  ftol=1e-4,
                                  dtol=1e-2
                                  )

env = dismech.Environment()
env.add_force('gravity', g=np.array([0.0, 0.0, -9.81]))
env.add_force('damping', eta=100)

input_txt = os.path.join('../tests/resources/tomato_pollination/plants/', f"{plant_name}.txt")
geo = dismech.Geometry.from_txt(input_txt)

robot = dismech.SoftRobot(geom, material, geo, dyn_sim, env)

# %% [markdown]
# ### Move the stem: Moving BC

# %%
# # --- pick the main grip node robustly ---
# grasping_point = np.array([
#       1.1154284,
#       0.0092739,
#       0.4896594
#     ])
# xyz = robot.state.q[robot.node_dof_indices].reshape(-1, 3)

main_grip = 21  # node at the main grip

print("Main grip node:", main_grip)

other_grip_nodes_below = np.array(range(main_grip-4, main_grip), dtype=int)
other_grip_nodes_above = np.arange(main_grip+4, main_grip, -1, dtype=int)

print("Other grip nodes below:", other_grip_nodes_below)
print("Other grip nodes above:", other_grip_nodes_above)
# Out:
# Main grip node: 21
# Other grip nodes below: [17 18 19 20]
# Other grip nodes above: [25 24 23 22]

# %%
base_nodes = np.where((robot.state.q[robot.node_dof_indices].reshape(-1, 3)[:, 2]) < 0.22)[0] # fixed base
# Fix only main_grip and base nodes
robot = robot.fix_nodes(np.unique(np.r_[main_grip, base_nodes]))

# %%
# ----- once, before simulation -----

all_grip_nodes = np.r_[main_grip, other_grip_nodes_below, other_grip_nodes_above].astype(int)

xyz0 = robot.state.q[robot.node_dof_indices].reshape(-1, 3).copy()
x0 = xyz0[all_grip_nodes, 0].copy()          # initial x of all prescribed nodes
prev_target_x = x0.copy()                     # last absolute target (starts at initial)

# (Optional) precompute amplitude scalings from *initial* geometry
def build_amps_from_xyz0(xyz0, main_grip, all_grip_nodes, A_main):
    amps = np.empty(all_grip_nodes.size, float)
    amps[0] = A_main  # main_grip
    # below group
    below = np.array(other_grip_nodes_below, dtype=int)
    if below.size:
        ref = below[0]
        L = max(np.linalg.norm(xyz0[main_grip]-xyz0[ref]), 1e-12)
        for j, node in enumerate(below, start=1):  # start=1 because 0 is main_grip
            amps[j] = A_main * (np.linalg.norm(xyz0[ref]-xyz0[node]) / L)
    # above group
    above = np.array(other_grip_nodes_above, dtype=int)
    if above.size:
        ref = above[0]
        offset = 1 + below.size
        L = max(np.linalg.norm(xyz0[main_grip]-xyz0[ref]), 1e-12)
        for j, node in enumerate(above, start=offset):
            amps[j] = A_main * (np.linalg.norm(xyz0[ref]-xyz0[node]) / L)
    return amps

A_main = 0.340670063e-2   # m at main_grip
freq   = 1.0    # Hz
amps   = build_amps_from_xyz0(xyz0, main_grip, all_grip_nodes, A_main)

def shake_distributed(robot, t: float):
    # absolute target centered at initial pose
    target_x = x0 + amps * np.sin(2*np.pi*freq*t)

    # INCREMENT ONLY: avoids velocity spikes and keeps symmetry
    delta_x = target_x - prev_target_x
    prev_target_x[:] = target_x

    return robot.move_nodes(all_grip_nodes, delta_x.reshape(-1,1).flatten(), axis=0)

print("grasping points:", all_grip_nodes)
# Out:
# grasping points: [21 17 18 19 20 25 24 23 22]

# %%
stepper = dismech.ImplicitEulerTimeStepper(robot)
stepper.before_step = shake_distributed

# %% [markdown]
# ### Simulate

# %%
# simulate
robots = stepper.simulate()

qs = np.stack([robot.state.q for robot in robots])
# Out:
# iter: 1, error: 6924.997
# iter: 2, error: 78.924
# current_time:  0.01
# iter: 1, error: 6899.047
# iter: 2, error: 47.606
# current_time:  0.02
# iter: 1, error: 6845.001
# iter: 2, error: 41.413
# current_time:  0.03
# iter: 1, error: 6763.705
# iter: 2, error: 39.614
# current_time:  0.04
# iter: 1, error: 6655.736
# iter: 2, error: 38.052
# current_time:  0.05
# iter: 1, error: 6521.522
# iter: 2, error: 36.675
# current_time:  0.06
# iter: 1, error: 6361.556
# iter: 2, error: 35.050
# current_time:  0.07
# iter: 1, error: 6176.457
# iter: 2, error: 32.982
# current_time:  0.08
# iter: 1, error: 5966.949
# iter: 2, error: 30.721
# current_time:  0.09
# iter: 1, error: 5733.852
# iter: 2, error: 28.434
# current_time:  0.1
# iter: 1, error: 5478.077
# iter: 2, error: 26.082
# current_time:  0.11
# iter: 1, error: 5200.632
# iter: 2, error: 23.609
# current_time:  0.12
# iter: 1, error: 4902.611
# iter: 2, error: 21.028
# current_time:  0.13
# iter: 1, error: 4585.194
# iter: 2, error: 18.389
# current_time:  0.14
# iter: 1, error: 4249.641
# iter: 2, error: 15.760
# current_time:  0.15
# iter: 1, error: 3897.282
# iter: 2, error: 13.206
# current_time:  0.16
# iter: 1, error: 3529.518
# iter: 2, error: 10.785
# current_time:  0.17
# iter: 1, error: 3147.806
# iter: 2, error: 8.545
# current_time:  0.18
# iter: 1, error: 2753.660
# iter: 2, error: 6.520
# current_time:  0.19
# iter: 1, error: 2348.641
# iter: 2, error: 4.736
# current_time:  0.2
# iter: 1, error: 1934.355
# iter: 2, error: 3.212
# current_time:  0.21
# iter: 1, error: 1512.442
# current_time:  0.22
# iter: 1, error: 1084.760
# current_time:  0.23
# iter: 1, error: 652.563
# current_time:  0.24
# iter: 1, error: 217.802
# current_time:  0.25
# iter: 1, error: 217.746
# current_time:  0.26
# iter: 1, error: 652.360
# current_time:  0.27
# iter: 1, error: 1084.325
# current_time:  0.28
# iter: 1, error: 1511.938
# current_time:  0.29
# iter: 1, error: 1933.511
# current_time:  0.3
# iter: 1, error: 2347.383
# current_time:  0.31
# iter: 1, error: 2751.921
# iter: 2, error: 6.600
# current_time:  0.32
# iter: 1, error: 3145.970
# iter: 2, error: 8.651
# current_time:  0.33
# iter: 1, error: 3527.191
# iter: 2, error: 10.882
# current_time:  0.34
# iter: 1, error: 3894.427
# iter: 2, error: 13.271
# current_time:  0.35000000000000003
# iter: 1, error: 4246.225
# iter: 2, error: 15.783
# current_time:  0.36
# iter: 1, error: 4581.196
# iter: 2, error: 18.381
# current_time:  0.37
# iter: 1, error: 4898.020
# iter: 2, error: 21.024
# current_time:  0.38
# iter: 1, error: 5195.449
# iter: 2, error: 23.670
# current_time:  0.39
# iter: 1, error: 5472.311
# iter: 2, error: 26.278
# current_time:  0.4
# iter: 1, error: 5727.518
# iter: 2, error: 28.808
# current_time:  0.41000000000000003
# iter: 1, error: 5960.066
# iter: 2, error: 31.218
# current_time:  0.42
# iter: 1, error: 6169.044
# iter: 2, error: 33.471
# current_time:  0.43
# iter: 1, error: 6353.632
# iter: 2, error: 35.529
# current_time:  0.44
# iter: 1, error: 6513.109
# iter: 2, error: 37.359
# current_time:  0.45
# iter: 1, error: 6646.852
# iter: 2, error: 38.933
# current_time:  0.46
# iter: 1, error: 6754.342
# iter: 2, error: 40.223
# current_time:  0.47000000000000003
# iter: 1, error: 6835.162
# iter: 2, error: 41.210
# current_time:  0.48
# iter: 1, error: 6889.002
# iter: 2, error: 41.878
# current_time:  0.49
# iter: 1, error: 6915.656
# iter: 2, error: 42.214
# current_time:  0.5
# iter: 1, error: 6915.029
# iter: 2, error: 42.215
# current_time:  0.51
# iter: 1, error: 6887.130
# iter: 2, error: 41.880
# current_time:  0.52
# iter: 1, error: 6832.077
# iter: 2, error: 41.214
# current_time:  0.53
# iter: 1, error: 6750.094
# iter: 2, error: 40.228
# current_time:  0.54
# iter: 1, error: 6641.512
# iter: 2, error: 38.938
# current_time:  0.55
# iter: 1, error: 6506.764
# iter: 2, error: 37.364
# current_time:  0.56
# iter: 1, error: 6346.387
# iter: 2, error: 35.533
# current_time:  0.5700000000000001
# iter: 1, error: 6161.017
# iter: 2, error: 33.474
# current_time:  0.58
# iter: 1, error: 5951.389
# iter: 2, error: 31.219
# current_time:  0.59
# iter: 1, error: 5718.331
# iter: 2, error: 28.805
# current_time:  0.6
# iter: 1, error: 5462.764
# iter: 2, error: 26.271
# current_time:  0.61
# iter: 1, error: 5185.696
# iter: 2, error: 23.656
# current_time:  0.62
# iter: 1, error: 4888.217
# iter: 2, error: 21.003
# current_time:  0.63
# iter: 1, error: 4571.499
# iter: 2, error: 18.354
# current_time:  0.64
# iter: 1, error: 4236.788
# iter: 2, error: 15.750
# current_time:  0.65
# iter: 1, error: 3885.398
# iter: 2, error: 13.233
# current_time:  0.66
# iter: 1, error: 3518.711
# iter: 2, error: 10.841
# current_time:  0.67
# iter: 1, error: 3138.167
# iter: 2, error: 8.613
# current_time:  0.68
# iter: 1, error: 2745.259
# iter: 2, error: 6.583
# current_time:  0.6900000000000001
# iter: 1, error: 2341.530
# iter: 2, error: 4.783
# current_time:  0.7000000000000001
# iter: 1, error: 1928.565
# current_time:  0.71
# iter: 1, error: 1507.564
# current_time:  0.72
# iter: 1, error: 1081.241
# current_time:  0.73
# iter: 1, error: 650.493
# current_time:  0.74
# iter: 1, error: 217.122
# current_time:  0.75
# iter: 1, error: 217.177
# current_time:  0.76
# iter: 1, error: 650.703
# current_time:  0.77
# iter: 1, error: 1081.760
# current_time:  0.78
# iter: 1, error: 1508.656
# current_time:  0.79
# iter: 1, error: 1929.718
# current_time:  0.8
# iter: 1, error: 2343.291
# current_time:  0.81
# iter: 1, error: 2747.748
# iter: 2, error: 6.611
# current_time:  0.8200000000000001
# iter: 1, error: 3140.455
# iter: 2, error: 8.620
# current_time:  0.8300000000000001
# iter: 1, error: 3521.577
# iter: 2, error: 10.829
# current_time:  0.84
# iter: 1, error: 3888.880
# iter: 2, error: 13.200
# current_time:  0.85
# iter: 1, error: 4240.911
# iter: 2, error: 15.692
# current_time:  0.86
# iter: 1, error: 4576.279
# iter: 2, error: 18.266
# current_time:  0.87
# iter: 1, error: 4893.656
# iter: 2, error: 20.882
# current_time:  0.88
# iter: 1, error: 5191.786
# iter: 2, error: 23.498
# current_time:  0.89
# iter: 1, error: 5469.486
# iter: 2, error: 26.074
# current_time:  0.9
# iter: 1, error: 5725.654
# iter: 2, error: 28.570
# current_time:  0.91
# iter: 1, error: 5959.272
# iter: 2, error: 30.944
# current_time:  0.92
# iter: 1, error: 6169.412
# iter: 2, error: 33.161
# current_time:  0.93
# iter: 1, error: 6355.236
# iter: 2, error: 35.185
# current_time:  0.9400000000000001
# iter: 1, error: 6516.002
# iter: 2, error: 36.983
# current_time:  0.9500000000000001
# iter: 1, error: 6651.068
# iter: 2, error: 38.527
# current_time:  0.96
# iter: 1, error: 6759.893
# iter: 2, error: 39.792
# current_time:  0.97
# iter: 1, error: 6842.040
# iter: 2, error: 40.758
# current_time:  0.98
# iter: 1, error: 6897.176
# iter: 2, error: 41.410
# current_time:  0.99
# iter: 1, error: 6925.078
# iter: 2, error: 41.737
# current_time:  1.0
# iter: 1, error: 6925.627
# iter: 2, error: 41.734
# current_time:  1.01
# iter: 1, error: 6898.817
# iter: 2, error: 41.400
# current_time:  1.02
# iter: 1, error: 6844.747
# iter: 2, error: 40.742
# current_time:  1.03
# iter: 1, error: 6763.626
# iter: 2, error: 39.769
# current_time:  1.04
# iter: 1, error: 6655.771
# iter: 2, error: 38.497
# current_time:  1.05
# iter: 1, error: 6521.604
# iter: 2, error: 36.947
# current_time:  1.06
# iter: 1, error: 6361.653
# iter: 2, error: 35.142
# current_time:  1.07
# iter: 1, error: 6176.547
# iter: 2, error: 33.113
# current_time:  1.08
# iter: 1, error: 5967.017
# iter: 2, error: 30.891
# current_time:  1.09
# iter: 1, error: 5733.890
# iter: 2, error: 28.511
# current_time:  1.1
# iter: 1, error: 5478.087
# iter: 2, error: 26.012
# current_time:  1.11
# iter: 1, error: 5200.619
# iter: 2, error: 23.432
# current_time:  1.12
# iter: 1, error: 4902.586
# iter: 2, error: 20.813
# current_time:  1.1300000000000001
# iter: 1, error: 4585.166
# iter: 2, error: 18.196
# current_time:  1.1400000000000001
# iter: 1, error: 4249.615
# iter: 2, error: 15.623
# current_time:  1.1500000000000001
# iter: 1, error: 3897.264
# iter: 2, error: 13.133
# current_time:  1.16
# iter: 1, error: 3529.507
# iter: 2, error: 10.766
# current_time:  1.17
# iter: 1, error: 3147.802
# iter: 2, error: 8.558
# current_time:  1.18
# iter: 1, error: 2753.660
# iter: 2, error: 6.545
# current_time:  1.19
# iter: 1, error: 2348.644
# iter: 2, error: 4.758
# current_time:  1.2
# iter: 1, error: 1934.358
# current_time:  1.21
# iter: 1, error: 1512.755
# current_time:  1.22
# iter: 1, error: 1084.823
# current_time:  1.23
# iter: 1, error: 652.565
# current_time:  1.24
# iter: 1, error: 217.802
# current_time:  1.25
# iter: 1, error: 217.746
# current_time:  1.26
# iter: 1, error: 652.359
# current_time:  1.27
# iter: 1, error: 1084.324
# current_time:  1.28
# iter: 1, error: 1511.936
# current_time:  1.29
# iter: 1, error: 1933.509
# current_time:  1.3
# iter: 1, error: 2347.380
# current_time:  1.31
# iter: 1, error: 2751.919
# iter: 2, error: 6.598
# current_time:  1.32
# iter: 1, error: 3145.968
# iter: 2, error: 8.646
# current_time:  1.33
# iter: 1, error: 3527.190
# iter: 2, error: 10.876
# current_time:  1.34
# iter: 1, error: 3894.426
# iter: 2, error: 13.265
# current_time:  1.35
# iter: 1, error: 4246.223
# iter: 2, error: 15.778
# current_time:  1.36
# iter: 1, error: 4581.194
# iter: 2, error: 18.378
# current_time:  1.37
# iter: 1, error: 4898.018
# iter: 2, error: 21.023
# current_time:  1.3800000000000001
# iter: 1, error: 5195.446
# iter: 2, error: 23.671
# current_time:  1.3900000000000001
# iter: 1, error: 5472.308
# iter: 2, error: 26.281
# current_time:  1.4000000000000001
# iter: 1, error: 5727.514
# iter: 2, error: 28.811
# current_time:  1.41
# iter: 1, error: 5960.062
# iter: 2, error: 31.221
# current_time:  1.42
# iter: 1, error: 6169.040
# iter: 2, error: 33.473
# current_time:  1.43
# iter: 1, error: 6353.628
# iter: 2, error: 35.530
# current_time:  1.44
# iter: 1, error: 6513.105
# iter: 2, error: 37.360
# current_time:  1.45
# iter: 1, error: 6646.848
# iter: 2, error: 38.932
# current_time:  1.46
# iter: 1, error: 6754.338
# iter: 2, error: 40.222
# current_time:  1.47
# iter: 1, error: 6835.158
# iter: 2, error: 41.209
# current_time:  1.48
# iter: 1, error: 6888.998
# iter: 2, error: 41.877
# current_time:  1.49
# iter: 1, error: 6915.653
# iter: 2, error: 42.214
# current_time:  1.5
# iter: 1, error: 6915.025
# iter: 2, error: 42.215
# current_time:  1.51
# iter: 1, error: 6887.126
# iter: 2, error: 41.880
# current_time:  1.52
# iter: 1, error: 6832.073
# iter: 2, error: 41.214
# current_time:  1.53
# iter: 1, error: 6750.091
# iter: 2, error: 40.228
# current_time:  1.54
# iter: 1, error: 6641.509
# iter: 2, error: 38.938
# current_time:  1.55
# iter: 1, error: 6506.761
# iter: 2, error: 37.365
# current_time:  1.56
# iter: 1, error: 6346.383
# iter: 2, error: 35.534
# current_time:  1.57
# iter: 1, error: 6161.014
# iter: 2, error: 33.474
# current_time:  1.58
# iter: 1, error: 5951.386
# iter: 2, error: 31.219
# current_time:  1.59
# iter: 1, error: 5718.328
# iter: 2, error: 28.805
# current_time:  1.6
# iter: 1, error: 5462.762
# iter: 2, error: 26.271
# current_time:  1.61
# iter: 1, error: 5185.693
# iter: 2, error: 23.656
# current_time:  1.62
# iter: 1, error: 4888.215
# iter: 2, error: 21.003
# current_time:  1.6300000000000001
# iter: 1, error: 4571.497
# iter: 2, error: 18.354
# current_time:  1.6400000000000001
# iter: 1, error: 4236.786
# iter: 2, error: 15.750
# current_time:  1.6500000000000001
# iter: 1, error: 3885.396
# iter: 2, error: 13.233
# current_time:  1.6600000000000001
# iter: 1, error: 3518.709
# iter: 2, error: 10.841
# current_time:  1.67
# iter: 1, error: 3138.165
# iter: 2, error: 8.613
# current_time:  1.68
# iter: 1, error: 2745.258
# iter: 2, error: 6.583
# current_time:  1.69
# iter: 1, error: 2341.529
# iter: 2, error: 4.783
# current_time:  1.7
# iter: 1, error: 1928.564
# current_time:  1.71
# iter: 1, error: 1507.563
# current_time:  1.72
# iter: 1, error: 1081.240
# current_time:  1.73
# iter: 1, error: 650.493
# current_time:  1.74
# iter: 1, error: 217.122
# current_time:  1.75
# iter: 1, error: 217.177
# current_time:  1.76
# iter: 1, error: 650.703
# current_time:  1.77
# iter: 1, error: 1081.759
# current_time:  1.78
# iter: 1, error: 1508.656
# current_time:  1.79
# iter: 1, error: 1929.717
# current_time:  1.8
# iter: 1, error: 2343.290
# current_time:  1.81
# iter: 1, error: 2747.747
# iter: 2, error: 6.611
# current_time:  1.82
# iter: 1, error: 3140.453
# iter: 2, error: 8.620
# current_time:  1.83
# iter: 1, error: 3521.575
# iter: 2, error: 10.829
# current_time:  1.84
# iter: 1, error: 3888.878
# iter: 2, error: 13.200
# current_time:  1.85
# iter: 1, error: 4240.909
# iter: 2, error: 15.692
# current_time:  1.86
# iter: 1, error: 4576.277
# iter: 2, error: 18.266
# current_time:  1.87
# iter: 1, error: 4893.654
# iter: 2, error: 20.882
# current_time:  1.8800000000000001
# iter: 1, error: 5191.783
# iter: 2, error: 23.498
# current_time:  1.8900000000000001
# iter: 1, error: 5469.483
# iter: 2, error: 26.074
# current_time:  1.9000000000000001
# iter: 1, error: 5725.651
# iter: 2, error: 28.570
# current_time:  1.9100000000000001
# iter: 1, error: 5959.270
# iter: 2, error: 30.944
# current_time:  1.92
# iter: 1, error: 6169.409
# iter: 2, error: 33.161
# current_time:  1.93
# iter: 1, error: 6355.233
# iter: 2, error: 35.185
# current_time:  1.94
# iter: 1, error: 6515.999
# iter: 2, error: 36.983
# current_time:  1.95
# iter: 1, error: 6651.065
# iter: 2, error: 38.527
# current_time:  1.96
# iter: 1, error: 6759.890
# iter: 2, error: 39.792
# current_time:  1.97
# iter: 1, error: 6842.037
# iter: 2, error: 40.758
# current_time:  1.98
# iter: 1, error: 6897.173
# iter: 2, error: 41.410
# current_time:  1.99
# iter: 1, error: 6925.074
# iter: 2, error: 41.737
# current_time:  2.0
# iter: 1, error: 6925.624
# iter: 2, error: 41.734
# current_time:  2.0100000000000002
# iter: 1, error: 6898.814
# iter: 2, error: 41.400
# current_time:  2.02
# iter: 1, error: 6844.744
# iter: 2, error: 40.742
# current_time:  2.0300000000000002
# iter: 1, error: 6763.623
# iter: 2, error: 39.769
# current_time:  2.04
# iter: 1, error: 6655.768
# iter: 2, error: 38.497
# current_time:  2.05
# iter: 1, error: 6521.601
# iter: 2, error: 36.947
# current_time:  2.06
# iter: 1, error: 6361.650
# iter: 2, error: 35.142
# current_time:  2.07
# iter: 1, error: 6176.544
# iter: 2, error: 33.113
# current_time:  2.08
# iter: 1, error: 5967.014
# iter: 2, error: 30.891
# current_time:  2.09
# iter: 1, error: 5733.887
# iter: 2, error: 28.511
# current_time:  2.1
# iter: 1, error: 5478.084
# iter: 2, error: 26.012
# current_time:  2.11
# iter: 1, error: 5200.617
# iter: 2, error: 23.432
# current_time:  2.12
# iter: 1, error: 4902.584
# iter: 2, error: 20.813
# current_time:  2.13
# iter: 1, error: 4585.163
# iter: 2, error: 18.197
# current_time:  2.14
# iter: 1, error: 4249.613
# iter: 2, error: 15.623
# current_time:  2.15
# iter: 1, error: 3897.262
# iter: 2, error: 13.133
# current_time:  2.16
# iter: 1, error: 3529.505
# iter: 2, error: 10.766
# current_time:  2.17
# iter: 1, error: 3147.800
# iter: 2, error: 8.558
# current_time:  2.18
# iter: 1, error: 2753.659
# iter: 2, error: 6.545
# current_time:  2.19
# iter: 1, error: 2348.643
# iter: 2, error: 4.758
# current_time:  2.2
# iter: 1, error: 1934.357
# current_time:  2.21
# iter: 1, error: 1512.754
# current_time:  2.22
# iter: 1, error: 1084.823
# current_time:  2.23
# iter: 1, error: 652.564
# current_time:  2.24
# iter: 1, error: 217.802
# current_time:  2.25
# iter: 1, error: 217.745
# current_time:  2.2600000000000002
# iter: 1, error: 652.359
# current_time:  2.27
# iter: 1, error: 1084.324
# current_time:  2.2800000000000002
# iter: 1, error: 1511.935
# current_time:  2.29
# iter: 1, error: 1933.508
# current_time:  2.3000000000000003
# iter: 1, error: 2347.379
# current_time:  2.31
# iter: 1, error: 2751.918
# iter: 2, error: 6.598
# current_time:  2.32
# iter: 1, error: 3145.967
# iter: 2, error: 8.646
# current_time:  2.33
# iter: 1, error: 3527.188
# iter: 2, error: 10.876
# current_time:  2.34
# iter: 1, error: 3894.424
# iter: 2, error: 13.265
# current_time:  2.35
# iter: 1, error: 4246.221
# iter: 2, error: 15.778
# current_time:  2.36
# iter: 1, error: 4581.192
# iter: 2, error: 18.378
# current_time:  2.37
# iter: 1, error: 4898.016
# iter: 2, error: 21.023
# current_time:  2.38
# iter: 1, error: 5195.444
# iter: 2, error: 23.671
# current_time:  2.39
# iter: 1, error: 5472.305
# iter: 2, error: 26.281
# current_time:  2.4
# iter: 1, error: 5727.511
# iter: 2, error: 28.811
# current_time:  2.41
# iter: 1, error: 5960.059
# iter: 2, error: 31.221
# current_time:  2.42
# iter: 1, error: 6169.037
# iter: 2, error: 33.473
# current_time:  2.43
# iter: 1, error: 6353.625
# iter: 2, error: 35.530
# current_time:  2.44
# iter: 1, error: 6513.101
# iter: 2, error: 37.360
# current_time:  2.45
# iter: 1, error: 6646.845
# iter: 2, error: 38.932
# current_time:  2.46
# iter: 1, error: 6754.335
# iter: 2, error: 40.223
# current_time:  2.47
# iter: 1, error: 6835.155
# iter: 2, error: 41.209
# current_time:  2.48
# iter: 1, error: 6888.994
# iter: 2, error: 41.877
# current_time:  2.49
# iter: 1, error: 6915.649
# iter: 2, error: 42.214
# current_time:  2.5
# iter: 1, error: 6915.022
# iter: 2, error: 42.215
# current_time:  2.5100000000000002
# iter: 1, error: 6887.123
# iter: 2, error: 41.880
# current_time:  2.52
# iter: 1, error: 6832.070
# iter: 2, error: 41.214
# current_time:  2.5300000000000002
# iter: 1, error: 6750.087
# iter: 2, error: 40.228
# current_time:  2.54
# iter: 1, error: 6641.505
# iter: 2, error: 38.938
# current_time:  2.5500000000000003
# iter: 1, error: 6506.757
# iter: 2, error: 37.365
# current_time:  2.56
# iter: 1, error: 6346.380
# iter: 2, error: 35.534
# current_time:  2.57
# iter: 1, error: 6161.011
# iter: 2, error: 33.474
# current_time:  2.58
# iter: 1, error: 5951.383
# iter: 2, error: 31.219
# current_time:  2.59
# iter: 1, error: 5718.325
# iter: 2, error: 28.805
# current_time:  2.6
# iter: 1, error: 5462.759
# iter: 2, error: 26.271
# current_time:  2.61
# iter: 1, error: 5185.690
# iter: 2, error: 23.656
# current_time:  2.62
# iter: 1, error: 4888.212
# iter: 2, error: 21.003
# current_time:  2.63
# iter: 1, error: 4571.495
# iter: 2, error: 18.354
# current_time:  2.64
# iter: 1, error: 4236.783
# iter: 2, error: 15.750
# current_time:  2.65
# iter: 1, error: 3885.394
# iter: 2, error: 13.233
# current_time:  2.66
# iter: 1, error: 3518.708
# iter: 2, error: 10.841
# current_time:  2.67
# iter: 1, error: 3138.164
# iter: 2, error: 8.613
# current_time:  2.68
# iter: 1, error: 2745.256
# iter: 2, error: 6.583
# current_time:  2.69
# iter: 1, error: 2341.528
# iter: 2, error: 4.783
# current_time:  2.7
# iter: 1, error: 1928.563
# current_time:  2.71
# iter: 1, error: 1507.563
# current_time:  2.72
# iter: 1, error: 1081.240
# current_time:  2.73
# iter: 1, error: 650.493
# current_time:  2.74
# iter: 1, error: 217.122
# current_time:  2.75
# iter: 1, error: 217.177
# current_time:  2.7600000000000002
# iter: 1, error: 650.703
# current_time:  2.77
# iter: 1, error: 1081.759
# current_time:  2.7800000000000002
# iter: 1, error: 1508.655
# current_time:  2.79
# iter: 1, error: 1929.716
# current_time:  2.8000000000000003
# iter: 1, error: 2343.289
# current_time:  2.81
# iter: 1, error: 2747.746
# iter: 2, error: 6.611
# current_time:  2.82
# iter: 1, error: 3140.452
# iter: 2, error: 8.620
# current_time:  2.83
# iter: 1, error: 3521.573
# iter: 2, error: 10.829
# current_time:  2.84
# iter: 1, error: 3888.876
# iter: 2, error: 13.200
# current_time:  2.85
# iter: 1, error: 4240.907
# iter: 2, error: 15.692
# current_time:  2.86
# iter: 1, error: 4576.274
# iter: 2, error: 18.266
# current_time:  2.87
# iter: 1, error: 4893.651
# iter: 2, error: 20.882
# current_time:  2.88
# iter: 1, error: 5191.781
# iter: 2, error: 23.498
# current_time:  2.89
# iter: 1, error: 5469.480
# iter: 2, error: 26.074
# current_time:  2.9
# iter: 1, error: 5725.648
# iter: 2, error: 28.570
# current_time:  2.91
# iter: 1, error: 5959.267
# iter: 2, error: 30.944
# current_time:  2.92
# iter: 1, error: 6169.406
# iter: 2, error: 33.161
# current_time:  2.93
# iter: 1, error: 6355.230
# iter: 2, error: 35.185
# current_time:  2.94
# iter: 1, error: 6515.996
# iter: 2, error: 36.983
# current_time:  2.95
# iter: 1, error: 6651.062
# iter: 2, error: 38.527
# current_time:  2.96
# iter: 1, error: 6759.887
# iter: 2, error: 39.792
# current_time:  2.97
# iter: 1, error: 6842.033
# iter: 2, error: 40.758
# current_time:  2.98
# iter: 1, error: 6897.170
# iter: 2, error: 41.410
# current_time:  2.99
# iter: 1, error: 6925.071
# iter: 2, error: 41.737
# current_time:  3.0
# iter: 1, error: 6925.621
# iter: 2, error: 41.734
# current_time:  3.0100000000000002
# iter: 1, error: 6898.810
# iter: 2, error: 41.400
# current_time:  3.02
# iter: 1, error: 6844.741
# iter: 2, error: 40.742
# current_time:  3.0300000000000002
# iter: 1, error: 6763.620
# iter: 2, error: 39.769
# current_time:  3.04
# iter: 1, error: 6655.765
# iter: 2, error: 38.497
# current_time:  3.0500000000000003
# iter: 1, error: 6521.598
# iter: 2, error: 36.947
# current_time:  3.06
# iter: 1, error: 6361.647
# iter: 2, error: 35.142
# current_time:  3.0700000000000003
# iter: 1, error: 6176.541
# iter: 2, error: 33.113
# current_time:  3.08
# iter: 1, error: 5967.011
# iter: 2, error: 30.891
# current_time:  3.09
# iter: 1, error: 5733.884
# iter: 2, error: 28.511
# current_time:  3.1
# iter: 1, error: 5478.081
# iter: 2, error: 26.012
# current_time:  3.11
# iter: 1, error: 5200.614
# iter: 2, error: 23.432
# current_time:  3.12
# iter: 1, error: 4902.581
# iter: 2, error: 20.813
# current_time:  3.13
# iter: 1, error: 4585.161
# iter: 2, error: 18.197
# current_time:  3.14
# iter: 1, error: 4249.611
# iter: 2, error: 15.623
# current_time:  3.15
# iter: 1, error: 3897.260
# iter: 2, error: 13.133
# current_time:  3.16
# iter: 1, error: 3529.504
# iter: 2, error: 10.766
# current_time:  3.17
# iter: 1, error: 3147.799
# iter: 2, error: 8.558
# current_time:  3.18
# iter: 1, error: 2753.657
# iter: 2, error: 6.545
# current_time:  3.19
# iter: 1, error: 2348.642
# iter: 2, error: 4.758
# current_time:  3.2
# iter: 1, error: 1934.356
# current_time:  3.21
# iter: 1, error: 1512.753
# current_time:  3.22
# iter: 1, error: 1084.822
# current_time:  3.23
# iter: 1, error: 652.564
# current_time:  3.24
# iter: 1, error: 217.802
# current_time:  3.25
# iter: 1, error: 217.745
# current_time:  3.2600000000000002
# iter: 1, error: 652.359
# current_time:  3.27
# iter: 1, error: 1084.323
# current_time:  3.2800000000000002
# iter: 1, error: 1511.935
# current_time:  3.29
# iter: 1, error: 1933.507
# current_time:  3.3000000000000003
# iter: 1, error: 2347.378
# current_time:  3.31
# iter: 1, error: 2751.916
# iter: 2, error: 6.598
# current_time:  3.3200000000000003
# iter: 1, error: 3145.965
# iter: 2, error: 8.646
# current_time:  3.33
# iter: 1, error: 3527.186
# iter: 2, error: 10.876
# current_time:  3.34
# iter: 1, error: 3894.422
# iter: 2, error: 13.265
# current_time:  3.35
# iter: 1, error: 4246.219
# iter: 2, error: 15.778
# current_time:  3.36
# iter: 1, error: 4581.190
# iter: 2, error: 18.378
# current_time:  3.37
# iter: 1, error: 4898.013
# iter: 2, error: 21.023
# current_time:  3.38
# iter: 1, error: 5195.441
# iter: 2, error: 23.671
# current_time:  3.39
# iter: 1, error: 5472.302
# iter: 2, error: 26.281
# current_time:  3.4
# iter: 1, error: 5727.508
# iter: 2, error: 28.811
# current_time:  3.41
# iter: 1, error: 5960.056
# iter: 2, error: 31.221
# current_time:  3.42
# iter: 1, error: 6169.033
# iter: 2, error: 33.473
# current_time:  3.43
# iter: 1, error: 6353.621
# iter: 2, error: 35.530
# current_time:  3.44
# iter: 1, error: 6513.098
# iter: 2, error: 37.360
# current_time:  3.45
# iter: 1, error: 6646.841
# iter: 2, error: 38.932
# current_time:  3.46
# iter: 1, error: 6754.331
# iter: 2, error: 40.223
# current_time:  3.47
# iter: 1, error: 6835.151
# iter: 2, error: 41.209
# current_time:  3.48
# iter: 1, error: 6888.991
# iter: 2, error: 41.877
# current_time:  3.49
# iter: 1, error: 6915.645
# iter: 2, error: 42.214
# current_time:  3.5
# iter: 1, error: 6915.018
# iter: 2, error: 42.215
# current_time:  3.5100000000000002
# iter: 1, error: 6887.119
# iter: 2, error: 41.880
# current_time:  3.52
# iter: 1, error: 6832.066
# iter: 2, error: 41.214
# current_time:  3.5300000000000002
# iter: 1, error: 6750.084
# iter: 2, error: 40.228
# current_time:  3.54
# iter: 1, error: 6641.502
# iter: 2, error: 38.938
# current_time:  3.5500000000000003
# iter: 1, error: 6506.754
# iter: 2, error: 37.365
# current_time:  3.56
# iter: 1, error: 6346.377
# iter: 2, error: 35.534
# current_time:  3.5700000000000003
# iter: 1, error: 6161.007
# iter: 2, error: 33.474
# current_time:  3.58
# iter: 1, error: 5951.380
# iter: 2, error: 31.219
# current_time:  3.59
# iter: 1, error: 5718.322
# iter: 2, error: 28.805
# current_time:  3.6
# iter: 1, error: 5462.756
# iter: 2, error: 26.271
# current_time:  3.61
# iter: 1, error: 5185.688
# iter: 2, error: 23.656
# current_time:  3.62
# iter: 1, error: 4888.210
# iter: 2, error: 21.003
# current_time:  3.63
# iter: 1, error: 4571.492
# iter: 2, error: 18.354
# current_time:  3.64
# iter: 1, error: 4236.781
# iter: 2, error: 15.750
# current_time:  3.65
# iter: 1, error: 3885.392
# iter: 2, error: 13.233
# current_time:  3.66
# iter: 1, error: 3518.706
# iter: 2, error: 10.841
# current_time:  3.67
# iter: 1, error: 3138.162
# iter: 2, error: 8.614
# current_time:  3.68
# iter: 1, error: 2745.255
# iter: 2, error: 6.583
# current_time:  3.69
# iter: 1, error: 2341.526
# iter: 2, error: 4.783
# current_time:  3.7
# iter: 1, error: 1928.562
# current_time:  3.71
# iter: 1, error: 1507.562
# current_time:  3.72
# iter: 1, error: 1081.239
# current_time:  3.73
# iter: 1, error: 650.492
# current_time:  3.74
# iter: 1, error: 217.122
# current_time:  3.75
# iter: 1, error: 217.176
# current_time:  3.7600000000000002
# iter: 1, error: 650.702
# current_time:  3.77
# iter: 1, error: 1081.758
# current_time:  3.7800000000000002
# iter: 1, error: 1508.654
# current_time:  3.79
# iter: 1, error: 1929.715
# current_time:  3.8000000000000003
# iter: 1, error: 2343.288
# current_time:  3.81
# iter: 1, error: 2747.744
# iter: 2, error: 6.611
# current_time:  3.8200000000000003
# iter: 1, error: 3140.450
# iter: 2, error: 8.620
# current_time:  3.83
# iter: 1, error: 3521.571
# iter: 2, error: 10.829
# current_time:  3.84
# iter: 1, error: 3888.874
# iter: 2, error: 13.200
# current_time:  3.85
# iter: 1, error: 4240.905
# iter: 2, error: 15.692
# current_time:  3.86
# iter: 1, error: 4576.272
# iter: 2, error: 18.266
# current_time:  3.87
# iter: 1, error: 4893.649
# iter: 2, error: 20.882
# current_time:  3.88
# iter: 1, error: 5191.778
# iter: 2, error: 23.498
# current_time:  3.89
# iter: 1, error: 5469.478
# iter: 2, error: 26.074
# current_time:  3.9
# iter: 1, error: 5725.646
# iter: 2, error: 28.570
# current_time:  3.91
# iter: 1, error: 5959.264
# iter: 2, error: 30.944
# current_time:  3.92
# iter: 1, error: 6169.403
# iter: 2, error: 33.161
# current_time:  3.93
# iter: 1, error: 6355.227
# iter: 2, error: 35.185
# current_time:  3.94
# iter: 1, error: 6515.993
# iter: 2, error: 36.983
# current_time:  3.95
# iter: 1, error: 6651.059
# iter: 2, error: 38.527
# current_time:  3.96
# iter: 1, error: 6759.884
# iter: 2, error: 39.792
# current_time:  3.97
# iter: 1, error: 6842.030
# iter: 2, error: 40.758
# current_time:  3.98
# iter: 1, error: 6897.166
# iter: 2, error: 41.410
# current_time:  3.99
# iter: 1, error: 6925.068
# iter: 2, error: 41.737
# current_time:  4.0
# iter: 1, error: 6925.617
# iter: 2, error: 41.734
# current_time:  4.01
# iter: 1, error: 6898.807
# iter: 2, error: 41.400
# current_time:  4.0200000000000005
# iter: 1, error: 6844.737
# iter: 2, error: 40.742
# current_time:  4.03
# iter: 1, error: 6763.617
# iter: 2, error: 39.769
# current_time:  4.04
# iter: 1, error: 6655.762
# iter: 2, error: 38.497
# current_time:  4.05
# iter: 1, error: 6521.595
# iter: 2, error: 36.947
# current_time:  4.0600000000000005
# iter: 1, error: 6361.644
# iter: 2, error: 35.142
# current_time:  4.07
# iter: 1, error: 6176.538
# iter: 2, error: 33.113
# current_time:  4.08
# iter: 1, error: 5967.008
# iter: 2, error: 30.891
# current_time:  4.09
# iter: 1, error: 5733.881
# iter: 2, error: 28.511
# current_time:  4.1
# iter: 1, error: 5478.079
# iter: 2, error: 26.012
# current_time:  4.11
# iter: 1, error: 5200.612
# iter: 2, error: 23.432
# current_time:  4.12
# iter: 1, error: 4902.579
# iter: 2, error: 20.813
# current_time:  4.13
# iter: 1, error: 4585.159
# iter: 2, error: 18.197
# current_time:  4.14
# iter: 1, error: 4249.609
# iter: 2, error: 15.623
# current_time:  4.15
# iter: 1, error: 3897.258
# iter: 2, error: 13.133
# current_time:  4.16
# iter: 1, error: 3529.502
# iter: 2, error: 10.766
# current_time:  4.17
# iter: 1, error: 3147.797
# iter: 2, error: 8.558
# current_time:  4.18
# iter: 1, error: 2753.656
# iter: 2, error: 6.545
# current_time:  4.19
# iter: 1, error: 2348.641
# iter: 2, error: 4.758
# current_time:  4.2
# iter: 1, error: 1934.355
# current_time:  4.21
# iter: 1, error: 1512.753
# current_time:  4.22
# iter: 1, error: 1084.822
# current_time:  4.23
# iter: 1, error: 652.564
# current_time:  4.24
# iter: 1, error: 217.802
# current_time:  4.25
# iter: 1, error: 217.745
# current_time:  4.26
# iter: 1, error: 652.358
# current_time:  4.2700000000000005
# iter: 1, error: 1084.323
# current_time:  4.28
# iter: 1, error: 1511.934
# current_time:  4.29
# iter: 1, error: 1933.506
# current_time:  4.3
# iter: 1, error: 2347.377
# current_time:  4.3100000000000005
# iter: 1, error: 2751.915
# iter: 2, error: 6.598
# current_time:  4.32
# iter: 1, error: 3145.964
# iter: 2, error: 8.646
# current_time:  4.33
# iter: 1, error: 3527.185
# iter: 2, error: 10.876
# current_time:  4.34
# iter: 1, error: 3894.420
# iter: 2, error: 13.265
# current_time:  4.3500000000000005
# iter: 1, error: 4246.217
# iter: 2, error: 15.778
# current_time:  4.36
# iter: 1, error: 4581.187
# iter: 2, error: 18.378
# current_time:  4.37
# iter: 1, error: 4898.010
# iter: 2, error: 21.023
# current_time:  4.38
# iter: 1, error: 5195.438
# iter: 2, error: 23.671
# current_time:  4.39
# iter: 1, error: 5472.299
# iter: 2, error: 26.281
# current_time:  4.4
# iter: 1, error: 5727.505
# iter: 2, error: 28.811
# current_time:  4.41
# iter: 1, error: 5960.053
# iter: 2, error: 31.221
# current_time:  4.42
# iter: 1, error: 6169.030
# iter: 2, error: 33.473
# current_time:  4.43
# iter: 1, error: 6353.618
# iter: 2, error: 35.530
# current_time:  4.44
# iter: 1, error: 6513.094
# iter: 2, error: 37.360
# current_time:  4.45
# iter: 1, error: 6646.838
# iter: 2, error: 38.932
# current_time:  4.46
# iter: 1, error: 6754.328
# iter: 2, error: 40.223
# current_time:  4.47
# iter: 1, error: 6835.148
# iter: 2, error: 41.209
# current_time:  4.48
# iter: 1, error: 6888.987
# iter: 2, error: 41.877
# current_time:  4.49
# iter: 1, error: 6915.641
# iter: 2, error: 42.214
# current_time:  4.5
# iter: 1, error: 6915.014
# iter: 2, error: 42.215
# current_time:  4.51
# iter: 1, error: 6887.115
# iter: 2, error: 41.880
# current_time:  4.5200000000000005
# iter: 1, error: 6832.062
# iter: 2, error: 41.214
# current_time:  4.53
# iter: 1, error: 6750.080
# iter: 2, error: 40.228
# current_time:  4.54
# iter: 1, error: 6641.498
# iter: 2, error: 38.938
# current_time:  4.55
# iter: 1, error: 6506.750
# iter: 2, error: 37.365
# current_time:  4.5600000000000005
# iter: 1, error: 6346.373
# iter: 2, error: 35.534
# current_time:  4.57
# iter: 1, error: 6161.004
# iter: 2, error: 33.474
# current_time:  4.58
# iter: 1, error: 5951.376
# iter: 2, error: 31.219
# current_time:  4.59
# iter: 1, error: 5718.319
# iter: 2, error: 28.805
# current_time:  4.6000000000000005
# iter: 1, error: 5462.753
# iter: 2, error: 26.271
# current_time:  4.61
# iter: 1, error: 5185.685
# iter: 2, error: 23.656
# current_time:  4.62
# iter: 1, error: 4888.207
# iter: 2, error: 21.003
# current_time:  4.63
# iter: 1, error: 4571.490
# iter: 2, error: 18.354
# current_time:  4.64
# iter: 1, error: 4236.779
# iter: 2, error: 15.750
# current_time:  4.65
# iter: 1, error: 3885.390
# iter: 2, error: 13.233
# current_time:  4.66
# iter: 1, error: 3518.704
# iter: 2, error: 10.841
# current_time:  4.67
# iter: 1, error: 3138.160
# iter: 2, error: 8.614
# current_time:  4.68
# iter: 1, error: 2745.253
# iter: 2, error: 6.583
# current_time:  4.69
# iter: 1, error: 2341.525
# iter: 2, error: 4.783
# current_time:  4.7
# iter: 1, error: 1928.561
# current_time:  4.71
# iter: 1, error: 1507.561
# current_time:  4.72
# iter: 1, error: 1081.239
# current_time:  4.73
# iter: 1, error: 650.492
# current_time:  4.74
# iter: 1, error: 217.122
# current_time:  4.75
# iter: 1, error: 217.176
# current_time:  4.76
# iter: 1, error: 650.702
# current_time:  4.7700000000000005
# iter: 1, error: 1081.758
# current_time:  4.78
# iter: 1, error: 1508.653
# current_time:  4.79
# iter: 1, error: 1929.714
# current_time:  4.8
# iter: 1, error: 2343.286
# current_time:  4.8100000000000005
# iter: 1, error: 2747.743
# iter: 2, error: 6.611
# current_time:  4.82
# iter: 1, error: 3140.449
# iter: 2, error: 8.620
# current_time:  4.83
# iter: 1, error: 3521.570
# iter: 2, error: 10.829
# current_time:  4.84
# iter: 1, error: 3888.872
# iter: 2, error: 13.200
# current_time:  4.8500000000000005
# iter: 1, error: 4240.903
# iter: 2, error: 15.692
# current_time:  4.86
# iter: 1, error: 4576.270
# iter: 2, error: 18.266
# current_time:  4.87
# iter: 1, error: 4893.647
# iter: 2, error: 20.882
# current_time:  4.88
# iter: 1, error: 5191.776
# iter: 2, error: 23.498
# current_time:  4.89
# iter: 1, error: 5469.475
# iter: 2, error: 26.074
# current_time:  4.9
# iter: 1, error: 5725.643
# iter: 2, error: 28.570
# current_time:  4.91
# iter: 1, error: 5959.261
# iter: 2, error: 30.944
# current_time:  4.92
# iter: 1, error: 6169.400
# iter: 2, error: 33.161
# current_time:  4.93
# iter: 1, error: 6355.224
# iter: 2, error: 35.185
# current_time:  4.94
# iter: 1, error: 6515.989
# iter: 2, error: 36.983
# current_time:  4.95
# iter: 1, error: 6651.055
# iter: 2, error: 38.527
# current_time:  4.96
# iter: 1, error: 6759.880
# iter: 2, error: 39.792
# current_time:  4.97
# iter: 1, error: 6842.027
# iter: 2, error: 40.758
# current_time:  4.98
# iter: 1, error: 6897.163
# iter: 2, error: 41.410
# current_time:  4.99
# iter: 1, error: 6925.064
# iter: 2, error: 41.737
# current_time:  5.0

# %% [markdown]
# ### Plotting

# %%
t = np.arange(robot.sim_params.total_time, step=robot.sim_params.dt)
options = dismech.AnimationOptions(title='Tomato2', plot_step=10)

fig = dismech.get_interactive_animation_plotly(robot, t, qs , options)
fig.show()

# %%
# # save gif
# ani = dismech.get_animation(robot, t, qs, options)
# save_path = os.path.join("tomato_results", f"{plant_name}_{position}.gif")
# ani.save(save_path)

# %%
# plot the trajectory of the flower location
flower_node = 73  # pick a node at the flower

import matplotlib.pyplot as plt

# Extract the DOF indices (x, y, z) of the node you want to track
flower_node_dofs = robot.map_node_to_dof(flower_node)  # e.g., [ix, iy, iz]

# Extract position of that node across all timesteps
logged = qs[:, flower_node_dofs].squeeze()  # shape (n_timesteps, 3)

# remove value at t=0
logged -= robot.nodes[flower_node]

# Plot x, y, z over time
t = np.arange(qs.shape[0]) * robot.sim_params.dt

plt.figure(figsize=(10, 4))
plt.plot(t, logged[:, 0], label='x')
plt.plot(t, logged[:, 1], label='y')
plt.plot(t, logged[:, 2], label='z')
plt.xlabel('Time (s)')
plt.ylabel('Position')
plt.title(f'Position of Node {flower_node} Over Time')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Save data for rendering

# %%
from dismech.logging import logDataForRendering
from dismech.logging import export_parachute_data

rod_data, shell_data = logDataForRendering(qs, t.reshape(-1, 1), robot, len(t), robot.sim_params.static_sim, robot.map_node_to_dof)

js_file = os.path.join("tomato_results", f"{plant_name}_{position}.js")
export_parachute_data(qs, geo.rod_edges, robot,
                          rod_js=js_file,
                          scaleFactor=100)
# Out:
# /Users/radha/GitRepos/dismech-python/src/dismech/logging.py:176: UserWarning:
#
# loadtxt: input contained no data: "rawDataShell.txt"

# %%
import numpy as np
from scipy.signal import hilbert, detrend, find_peaks

def avg_cycle_amplitude_hilbert(x: np.ndarray) -> float:
    """
    Robust average oscillation amplitude using the analytic-signal envelope.
    Returns the median envelope value (less sensitive to outliers).
    """
    x = np.asarray(x).ravel()
    x = detrend(x)  # remove slow drift
    envelope = np.abs(hilbert(x))
    # Use median to resist occasional spikes; mean is also fine.
    return float(np.median(envelope))

# %%
# amplitude of flower node motion
amp_x_flower_hilbert = avg_cycle_amplitude_hilbert(logged[:, 0]) # hilbert-based amplitude
amp_x_flower_peak = (np.max(logged[:, 0]) - np.min(logged[:, 0])) / 2.0 # peak-to-peak amplitude
print(f"Amplitude of flower node {flower_node} motion in x (peak-to-peak): {amp_x_flower_peak:.4f} m")
print(f"Amplitude of flower node {flower_node} motion in x (hilbert): {amp_x_flower_hilbert:.4f} m")
# Out:
# Amplitude of flower node 73 motion in x (peak-to-peak): 0.0048 m
# Amplitude of flower node 73 motion in x (hilbert): 0.0048 m

# %% [markdown]
# #### Estimate frequency

# %%
import numpy as np

def estimate_frequency(signal, dt):
    """
    Estimate dominant frequency of a periodic signal using FFT.
    
    Parameters
    ----------
    signal : 1D np.ndarray
        The time-varying signal (samples).
    dt : float
        Time step between samples.
    
    Returns
    -------
    freq : float
        Dominant frequency (Hz).
    """
    n = len(signal)
    # Remove mean to avoid 0 Hz dominance
    signal = signal - np.mean(signal)

    # FFT
    freqs = np.fft.rfftfreq(n, d=dt)       # frequency bins (Hz)
    fft_vals = np.fft.rfft(signal)         # FFT coefficients
    magnitude = np.abs(fft_vals)

    # Find the peak frequency (excluding DC = 0 Hz)
    peak_idx = np.argmax(magnitude[1:]) + 1
    freq = freqs[peak_idx]
    return freq


# Example: make a sine wave of 5 Hz, sample at 100 Hz

f_est = estimate_frequency(logged[:, 0], robot.sim_params.dt)
print(f"Estimated frequency: {f_est:.2f} Hz")   # ~5.00 Hz
# Out:
# Estimated frequency: 1.00 Hz
