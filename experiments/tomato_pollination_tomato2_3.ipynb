# %% [markdown]
# ## Tomato Pollination: Tomato 2

# %%
import numpy as np
import dismech
import os

plant_name = "tomato2"

position = "3"

geom = dismech.GeomParams(
    rod_r0=0.03,
    shell_h=0.0,
)

material = dismech.Material(density=1100,
                            youngs_rod=2.16e7,
                            youngs_shell=0,
                            poisson_rod=0.5,
                            poisson_shell=0)

dyn_sim = dismech.SimParams(static_sim=False,
                                  two_d_sim=True,   # no twisting
                                  use_mid_edge=False,
                                  use_line_search=False,
                                  show_floor=False,
                                  log_data=True,
                                  log_step=1,
                                  dt=1e-2,
                                  max_iter=50,
                                  total_time=5,
                                  plot_step=10,
                                  tol=1e-4,
                                  ftol=1e-4,
                                  dtol=1e-2
                                  )

env = dismech.Environment()
env.add_force('gravity', g=np.array([0.0, 0.0, -9.81]))
env.add_force('damping', eta=100)

input_txt = os.path.join('../tests/resources/tomato_pollination/plants/', f"{plant_name}.txt")
geo = dismech.Geometry.from_txt(input_txt)

robot = dismech.SoftRobot(geom, material, geo, dyn_sim, env)

# %% [markdown]
# ### Move the stem: Moving BC

# %%
# # --- pick the main grip node robustly ---
# grasping_point = np.array([
#       1.1154284,
#       0.0092739,
#       0.4896594
#     ])
# xyz = robot.state.q[robot.node_dof_indices].reshape(-1, 3)

main_grip = 27  # node at the main grip

print("Main grip node:", main_grip)

other_grip_nodes_below = np.array(range(main_grip-4, main_grip), dtype=int)
other_grip_nodes_above = np.arange(main_grip+4, main_grip, -1, dtype=int)

print("Other grip nodes below:", other_grip_nodes_below)
print("Other grip nodes above:", other_grip_nodes_above)
# Out:
# Main grip node: 27
# Other grip nodes below: [23 24 25 26]
# Other grip nodes above: [31 30 29 28]

# %%
base_nodes = np.where((robot.state.q[robot.node_dof_indices].reshape(-1, 3)[:, 2]) < 0.22)[0] # fixed base
# Fix only main_grip and base nodes
robot = robot.fix_nodes(np.unique(np.r_[main_grip, base_nodes]))

# %%
# ----- once, before simulation -----

all_grip_nodes = np.r_[main_grip, other_grip_nodes_below, other_grip_nodes_above].astype(int)

xyz0 = robot.state.q[robot.node_dof_indices].reshape(-1, 3).copy()
x0 = xyz0[all_grip_nodes, 0].copy()          # initial x of all prescribed nodes
prev_target_x = x0.copy()                     # last absolute target (starts at initial)

# (Optional) precompute amplitude scalings from *initial* geometry
def build_amps_from_xyz0(xyz0, main_grip, all_grip_nodes, A_main):
    amps = np.empty(all_grip_nodes.size, float)
    amps[0] = A_main  # main_grip
    # below group
    below = np.array(other_grip_nodes_below, dtype=int)
    if below.size:
        ref = below[0]
        L = max(np.linalg.norm(xyz0[main_grip]-xyz0[ref]), 1e-12)
        for j, node in enumerate(below, start=1):  # start=1 because 0 is main_grip
            amps[j] = A_main * (np.linalg.norm(xyz0[ref]-xyz0[node]) / L)
    # above group
    above = np.array(other_grip_nodes_above, dtype=int)
    if above.size:
        ref = above[0]
        offset = 1 + below.size
        L = max(np.linalg.norm(xyz0[main_grip]-xyz0[ref]), 1e-12)
        for j, node in enumerate(above, start=offset):
            amps[j] = A_main * (np.linalg.norm(xyz0[ref]-xyz0[node]) / L)
    return amps

A_main = 0.340670063e-2   # m at main_grip
freq   = 1.3    # Hz
amps   = build_amps_from_xyz0(xyz0, main_grip, all_grip_nodes, A_main)

def shake_distributed(robot, t: float):
    # absolute target centered at initial pose
    target_x = x0 + amps * np.sin(2*np.pi*freq*t)

    # INCREMENT ONLY: avoids velocity spikes and keeps symmetry
    delta_x = target_x - prev_target_x
    prev_target_x[:] = target_x

    return robot.move_nodes(all_grip_nodes, delta_x.reshape(-1,1).flatten(), axis=0)

print("grasping points:", all_grip_nodes)
# Out:
# grasping points: [27 23 24 25 26 31 30 29 28]

# %%
stepper = dismech.ImplicitEulerTimeStepper(robot)
stepper.before_step = shake_distributed

# %% [markdown]
# ### Simulate

# %%
# simulate
robots = stepper.simulate()

qs = np.stack([robot.state.q for robot in robots])
# Out:
# iter: 1, error: 8861.758
# iter: 2, error: 107.607
# current_time:  0.01
# iter: 1, error: 8803.910
# iter: 2, error: 61.796
# current_time:  0.02
# iter: 1, error: 8685.950
# iter: 2, error: 53.173
# current_time:  0.03
# iter: 1, error: 8510.268
# iter: 2, error: 51.333
# current_time:  0.04
# iter: 1, error: 8278.352
# iter: 2, error: 49.583
# current_time:  0.05
# iter: 1, error: 7991.423
# iter: 2, error: 46.721
# current_time:  0.06
# iter: 1, error: 7651.130
# iter: 2, error: 42.128
# current_time:  0.07
# iter: 1, error: 7259.615
# iter: 2, error: 37.253
# current_time:  0.08
# iter: 1, error: 6819.461
# iter: 2, error: 32.626
# current_time:  0.09
# iter: 1, error: 6333.639
# iter: 2, error: 28.065
# current_time:  0.1
# iter: 1, error: 5805.453
# iter: 2, error: 23.550
# current_time:  0.11
# iter: 1, error: 5238.489
# iter: 2, error: 19.169
# current_time:  0.12
# iter: 1, error: 4636.574
# iter: 2, error: 15.023
# current_time:  0.13
# iter: 1, error: 4003.746
# iter: 2, error: 11.213
# current_time:  0.14
# iter: 1, error: 3344.233
# iter: 2, error: 7.836
# current_time:  0.15
# iter: 1, error: 2662.430
# iter: 2, error: 4.983
# current_time:  0.16
# iter: 1, error: 1962.883
# current_time:  0.17
# iter: 1, error: 1250.398
# current_time:  0.18
# iter: 1, error: 529.425
# current_time:  0.19
# iter: 1, error: 195.092
# current_time:  0.2
# iter: 1, error: 918.188
# current_time:  0.21
# iter: 1, error: 1635.053
# current_time:  0.22
# iter: 1, error: 2340.916
# current_time:  0.23
# iter: 1, error: 3031.087
# iter: 2, error: 6.439
# current_time:  0.24
# iter: 1, error: 3701.195
# iter: 2, error: 9.638
# current_time:  0.25
# iter: 1, error: 4346.367
# iter: 2, error: 13.317
# current_time:  0.26
# iter: 1, error: 4962.472
# iter: 2, error: 17.393
# current_time:  0.27
# iter: 1, error: 5545.396
# iter: 2, error: 21.760
# current_time:  0.28
# iter: 1, error: 6091.252
# iter: 2, error: 26.305
# current_time:  0.29
# iter: 1, error: 6596.404
# iter: 2, error: 30.908
# current_time:  0.3
# iter: 1, error: 7057.487
# iter: 2, error: 35.446
# current_time:  0.31
# iter: 1, error: 7471.431
# iter: 2, error: 39.796
# current_time:  0.32
# iter: 1, error: 7835.484
# iter: 2, error: 43.841
# current_time:  0.33
# iter: 1, error: 8147.229
# iter: 2, error: 47.471
# current_time:  0.34
# iter: 1, error: 8404.597
# iter: 2, error: 50.586
# current_time:  0.35000000000000003
# iter: 1, error: 8605.885
# iter: 2, error: 53.100
# current_time:  0.36
# iter: 1, error: 8749.764
# iter: 2, error: 54.944
# current_time:  0.37
# iter: 1, error: 8835.288
# iter: 2, error: 56.066
# current_time:  0.38
# iter: 1, error: 8861.900
# iter: 2, error: 56.434
# current_time:  0.39
# iter: 1, error: 8829.438
# iter: 2, error: 56.038
# current_time:  0.4
# iter: 1, error: 8738.129
# iter: 2, error: 54.890
# current_time:  0.41000000000000003
# iter: 1, error: 8588.597
# iter: 2, error: 53.020
# current_time:  0.42
# iter: 1, error: 8381.848
# iter: 2, error: 50.480
# current_time:  0.43
# iter: 1, error: 8119.270
# iter: 2, error: 47.340
# current_time:  0.44
# iter: 1, error: 7802.623
# iter: 2, error: 43.687
# current_time:  0.45
# iter: 1, error: 7434.022
# iter: 2, error: 39.622
# current_time:  0.46
# iter: 1, error: 7015.928
# iter: 2, error: 35.254
# current_time:  0.47000000000000003
# iter: 1, error: 6551.130
# iter: 2, error: 30.703
# current_time:  0.48
# iter: 1, error: 6042.724
# iter: 2, error: 26.091
# current_time:  0.49
# iter: 1, error: 5494.095
# iter: 2, error: 21.541
# current_time:  0.5
# iter: 1, error: 4908.895
# iter: 2, error: 17.175
# current_time:  0.51
# iter: 1, error: 4291.015
# iter: 2, error: 13.108
# current_time:  0.52
# iter: 1, error: 3644.563
# iter: 2, error: 9.446
# current_time:  0.53
# iter: 1, error: 2973.837
# iter: 2, error: 6.284
# current_time:  0.54
# iter: 1, error: 2283.294
# current_time:  0.55
# iter: 1, error: 1577.219
# current_time:  0.56
# iter: 1, error: 861.153
# current_time:  0.5700000000000001
# iter: 1, error: 139.106
# current_time:  0.58
# iter: 1, error: 583.943
# current_time:  0.59
# iter: 1, error: 1303.206
# current_time:  0.6
# iter: 1, error: 2013.924
# current_time:  0.61
# iter: 1, error: 2711.387
# current_time:  0.62
# iter: 1, error: 3390.971
# iter: 2, error: 8.090
# current_time:  0.63
# iter: 1, error: 4047.227
# iter: 2, error: 11.531
# current_time:  0.64
# iter: 1, error: 4677.151
# iter: 2, error: 15.399
# current_time:  0.65
# iter: 1, error: 5276.000
# iter: 2, error: 19.599
# current_time:  0.66
# iter: 1, error: 5839.772
# iter: 2, error: 24.020
# current_time:  0.67
# iter: 1, error: 6364.705
# iter: 2, error: 28.542
# current_time:  0.68
# iter: 1, error: 6847.291
# iter: 2, error: 33.045
# current_time:  0.6900000000000001
# iter: 1, error: 7284.301
# iter: 2, error: 37.411
# current_time:  0.7000000000000001
# iter: 1, error: 7672.811
# iter: 2, error: 41.520
# current_time:  0.71
# iter: 1, error: 8010.215
# iter: 2, error: 45.263
# current_time:  0.72
# iter: 1, error: 8294.248
# iter: 2, error: 48.539
# current_time:  0.73
# iter: 1, error: 8523.003
# iter: 2, error: 51.258
# current_time:  0.74
# iter: 1, error: 8694.937
# iter: 2, error: 53.348
# current_time:  0.75
# iter: 1, error: 8808.890
# iter: 2, error: 54.750
# current_time:  0.76
# iter: 1, error: 8864.087
# iter: 2, error: 55.428
# current_time:  0.77
# iter: 1, error: 8860.147
# iter: 2, error: 55.362
# current_time:  0.78
# iter: 1, error: 8797.086
# iter: 2, error: 54.555
# current_time:  0.79
# iter: 1, error: 8675.313
# iter: 2, error: 53.028
# current_time:  0.8
# iter: 1, error: 8495.632
# iter: 2, error: 50.825
# current_time:  0.81
# iter: 1, error: 8259.236
# iter: 2, error: 48.004
# current_time:  0.8200000000000001
# iter: 1, error: 7967.697
# iter: 2, error: 44.643
# current_time:  0.8300000000000001
# iter: 1, error: 7622.958
# iter: 2, error: 40.833
# current_time:  0.84
# iter: 1, error: 7227.318
# iter: 2, error: 36.677
# current_time:  0.85
# iter: 1, error: 6783.418
# iter: 2, error: 32.286
# current_time:  0.86
# iter: 1, error: 6294.222
# iter: 2, error: 27.778
# current_time:  0.87
# iter: 1, error: 5763.000
# iter: 2, error: 23.273
# current_time:  0.88
# iter: 1, error: 5193.301
# iter: 2, error: 18.890
# current_time:  0.89
# iter: 1, error: 4588.933
# iter: 2, error: 14.744
# current_time:  0.9
# iter: 1, error: 3953.936
# iter: 2, error: 10.945
# current_time:  0.91
# iter: 1, error: 3292.557
# iter: 2, error: 7.590
# current_time:  0.92
# iter: 1, error: 2609.216
# iter: 2, error: 4.770
# current_time:  0.93
# iter: 1, error: 1908.483
# current_time:  0.9400000000000001
# iter: 1, error: 1195.179
# current_time:  0.9500000000000001
# iter: 1, error: 473.756
# current_time:  0.96
# iter: 1, error: 250.825
# current_time:  0.97
# iter: 1, error: 973.611
# current_time:  0.98
# iter: 1, error: 1689.796
# current_time:  0.99
# iter: 1, error: 2394.617
# current_time:  1.0
# iter: 1, error: 3083.391
# iter: 2, error: 6.663
# current_time:  1.01
# iter: 1, error: 3751.761
# iter: 2, error: 9.904
# current_time:  1.02
# iter: 1, error: 4394.849
# iter: 2, error: 13.618
# current_time:  1.03
# iter: 1, error: 5008.545
# iter: 2, error: 17.721
# current_time:  1.04
# iter: 1, error: 5588.752
# iter: 2, error: 22.106
# current_time:  1.05
# iter: 1, error: 6131.602
# iter: 2, error: 26.660
# current_time:  1.06
# iter: 1, error: 6633.478
# iter: 2, error: 31.262
# current_time:  1.07
# iter: 1, error: 7091.038
# iter: 2, error: 35.789
# current_time:  1.08
# iter: 1, error: 7501.237
# iter: 2, error: 40.119
# current_time:  1.09
# iter: 1, error: 7861.349
# iter: 2, error: 44.136
# current_time:  1.1
# iter: 1, error: 8168.980
# iter: 2, error: 47.730
# current_time:  1.11
# iter: 1, error: 8422.091
# iter: 2, error: 50.802
# current_time:  1.12
# iter: 1, error: 8619.006
# iter: 2, error: 53.266
# current_time:  1.1300000000000001
# iter: 1, error: 8758.425
# iter: 2, error: 55.056
# current_time:  1.1400000000000001
# iter: 1, error: 8839.432
# iter: 2, error: 56.121
# current_time:  1.1500000000000001
# iter: 1, error: 8861.500
# iter: 2, error: 56.431
# current_time:  1.16
# iter: 1, error: 8824.498
# iter: 2, error: 55.977
# current_time:  1.17
# iter: 1, error: 8728.684
# iter: 2, error: 54.771
# current_time:  1.18
# iter: 1, error: 8574.709
# iter: 2, error: 52.847
# current_time:  1.19
# iter: 1, error: 8363.611
# iter: 2, error: 50.258
# current_time:  1.2
# iter: 1, error: 8096.807
# iter: 2, error: 47.076
# current_time:  1.21
# iter: 1, error: 7776.084
# iter: 2, error: 43.388
# current_time:  1.22
# iter: 1, error: 7403.584
# iter: 2, error: 39.295
# current_time:  1.23
# iter: 1, error: 6981.795
# iter: 2, error: 34.909
# current_time:  1.24
# iter: 1, error: 6513.529
# iter: 2, error: 30.348
# current_time:  1.25
# iter: 1, error: 6001.905
# iter: 2, error: 25.737
# current_time:  1.26
# iter: 1, error: 5450.330
# iter: 2, error: 21.197
# current_time:  1.27
# iter: 1, error: 4862.475
# iter: 2, error: 16.850
# current_time:  1.28
# iter: 1, error: 4242.249
# iter: 2, error: 12.811
# current_time:  1.29
# iter: 1, error: 3593.775
# iter: 2, error: 9.184
# current_time:  1.3
# iter: 1, error: 2921.364
# iter: 2, error: 6.064
# current_time:  1.31
# iter: 1, error: 2229.486
# current_time:  1.32
# iter: 1, error: 1522.446
# current_time:  1.33
# iter: 1, error: 805.755
# current_time:  1.34
# iter: 1, error: 83.462
# current_time:  1.35
# iter: 1, error: 639.466
# current_time:  1.36
# iter: 1, error: 1358.241
# current_time:  1.37
# iter: 1, error: 2068.105
# current_time:  1.3800000000000001
# iter: 1, error: 2764.355
# iter: 2, error: 5.377
# current_time:  1.3900000000000001
# iter: 1, error: 3441.795
# iter: 2, error: 8.338
# current_time:  1.4000000000000001
# iter: 1, error: 4096.686
# iter: 2, error: 11.812
# current_time:  1.41
# iter: 1, error: 4724.371
# iter: 2, error: 15.712
# current_time:  1.42
# iter: 1, error: 5320.660
# iter: 2, error: 19.934
# current_time:  1.43
# iter: 1, error: 5881.577
# iter: 2, error: 24.366
# current_time:  1.44
# iter: 1, error: 6403.374
# iter: 2, error: 28.891
# current_time:  1.45
# iter: 1, error: 6882.565
# iter: 2, error: 33.388
# current_time:  1.46
# iter: 1, error: 7315.945
# iter: 2, error: 37.737
# current_time:  1.47
# iter: 1, error: 7700.611
# iter: 2, error: 41.822
# current_time:  1.48
# iter: 1, error: 8033.985
# iter: 2, error: 45.532
# current_time:  1.49
# iter: 1, error: 8313.830
# iter: 2, error: 48.768
# current_time:  1.5
# iter: 1, error: 8538.263
# iter: 2, error: 51.442
# current_time:  1.51
# iter: 1, error: 8705.773
# iter: 2, error: 53.480
# current_time:  1.52
# iter: 1, error: 8815.228
# iter: 2, error: 54.828
# current_time:  1.53
# iter: 1, error: 8865.885
# iter: 2, error: 55.449
# current_time:  1.54
# iter: 1, error: 8857.392
# iter: 2, error: 55.326
# current_time:  1.55
# iter: 1, error: 8789.795
# iter: 2, error: 54.463
# current_time:  1.56
# iter: 1, error: 8663.534
# iter: 2, error: 52.882
# current_time:  1.57
# iter: 1, error: 8479.444
# iter: 2, error: 50.629
# current_time:  1.58
# iter: 1, error: 8238.745
# iter: 2, error: 47.764
# current_time:  1.59
# iter: 1, error: 7943.040
# iter: 2, error: 44.365
# current_time:  1.6
# iter: 1, error: 7594.300
# iter: 2, error: 40.524
# current_time:  1.61
# iter: 1, error: 7194.849
# iter: 2, error: 36.346
# current_time:  1.62
# iter: 1, error: 6747.356
# iter: 2, error: 31.942
# current_time:  1.6300000000000001
# iter: 1, error: 6254.808
# iter: 2, error: 27.430
# current_time:  1.6400000000000001
# iter: 1, error: 5720.496
# iter: 2, error: 22.930
# current_time:  1.6500000000000001
# iter: 1, error: 5147.991
# iter: 2, error: 18.561
# current_time:  1.6600000000000001
# iter: 1, error: 4541.121
# iter: 2, error: 14.438
# current_time:  1.67
# iter: 1, error: 3903.942
# iter: 2, error: 10.670
# current_time:  1.68
# iter: 1, error: 3240.715
# iter: 2, error: 7.354
# current_time:  1.69
# iter: 1, error: 2555.872
# iter: 2, error: 4.577
# current_time:  1.7
# iter: 1, error: 1853.994
# current_time:  1.71
# iter: 1, error: 1139.901
# current_time:  1.72
# iter: 1, error: 418.065
# current_time:  1.73
# iter: 1, error: 306.549
# current_time:  1.74
# iter: 1, error: 1028.998
# current_time:  1.75
# iter: 1, error: 1744.477
# current_time:  1.76
# iter: 1, error: 2448.229
# current_time:  1.77
# iter: 1, error: 3135.577
# iter: 2, error: 6.891
# current_time:  1.78
# iter: 1, error: 3802.177
# iter: 2, error: 10.173
# current_time:  1.79
# iter: 1, error: 4443.154
# iter: 2, error: 13.922
# current_time:  1.8
# iter: 1, error: 5054.416
# iter: 2, error: 18.049
# current_time:  1.81
# iter: 1, error: 5631.884
# iter: 2, error: 22.452
# current_time:  1.82
# iter: 1, error: 6171.707
# iter: 2, error: 27.014
# current_time:  1.83
# iter: 1, error: 6670.289
# iter: 2, error: 31.614
# current_time:  1.84
# iter: 1, error: 7124.310
# iter: 2, error: 36.130
# current_time:  1.85
# iter: 1, error: 7530.749
# iter: 2, error: 40.441
# current_time:  1.86
# iter: 1, error: 7886.904
# iter: 2, error: 44.429
# current_time:  1.87
# iter: 1, error: 8190.409
# iter: 2, error: 47.986
# current_time:  1.8800000000000001
# iter: 1, error: 8439.252
# iter: 2, error: 51.014
# current_time:  1.8900000000000001
# iter: 1, error: 8631.785
# iter: 2, error: 53.429
# current_time:  1.9000000000000001
# iter: 1, error: 8766.739
# iter: 2, error: 55.164
# current_time:  1.9100000000000001
# iter: 1, error: 8843.226
# iter: 2, error: 56.172
# current_time:  1.92
# iter: 1, error: 8860.750
# iter: 2, error: 56.423
# current_time:  1.93
# iter: 1, error: 8819.209
# iter: 2, error: 55.910
# current_time:  1.94
# iter: 1, error: 8718.893
# iter: 2, error: 54.648
# current_time:  1.95
# iter: 1, error: 8560.483
# iter: 2, error: 52.671
# current_time:  1.96
# iter: 1, error: 8345.045
# iter: 2, error: 50.034
# current_time:  1.97
# iter: 1, error: 8074.025
# iter: 2, error: 46.809
# current_time:  1.98
# iter: 1, error: 7749.239
# iter: 2, error: 43.086
# current_time:  1.99
# iter: 1, error: 7372.855
# iter: 2, error: 38.966
# current_time:  2.0
# iter: 1, error: 6947.387
# iter: 2, error: 34.563
# current_time:  2.0100000000000002
# iter: 1, error: 6475.671
# iter: 2, error: 29.994
# current_time:  2.02
# iter: 1, error: 5960.849
# iter: 2, error: 25.383
# current_time:  2.0300000000000002
# iter: 1, error: 5406.350
# iter: 2, error: 20.855
# current_time:  2.04
# iter: 1, error: 4815.863
# iter: 2, error: 16.527
# current_time:  2.05
# iter: 1, error: 4193.315
# iter: 2, error: 12.516
# current_time:  2.06
# iter: 1, error: 3542.845
# iter: 2, error: 8.925
# current_time:  2.07
# iter: 1, error: 2868.776
# iter: 2, error: 5.847
# current_time:  2.08
# iter: 1, error: 2175.589
# current_time:  2.09
# iter: 1, error: 1467.613
# current_time:  2.1
# iter: 1, error: 750.325
# current_time:  2.11
# iter: 1, error: 27.815
# current_time:  2.12
# iter: 1, error: 694.965
# current_time:  2.13
# iter: 1, error: 1413.222
# current_time:  2.14
# iter: 1, error: 2122.205
# current_time:  2.15
# iter: 1, error: 2817.216
# iter: 2, error: 5.585
# current_time:  2.16
# iter: 1, error: 3493.039
# iter: 2, error: 8.588
# current_time:  2.17
# iter: 1, error: 4145.990
# iter: 2, error: 12.098
# current_time:  2.18
# iter: 1, error: 4771.406
# iter: 2, error: 16.027
# current_time:  2.19
# iter: 1, error: 5365.113
# iter: 2, error: 20.269
# current_time:  2.2
# iter: 1, error: 5923.150
# iter: 2, error: 24.712
# current_time:  2.21
# iter: 1, error: 6441.790
# iter: 2, error: 29.239
# current_time:  2.22
# iter: 1, error: 6917.567
# iter: 2, error: 33.729
# current_time:  2.23
# iter: 1, error: 7347.299
# iter: 2, error: 38.062
# current_time:  2.24
# iter: 1, error: 7728.107
# iter: 2, error: 42.122
# current_time:  2.25
# iter: 1, error: 8057.438
# iter: 2, error: 45.799
# current_time:  2.2600000000000002
# iter: 1, error: 8333.082
# iter: 2, error: 48.995
# current_time:  2.27
# iter: 1, error: 8553.186
# iter: 2, error: 51.622
# current_time:  2.2800000000000002
# iter: 1, error: 8716.266
# iter: 2, error: 53.609
# current_time:  2.29
# iter: 1, error: 8821.220
# iter: 2, error: 54.902
# current_time:  2.3000000000000003
# iter: 1, error: 8867.334
# iter: 2, error: 55.466
# current_time:  2.31
# iter: 1, error: 8854.288
# iter: 2, error: 55.286
# current_time:  2.32
# iter: 1, error: 8782.157
# iter: 2, error: 54.366
# current_time:  2.33
# iter: 1, error: 8651.413
# iter: 2, error: 52.732
# current_time:  2.34
# iter: 1, error: 8462.920
# iter: 2, error: 50.429
# current_time:  2.35
# iter: 1, error: 8217.929
# iter: 2, error: 47.520
# current_time:  2.36
# iter: 1, error: 7918.070
# iter: 2, error: 44.084
# current_time:  2.37
# iter: 1, error: 7565.341
# iter: 2, error: 40.214
# current_time:  2.38
# iter: 1, error: 7162.096
# iter: 2, error: 36.014
# current_time:  2.39
# iter: 1, error: 6711.027
# iter: 2, error: 31.597
# current_time:  2.4
# iter: 1, error: 6215.145
# iter: 2, error: 27.082
# current_time:  2.41
# iter: 1, error: 5677.766
# iter: 2, error: 22.588
# current_time:  2.42
# iter: 1, error: 5102.479
# iter: 2, error: 18.234
# current_time:  2.43
# iter: 1, error: 4493.130
# iter: 2, error: 14.134
# current_time:  2.44
# iter: 1, error: 3853.794
# iter: 2, error: 10.397
# current_time:  2.45
# iter: 1, error: 3188.744
# iter: 2, error: 7.120
# current_time:  2.46
# iter: 1, error: 2502.427
# iter: 2, error: 4.388
# current_time:  2.47
# iter: 1, error: 1799.431
# current_time:  2.48
# iter: 1, error: 1084.578
# current_time:  2.49
# iter: 1, error: 362.359
# current_time:  2.5
# iter: 1, error: 362.260
# current_time:  2.5100000000000002
# iter: 1, error: 1084.343
# current_time:  2.52
# iter: 1, error: 1799.088
# current_time:  2.5300000000000002
# iter: 1, error: 2501.743
# current_time:  2.54
# iter: 1, error: 3187.638
# iter: 2, error: 7.122
# current_time:  2.5500000000000003
# iter: 1, error: 3852.442
# iter: 2, error: 10.446
# current_time:  2.56
# iter: 1, error: 4491.282
# iter: 2, error: 14.227
# current_time:  2.57
# iter: 1, error: 5100.087
# iter: 2, error: 18.380
# current_time:  2.58
# iter: 1, error: 5674.793
# iter: 2, error: 22.799
# current_time:  2.59
# iter: 1, error: 6211.567
# iter: 2, error: 27.368
# current_time:  2.6
# iter: 1, error: 6706.836
# iter: 2, error: 31.966
# current_time:  2.61
# iter: 1, error: 7157.300
# iter: 2, error: 36.471
# current_time:  2.62
# iter: 1, error: 7559.963
# iter: 2, error: 40.760
# current_time:  2.63
# iter: 1, error: 7912.147
# iter: 2, error: 44.719
# current_time:  2.64
# iter: 1, error: 8211.515
# iter: 2, error: 48.239
# current_time:  2.65
# iter: 1, error: 8456.080
# iter: 2, error: 51.222
# current_time:  2.66
# iter: 1, error: 8644.224
# iter: 2, error: 53.587
# current_time:  2.67
# iter: 1, error: 8774.707
# iter: 2, error: 55.268
# current_time:  2.68
# iter: 1, error: 8846.671
# iter: 2, error: 56.218
# current_time:  2.69
# iter: 1, error: 8859.651
# iter: 2, error: 56.411
# current_time:  2.7
# iter: 1, error: 8813.573
# iter: 2, error: 55.839
# current_time:  2.71
# iter: 1, error: 8708.759
# iter: 2, error: 54.521
# current_time:  2.72
# iter: 1, error: 8545.919
# iter: 2, error: 52.491
# current_time:  2.73
# iter: 1, error: 8326.150
# iter: 2, error: 49.805
# current_time:  2.74
# iter: 1, error: 8050.925
# iter: 2, error: 46.539
# current_time:  2.75
# iter: 1, error: 7722.088
# iter: 2, error: 42.782
# current_time:  2.7600000000000002
# iter: 1, error: 7341.835
# iter: 2, error: 38.636
# current_time:  2.77
# iter: 1, error: 6912.705
# iter: 2, error: 34.215
# current_time:  2.7800000000000002
# iter: 1, error: 6437.557
# iter: 2, error: 29.639
# current_time:  2.79
# iter: 1, error: 5919.559
# iter: 2, error: 25.031
# current_time:  2.8000000000000003
# iter: 1, error: 5362.157
# iter: 2, error: 20.513
# current_time:  2.81
# iter: 1, error: 4769.061
# iter: 2, error: 16.206
# current_time:  2.82
# iter: 1, error: 4144.216
# iter: 2, error: 12.223
# current_time:  2.83
# iter: 1, error: 3491.775
# iter: 2, error: 8.669
# current_time:  2.84
# iter: 1, error: 2816.075
# iter: 2, error: 5.634
# current_time:  2.85
# iter: 1, error: 2121.606
# current_time:  2.86
# iter: 1, error: 1412.721
# current_time:  2.87
# iter: 1, error: 694.865
# current_time:  2.88
# iter: 1, error: 27.840
# current_time:  2.89
# iter: 1, error: 750.437
# current_time:  2.9
# iter: 1, error: 1468.149
# current_time:  2.91
# iter: 1, error: 2176.223
# current_time:  2.92
# iter: 1, error: 2869.967
# iter: 2, error: 5.796
# current_time:  2.93
# iter: 1, error: 3544.146
# iter: 2, error: 8.841
# current_time:  2.94
# iter: 1, error: 4195.131
# iter: 2, error: 12.387
# current_time:  2.95
# iter: 1, error: 4818.253
# iter: 2, error: 16.343
# current_time:  2.96
# iter: 1, error: 5409.354
# iter: 2, error: 20.605
# current_time:  2.97
# iter: 1, error: 5964.490
# iter: 2, error: 25.059
# current_time:  2.98
# iter: 1, error: 6479.952
# iter: 2, error: 29.587
# current_time:  2.99
# iter: 1, error: 6952.297
# iter: 2, error: 34.069
# current_time:  3.0
# iter: 1, error: 7378.363
# iter: 2, error: 38.386
# current_time:  3.0100000000000002
# iter: 1, error: 7755.298
# iter: 2, error: 42.420
# current_time:  3.02
# iter: 1, error: 8080.574
# iter: 2, error: 46.064
# current_time:  3.0300000000000002
# iter: 1, error: 8352.007
# iter: 2, error: 49.218
# current_time:  3.04
# iter: 1, error: 8567.771
# iter: 2, error: 51.798
# current_time:  3.0500000000000003
# iter: 1, error: 8726.414
# iter: 2, error: 53.734
# current_time:  3.06
# iter: 1, error: 8826.862
# iter: 2, error: 54.972
# current_time:  3.0700000000000003
# iter: 1, error: 8868.432
# iter: 2, error: 55.479
# current_time:  3.08
# iter: 1, error: 8850.833
# iter: 2, error: 55.241
# current_time:  3.09
# iter: 1, error: 8774.172
# iter: 2, error: 54.265
# current_time:  3.1
# iter: 1, error: 8638.950
# iter: 2, error: 52.578
# current_time:  3.11
# iter: 1, error: 8446.062
# iter: 2, error: 50.226
# current_time:  3.12
# iter: 1, error: 8196.787
# iter: 2, error: 47.273
# current_time:  3.13
# iter: 1, error: 7892.786
# iter: 2, error: 43.800
# current_time:  3.14
# iter: 1, error: 7536.084
# iter: 2, error: 39.901
# current_time:  3.15
# iter: 1, error: 7129.060
# iter: 2, error: 35.680
# current_time:  3.16
# iter: 1, error: 6674.433
# iter: 2, error: 31.252
# current_time:  3.17
# iter: 1, error: 6175.238
# iter: 2, error: 26.734
# current_time:  3.18
# iter: 1, error: 5634.811
# iter: 2, error: 22.247
# current_time:  3.19
# iter: 1, error: 5056.764
# iter: 2, error: 17.908
# current_time:  3.2
# iter: 1, error: 4444.962
# iter: 2, error: 13.833
# current_time:  3.21
# iter: 1, error: 3803.494
# iter: 2, error: 10.128
# current_time:  3.22
# iter: 1, error: 3136.648
# iter: 2, error: 6.889
# current_time:  3.23
# iter: 1, error: 2448.884
# iter: 2, error: 4.202
# current_time:  3.24
# iter: 1, error: 1744.798
# current_time:  3.25
# iter: 1, error: 1029.213
# current_time:  3.2600000000000002
# iter: 1, error: 306.638
# current_time:  3.27
# iter: 1, error: 417.956
# current_time:  3.2800000000000002
# iter: 1, error: 1139.645
# current_time:  3.29
# iter: 1, error: 1853.628
# current_time:  3.3000000000000003
# iter: 1, error: 2555.158
# current_time:  3.31
# iter: 1, error: 3239.574
# iter: 2, error: 7.356
# current_time:  3.3200000000000003
# iter: 1, error: 3902.555
# iter: 2, error: 10.720
# current_time:  3.33
# iter: 1, error: 4539.233
# iter: 2, error: 14.534
# current_time:  3.34
# iter: 1, error: 5145.556
# iter: 2, error: 18.712
# current_time:  3.35
# iter: 1, error: 5717.477
# iter: 2, error: 23.146
# current_time:  3.36
# iter: 1, error: 6251.182
# iter: 2, error: 27.722
# current_time:  3.37
# iter: 1, error: 6743.117
# iter: 2, error: 32.317
# current_time:  3.38
# iter: 1, error: 7190.007
# iter: 2, error: 36.810
# current_time:  3.39
# iter: 1, error: 7588.878
# iter: 2, error: 41.078
# current_time:  3.4
# iter: 1, error: 7937.078
# iter: 2, error: 45.007
# current_time:  3.41
# iter: 1, error: 8232.296
# iter: 2, error: 48.488
# current_time:  3.42
# iter: 1, error: 8472.574
# iter: 2, error: 51.427
# current_time:  3.43
# iter: 1, error: 8656.322
# iter: 2, error: 53.742
# current_time:  3.44
# iter: 1, error: 8782.328
# iter: 2, error: 55.368
# current_time:  3.45
# iter: 1, error: 8849.767
# iter: 2, error: 56.260
# current_time:  3.46
# iter: 1, error: 8858.201
# iter: 2, error: 56.394
# current_time:  3.47
# iter: 1, error: 8807.589
# iter: 2, error: 55.764
# current_time:  3.48
# iter: 1, error: 8698.281
# iter: 2, error: 54.389
# current_time:  3.49
# iter: 1, error: 8531.018
# iter: 2, error: 52.307
# current_time:  3.5
# iter: 1, error: 8306.926
# iter: 2, error: 49.574
# current_time:  3.5100000000000002
# iter: 1, error: 8027.508
# iter: 2, error: 46.266
# current_time:  3.52
# iter: 1, error: 7694.633
# iter: 2, error: 42.475
# current_time:  3.5300000000000002
# iter: 1, error: 7310.526
# iter: 2, error: 38.304
# current_time:  3.54
# iter: 1, error: 6877.750
# iter: 2, error: 33.867
# current_time:  3.5500000000000003
# iter: 1, error: 6399.190
# iter: 2, error: 29.284
# current_time:  3.56
# iter: 1, error: 5878.035
# iter: 2, error: 24.678
# current_time:  3.5700000000000003
# iter: 1, error: 5317.753
# iter: 2, error: 20.173
# current_time:  3.58
# iter: 1, error: 4722.072
# iter: 2, error: 15.887
# current_time:  3.59
# iter: 1, error: 4094.954
# iter: 2, error: 11.934
# current_time:  3.6
# iter: 1, error: 3440.567
# iter: 2, error: 8.416
# current_time:  3.61
# iter: 1, error: 2763.262
# iter: 2, error: 5.425
# current_time:  3.62
# iter: 1, error: 2067.540
# current_time:  3.63
# iter: 1, error: 1357.774
# current_time:  3.64
# iter: 1, error: 639.378
# current_time:  3.65
# iter: 1, error: 83.488
# current_time:  3.66
# iter: 1, error: 805.880
# current_time:  3.67
# iter: 1, error: 1523.019
# current_time:  3.68
# iter: 1, error: 2230.156
# current_time:  3.69
# iter: 1, error: 2922.606
# iter: 2, error: 6.010
# current_time:  3.7
# iter: 1, error: 3595.114
# iter: 2, error: 9.097
# current_time:  3.71
# iter: 1, error: 4244.108
# iter: 2, error: 12.678
# current_time:  3.72
# iter: 1, error: 4864.911
# iter: 2, error: 16.662
# current_time:  3.73
# iter: 1, error: 5453.383
# iter: 2, error: 20.942
# current_time:  3.74
# iter: 1, error: 6005.595
# iter: 2, error: 25.406
# current_time:  3.75
# iter: 1, error: 6517.859
# iter: 2, error: 29.935
# current_time:  3.7600000000000002
# iter: 1, error: 6986.753
# iter: 2, error: 34.409
# current_time:  3.77
# iter: 1, error: 7409.137
# iter: 2, error: 38.707
# current_time:  3.7800000000000002
# iter: 1, error: 7782.183
# iter: 2, error: 42.715
# current_time:  3.79
# iter: 1, error: 8103.390
# iter: 2, error: 46.325
# current_time:  3.8000000000000003
# iter: 1, error: 8370.601
# iter: 2, error: 49.438
# current_time:  3.81
# iter: 1, error: 8582.019
# iter: 2, error: 51.971
# current_time:  3.8200000000000003
# iter: 1, error: 8736.218
# iter: 2, error: 53.854
# current_time:  3.83
# iter: 1, error: 8832.156
# iter: 2, error: 55.037
# current_time:  3.84
# iter: 1, error: 8869.180
# iter: 2, error: 55.487
# current_time:  3.85
# iter: 1, error: 8847.029
# iter: 2, error: 55.192
# current_time:  3.86
# iter: 1, error: 8765.841
# iter: 2, error: 54.160
# current_time:  3.87
# iter: 1, error: 8626.146
# iter: 2, error: 52.420
# current_time:  3.88
# iter: 1, error: 8428.870
# iter: 2, error: 50.019
# current_time:  3.89
# iter: 1, error: 8175.322
# iter: 2, error: 47.024
# current_time:  3.9
# iter: 1, error: 7867.190
# iter: 2, error: 43.514
# current_time:  3.91
# iter: 1, error: 7506.528
# iter: 2, error: 39.586
# current_time:  3.92
# iter: 1, error: 7095.742
# iter: 2, error: 35.346
# current_time:  3.93
# iter: 1, error: 6637.574
# iter: 2, error: 30.906
# current_time:  3.94
# iter: 1, error: 6135.086
# iter: 2, error: 26.386
# current_time:  3.95
# iter: 1, error: 5591.634
# iter: 2, error: 21.906
# current_time:  3.96
# iter: 1, error: 5010.850
# iter: 2, error: 17.584
# current_time:  3.97
# iter: 1, error: 4396.618
# iter: 2, error: 13.533
# current_time:  3.98
# iter: 1, error: 3753.043
# iter: 2, error: 9.861
# current_time:  3.99
# iter: 1, error: 3084.428
# iter: 2, error: 6.662
# current_time:  4.0
# iter: 1, error: 2395.243
# iter: 2, error: 4.021
# current_time:  4.01
# iter: 1, error: 1690.096
# current_time:  4.0200000000000005
# iter: 1, error: 973.808
# current_time:  4.03
# iter: 1, error: 250.907
# current_time:  4.04
# iter: 1, error: 473.635
# current_time:  4.05
# iter: 1, error: 1194.901
# current_time:  4.0600000000000005
# iter: 1, error: 1908.094
# current_time:  4.07
# iter: 1, error: 2608.472
# current_time:  4.08
# iter: 1, error: 3291.381
# iter: 2, error: 7.594
# current_time:  4.09
# iter: 1, error: 3952.513
# iter: 2, error: 10.998
# current_time:  4.1
# iter: 1, error: 4587.004
# iter: 2, error: 14.844
# current_time:  4.11
# iter: 1, error: 5190.822
# iter: 2, error: 19.045
# current_time:  4.12
# iter: 1, error: 5759.935
# iter: 2, error: 23.495
# current_time:  4.13
# iter: 1, error: 6290.550
# iter: 2, error: 28.076
# current_time:  4.14
# iter: 1, error: 6779.133
# iter: 2, error: 32.668
# current_time:  4.15
# iter: 1, error: 7222.430
# iter: 2, error: 37.148
# current_time:  4.16
# iter: 1, error: 7617.493
# iter: 2, error: 41.394
# current_time:  4.17
# iter: 1, error: 7961.695
# iter: 2, error: 45.292
# current_time:  4.18
# iter: 1, error: 8252.752
# iter: 2, error: 48.735
# current_time:  4.19
# iter: 1, error: 8488.733
# iter: 2, error: 51.628
# current_time:  4.2
# iter: 1, error: 8668.078
# iter: 2, error: 53.892
# current_time:  4.21
# iter: 1, error: 8789.603
# iter: 2, error: 55.463
# current_time:  4.22
# iter: 1, error: 8852.513
# iter: 2, error: 56.298
# current_time:  4.23
# iter: 1, error: 8856.402
# iter: 2, error: 56.372
# current_time:  4.24
# iter: 1, error: 8801.258
# iter: 2, error: 55.685
# current_time:  4.25
# iter: 1, error: 8687.461
# iter: 2, error: 54.253
# current_time:  4.26
# iter: 1, error: 8515.781
# iter: 2, error: 52.119
# current_time:  4.2700000000000005
# iter: 1, error: 8287.375
# iter: 2, error: 49.339
# current_time:  4.28
# iter: 1, error: 8003.773
# iter: 2, error: 45.991
# current_time:  4.29
# iter: 1, error: 7666.874
# iter: 2, error: 42.167
# current_time:  4.3
# iter: 1, error: 7278.928
# iter: 2, error: 37.971
# current_time:  4.3100000000000005
# iter: 1, error: 6842.524
# iter: 2, error: 33.518
# current_time:  4.32
# iter: 1, error: 6360.571
# iter: 2, error: 28.929
# current_time:  4.33
# iter: 1, error: 5836.279
# iter: 2, error: 24.327
# current_time:  4.34
# iter: 1, error: 5273.139
# iter: 2, error: 19.834
# current_time:  4.3500000000000005
# iter: 1, error: 4674.896
# iter: 2, error: 15.570
# current_time:  4.36
# iter: 1, error: 4045.530
# iter: 2, error: 11.646
# current_time:  4.37
# iter: 1, error: 3389.224
# iter: 2, error: 8.166
# current_time:  4.38
# iter: 1, error: 2710.341
# iter: 2, error: 5.219
# current_time:  4.39
# iter: 1, error: 2013.392
# current_time:  4.4
# iter: 1, error: 1302.772
# current_time:  4.41
# iter: 1, error: 583.865
# current_time:  4.42
# iter: 1, error: 139.134
# current_time:  4.43
# iter: 1, error: 861.292
# current_time:  4.44
# iter: 1, error: 1577.829
# current_time:  4.45
# iter: 1, error: 2284.002
# current_time:  4.46
# iter: 1, error: 2975.130
# iter: 2, error: 6.228
# current_time:  4.47
# iter: 1, error: 3645.941
# iter: 2, error: 9.356
# current_time:  4.48
# iter: 1, error: 4292.917
# iter: 2, error: 12.971
# current_time:  4.49
# iter: 1, error: 4911.378
# iter: 2, error: 16.982
# current_time:  4.5
# iter: 1, error: 5497.196
# iter: 2, error: 21.281
# current_time:  4.51
# iter: 1, error: 6046.463
# iter: 2, error: 25.754
# current_time:  4.5200000000000005
# iter: 1, error: 6555.510
# iter: 2, error: 30.283
# current_time:  4.53
# iter: 1, error: 7020.933
# iter: 2, error: 34.747
# current_time:  4.54
# iter: 1, error: 7439.618
# iter: 2, error: 39.027
# current_time:  4.55
# iter: 1, error: 7808.762
# iter: 2, error: 43.008
# current_time:  4.5600000000000005
# iter: 1, error: 8125.887
# iter: 2, error: 46.583
# current_time:  4.57
# iter: 1, error: 8388.865
# iter: 2, error: 49.655
# current_time:  4.58
# iter: 1, error: 8595.927
# iter: 2, error: 52.140
# current_time:  4.59
# iter: 1, error: 8745.677
# iter: 2, error: 53.971
# current_time:  4.6000000000000005
# iter: 1, error: 8837.102
# iter: 2, error: 55.098
# current_time:  4.61
# iter: 1, error: 8869.578
# iter: 2, error: 55.491
# current_time:  4.62
# iter: 1, error: 8842.876
# iter: 2, error: 55.139
# current_time:  4.63
# iter: 1, error: 8757.163
# iter: 2, error: 54.051
# current_time:  4.64
# iter: 1, error: 8613.001
# iter: 2, error: 52.258
# current_time:  4.65
# iter: 1, error: 8411.345
# iter: 2, error: 49.809
# current_time:  4.66
# iter: 1, error: 8153.533
# iter: 2, error: 46.771
# current_time:  4.67
# iter: 1, error: 7841.283
# iter: 2, error: 43.226
# current_time:  4.68
# iter: 1, error: 7476.676
# iter: 2, error: 39.270
# current_time:  4.69
# iter: 1, error: 7062.143
# iter: 2, error: 35.010
# current_time:  4.7
# iter: 1, error: 6600.454
# iter: 2, error: 30.560
# current_time:  4.71
# iter: 1, error: 6094.691
# iter: 2, error: 26.039
# current_time:  4.72
# iter: 1, error: 5548.235
# iter: 2, error: 21.566
# current_time:  4.73
# iter: 1, error: 4964.738
# iter: 2, error: 17.261
# current_time:  4.74
# iter: 1, error: 4348.100
# iter: 2, error: 13.236
# current_time:  4.75
# iter: 1, error: 3702.444
# iter: 2, error: 9.597
# current_time:  4.76
# iter: 1, error: 3032.086
# iter: 2, error: 6.438
# current_time:  4.7700000000000005
# iter: 1, error: 2341.508
# current_time:  4.78
# iter: 1, error: 1635.536
# current_time:  4.79
# iter: 1, error: 918.453
# current_time:  4.8
# iter: 1, error: 195.167
# current_time:  4.8100000000000005
# iter: 1, error: 529.295
# current_time:  4.82
# iter: 1, error: 1250.110
# current_time:  4.83
# iter: 1, error: 1962.484
# current_time:  4.84
# iter: 1, error: 2661.682
# current_time:  4.8500000000000005
# iter: 1, error: 3343.058
# iter: 2, error: 7.834
# current_time:  4.86
# iter: 1, error: 4002.314
# iter: 2, error: 11.279
# current_time:  4.87
# iter: 1, error: 4634.593
# iter: 2, error: 15.156
# current_time:  4.88
# iter: 1, error: 5235.882
# iter: 2, error: 19.380
# current_time:  4.89
# iter: 1, error: 5802.165
# iter: 2, error: 23.844
# current_time:  4.9
# iter: 1, error: 6329.669
# iter: 2, error: 28.431
# current_time:  4.91
# iter: 1, error: 6814.880
# iter: 2, error: 33.018
# current_time:  4.92
# iter: 1, error: 7254.567
# iter: 2, error: 37.484
# current_time:  4.93
# iter: 1, error: 7645.807
# iter: 2, error: 41.707
# current_time:  4.94
# iter: 1, error: 7985.998
# iter: 2, error: 45.574
# current_time:  4.95
# iter: 1, error: 8272.882
# iter: 2, error: 48.978
# current_time:  4.96
# iter: 1, error: 8504.557
# iter: 2, error: 51.825
# current_time:  4.97
# iter: 1, error: 8679.491
# iter: 2, error: 54.038
# current_time:  4.98
# iter: 1, error: 8796.531
# iter: 2, error: 55.554
# current_time:  4.99
# iter: 1, error: 8854.910
# iter: 2, error: 56.330
# current_time:  5.0

# %% [markdown]
# ### Plotting

# %%
t = np.arange(robot.sim_params.total_time, step=robot.sim_params.dt)
options = dismech.AnimationOptions(title='Tomato2', plot_step=10)

fig = dismech.get_interactive_animation_plotly(robot, t, qs , options)
fig.show()

# %%
# # save gif
# ani = dismech.get_animation(robot, t, qs, options)
# save_path = os.path.join("tomato_results", f"{plant_name}_{position}.gif")
# ani.save(save_path)

# %%
# plot the trajectory of the flower location
flower_node = 73  # pick a node at the flower

import matplotlib.pyplot as plt

# Extract the DOF indices (x, y, z) of the node you want to track
flower_node_dofs = robot.map_node_to_dof(flower_node)  # e.g., [ix, iy, iz]

# Extract position of that node across all timesteps
logged = qs[:, flower_node_dofs].squeeze()  # shape (n_timesteps, 3)

# remove value at t=0
logged -= robot.nodes[flower_node]

# Plot x, y, z over time
t = np.arange(qs.shape[0]) * robot.sim_params.dt

plt.figure(figsize=(10, 4))
plt.plot(t, logged[:, 0], label='x')
plt.plot(t, logged[:, 1], label='y')
plt.plot(t, logged[:, 2], label='z')
plt.xlabel('Time (s)')
plt.ylabel('Position')
plt.title(f'Position of Node {flower_node} Over Time')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Save data for rendering

# %%
# from dismech.logging import logDataForRendering
# from dismech.logging import export_parachute_data

# rod_data, shell_data = logDataForRendering(qs, t.reshape(-1, 1), robot, len(t), robot.sim_params.static_sim, robot.map_node_to_dof)

# js_file = os.path.join("tomato_results", f"{plant_name}_{position}.js")
# export_parachute_data(qs, geo.rod_edges, robot,
#                           rod_js=js_file,
#                           scaleFactor=100)

# %%
import numpy as np
from scipy.signal import hilbert, detrend, find_peaks

def avg_cycle_amplitude_hilbert(x: np.ndarray) -> float:
    """
    Robust average oscillation amplitude using the analytic-signal envelope.
    Returns the median envelope value (less sensitive to outliers).
    """
    x = np.asarray(x).ravel()
    x = detrend(x)  # remove slow drift
    envelope = np.abs(hilbert(x))
    # Use median to resist occasional spikes; mean is also fine.
    return float(np.median(envelope))

# %%
# amplitude of flower node motion
amp_x_flower_hilbert = avg_cycle_amplitude_hilbert(logged[:, 0]) # hilbert-based amplitude
amp_x_flower_peak = (np.max(logged[:, 0]) - np.min(logged[:, 0])) / 2.0 # peak-to-peak amplitude
print(f"Amplitude of flower node {flower_node} motion in x (peak-to-peak): {amp_x_flower_peak:.4f} m")
print(f"Amplitude of flower node {flower_node} motion in x (hilbert): {amp_x_flower_hilbert:.4f} m")
# Out:
# Amplitude of flower node 73 motion in x (peak-to-peak): 0.0042 m
# Amplitude of flower node 73 motion in x (hilbert): 0.0042 m

# %% [markdown]
# #### Estimate frequency

# %%
import numpy as np

def estimate_frequency(signal, dt):
    """
    Estimate dominant frequency of a periodic signal using FFT.
    
    Parameters
    ----------
    signal : 1D np.ndarray
        The time-varying signal (samples).
    dt : float
        Time step between samples.
    
    Returns
    -------
    freq : float
        Dominant frequency (Hz).
    """
    n = len(signal)
    # Remove mean to avoid 0 Hz dominance
    signal = signal - np.mean(signal)

    # FFT
    freqs = np.fft.rfftfreq(n, d=dt)       # frequency bins (Hz)
    fft_vals = np.fft.rfft(signal)         # FFT coefficients
    magnitude = np.abs(fft_vals)

    # Find the peak frequency (excluding DC = 0 Hz)
    peak_idx = np.argmax(magnitude[1:]) + 1
    freq = freqs[peak_idx]
    return freq


# Example: make a sine wave of 5 Hz, sample at 100 Hz

f_est = estimate_frequency(logged[:, 0], robot.sim_params.dt)
print(f"Estimated frequency: {f_est:.2f} Hz")   # ~5.00 Hz
# Out:
# Estimated frequency: 1.20 Hz
