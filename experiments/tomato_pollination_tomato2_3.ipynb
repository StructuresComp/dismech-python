# %% [markdown]
# ## Tomato Pollination: Tomato 2

# %%
import numpy as np
import dismech
import os

plant_name = "tomato2"

position = "3"

geom = dismech.GeomParams(
    rod_r0=0.059,
    shell_h=0.0,
)

material = dismech.Material(density=1500,
                            youngs_rod=3.16e7,
                            youngs_shell=0,
                            poisson_rod=0.5,
                            poisson_shell=0)

dyn_sim = dismech.SimParams(static_sim=False,
                                  two_d_sim=True,   # no twisting
                                  use_mid_edge=False,
                                  use_line_search=False,
                                  show_floor=False,
                                  log_data=True,
                                  log_step=1,
                                  dt=1e-2,
                                  max_iter=50,
                                  total_time=5,
                                  plot_step=10,
                                  tol=1e-4,
                                  ftol=1e-4,
                                  dtol=1e-2
                                  )

env = dismech.Environment()
env.add_force('gravity', g=np.array([0.0, 0.0, -9.81]))
env.add_force('damping', eta=100)

input_txt = os.path.join('../tests/resources/tomato_pollination/plants/', f"{plant_name}.txt")
geo = dismech.Geometry.from_txt(input_txt)

robot = dismech.SoftRobot(geom, material, geo, dyn_sim, env)

# %% [markdown]
# ### Move the stem: Moving BC

# %%
# # --- pick the main grip node robustly ---
# grasping_point = np.array([
#       1.1154284,
#       0.0092739,
#       0.4896594
#     ])
# xyz = robot.state.q[robot.node_dof_indices].reshape(-1, 3)

main_grip = 27  # node at the main grip

print("Main grip node:", main_grip)

other_grip_nodes_below = np.array(range(main_grip-4, main_grip), dtype=int)
other_grip_nodes_above = np.arange(main_grip+4, main_grip, -1, dtype=int)

print("Other grip nodes below:", other_grip_nodes_below)
print("Other grip nodes above:", other_grip_nodes_above)
# Out:
# Main grip node: 27
# Other grip nodes below: [23 24 25 26]
# Other grip nodes above: [31 30 29 28]

# %%
base_nodes = np.where((robot.state.q[robot.node_dof_indices].reshape(-1, 3)[:, 2]) < 0.22)[0] # fixed base
# Fix only main_grip and base nodes
robot = robot.fix_nodes(np.unique(np.r_[main_grip, base_nodes]))

# %%
# ----- once, before simulation -----

all_grip_nodes = np.r_[main_grip, other_grip_nodes_below, other_grip_nodes_above].astype(int)

xyz0 = robot.state.q[robot.node_dof_indices].reshape(-1, 3).copy()
x0 = xyz0[all_grip_nodes, 0].copy()          # initial x of all prescribed nodes
prev_target_x = x0.copy()                     # last absolute target (starts at initial)

# (Optional) precompute amplitude scalings from *initial* geometry
def build_amps_from_xyz0(xyz0, main_grip, all_grip_nodes, A_main):
    amps = np.empty(all_grip_nodes.size, float)
    amps[0] = A_main  # main_grip
    # below group
    below = np.array(other_grip_nodes_below, dtype=int)
    if below.size:
        ref = below[0]
        L = max(np.linalg.norm(xyz0[main_grip]-xyz0[ref]), 1e-12)
        for j, node in enumerate(below, start=1):  # start=1 because 0 is main_grip
            amps[j] = A_main * (np.linalg.norm(xyz0[ref]-xyz0[node]) / L)
    # above group
    above = np.array(other_grip_nodes_above, dtype=int)
    if above.size:
        ref = above[0]
        offset = 1 + below.size
        L = max(np.linalg.norm(xyz0[main_grip]-xyz0[ref]), 1e-12)
        for j, node in enumerate(above, start=offset):
            amps[j] = A_main * (np.linalg.norm(xyz0[ref]-xyz0[node]) / L)
    return amps

A_main = 12e-3   # m at main_grip
freq   = 1.0    # Hz
amps   = build_amps_from_xyz0(xyz0, main_grip, all_grip_nodes, A_main)

def shake_distributed(robot, t: float):
    # absolute target centered at initial pose
    target_x = x0 + amps * np.sin(2*np.pi*freq*t)

    # INCREMENT ONLY: avoids velocity spikes and keeps symmetry
    delta_x = target_x - prev_target_x
    prev_target_x[:] = target_x

    return robot.move_nodes(all_grip_nodes, delta_x.reshape(-1,1).flatten(), axis=0)

print("grasping points:", all_grip_nodes)
# Out:
# grasping points: [27 23 24 25 26 31 30 29 28]

# %%
stepper = dismech.ImplicitEulerTimeStepper(robot)
stepper.before_step = shake_distributed

# %% [markdown]
# ### Simulate

# %%
# simulate
robots = stepper.simulate()

qs = np.stack([robot.state.q for robot in robots])
# Out:
# iter: 1, error: 529106.746
# iter: 2, error: 17752.290
# iter: 3, error: 631.018
# current_time:  0.01
# iter: 1, error: 527126.557
# iter: 2, error: 18506.152
# iter: 3, error: 1200.096
# current_time:  0.02
# iter: 1, error: 523066.334
# iter: 2, error: 18487.497
# iter: 3, error: 1337.813
# current_time:  0.03
# iter: 1, error: 516942.790
# iter: 2, error: 17466.375
# iter: 3, error: 1091.183
# current_time:  0.04
# iter: 1, error: 508751.947
# iter: 2, error: 16329.596
# iter: 3, error: 840.818
# current_time:  0.05
# iter: 1, error: 498520.748
# iter: 2, error: 15278.977
# iter: 3, error: 690.798
# current_time:  0.06
# iter: 1, error: 486302.671
# iter: 2, error: 14227.820
# iter: 3, error: 598.817
# current_time:  0.07
# iter: 1, error: 472157.487
# iter: 2, error: 13106.229
# iter: 3, error: 517.696
# current_time:  0.08
# iter: 1, error: 456144.514
# iter: 2, error: 11903.896
# iter: 3, error: 431.705
# current_time:  0.09
# iter: 1, error: 438325.898
# iter: 2, error: 10652.035
# iter: 3, error: 345.792
# current_time:  0.1
# iter: 1, error: 418770.691
# iter: 2, error: 9391.643
# iter: 3, error: 268.045
# current_time:  0.11
# iter: 1, error: 397556.178
# iter: 2, error: 8155.772
# iter: 3, error: 202.209
# current_time:  0.12
# iter: 1, error: 374767.220
# iter: 2, error: 6968.488
# current_time:  0.13
# iter: 1, error: 350418.970
# iter: 2, error: 5840.701
# current_time:  0.14
# iter: 1, error: 324784.085
# iter: 2, error: 4806.927
# current_time:  0.15
# iter: 1, error: 297859.670
# iter: 2, error: 3867.921
# current_time:  0.16
# iter: 1, error: 269754.067
# iter: 2, error: 3032.566
# current_time:  0.17
# iter: 1, error: 240579.835
# iter: 2, error: 2305.639
# current_time:  0.18
# iter: 1, error: 210453.716
# iter: 2, error: 1688.103
# current_time:  0.19
# iter: 1, error: 179496.112
# iter: 2, error: 1177.519
# current_time:  0.2
# iter: 1, error: 147830.563
# iter: 2, error: 768.713
# current_time:  0.21
# iter: 1, error: 115583.214
# iter: 2, error: 454.705
# current_time:  0.22
# iter: 1, error: 82882.292
# iter: 2, error: 227.844
# current_time:  0.23
# iter: 1, error: 49857.601
# current_time:  0.24
# iter: 1, error: 16638.065
# current_time:  0.25
# iter: 1, error: 16635.734
# current_time:  0.26
# iter: 1, error: 49848.191
# current_time:  0.27
# iter: 1, error: 82857.741
# iter: 2, error: 226.155
# current_time:  0.28
# iter: 1, error: 115529.456
# iter: 2, error: 461.980
# current_time:  0.29
# iter: 1, error: 147742.292
# iter: 2, error: 783.697
# current_time:  0.3
# iter: 1, error: 179365.973
# iter: 2, error: 1203.398
# current_time:  0.31
# iter: 1, error: 210274.613
# iter: 2, error: 1728.231
# current_time:  0.32
# iter: 1, error: 240345.254
# iter: 2, error: 2363.178
# current_time:  0.33
# iter: 1, error: 269458.091
# iter: 2, error: 3110.273
# current_time:  0.34
# iter: 1, error: 297496.965
# iter: 2, error: 3967.955
# current_time:  0.35000000000000003
# iter: 1, error: 324349.914
# iter: 2, error: 4930.622
# current_time:  0.36
# iter: 1, error: 349909.699
# iter: 2, error: 5988.424
# current_time:  0.37
# iter: 1, error: 374074.332
# iter: 2, error: 7127.258
# current_time:  0.38
# iter: 1, error: 396747.582
# iter: 2, error: 8328.991
# current_time:  0.39
# iter: 1, error: 417839.453
# iter: 2, error: 9571.860
# iter: 3, error: 229.387
# current_time:  0.4
# iter: 1, error: 437444.306
# iter: 2, error: 10845.983
# iter: 3, error: 291.278
# current_time:  0.41000000000000003
# iter: 1, error: 455176.697
# iter: 2, error: 12100.391
# iter: 3, error: 358.290
# current_time:  0.42
# iter: 1, error: 471103.301
# iter: 2, error: 13316.405
# iter: 3, error: 430.334
# current_time:  0.43
# iter: 1, error: 485161.498
# iter: 2, error: 14464.902
# iter: 3, error: 505.370
# current_time:  0.44
# iter: 1, error: 497296.275
# iter: 2, error: 15517.051
# iter: 3, error: 580.589
# current_time:  0.45
# iter: 1, error: 507460.337
# iter: 2, error: 16445.359
# iter: 3, error: 652.643
# current_time:  0.46
# iter: 1, error: 515614.300
# iter: 2, error: 17224.673
# iter: 3, error: 717.932
# current_time:  0.47000000000000003
# iter: 1, error: 521726.870
# iter: 2, error: 17833.196
# iter: 3, error: 772.878
# current_time:  0.48
# iter: 1, error: 525774.986
# iter: 2, error: 18253.416
# iter: 3, error: 814.207
# current_time:  0.49
# iter: 1, error: 527743.905
# iter: 2, error: 18472.898
# iter: 3, error: 839.266
# current_time:  0.5
# iter: 1, error: 527627.240
# iter: 2, error: 18484.905
# iter: 3, error: 846.331
# current_time:  0.51
# iter: 1, error: 525426.951
# iter: 2, error: 18288.785
# iter: 3, error: 834.844
# current_time:  0.52
# iter: 1, error: 521153.315
# iter: 2, error: 17890.052
# iter: 3, error: 805.505
# current_time:  0.53
# iter: 1, error: 514824.848
# iter: 2, error: 17300.163
# iter: 3, error: 760.189
# current_time:  0.54
# iter: 1, error: 506468.194
# iter: 2, error: 16535.976
# iter: 3, error: 701.712
# current_time:  0.55
# iter: 1, error: 496117.989
# iter: 2, error: 15618.969
# iter: 3, error: 633.511
# current_time:  0.56
# iter: 1, error: 483816.672
# iter: 2, error: 14574.279
# iter: 3, error: 559.280
# current_time:  0.5700000000000001
# iter: 1, error: 469614.283
# iter: 2, error: 13429.646
# iter: 3, error: 482.651
# current_time:  0.58
# iter: 1, error: 453568.222
# iter: 2, error: 12214.318
# iter: 3, error: 406.923
# current_time:  0.59
# iter: 1, error: 435742.979
# iter: 2, error: 10957.962
# iter: 3, error: 334.876
# current_time:  0.6
# iter: 1, error: 416209.846
# iter: 2, error: 9689.631
# iter: 3, error: 268.667
# current_time:  0.61
# iter: 1, error: 395046.602
# iter: 2, error: 8436.817
# iter: 3, error: 209.786
# current_time:  0.62
# iter: 1, error: 372337.181
# iter: 2, error: 7224.608
# current_time:  0.63
# iter: 1, error: 348068.072
# iter: 2, error: 6069.187
# current_time:  0.64
# iter: 1, error: 322570.483
# iter: 2, error: 5002.714
# current_time:  0.65
# iter: 1, error: 295805.417
# iter: 2, error: 4030.668
# current_time:  0.66
# iter: 1, error: 267878.677
# iter: 2, error: 3163.218
# current_time:  0.67
# iter: 1, error: 238900.021
# iter: 2, error: 2406.345
# current_time:  0.68
# iter: 1, error: 208983.252
# iter: 2, error: 1761.962
# current_time:  0.6900000000000001
# iter: 1, error: 178245.681
# iter: 2, error: 1228.352
# current_time:  0.7000000000000001
# iter: 1, error: 146807.592
# iter: 2, error: 800.835
# current_time:  0.71
# iter: 1, error: 114791.737
# iter: 2, error: 472.660
# current_time:  0.72
# iter: 1, error: 82322.859
# iter: 2, error: 236.095
# current_time:  0.73
# iter: 1, error: 49527.237
# current_time:  0.74
# iter: 1, error: 16518.103
# current_time:  0.75
# iter: 1, error: 16532.174
# current_time:  0.76
# iter: 1, error: 49545.331
# current_time:  0.77
# iter: 1, error: 82382.821
# iter: 2, error: 229.518
# current_time:  0.78
# iter: 1, error: 114878.742
# iter: 2, error: 464.994
# current_time:  0.79
# iter: 1, error: 146950.021
# iter: 2, error: 785.675
# current_time:  0.8
# iter: 1, error: 178456.547
# iter: 2, error: 1202.684
# current_time:  0.81
# iter: 1, error: 209274.404
# iter: 2, error: 1723.062
# current_time:  0.8200000000000001
# iter: 1, error: 239282.183
# iter: 2, error: 2352.046
# current_time:  0.8300000000000001
# iter: 1, error: 268361.168
# iter: 2, error: 3092.150
# current_time:  0.84
# iter: 1, error: 296395.826
# iter: 2, error: 3942.430
# current_time:  0.85
# iter: 1, error: 323274.326
# iter: 2, error: 4897.956
# current_time:  0.86
# iter: 1, error: 348889.063
# iter: 2, error: 5949.519
# current_time:  0.87
# iter: 1, error: 373137.184
# iter: 2, error: 7083.556
# iter: 3, error: 198.524
# current_time:  0.88
# iter: 1, error: 396005.558
# iter: 2, error: 8296.933
# iter: 3, error: 266.495
# current_time:  0.89
# iter: 1, error: 417264.109
# iter: 2, error: 9547.947
# iter: 3, error: 344.837
# current_time:  0.9
# iter: 1, error: 436886.881
# iter: 2, error: 10820.075
# iter: 3, error: 433.827
# current_time:  0.91
# iter: 1, error: 454794.478
# iter: 2, error: 12085.682
# iter: 3, error: 531.476
# current_time:  0.92
# iter: 1, error: 470914.139
# iter: 2, error: 13315.336
# iter: 3, error: 634.902
# current_time:  0.93
# iter: 1, error: 485180.122
# iter: 2, error: 14478.454
# iter: 3, error: 740.277
# current_time:  0.9400000000000001
# iter: 1, error: 497534.020
# iter: 2, error: 15544.107
# iter: 3, error: 842.854
# current_time:  0.9500000000000001
# iter: 1, error: 507925.028
# iter: 2, error: 16482.158
# iter: 3, error: 937.202
# current_time:  0.96
# iter: 1, error: 516310.175
# iter: 2, error: 17264.676
# iter: 3, error: 1017.656
# current_time:  0.97
# iter: 1, error: 522654.530
# iter: 2, error: 17867.430
# iter: 3, error: 1078.903
# current_time:  0.98
# iter: 1, error: 526931.388
# iter: 2, error: 18271.330
# iter: 3, error: 1116.621
# current_time:  0.99
# iter: 1, error: 529122.402
# iter: 2, error: 18463.627
# iter: 3, error: 1128.055
# current_time:  1.0
# iter: 1, error: 529217.691
# iter: 2, error: 18438.726
# iter: 3, error: 1112.406
# current_time:  1.01
# iter: 1, error: 527215.887
# iter: 2, error: 18198.479
# iter: 3, error: 1070.955
# current_time:  1.02
# iter: 1, error: 523124.156
# iter: 2, error: 17751.895
# iter: 3, error: 1006.873
# current_time:  1.03
# iter: 1, error: 516958.168
# iter: 2, error: 17114.353
# iter: 3, error: 924.757
# current_time:  1.04
# iter: 1, error: 508742.033
# iter: 2, error: 16306.475
# iter: 3, error: 830.012
# current_time:  1.05
# iter: 1, error: 498508.195
# iter: 2, error: 15352.852
# iter: 3, error: 728.218
# current_time:  1.06
# iter: 1, error: 486297.285
# iter: 2, error: 14280.797
# iter: 3, error: 624.593
# current_time:  1.07
# iter: 1, error: 472157.938
# iter: 2, error: 13119.196
# iter: 3, error: 523.613
# current_time:  1.08
# iter: 1, error: 456146.578
# iter: 2, error: 11897.487
# iter: 3, error: 428.817
# current_time:  1.09
# iter: 1, error: 438327.161
# iter: 2, error: 10644.756
# iter: 3, error: 342.744
# current_time:  1.1
# iter: 1, error: 418770.895
# iter: 2, error: 9388.910
# iter: 3, error: 266.983
# current_time:  1.11
# iter: 1, error: 397555.925
# iter: 2, error: 8155.937
# iter: 3, error: 202.277
# current_time:  1.12
# iter: 1, error: 374766.991
# iter: 2, error: 6969.237
# current_time:  1.1300000000000001
# iter: 1, error: 350418.829
# iter: 2, error: 5841.080
# current_time:  1.1400000000000001
# iter: 1, error: 324784.079
# iter: 2, error: 4806.976
# current_time:  1.1500000000000001
# iter: 1, error: 297859.706
# iter: 2, error: 3867.863
# current_time:  1.16
# iter: 1, error: 269754.092
# iter: 2, error: 3032.523
# current_time:  1.17
# iter: 1, error: 240579.842
# iter: 2, error: 2305.627
# current_time:  1.18
# iter: 1, error: 210453.716
# iter: 2, error: 1688.106
# current_time:  1.19
# iter: 1, error: 179496.112
# iter: 2, error: 1177.523
# current_time:  1.2
# iter: 1, error: 147830.564
# iter: 2, error: 768.714
# current_time:  1.21
# iter: 1, error: 115583.215
# iter: 2, error: 454.705
# current_time:  1.22
# iter: 1, error: 82882.293
# iter: 2, error: 227.843
# current_time:  1.23
# iter: 1, error: 49857.601
# current_time:  1.24
# iter: 1, error: 16638.065
# current_time:  1.25
# iter: 1, error: 16635.734
# current_time:  1.26
# iter: 1, error: 49848.191
# current_time:  1.27
# iter: 1, error: 82857.742
# iter: 2, error: 226.155
# current_time:  1.28
# iter: 1, error: 115529.457
# iter: 2, error: 461.980
# current_time:  1.29
# iter: 1, error: 147742.294
# iter: 2, error: 783.697
# current_time:  1.3
# iter: 1, error: 179365.976
# iter: 2, error: 1203.398
# current_time:  1.31
# iter: 1, error: 210274.616
# iter: 2, error: 1728.232
# current_time:  1.32
# iter: 1, error: 240345.258
# iter: 2, error: 2363.178
# current_time:  1.33
# iter: 1, error: 269458.094
# iter: 2, error: 3110.273
# current_time:  1.34
# iter: 1, error: 297496.970
# iter: 2, error: 3967.955
# current_time:  1.35
# iter: 1, error: 324349.919
# iter: 2, error: 4930.623
# current_time:  1.36
# iter: 1, error: 349909.705
# iter: 2, error: 5988.424
# current_time:  1.37
# iter: 1, error: 374074.339
# iter: 2, error: 7127.259
# current_time:  1.3800000000000001
# iter: 1, error: 396747.588
# iter: 2, error: 8328.992
# current_time:  1.3900000000000001
# iter: 1, error: 417839.461
# iter: 2, error: 9571.861
# iter: 3, error: 229.386
# current_time:  1.4000000000000001
# iter: 1, error: 437444.314
# iter: 2, error: 10845.984
# iter: 3, error: 291.278
# current_time:  1.41
# iter: 1, error: 455176.705
# iter: 2, error: 12100.392
# iter: 3, error: 358.290
# current_time:  1.42
# iter: 1, error: 471103.310
# iter: 2, error: 13316.406
# iter: 3, error: 430.334
# current_time:  1.43
# iter: 1, error: 485161.508
# iter: 2, error: 14464.903
# iter: 3, error: 505.370
# current_time:  1.44
# iter: 1, error: 497296.285
# iter: 2, error: 15517.052
# iter: 3, error: 580.589
# current_time:  1.45
# iter: 1, error: 507460.348
# iter: 2, error: 16445.360
# iter: 3, error: 652.644
# current_time:  1.46
# iter: 1, error: 515614.312
# iter: 2, error: 17224.675
# iter: 3, error: 717.933
# current_time:  1.47
# iter: 1, error: 521726.882
# iter: 2, error: 17833.198
# iter: 3, error: 772.878
# current_time:  1.48
# iter: 1, error: 525774.998
# iter: 2, error: 18253.418
# iter: 3, error: 814.208
# current_time:  1.49
# iter: 1, error: 527743.918
# iter: 2, error: 18472.900
# iter: 3, error: 839.267
# current_time:  1.5
# iter: 1, error: 527627.253
# iter: 2, error: 18484.907
# iter: 3, error: 846.331
# current_time:  1.51
# iter: 1, error: 525426.964
# iter: 2, error: 18288.787
# iter: 3, error: 834.844
# current_time:  1.52
# iter: 1, error: 521153.329
# iter: 2, error: 17890.054
# iter: 3, error: 805.505
# current_time:  1.53
# iter: 1, error: 514824.861
# iter: 2, error: 17300.165
# iter: 3, error: 760.189
# current_time:  1.54
# iter: 1, error: 506468.208
# iter: 2, error: 16535.978
# iter: 3, error: 701.713
# current_time:  1.55
# iter: 1, error: 496118.002
# iter: 2, error: 15618.970
# iter: 3, error: 633.511
# current_time:  1.56
# iter: 1, error: 483816.685
# iter: 2, error: 14574.280
# iter: 3, error: 559.280
# current_time:  1.57
# iter: 1, error: 469614.297
# iter: 2, error: 13429.648
# iter: 3, error: 482.651
# current_time:  1.58
# iter: 1, error: 453568.235
# iter: 2, error: 12214.319
# iter: 3, error: 406.923
# current_time:  1.59
# iter: 1, error: 435742.991
# iter: 2, error: 10957.962
# iter: 3, error: 334.876
# current_time:  1.6
# iter: 1, error: 416209.858
# iter: 2, error: 9689.631
# iter: 3, error: 268.667
# current_time:  1.61
# iter: 1, error: 395046.613
# iter: 2, error: 8436.818
# iter: 3, error: 209.786
# current_time:  1.62
# iter: 1, error: 372337.192
# iter: 2, error: 7224.609
# current_time:  1.6300000000000001
# iter: 1, error: 348068.083
# iter: 2, error: 6069.187
# current_time:  1.6400000000000001
# iter: 1, error: 322570.493
# iter: 2, error: 5002.714
# current_time:  1.6500000000000001
# iter: 1, error: 295805.426
# iter: 2, error: 4030.668
# current_time:  1.6600000000000001
# iter: 1, error: 267878.685
# iter: 2, error: 3163.218
# current_time:  1.67
# iter: 1, error: 238900.028
# iter: 2, error: 2406.345
# current_time:  1.68
# iter: 1, error: 208983.258
# iter: 2, error: 1761.962
# current_time:  1.69
# iter: 1, error: 178245.686
# iter: 2, error: 1228.352
# current_time:  1.7
# iter: 1, error: 146807.596
# iter: 2, error: 800.835
# current_time:  1.71
# iter: 1, error: 114791.740
# iter: 2, error: 472.660
# current_time:  1.72
# iter: 1, error: 82322.861
# iter: 2, error: 236.095
# current_time:  1.73
# iter: 1, error: 49527.239
# current_time:  1.74
# iter: 1, error: 16518.103
# current_time:  1.75
# iter: 1, error: 16532.174
# current_time:  1.76
# iter: 1, error: 49545.332
# current_time:  1.77
# iter: 1, error: 82382.824
# iter: 2, error: 229.518
# current_time:  1.78
# iter: 1, error: 114878.745
# iter: 2, error: 464.994
# current_time:  1.79
# iter: 1, error: 146950.026
# iter: 2, error: 785.675
# current_time:  1.8
# iter: 1, error: 178456.552
# iter: 2, error: 1202.684
# current_time:  1.81
# iter: 1, error: 209274.411
# iter: 2, error: 1723.062
# current_time:  1.82
# iter: 1, error: 239282.190
# iter: 2, error: 2352.046
# current_time:  1.83
# iter: 1, error: 268361.176
# iter: 2, error: 3092.150
# current_time:  1.84
# iter: 1, error: 296395.835
# iter: 2, error: 3942.430
# current_time:  1.85
# iter: 1, error: 323274.335
# iter: 2, error: 4897.956
# current_time:  1.86
# iter: 1, error: 348889.073
# iter: 2, error: 5949.518
# current_time:  1.87
# iter: 1, error: 373137.196
# iter: 2, error: 7083.556
# iter: 3, error: 198.523
# current_time:  1.8800000000000001
# iter: 1, error: 396005.570
# iter: 2, error: 8296.933
# iter: 3, error: 266.495
# current_time:  1.8900000000000001
# iter: 1, error: 417264.121
# iter: 2, error: 9547.947
# iter: 3, error: 344.836
# current_time:  1.9000000000000001
# iter: 1, error: 436886.894
# iter: 2, error: 10820.075
# iter: 3, error: 433.826
# current_time:  1.9100000000000001
# iter: 1, error: 454794.491
# iter: 2, error: 12085.681
# iter: 3, error: 531.475
# current_time:  1.92
# iter: 1, error: 470914.152
# iter: 2, error: 13315.335
# iter: 3, error: 634.901
# current_time:  1.93
# iter: 1, error: 485180.135
# iter: 2, error: 14478.453
# iter: 3, error: 740.276
# current_time:  1.94
# iter: 1, error: 497534.034
# iter: 2, error: 15544.106
# iter: 3, error: 842.853
# current_time:  1.95
# iter: 1, error: 507925.042
# iter: 2, error: 16482.157
# iter: 3, error: 937.201
# current_time:  1.96
# iter: 1, error: 516310.189
# iter: 2, error: 17264.675
# iter: 3, error: 1017.655
# current_time:  1.97
# iter: 1, error: 522654.544
# iter: 2, error: 17867.429
# iter: 3, error: 1078.901
# current_time:  1.98
# iter: 1, error: 526931.401
# iter: 2, error: 18271.329
# iter: 3, error: 1116.620
# current_time:  1.99
# iter: 1, error: 529122.416
# iter: 2, error: 18463.626
# iter: 3, error: 1128.054
# current_time:  2.0
# iter: 1, error: 529217.704
# iter: 2, error: 18438.725
# iter: 3, error: 1112.404
# current_time:  2.0100000000000002
# iter: 1, error: 527215.900
# iter: 2, error: 18198.478
# iter: 3, error: 1070.954
# current_time:  2.02
# iter: 1, error: 523124.168
# iter: 2, error: 17751.894
# iter: 3, error: 1006.872
# current_time:  2.0300000000000002
# iter: 1, error: 516958.180
# iter: 2, error: 17114.352
# iter: 3, error: 924.755
# current_time:  2.04
# iter: 1, error: 508742.044
# iter: 2, error: 16306.473
# iter: 3, error: 830.010
# current_time:  2.05
# iter: 1, error: 498508.206
# iter: 2, error: 15352.850
# iter: 3, error: 728.217
# current_time:  2.06
# iter: 1, error: 486297.295
# iter: 2, error: 14280.796
# iter: 3, error: 624.591
# current_time:  2.07
# iter: 1, error: 472157.947
# iter: 2, error: 13119.194
# iter: 3, error: 523.612
# current_time:  2.08
# iter: 1, error: 456146.586
# iter: 2, error: 11897.486
# iter: 3, error: 428.816
# current_time:  2.09
# iter: 1, error: 438327.169
# iter: 2, error: 10644.755
# iter: 3, error: 342.743
# current_time:  2.1
# iter: 1, error: 418770.902
# iter: 2, error: 9388.909
# iter: 3, error: 266.982
# current_time:  2.11
# iter: 1, error: 397555.931
# iter: 2, error: 8155.936
# iter: 3, error: 202.276
# current_time:  2.12
# iter: 1, error: 374766.997
# iter: 2, error: 6969.236
# current_time:  2.13
# iter: 1, error: 350418.834
# iter: 2, error: 5841.080
# current_time:  2.14
# iter: 1, error: 324784.083
# iter: 2, error: 4806.976
# current_time:  2.15
# iter: 1, error: 297859.710
# iter: 2, error: 3867.863
# current_time:  2.16
# iter: 1, error: 269754.095
# iter: 2, error: 3032.523
# current_time:  2.17
# iter: 1, error: 240579.845
# iter: 2, error: 2305.627
# current_time:  2.18
# iter: 1, error: 210453.718
# iter: 2, error: 1688.106
# current_time:  2.19
# iter: 1, error: 179496.114
# iter: 2, error: 1177.523
# current_time:  2.2
# iter: 1, error: 147830.566
# iter: 2, error: 768.714
# current_time:  2.21
# iter: 1, error: 115583.217
# iter: 2, error: 454.705
# current_time:  2.22
# iter: 1, error: 82882.294
# iter: 2, error: 227.843
# current_time:  2.23
# iter: 1, error: 49857.602
# current_time:  2.24
# iter: 1, error: 16638.066
# current_time:  2.25
# iter: 1, error: 16635.734
# current_time:  2.2600000000000002
# iter: 1, error: 49848.192
# current_time:  2.27
# iter: 1, error: 82857.743
# iter: 2, error: 226.155
# current_time:  2.2800000000000002
# iter: 1, error: 115529.458
# iter: 2, error: 461.980
# current_time:  2.29
# iter: 1, error: 147742.295
# iter: 2, error: 783.697
# current_time:  2.3000000000000003
# iter: 1, error: 179365.978
# iter: 2, error: 1203.398
# current_time:  2.31
# iter: 1, error: 210274.618
# iter: 2, error: 1728.232
# current_time:  2.32
# iter: 1, error: 240345.260
# iter: 2, error: 2363.178
# current_time:  2.33
# iter: 1, error: 269458.098
# iter: 2, error: 3110.273
# current_time:  2.34
# iter: 1, error: 297496.973
# iter: 2, error: 3967.955
# current_time:  2.35
# iter: 1, error: 324349.923
# iter: 2, error: 4930.623
# current_time:  2.36
# iter: 1, error: 349909.710
# iter: 2, error: 5988.424
# current_time:  2.37
# iter: 1, error: 374074.344
# iter: 2, error: 7127.259
# current_time:  2.38
# iter: 1, error: 396747.594
# iter: 2, error: 8328.992
# current_time:  2.39
# iter: 1, error: 417839.467
# iter: 2, error: 9571.862
# iter: 3, error: 229.386
# current_time:  2.4
# iter: 1, error: 437444.321
# iter: 2, error: 10845.985
# iter: 3, error: 291.278
# current_time:  2.41
# iter: 1, error: 455176.713
# iter: 2, error: 12100.393
# iter: 3, error: 358.290
# current_time:  2.42
# iter: 1, error: 471103.318
# iter: 2, error: 13316.407
# iter: 3, error: 430.334
# current_time:  2.43
# iter: 1, error: 485161.516
# iter: 2, error: 14464.904
# iter: 3, error: 505.371
# current_time:  2.44
# iter: 1, error: 497296.294
# iter: 2, error: 15517.054
# iter: 3, error: 580.589
# current_time:  2.45
# iter: 1, error: 507460.358
# iter: 2, error: 16445.362
# iter: 3, error: 652.644
# current_time:  2.46
# iter: 1, error: 515614.322
# iter: 2, error: 17224.676
# iter: 3, error: 717.933
# current_time:  2.47
# iter: 1, error: 521726.892
# iter: 2, error: 17833.200
# iter: 3, error: 772.879
# current_time:  2.48
# iter: 1, error: 525775.009
# iter: 2, error: 18253.420
# iter: 3, error: 814.208
# current_time:  2.49
# iter: 1, error: 527743.930
# iter: 2, error: 18472.902
# iter: 3, error: 839.267
# current_time:  2.5
# iter: 1, error: 527627.264
# iter: 2, error: 18484.909
# iter: 3, error: 846.332
# current_time:  2.5100000000000002
# iter: 1, error: 525426.976
# iter: 2, error: 18288.789
# iter: 3, error: 834.845
# current_time:  2.52
# iter: 1, error: 521153.341
# iter: 2, error: 17890.056
# iter: 3, error: 805.506
# current_time:  2.5300000000000002
# iter: 1, error: 514824.873
# iter: 2, error: 17300.167
# iter: 3, error: 760.189
# current_time:  2.54
# iter: 1, error: 506468.220
# iter: 2, error: 16535.980
# iter: 3, error: 701.713
# current_time:  2.5500000000000003
# iter: 1, error: 496118.014
# iter: 2, error: 15618.972
# iter: 3, error: 633.511
# current_time:  2.56
# iter: 1, error: 483816.697
# iter: 2, error: 14574.281
# iter: 3, error: 559.280
# current_time:  2.57
# iter: 1, error: 469614.308
# iter: 2, error: 13429.649
# iter: 3, error: 482.651
# current_time:  2.58
# iter: 1, error: 453568.247
# iter: 2, error: 12214.320
# iter: 3, error: 406.923
# current_time:  2.59
# iter: 1, error: 435743.002
# iter: 2, error: 10957.963
# iter: 3, error: 334.876
# current_time:  2.6
# iter: 1, error: 416209.868
# iter: 2, error: 9689.632
# iter: 3, error: 268.667
# current_time:  2.61
# iter: 1, error: 395046.624
# iter: 2, error: 8436.818
# iter: 3, error: 209.786
# current_time:  2.62
# iter: 1, error: 372337.201
# iter: 2, error: 7224.609
# current_time:  2.63
# iter: 1, error: 348068.092
# iter: 2, error: 6069.188
# current_time:  2.64
# iter: 1, error: 322570.502
# iter: 2, error: 5002.714
# current_time:  2.65
# iter: 1, error: 295805.434
# iter: 2, error: 4030.669
# current_time:  2.66
# iter: 1, error: 267878.693
# iter: 2, error: 3163.218
# current_time:  2.67
# iter: 1, error: 238900.035
# iter: 2, error: 2406.345
# current_time:  2.68
# iter: 1, error: 208983.264
# iter: 2, error: 1761.962
# current_time:  2.69
# iter: 1, error: 178245.691
# iter: 2, error: 1228.352
# current_time:  2.7
# iter: 1, error: 146807.600
# iter: 2, error: 800.835
# current_time:  2.71
# iter: 1, error: 114791.743
# iter: 2, error: 472.660
# current_time:  2.72
# iter: 1, error: 82322.863
# iter: 2, error: 236.095
# current_time:  2.73
# iter: 1, error: 49527.240
# current_time:  2.74
# iter: 1, error: 16518.104
# current_time:  2.75
# iter: 1, error: 16532.175
# current_time:  2.7600000000000002
# iter: 1, error: 49545.334
# current_time:  2.77
# iter: 1, error: 82382.826
# iter: 2, error: 229.518
# current_time:  2.7800000000000002
# iter: 1, error: 114878.748
# iter: 2, error: 464.994
# current_time:  2.79
# iter: 1, error: 146950.030
# iter: 2, error: 785.675
# current_time:  2.8000000000000003
# iter: 1, error: 178456.557
# iter: 2, error: 1202.684
# current_time:  2.81
# iter: 1, error: 209274.417
# iter: 2, error: 1723.062
# current_time:  2.82
# iter: 1, error: 239282.197
# iter: 2, error: 2352.046
# current_time:  2.83
# iter: 1, error: 268361.183
# iter: 2, error: 3092.150
# current_time:  2.84
# iter: 1, error: 296395.843
# iter: 2, error: 3942.430
# current_time:  2.85
# iter: 1, error: 323274.344
# iter: 2, error: 4897.956
# current_time:  2.86
# iter: 1, error: 348889.083
# iter: 2, error: 5949.518
# current_time:  2.87
# iter: 1, error: 373137.206
# iter: 2, error: 7083.555
# iter: 3, error: 198.523
# current_time:  2.88
# iter: 1, error: 396005.581
# iter: 2, error: 8296.932
# iter: 3, error: 266.494
# current_time:  2.89
# iter: 1, error: 417264.132
# iter: 2, error: 9547.946
# iter: 3, error: 344.835
# current_time:  2.9
# iter: 1, error: 436886.905
# iter: 2, error: 10820.074
# iter: 3, error: 433.825
# current_time:  2.91
# iter: 1, error: 454794.503
# iter: 2, error: 12085.680
# iter: 3, error: 531.474
# current_time:  2.92
# iter: 1, error: 470914.164
# iter: 2, error: 13315.334
# iter: 3, error: 634.900
# current_time:  2.93
# iter: 1, error: 485180.147
# iter: 2, error: 14478.452
# iter: 3, error: 740.275
# current_time:  2.94
# iter: 1, error: 497534.046
# iter: 2, error: 15544.105
# iter: 3, error: 842.852
# current_time:  2.95
# iter: 1, error: 507925.055
# iter: 2, error: 16482.156
# iter: 3, error: 937.200
# current_time:  2.96
# iter: 1, error: 516310.201
# iter: 2, error: 17264.673
# iter: 3, error: 1017.654
# current_time:  2.97
# iter: 1, error: 522654.556
# iter: 2, error: 17867.427
# iter: 3, error: 1078.900
# current_time:  2.98
# iter: 1, error: 526931.413
# iter: 2, error: 18271.327
# iter: 3, error: 1116.619
# current_time:  2.99
# iter: 1, error: 529122.428
# iter: 2, error: 18463.624
# iter: 3, error: 1128.052
# current_time:  3.0
# iter: 1, error: 529217.716
# iter: 2, error: 18438.724
# iter: 3, error: 1112.403
# current_time:  3.0100000000000002
# iter: 1, error: 527215.911
# iter: 2, error: 18198.477
# iter: 3, error: 1070.953
# current_time:  3.02
# iter: 1, error: 523124.179
# iter: 2, error: 17751.892
# iter: 3, error: 1006.871
# current_time:  3.0300000000000002
# iter: 1, error: 516958.190
# iter: 2, error: 17114.350
# iter: 3, error: 924.754
# current_time:  3.04
# iter: 1, error: 508742.054
# iter: 2, error: 16306.472
# iter: 3, error: 830.009
# current_time:  3.0500000000000003
# iter: 1, error: 498508.215
# iter: 2, error: 15352.849
# iter: 3, error: 728.216
# current_time:  3.06
# iter: 1, error: 486297.303
# iter: 2, error: 14280.794
# iter: 3, error: 624.590
# current_time:  3.0700000000000003
# iter: 1, error: 472157.955
# iter: 2, error: 13119.193
# iter: 3, error: 523.611
# current_time:  3.08
# iter: 1, error: 456146.594
# iter: 2, error: 11897.485
# iter: 3, error: 428.815
# current_time:  3.09
# iter: 1, error: 438327.176
# iter: 2, error: 10644.754
# iter: 3, error: 342.742
# current_time:  3.1
# iter: 1, error: 418770.908
# iter: 2, error: 9388.908
# iter: 3, error: 266.981
# current_time:  3.11
# iter: 1, error: 397555.936
# iter: 2, error: 8155.935
# iter: 3, error: 202.275
# current_time:  3.12
# iter: 1, error: 374767.002
# iter: 2, error: 6969.235
# current_time:  3.13
# iter: 1, error: 350418.839
# iter: 2, error: 5841.079
# current_time:  3.14
# iter: 1, error: 324784.087
# iter: 2, error: 4806.975
# current_time:  3.15
# iter: 1, error: 297859.714
# iter: 2, error: 3867.863
# current_time:  3.16
# iter: 1, error: 269754.098
# iter: 2, error: 3032.523
# current_time:  3.17
# iter: 1, error: 240579.848
# iter: 2, error: 2305.627
# current_time:  3.18
# iter: 1, error: 210453.720
# iter: 2, error: 1688.106
# current_time:  3.19
# iter: 1, error: 179496.116
# iter: 2, error: 1177.523
# current_time:  3.2
# iter: 1, error: 147830.567
# iter: 2, error: 768.714
# current_time:  3.21
# iter: 1, error: 115583.218
# iter: 2, error: 454.705
# current_time:  3.22
# iter: 1, error: 82882.295
# iter: 2, error: 227.843
# current_time:  3.23
# iter: 1, error: 49857.602
# current_time:  3.24
# iter: 1, error: 16638.066
# current_time:  3.25
# iter: 1, error: 16635.734
# current_time:  3.2600000000000002
# iter: 1, error: 49848.192
# current_time:  3.27
# iter: 1, error: 82857.744
# iter: 2, error: 226.155
# current_time:  3.2800000000000002
# iter: 1, error: 115529.459
# iter: 2, error: 461.980
# current_time:  3.29
# iter: 1, error: 147742.296
# iter: 2, error: 783.697
# current_time:  3.3000000000000003
# iter: 1, error: 179365.979
# iter: 2, error: 1203.398
# current_time:  3.31
# iter: 1, error: 210274.620
# iter: 2, error: 1728.232
# current_time:  3.3200000000000003
# iter: 1, error: 240345.262
# iter: 2, error: 2363.178
# current_time:  3.33
# iter: 1, error: 269458.100
# iter: 2, error: 3110.273
# current_time:  3.34
# iter: 1, error: 297496.976
# iter: 2, error: 3967.955
# current_time:  3.35
# iter: 1, error: 324349.927
# iter: 2, error: 4930.623
# current_time:  3.36
# iter: 1, error: 349909.713
# iter: 2, error: 5988.424
# current_time:  3.37
# iter: 1, error: 374074.348
# iter: 2, error: 7127.259
# current_time:  3.38
# iter: 1, error: 396747.599
# iter: 2, error: 8328.993
# current_time:  3.39
# iter: 1, error: 417839.472
# iter: 2, error: 9571.862
# iter: 3, error: 229.386
# current_time:  3.4
# iter: 1, error: 437444.327
# iter: 2, error: 10845.985
# iter: 3, error: 291.277
# current_time:  3.41
# iter: 1, error: 455176.719
# iter: 2, error: 12100.393
# iter: 3, error: 358.290
# current_time:  3.42
# iter: 1, error: 471103.325
# iter: 2, error: 13316.408
# iter: 3, error: 430.334
# current_time:  3.43
# iter: 1, error: 485161.524
# iter: 2, error: 14464.905
# iter: 3, error: 505.371
# current_time:  3.44
# iter: 1, error: 497296.302
# iter: 2, error: 15517.055
# iter: 3, error: 580.590
# current_time:  3.45
# iter: 1, error: 507460.367
# iter: 2, error: 16445.363
# iter: 3, error: 652.644
# current_time:  3.46
# iter: 1, error: 515614.331
# iter: 2, error: 17224.678
# iter: 3, error: 717.934
# current_time:  3.47
# iter: 1, error: 521726.902
# iter: 2, error: 17833.202
# iter: 3, error: 772.879
# current_time:  3.48
# iter: 1, error: 525775.019
# iter: 2, error: 18253.422
# iter: 3, error: 814.209
# current_time:  3.49
# iter: 1, error: 527743.940
# iter: 2, error: 18472.903
# iter: 3, error: 839.268
# current_time:  3.5
# iter: 1, error: 527627.275
# iter: 2, error: 18484.911
# iter: 3, error: 846.333
# current_time:  3.5100000000000002
# iter: 1, error: 525426.987
# iter: 2, error: 18288.790
# iter: 3, error: 834.845
# current_time:  3.52
# iter: 1, error: 521153.352
# iter: 2, error: 17890.058
# iter: 3, error: 805.506
# current_time:  3.5300000000000002
# iter: 1, error: 514824.884
# iter: 2, error: 17300.169
# iter: 3, error: 760.190
# current_time:  3.54
# iter: 1, error: 506468.231
# iter: 2, error: 16535.981
# iter: 3, error: 701.713
# current_time:  3.5500000000000003
# iter: 1, error: 496118.025
# iter: 2, error: 15618.973
# iter: 3, error: 633.511
# current_time:  3.56
# iter: 1, error: 483816.708
# iter: 2, error: 14574.282
# iter: 3, error: 559.280
# current_time:  3.5700000000000003
# iter: 1, error: 469614.319
# iter: 2, error: 13429.650
# iter: 3, error: 482.651
# current_time:  3.58
# iter: 1, error: 453568.257
# iter: 2, error: 12214.321
# iter: 3, error: 406.923
# current_time:  3.59
# iter: 1, error: 435743.013
# iter: 2, error: 10957.964
# iter: 3, error: 334.876
# current_time:  3.6
# iter: 1, error: 416209.878
# iter: 2, error: 9689.633
# iter: 3, error: 268.666
# current_time:  3.61
# iter: 1, error: 395046.633
# iter: 2, error: 8436.818
# iter: 3, error: 209.785
# current_time:  3.62
# iter: 1, error: 372337.210
# iter: 2, error: 7224.609
# current_time:  3.63
# iter: 1, error: 348068.100
# iter: 2, error: 6069.188
# current_time:  3.64
# iter: 1, error: 322570.509
# iter: 2, error: 5002.714
# current_time:  3.65
# iter: 1, error: 295805.441
# iter: 2, error: 4030.669
# current_time:  3.66
# iter: 1, error: 267878.699
# iter: 2, error: 3163.218
# current_time:  3.67
# iter: 1, error: 238900.041
# iter: 2, error: 2406.345
# current_time:  3.68
# iter: 1, error: 208983.269
# iter: 2, error: 1761.962
# current_time:  3.69
# iter: 1, error: 178245.695
# iter: 2, error: 1228.352
# current_time:  3.7
# iter: 1, error: 146807.604
# iter: 2, error: 800.835
# current_time:  3.71
# iter: 1, error: 114791.746
# iter: 2, error: 472.660
# current_time:  3.72
# iter: 1, error: 82322.865
# iter: 2, error: 236.095
# current_time:  3.73
# iter: 1, error: 49527.241
# current_time:  3.74
# iter: 1, error: 16518.104
# current_time:  3.75
# iter: 1, error: 16532.175
# current_time:  3.7600000000000002
# iter: 1, error: 49545.335
# current_time:  3.77
# iter: 1, error: 82382.828
# iter: 2, error: 229.518
# current_time:  3.7800000000000002
# iter: 1, error: 114878.751
# iter: 2, error: 464.994
# current_time:  3.79
# iter: 1, error: 146950.033
# iter: 2, error: 785.675
# current_time:  3.8000000000000003
# iter: 1, error: 178456.562
# iter: 2, error: 1202.684
# current_time:  3.81
# iter: 1, error: 209274.422
# iter: 2, error: 1723.062
# current_time:  3.8200000000000003
# iter: 1, error: 239282.203
# iter: 2, error: 2352.046
# current_time:  3.83
# iter: 1, error: 268361.190
# iter: 2, error: 3092.150
# current_time:  3.84
# iter: 1, error: 296395.850
# iter: 2, error: 3942.430
# current_time:  3.85
# iter: 1, error: 323274.352
# iter: 2, error: 4897.956
# current_time:  3.86
# iter: 1, error: 348889.092
# iter: 2, error: 5949.518
# current_time:  3.87
# iter: 1, error: 373137.215
# iter: 2, error: 7083.555
# iter: 3, error: 198.522
# current_time:  3.88
# iter: 1, error: 396005.590
# iter: 2, error: 8296.932
# iter: 3, error: 266.493
# current_time:  3.89
# iter: 1, error: 417264.142
# iter: 2, error: 9547.946
# iter: 3, error: 344.835
# current_time:  3.9
# iter: 1, error: 436886.916
# iter: 2, error: 10820.073
# iter: 3, error: 433.824
# current_time:  3.91
# iter: 1, error: 454794.514
# iter: 2, error: 12085.679
# iter: 3, error: 531.473
# current_time:  3.92
# iter: 1, error: 470914.175
# iter: 2, error: 13315.333
# iter: 3, error: 634.899
# current_time:  3.93
# iter: 1, error: 485180.159
# iter: 2, error: 14478.451
# iter: 3, error: 740.274
# current_time:  3.94
# iter: 1, error: 497534.058
# iter: 2, error: 15544.103
# iter: 3, error: 842.850
# current_time:  3.95
# iter: 1, error: 507925.066
# iter: 2, error: 16482.155
# iter: 3, error: 937.199
# current_time:  3.96
# iter: 1, error: 516310.212
# iter: 2, error: 17264.672
# iter: 3, error: 1017.652
# current_time:  3.97
# iter: 1, error: 522654.567
# iter: 2, error: 17867.426
# iter: 3, error: 1078.899
# current_time:  3.98
# iter: 1, error: 526931.424
# iter: 2, error: 18271.326
# iter: 3, error: 1116.618
# current_time:  3.99
# iter: 1, error: 529122.438
# iter: 2, error: 18463.623
# iter: 3, error: 1128.051
# current_time:  4.0
# iter: 1, error: 529217.726
# iter: 2, error: 18438.722
# iter: 3, error: 1112.402
# current_time:  4.01
# iter: 1, error: 527215.921
# iter: 2, error: 18198.475
# iter: 3, error: 1070.951
# current_time:  4.0200000000000005
# iter: 1, error: 523124.188
# iter: 2, error: 17751.891
# iter: 3, error: 1006.869
# current_time:  4.03
# iter: 1, error: 516958.199
# iter: 2, error: 17114.349
# iter: 3, error: 924.753
# current_time:  4.04
# iter: 1, error: 508742.063
# iter: 2, error: 16306.470
# iter: 3, error: 830.008
# current_time:  4.05
# iter: 1, error: 498508.223
# iter: 2, error: 15352.848
# iter: 3, error: 728.214
# current_time:  4.0600000000000005
# iter: 1, error: 486297.310
# iter: 2, error: 14280.793
# iter: 3, error: 624.589
# current_time:  4.07
# iter: 1, error: 472157.962
# iter: 2, error: 13119.192
# iter: 3, error: 523.610
# current_time:  4.08
# iter: 1, error: 456146.600
# iter: 2, error: 11897.484
# iter: 3, error: 428.814
# current_time:  4.09
# iter: 1, error: 438327.181
# iter: 2, error: 10644.753
# iter: 3, error: 342.741
# current_time:  4.1
# iter: 1, error: 418770.913
# iter: 2, error: 9388.907
# iter: 3, error: 266.980
# current_time:  4.11
# iter: 1, error: 397555.941
# iter: 2, error: 8155.934
# iter: 3, error: 202.275
# current_time:  4.12
# iter: 1, error: 374767.006
# iter: 2, error: 6969.235
# current_time:  4.13
# iter: 1, error: 350418.842
# iter: 2, error: 5841.079
# current_time:  4.14
# iter: 1, error: 324784.090
# iter: 2, error: 4806.975
# current_time:  4.15
# iter: 1, error: 297859.716
# iter: 2, error: 3867.863
# current_time:  4.16
# iter: 1, error: 269754.100
# iter: 2, error: 3032.522
# current_time:  4.17
# iter: 1, error: 240579.849
# iter: 2, error: 2305.627
# current_time:  4.18
# iter: 1, error: 210453.722
# iter: 2, error: 1688.106
# current_time:  4.19
# iter: 1, error: 179496.117
# iter: 2, error: 1177.523
# current_time:  4.2
# iter: 1, error: 147830.568
# iter: 2, error: 768.714
# current_time:  4.21
# iter: 1, error: 115583.218
# iter: 2, error: 454.705
# current_time:  4.22
# iter: 1, error: 82882.295
# iter: 2, error: 227.843
# current_time:  4.23
# iter: 1, error: 49857.602
# current_time:  4.24
# iter: 1, error: 16638.066
# current_time:  4.25
# iter: 1, error: 16635.734
# current_time:  4.26
# iter: 1, error: 49848.192
# current_time:  4.2700000000000005
# iter: 1, error: 82857.744
# iter: 2, error: 226.155
# current_time:  4.28
# iter: 1, error: 115529.460
# iter: 2, error: 461.980
# current_time:  4.29
# iter: 1, error: 147742.297
# iter: 2, error: 783.697
# current_time:  4.3
# iter: 1, error: 179365.980
# iter: 2, error: 1203.398
# current_time:  4.3100000000000005
# iter: 1, error: 210274.621
# iter: 2, error: 1728.232
# current_time:  4.32
# iter: 1, error: 240345.264
# iter: 2, error: 2363.178
# current_time:  4.33
# iter: 1, error: 269458.102
# iter: 2, error: 3110.274
# current_time:  4.34
# iter: 1, error: 297496.978
# iter: 2, error: 3967.955
# current_time:  4.3500000000000005
# iter: 1, error: 324349.929
# iter: 2, error: 4930.623
# current_time:  4.36
# iter: 1, error: 349909.716
# iter: 2, error: 5988.425
# current_time:  4.37
# iter: 1, error: 374074.351
# iter: 2, error: 7127.259
# current_time:  4.38
# iter: 1, error: 396747.603
# iter: 2, error: 8328.993
# current_time:  4.39
# iter: 1, error: 417839.476
# iter: 2, error: 9571.862
# iter: 3, error: 229.386
# current_time:  4.4
# iter: 1, error: 437444.332
# iter: 2, error: 10845.986
# iter: 3, error: 291.277
# current_time:  4.41
# iter: 1, error: 455176.724
# iter: 2, error: 12100.394
# iter: 3, error: 358.290
# current_time:  4.42
# iter: 1, error: 471103.330
# iter: 2, error: 13316.409
# iter: 3, error: 430.334
# current_time:  4.43
# iter: 1, error: 485161.530
# iter: 2, error: 14464.906
# iter: 3, error: 505.371
# current_time:  4.44
# iter: 1, error: 497296.309
# iter: 2, error: 15517.056
# iter: 3, error: 580.590
# current_time:  4.45
# iter: 1, error: 507460.374
# iter: 2, error: 16445.365
# iter: 3, error: 652.645
# current_time:  4.46
# iter: 1, error: 515614.338
# iter: 2, error: 17224.679
# iter: 3, error: 717.934
# current_time:  4.47
# iter: 1, error: 521726.910
# iter: 2, error: 17833.203
# iter: 3, error: 772.880
# current_time:  4.48
# iter: 1, error: 525775.027
# iter: 2, error: 18253.423
# iter: 3, error: 814.209
# current_time:  4.49
# iter: 1, error: 527743.948
# iter: 2, error: 18472.905
# iter: 3, error: 839.268
# current_time:  4.5
# iter: 1, error: 527627.284
# iter: 2, error: 18484.913
# iter: 3, error: 846.333
# current_time:  4.51
# iter: 1, error: 525426.996
# iter: 2, error: 18288.792
# iter: 3, error: 834.846
# current_time:  4.5200000000000005
# iter: 1, error: 521153.361
# iter: 2, error: 17890.059
# iter: 3, error: 805.507
# current_time:  4.53
# iter: 1, error: 514824.894
# iter: 2, error: 17300.170
# iter: 3, error: 760.190
# current_time:  4.54
# iter: 1, error: 506468.241
# iter: 2, error: 16535.983
# iter: 3, error: 701.714
# current_time:  4.55
# iter: 1, error: 496118.035
# iter: 2, error: 15618.974
# iter: 3, error: 633.512
# current_time:  4.5600000000000005
# iter: 1, error: 483816.718
# iter: 2, error: 14574.284
# iter: 3, error: 559.280
# current_time:  4.57
# iter: 1, error: 469614.329
# iter: 2, error: 13429.651
# iter: 3, error: 482.651
# current_time:  4.58
# iter: 1, error: 453568.266
# iter: 2, error: 12214.322
# iter: 3, error: 406.922
# current_time:  4.59
# iter: 1, error: 435743.022
# iter: 2, error: 10957.965
# iter: 3, error: 334.876
# current_time:  4.6000000000000005
# iter: 1, error: 416209.887
# iter: 2, error: 9689.633
# iter: 3, error: 268.666
# current_time:  4.61
# iter: 1, error: 395046.642
# iter: 2, error: 8436.819
# iter: 3, error: 209.785
# current_time:  4.62
# iter: 1, error: 372337.218
# iter: 2, error: 7224.610
# current_time:  4.63
# iter: 1, error: 348068.108
# iter: 2, error: 6069.188
# current_time:  4.64
# iter: 1, error: 322570.517
# iter: 2, error: 5002.714
# current_time:  4.65
# iter: 1, error: 295805.448
# iter: 2, error: 4030.669
# current_time:  4.66
# iter: 1, error: 267878.705
# iter: 2, error: 3163.218
# current_time:  4.67
# iter: 1, error: 238900.046
# iter: 2, error: 2406.345
# current_time:  4.68
# iter: 1, error: 208983.274
# iter: 2, error: 1761.962
# current_time:  4.69
# iter: 1, error: 178245.699
# iter: 2, error: 1228.352
# current_time:  4.7
# iter: 1, error: 146807.607
# iter: 2, error: 800.835
# current_time:  4.71
# iter: 1, error: 114791.749
# iter: 2, error: 472.660
# current_time:  4.72
# iter: 1, error: 82322.867
# iter: 2, error: 236.095
# current_time:  4.73
# iter: 1, error: 49527.243
# current_time:  4.74
# iter: 1, error: 16518.105
# current_time:  4.75
# iter: 1, error: 16532.176
# current_time:  4.76
# iter: 1, error: 49545.336
# current_time:  4.7700000000000005
# iter: 1, error: 82382.830
# iter: 2, error: 229.519
# current_time:  4.78
# iter: 1, error: 114878.754
# iter: 2, error: 464.994
# current_time:  4.79
# iter: 1, error: 146950.037
# iter: 2, error: 785.675
# current_time:  4.8
# iter: 1, error: 178456.566
# iter: 2, error: 1202.684
# current_time:  4.8100000000000005
# iter: 1, error: 209274.426
# iter: 2, error: 1723.062
# current_time:  4.82
# iter: 1, error: 239282.208
# iter: 2, error: 2352.046
# current_time:  4.83
# iter: 1, error: 268361.196
# iter: 2, error: 3092.150
# current_time:  4.84
# iter: 1, error: 296395.857
# iter: 2, error: 3942.430
# current_time:  4.8500000000000005
# iter: 1, error: 323274.360
# iter: 2, error: 4897.956
# current_time:  4.86
# iter: 1, error: 348889.100
# iter: 2, error: 5949.518
# current_time:  4.87
# iter: 1, error: 373137.223
# iter: 2, error: 7083.555
# iter: 3, error: 198.522
# current_time:  4.88
# iter: 1, error: 396005.599
# iter: 2, error: 8296.931
# iter: 3, error: 266.493
# current_time:  4.89
# iter: 1, error: 417264.151
# iter: 2, error: 9547.945
# iter: 3, error: 344.834
# current_time:  4.9
# iter: 1, error: 436886.925
# iter: 2, error: 10820.073
# iter: 3, error: 433.823
# current_time:  4.91
# iter: 1, error: 454794.523
# iter: 2, error: 12085.678
# iter: 3, error: 531.472
# current_time:  4.92
# iter: 1, error: 470914.185
# iter: 2, error: 13315.332
# iter: 3, error: 634.898
# current_time:  4.93
# iter: 1, error: 485180.169
# iter: 2, error: 14478.450
# iter: 3, error: 740.273
# current_time:  4.94
# iter: 1, error: 497534.067
# iter: 2, error: 15544.102
# iter: 3, error: 842.849
# current_time:  4.95
# iter: 1, error: 507925.076
# iter: 2, error: 16482.153
# iter: 3, error: 937.197
# current_time:  4.96
# iter: 1, error: 516310.222
# iter: 2, error: 17264.671
# iter: 3, error: 1017.651
# current_time:  4.97
# iter: 1, error: 522654.577
# iter: 2, error: 17867.425
# iter: 3, error: 1078.898
# current_time:  4.98
# iter: 1, error: 526931.434
# iter: 2, error: 18271.324
# iter: 3, error: 1116.616
# current_time:  4.99
# iter: 1, error: 529122.447
# iter: 2, error: 18463.621
# iter: 3, error: 1128.050
# current_time:  5.0

# %% [markdown]
# ### Plotting

# %%
t = np.arange(robot.sim_params.total_time, step=robot.sim_params.dt)
options = dismech.AnimationOptions(title='Tomato2', plot_step=10)

fig = dismech.get_interactive_animation_plotly(robot, t, qs , options)
fig.show()

# %%
# save gif
ani = dismech.get_animation(robot, t, qs, options)
save_path = os.path.join("tomato_results", f"{plant_name}_{position}.gif")
ani.save(save_path)
# Out:
# 51

# %%
# plot the trajectory of the flower location
flower_node = 73  # pick a node at the flower

import matplotlib.pyplot as plt

# Extract the DOF indices (x, y, z) of the node you want to track
flower_node_dofs = robot.map_node_to_dof(flower_node)  # e.g., [ix, iy, iz]

# Extract position of that node across all timesteps
logged = qs[:, flower_node_dofs].squeeze()  # shape (n_timesteps, 3)

# remove value at t=0
logged -= robot.nodes[flower_node]

# Plot x, y, z over time
t = np.arange(qs.shape[0]) * robot.sim_params.dt

plt.figure(figsize=(10, 4))
plt.plot(t, logged[:, 0], label='x')
plt.plot(t, logged[:, 1], label='y')
plt.plot(t, logged[:, 2], label='z')
plt.xlabel('Time (s)')
plt.ylabel('Position')
plt.title(f'Position of Node {flower_node} Over Time')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Save data for rendering

# %%
from dismech.logging import logDataForRendering
from dismech.logging import export_parachute_data

rod_data, shell_data = logDataForRendering(qs, t.reshape(-1, 1), robot, len(t), robot.sim_params.static_sim, robot.map_node_to_dof)

js_file = os.path.join("tomato_results", f"{plant_name}_{position}.js")
export_parachute_data(qs, geo.rod_edges, robot,
                          rod_js=js_file,
                          scaleFactor=100)
# Out:
# /home/radha/Desktop/PhD/dismech-python/dismech-python/src/dismech/logging.py:176: UserWarning:
#
# loadtxt: input contained no data: "rawDataShell.txt"

# %%
import numpy as np
from scipy.signal import hilbert, detrend, find_peaks

def avg_cycle_amplitude_hilbert(x: np.ndarray) -> float:
    """
    Robust average oscillation amplitude using the analytic-signal envelope.
    Returns the median envelope value (less sensitive to outliers).
    """
    x = np.asarray(x).ravel()
    x = detrend(x)  # remove slow drift
    envelope = np.abs(hilbert(x))
    # Use median to resist occasional spikes; mean is also fine.
    return float(np.median(envelope))

# %%
# amplitude of flower node motion
amp_x_flower_hilbert = avg_cycle_amplitude_hilbert(logged[:, 0]) # hilbert-based amplitude
amp_x_flower_peak = (np.max(logged[:, 0]) - np.min(logged[:, 0])) / 2.0 # peak-to-peak amplitude
print(f"Amplitude of flower node {flower_node} motion in x (peak-to-peak): {amp_x_flower_peak:.4f} m")
print(f"Amplitude of flower node {flower_node} motion in x (hilbert): {amp_x_flower_hilbert:.4f} m")
# Out:
# Amplitude of flower node 73 motion in x (peak-to-peak): 0.0147 m
# Amplitude of flower node 73 motion in x (hilbert): 0.0147 m

# %% [markdown]
# #### Estimate frequency

# %%
import numpy as np

def estimate_frequency(signal, dt):
    """
    Estimate dominant frequency of a periodic signal using FFT.
    
    Parameters
    ----------
    signal : 1D np.ndarray
        The time-varying signal (samples).
    dt : float
        Time step between samples.
    
    Returns
    -------
    freq : float
        Dominant frequency (Hz).
    """
    n = len(signal)
    # Remove mean to avoid 0 Hz dominance
    signal = signal - np.mean(signal)

    # FFT
    freqs = np.fft.rfftfreq(n, d=dt)       # frequency bins (Hz)
    fft_vals = np.fft.rfft(signal)         # FFT coefficients
    magnitude = np.abs(fft_vals)

    # Find the peak frequency (excluding DC = 0 Hz)
    peak_idx = np.argmax(magnitude[1:]) + 1
    freq = freqs[peak_idx]
    return freq


# Example: make a sine wave of 5 Hz, sample at 100 Hz

f_est = estimate_frequency(logged[:, 0], robot.sim_params.dt)
print(f"Estimated frequency: {f_est:.2f} Hz")   # ~5.00 Hz
# Out:
# Estimated frequency: 1.00 Hz
