# %% [markdown]
# ## Tomato Pollination: Tomato 2

# %%
import numpy as np
import dismech
import os

plant_name = "tomato2"

position = "4"

geom = dismech.GeomParams(
    rod_r0=0.03,
    shell_h=0.0,
)

material = dismech.Material(density=1100,
                            youngs_rod=2.16e7,
                            youngs_shell=0,
                            poisson_rod=0.5,
                            poisson_shell=0)

dyn_sim = dismech.SimParams(static_sim=False,
                                  two_d_sim=True,   # no twisting
                                  use_mid_edge=False,
                                  use_line_search=False,
                                  show_floor=False,
                                  log_data=True,
                                  log_step=1,
                                  dt=1e-2,
                                  max_iter=50,
                                  total_time=5,
                                  plot_step=10,
                                  tol=1e-4,
                                  ftol=1e-4,
                                  dtol=1e-2
                                  )

env = dismech.Environment()
env.add_force('gravity', g=np.array([0.0, 0.0, -9.81]))
env.add_force('damping', eta=100)

input_txt = os.path.join('../tests/resources/tomato_pollination/plants/', f"{plant_name}.txt")
geo = dismech.Geometry.from_txt(input_txt)

robot = dismech.SoftRobot(geom, material, geo, dyn_sim, env)

# %% [markdown]
# ### Move the stem: Moving BC

# %%
# # --- pick the main grip node robustly ---
# grasping_point = np.array([
#       1.1154284,
#       0.0092739,
#       0.4896594
#     ])
# xyz = robot.state.q[robot.node_dof_indices].reshape(-1, 3)

main_grip = 33  # node at the main grip

print("Main grip node:", main_grip)

other_grip_nodes_below = np.array(range(main_grip-4, main_grip), dtype=int)
other_grip_nodes_above = np.arange(main_grip+4, main_grip, -1, dtype=int)

print("Other grip nodes below:", other_grip_nodes_below)
print("Other grip nodes above:", other_grip_nodes_above)
# Out:
# Main grip node: 33
# Other grip nodes below: [29 30 31 32]
# Other grip nodes above: [37 36 35 34]

# %%
base_nodes = np.where((robot.state.q[robot.node_dof_indices].reshape(-1, 3)[:, 2]) < 0.22)[0] # fixed base
# Fix only main_grip and base nodes
robot = robot.fix_nodes(np.unique(np.r_[main_grip, base_nodes]))

# %%
# ----- once, before simulation -----

all_grip_nodes = np.r_[main_grip, other_grip_nodes_below, other_grip_nodes_above].astype(int)

xyz0 = robot.state.q[robot.node_dof_indices].reshape(-1, 3).copy()
x0 = xyz0[all_grip_nodes, 0].copy()          # initial x of all prescribed nodes
prev_target_x = x0.copy()                     # last absolute target (starts at initial)

# (Optional) precompute amplitude scalings from *initial* geometry
def build_amps_from_xyz0(xyz0, main_grip, all_grip_nodes, A_main):
    amps = np.empty(all_grip_nodes.size, float)
    amps[0] = A_main  # main_grip
    # below group
    below = np.array(other_grip_nodes_below, dtype=int)
    if below.size:
        ref = below[0]
        L = max(np.linalg.norm(xyz0[main_grip]-xyz0[ref]), 1e-12)
        for j, node in enumerate(below, start=1):  # start=1 because 0 is main_grip
            amps[j] = A_main * (np.linalg.norm(xyz0[ref]-xyz0[node]) / L)
    # above group
    above = np.array(other_grip_nodes_above, dtype=int)
    if above.size:
        ref = above[0]
        offset = 1 + below.size
        L = max(np.linalg.norm(xyz0[main_grip]-xyz0[ref]), 1e-12)
        for j, node in enumerate(above, start=offset):
            amps[j] = A_main * (np.linalg.norm(xyz0[ref]-xyz0[node]) / L)
    return amps

A_main = 0.340670063e-2   # m at main_grip
freq   = 1.3    # Hz
amps   = build_amps_from_xyz0(xyz0, main_grip, all_grip_nodes, A_main)

def shake_distributed(robot, t: float):
    # absolute target centered at initial pose
    target_x = x0 + amps * np.sin(2*np.pi*freq*t)

    # INCREMENT ONLY: avoids velocity spikes and keeps symmetry
    delta_x = target_x - prev_target_x
    prev_target_x[:] = target_x

    return robot.move_nodes(all_grip_nodes, delta_x.reshape(-1,1).flatten(), axis=0)

print("grasping points:", all_grip_nodes)
# Out:
# grasping points: [33 29 30 31 32 37 36 35 34]

# %%
stepper = dismech.ImplicitEulerTimeStepper(robot)
stepper.before_step = shake_distributed

# %% [markdown]
# ### Simulate

# %%
# simulate
robots = stepper.simulate()

qs = np.stack([robot.state.q for robot in robots])
# Out:
# iter: 1, error: 8255.541
# iter: 2, error: 187.906
# current_time:  0.01
# iter: 1, error: 8193.377
# iter: 2, error: 72.763
# current_time:  0.02
# iter: 1, error: 8083.292
# iter: 2, error: 79.325
# current_time:  0.03
# iter: 1, error: 7924.704
# iter: 2, error: 79.812
# current_time:  0.04
# iter: 1, error: 7715.163
# iter: 2, error: 74.045
# current_time:  0.05
# iter: 1, error: 7453.270
# iter: 2, error: 65.990
# current_time:  0.06
# iter: 1, error: 7139.770
# iter: 2, error: 58.082
# current_time:  0.07
# iter: 1, error: 6777.052
# iter: 2, error: 51.039
# current_time:  0.08
# iter: 1, error: 6368.265
# iter: 2, error: 44.720
# current_time:  0.09
# iter: 1, error: 5916.693
# iter: 2, error: 38.697
# current_time:  0.1
# iter: 1, error: 5425.534
# iter: 2, error: 32.681
# current_time:  0.11
# iter: 1, error: 4897.973
# iter: 2, error: 26.652
# current_time:  0.12
# iter: 1, error: 4337.332
# iter: 2, error: 20.800
# current_time:  0.13
# iter: 1, error: 3747.193
# iter: 2, error: 15.384
# current_time:  0.14
# iter: 1, error: 3131.420
# iter: 2, error: 10.625
# current_time:  0.15
# iter: 1, error: 2494.118
# iter: 2, error: 6.670
# current_time:  0.16
# iter: 1, error: 1839.573
# current_time:  0.17
# iter: 1, error: 1170.501
# current_time:  0.18
# iter: 1, error: 495.815
# current_time:  0.19
# iter: 1, error: 183.186
# current_time:  0.2
# iter: 1, error: 861.825
# current_time:  0.21
# iter: 1, error: 1535.526
# current_time:  0.22
# iter: 1, error: 2199.751
# current_time:  0.23
# iter: 1, error: 2850.026
# iter: 2, error: 8.019
# current_time:  0.24
# iter: 1, error: 3477.902
# iter: 2, error: 11.866
# current_time:  0.25
# iter: 1, error: 4084.919
# iter: 2, error: 16.263
# current_time:  0.26
# iter: 1, error: 4664.681
# iter: 2, error: 21.040
# current_time:  0.27
# iter: 1, error: 5213.278
# iter: 2, error: 26.094
# current_time:  0.28
# iter: 1, error: 5726.993
# iter: 2, error: 31.314
# current_time:  0.29
# iter: 1, error: 6202.331
# iter: 2, error: 36.571
# current_time:  0.3
# iter: 1, error: 6636.054
# iter: 2, error: 41.726
# current_time:  0.31
# iter: 1, error: 7025.213
# iter: 2, error: 46.636
# current_time:  0.32
# iter: 1, error: 7367.174
# iter: 2, error: 51.170
# current_time:  0.33
# iter: 1, error: 7659.639
# iter: 2, error: 55.209
# current_time:  0.34
# iter: 1, error: 7900.651
# iter: 2, error: 58.656
# current_time:  0.35000000000000003
# iter: 1, error: 8088.614
# iter: 2, error: 61.430
# current_time:  0.36
# iter: 1, error: 8222.292
# iter: 2, error: 63.463
# current_time:  0.37
# iter: 1, error: 8300.823
# iter: 2, error: 64.709
# current_time:  0.38
# iter: 1, error: 8323.723
# iter: 2, error: 65.136
# current_time:  0.39
# iter: 1, error: 8290.891
# iter: 2, error: 64.731
# current_time:  0.4
# iter: 1, error: 8202.606
# iter: 2, error: 63.505
# current_time:  0.41000000000000003
# iter: 1, error: 8059.526
# iter: 2, error: 61.485
# current_time:  0.42
# iter: 1, error: 7862.680
# iter: 2, error: 58.720
# current_time:  0.43
# iter: 1, error: 7613.459
# iter: 2, error: 55.278
# current_time:  0.44
# iter: 1, error: 7313.605
# iter: 2, error: 51.244
# current_time:  0.45
# iter: 1, error: 6965.198
# iter: 2, error: 46.718
# current_time:  0.46
# iter: 1, error: 6570.638
# iter: 2, error: 41.812
# current_time:  0.47000000000000003
# iter: 1, error: 6132.628
# iter: 2, error: 36.651
# current_time:  0.48
# iter: 1, error: 5654.154
# iter: 2, error: 31.367
# current_time:  0.49
# iter: 1, error: 5138.464
# iter: 2, error: 26.097
# current_time:  0.5
# iter: 1, error: 4589.044
# iter: 2, error: 20.979
# current_time:  0.51
# iter: 1, error: 4009.593
# iter: 2, error: 16.152
# current_time:  0.52
# iter: 1, error: 3403.998
# iter: 2, error: 11.750
# current_time:  0.53
# iter: 1, error: 2776.307
# iter: 2, error: 7.896
# current_time:  0.54
# iter: 1, error: 2130.704
# current_time:  0.55
# iter: 1, error: 1473.697
# current_time:  0.56
# iter: 1, error: 804.141
# current_time:  0.5700000000000001
# iter: 1, error: 130.023
# current_time:  0.58
# iter: 1, error: 544.049
# current_time:  0.59
# iter: 1, error: 1213.624
# current_time:  0.6
# iter: 1, error: 1874.331
# current_time:  0.61
# iter: 1, error: 2521.891
# current_time:  0.62
# iter: 1, error: 3152.131
# iter: 2, error: 10.637
# current_time:  0.63
# iter: 1, error: 3765.495
# iter: 2, error: 15.380
# current_time:  0.64
# iter: 1, error: 4350.627
# iter: 2, error: 20.757
# current_time:  0.65
# iter: 1, error: 4906.781
# iter: 2, error: 26.722
# current_time:  0.66
# iter: 1, error: 5430.364
# iter: 2, error: 33.079
# current_time:  0.67
# iter: 1, error: 5917.967
# iter: 2, error: 39.619
# current_time:  0.68
# iter: 1, error: 6366.383
# iter: 2, error: 46.153
# current_time:  0.6900000000000001
# iter: 1, error: 6772.646
# iter: 2, error: 52.509
# current_time:  0.7000000000000001
# iter: 1, error: 7134.069
# iter: 2, error: 58.528
# current_time:  0.71
# iter: 1, error: 7448.260
# iter: 2, error: 64.053
# current_time:  0.72
# iter: 1, error: 7713.141
# iter: 2, error: 68.927
# current_time:  0.73
# iter: 1, error: 7926.955
# iter: 2, error: 73.007
# current_time:  0.74
# iter: 1, error: 8088.271
# iter: 2, error: 76.163
# current_time:  0.75
# iter: 1, error: 8195.991
# iter: 2, error: 78.298
# current_time:  0.76
# iter: 1, error: 8249.361
# iter: 2, error: 79.345
# current_time:  0.77
# iter: 1, error: 8247.977
# iter: 2, error: 79.271
# current_time:  0.78
# iter: 1, error: 8191.789
# iter: 2, error: 78.082
# current_time:  0.79
# iter: 1, error: 8081.106
# iter: 2, error: 75.814
# current_time:  0.8
# iter: 1, error: 7916.593
# iter: 2, error: 72.536
# current_time:  0.81
# iter: 1, error: 7699.272
# iter: 2, error: 68.347
# current_time:  0.8200000000000001
# iter: 1, error: 7430.512
# iter: 2, error: 63.372
# current_time:  0.8300000000000001
# iter: 1, error: 7112.026
# iter: 2, error: 57.755
# current_time:  0.84
# iter: 1, error: 6745.860
# iter: 2, error: 51.661
# current_time:  0.85
# iter: 1, error: 6334.379
# iter: 2, error: 45.263
# current_time:  0.86
# iter: 1, error: 5880.261
# iter: 2, error: 38.742
# current_time:  0.87
# iter: 1, error: 5386.472
# iter: 2, error: 32.277
# current_time:  0.88
# iter: 1, error: 4856.253
# iter: 2, error: 26.042
# current_time:  0.89
# iter: 1, error: 4293.100
# iter: 2, error: 20.199
# current_time:  0.9
# iter: 1, error: 3700.739
# iter: 2, error: 14.898
# current_time:  0.91
# iter: 1, error: 3083.104
# iter: 2, error: 10.267
# current_time:  0.92
# iter: 1, error: 2444.311
# current_time:  0.93
# iter: 1, error: 1785.646
# current_time:  0.9400000000000001
# iter: 1, error: 1118.980
# current_time:  0.9500000000000001
# iter: 1, error: 443.695
# current_time:  0.96
# iter: 1, error: 235.458
# current_time:  0.97
# iter: 1, error: 913.886
# current_time:  0.98
# iter: 1, error: 1587.017
# current_time:  0.99
# iter: 1, error: 2250.326
# current_time:  1.0
# iter: 1, error: 2899.348
# iter: 2, error: 8.290
# current_time:  1.01
# iter: 1, error: 3525.503
# iter: 2, error: 12.186
# current_time:  1.02
# iter: 1, error: 4130.572
# iter: 2, error: 16.625
# current_time:  1.03
# iter: 1, error: 4708.073
# iter: 2, error: 21.431
# current_time:  1.04
# iter: 1, error: 5254.112
# iter: 2, error: 26.499
# current_time:  1.05
# iter: 1, error: 5764.994
# iter: 2, error: 31.721
# current_time:  1.06
# iter: 1, error: 6237.244
# iter: 2, error: 36.972
# current_time:  1.07
# iter: 1, error: 6667.643
# iter: 2, error: 42.111
# current_time:  1.08
# iter: 1, error: 7053.265
# iter: 2, error: 46.997
# current_time:  1.09
# iter: 1, error: 7391.500
# iter: 2, error: 51.498
# current_time:  1.1
# iter: 1, error: 7680.074
# iter: 2, error: 55.497
# current_time:  1.11
# iter: 1, error: 7917.059
# iter: 2, error: 58.895
# current_time:  1.12
# iter: 1, error: 8100.886
# iter: 2, error: 61.614
# current_time:  1.1300000000000001
# iter: 1, error: 8230.347
# iter: 2, error: 63.588
# current_time:  1.1400000000000001
# iter: 1, error: 8304.612
# iter: 2, error: 64.771
# current_time:  1.1500000000000001
# iter: 1, error: 8323.224
# iter: 2, error: 65.134
# current_time:  1.16
# iter: 1, error: 8286.111
# iter: 2, error: 64.666
# current_time:  1.17
# iter: 1, error: 8193.583
# iter: 2, error: 63.377
# current_time:  1.18
# iter: 1, error: 8046.325
# iter: 2, error: 61.297
# current_time:  1.19
# iter: 1, error: 7845.395
# iter: 2, error: 58.478
# current_time:  1.2
# iter: 1, error: 7592.211
# iter: 2, error: 54.988
# current_time:  1.21
# iter: 1, error: 7288.543
# iter: 2, error: 50.912
# current_time:  1.22
# iter: 1, error: 6936.494
# iter: 2, error: 46.352
# current_time:  1.23
# iter: 1, error: 6538.489
# iter: 2, error: 41.423
# current_time:  1.24
# iter: 1, error: 6097.255
# iter: 2, error: 36.247
# current_time:  1.25
# iter: 1, error: 5615.797
# iter: 2, error: 30.959
# current_time:  1.26
# iter: 1, error: 5097.383
# iter: 2, error: 25.696
# current_time:  1.27
# iter: 1, error: 4545.516
# iter: 2, error: 20.596
# current_time:  1.28
# iter: 1, error: 3963.910
# iter: 2, error: 15.797
# current_time:  1.29
# iter: 1, error: 3356.466
# iter: 2, error: 11.432
# current_time:  1.3
# iter: 1, error: 2727.244
# iter: 2, error: 7.626
# current_time:  1.31
# iter: 1, error: 2080.435
# current_time:  1.32
# iter: 1, error: 1422.454
# current_time:  1.33
# iter: 1, error: 752.387
# current_time:  1.34
# iter: 1, error: 78.113
# current_time:  1.35
# iter: 1, error: 595.774
# current_time:  1.36
# iter: 1, error: 1264.826
# current_time:  1.37
# iter: 1, error: 1924.676
# current_time:  1.3800000000000001
# iter: 1, error: 2571.055
# current_time:  1.3900000000000001
# iter: 1, error: 3199.796
# iter: 2, error: 10.963
# current_time:  1.4000000000000001
# iter: 1, error: 3811.486
# iter: 2, error: 15.762
# current_time:  1.41
# iter: 1, error: 4394.520
# iter: 2, error: 21.187
# current_time:  1.42
# iter: 1, error: 4948.292
# iter: 2, error: 27.190
# current_time:  1.43
# iter: 1, error: 5469.223
# iter: 2, error: 33.574
# current_time:  1.44
# iter: 1, error: 5953.922
# iter: 2, error: 40.125
# current_time:  1.45
# iter: 1, error: 6399.200
# iter: 2, error: 46.654
# current_time:  1.46
# iter: 1, error: 6802.111
# iter: 2, error: 52.990
# current_time:  1.47
# iter: 1, error: 7159.986
# iter: 2, error: 58.975
# current_time:  1.48
# iter: 1, error: 7470.456
# iter: 2, error: 64.453
# current_time:  1.49
# iter: 1, error: 7731.469
# iter: 2, error: 69.270
# current_time:  1.5
# iter: 1, error: 7941.292
# iter: 2, error: 73.282
# current_time:  1.51
# iter: 1, error: 8098.520
# iter: 2, error: 76.364
# current_time:  1.52
# iter: 1, error: 8202.082
# iter: 2, error: 78.418
# current_time:  1.53
# iter: 1, error: 8251.251
# iter: 2, error: 79.379
# current_time:  1.54
# iter: 1, error: 8245.648
# iter: 2, error: 79.219
# current_time:  1.55
# iter: 1, error: 8185.253
# iter: 2, error: 77.945
# current_time:  1.56
# iter: 1, error: 8070.400
# iter: 2, error: 75.596
# current_time:  1.57
# iter: 1, error: 7901.784
# iter: 2, error: 72.245
# current_time:  1.58
# iter: 1, error: 7680.451
# iter: 2, error: 67.991
# current_time:  1.59
# iter: 1, error: 7407.799
# iter: 2, error: 62.960
# current_time:  1.6
# iter: 1, error: 7085.567
# iter: 2, error: 57.301
# current_time:  1.61
# iter: 1, error: 6715.824
# iter: 2, error: 51.177
# current_time:  1.62
# iter: 1, error: 6300.963
# iter: 2, error: 44.764
# current_time:  1.6300000000000001
# iter: 1, error: 5843.681
# iter: 2, error: 38.240
# current_time:  1.6400000000000001
# iter: 1, error: 5346.968
# iter: 2, error: 31.787
# current_time:  1.6500000000000001
# iter: 1, error: 4814.086
# iter: 2, error: 25.576
# current_time:  1.6600000000000001
# iter: 1, error: 4248.547
# iter: 2, error: 19.771
# current_time:  1.67
# iter: 1, error: 3654.097
# iter: 2, error: 14.517
# current_time:  1.68
# iter: 1, error: 3034.682
# iter: 2, error: 9.942
# current_time:  1.69
# iter: 1, error: 2394.433
# current_time:  1.7
# iter: 1, error: 1734.764
# current_time:  1.71
# iter: 1, error: 1067.279
# current_time:  1.72
# iter: 1, error: 391.531
# current_time:  1.73
# iter: 1, error: 287.731
# current_time:  1.74
# iter: 1, error: 965.918
# current_time:  1.75
# iter: 1, error: 1638.458
# current_time:  1.76
# iter: 1, error: 2300.829
# current_time:  1.77
# iter: 1, error: 2948.573
# iter: 2, error: 8.575
# current_time:  1.78
# iter: 1, error: 3572.965
# iter: 2, error: 12.516
# current_time:  1.79
# iter: 1, error: 4176.057
# iter: 2, error: 16.991
# current_time:  1.8
# iter: 1, error: 4751.273
# iter: 2, error: 21.819
# current_time:  1.81
# iter: 1, error: 5294.735
# iter: 2, error: 26.899
# current_time:  1.82
# iter: 1, error: 5802.766
# iter: 2, error: 32.125
# current_time:  1.83
# iter: 1, error: 6271.910
# iter: 2, error: 37.370
# current_time:  1.84
# iter: 1, error: 6698.969
# iter: 2, error: 42.495
# current_time:  1.85
# iter: 1, error: 7081.038
# iter: 2, error: 47.357
# current_time:  1.86
# iter: 1, error: 7415.533
# iter: 2, error: 51.824
# current_time:  1.87
# iter: 1, error: 7700.204
# iter: 2, error: 55.781
# current_time:  1.8800000000000001
# iter: 1, error: 7933.152
# iter: 2, error: 59.130
# current_time:  1.8900000000000001
# iter: 1, error: 8112.836
# iter: 2, error: 61.793
# current_time:  1.9000000000000001
# iter: 1, error: 8238.076
# iter: 2, error: 63.707
# current_time:  1.9100000000000001
# iter: 1, error: 8308.071
# iter: 2, error: 64.828
# current_time:  1.92
# iter: 1, error: 8322.395
# iter: 2, error: 65.127
# current_time:  1.93
# iter: 1, error: 8281.003
# iter: 2, error: 64.595
# current_time:  1.94
# iter: 1, error: 8184.236
# iter: 2, error: 63.244
# current_time:  1.95
# iter: 1, error: 8032.806
# iter: 2, error: 61.106
# current_time:  1.96
# iter: 1, error: 7827.800
# iter: 2, error: 58.232
# current_time:  1.97
# iter: 1, error: 7570.664
# iter: 2, error: 54.694
# current_time:  1.98
# iter: 1, error: 7263.193
# iter: 2, error: 50.577
# current_time:  1.99
# iter: 1, error: 6907.518
# iter: 2, error: 45.985
# current_time:  2.0
# iter: 1, error: 6506.085
# iter: 2, error: 41.031
# current_time:  2.0100000000000002
# iter: 1, error: 6061.643
# iter: 2, error: 35.843
# current_time:  2.02
# iter: 1, error: 5577.221
# iter: 2, error: 30.552
# current_time:  2.0300000000000002
# iter: 1, error: 5056.103
# iter: 2, error: 25.296
# current_time:  2.04
# iter: 1, error: 4501.811
# iter: 2, error: 20.214
# current_time:  2.05
# iter: 1, error: 3918.073
# iter: 2, error: 15.444
# current_time:  2.06
# iter: 1, error: 3308.804
# iter: 2, error: 11.118
# current_time:  2.07
# iter: 1, error: 2678.075
# iter: 2, error: 7.360
# current_time:  2.08
# iter: 1, error: 2030.087
# current_time:  2.09
# iter: 1, error: 1371.159
# current_time:  2.1
# iter: 1, error: 700.610
# current_time:  2.11
# iter: 1, error: 26.206
# current_time:  2.12
# iter: 1, error: 647.471
# current_time:  2.13
# iter: 1, error: 1315.974
# current_time:  2.14
# iter: 1, error: 1974.943
# current_time:  2.15
# iter: 1, error: 2620.115
# iter: 2, error: 7.319
# current_time:  2.16
# iter: 1, error: 3250.479
# iter: 2, error: 11.413
# current_time:  2.17
# iter: 1, error: 3857.189
# iter: 2, error: 16.240
# current_time:  2.18
# iter: 1, error: 4438.150
# iter: 2, error: 21.735
# current_time:  2.19
# iter: 1, error: 4989.585
# iter: 2, error: 27.744
# current_time:  2.2
# iter: 1, error: 5507.898
# iter: 2, error: 34.094
# current_time:  2.21
# iter: 1, error: 5989.695
# iter: 2, error: 40.608
# current_time:  2.22
# iter: 1, error: 6431.807
# iter: 2, error: 47.112
# current_time:  2.23
# iter: 1, error: 6831.325
# iter: 2, error: 53.434
# current_time:  2.24
# iter: 1, error: 7185.618
# iter: 2, error: 59.403
# current_time:  2.25
# iter: 1, error: 7492.347
# iter: 2, error: 64.851
# current_time:  2.2600000000000002
# iter: 1, error: 7749.482
# iter: 2, error: 69.619
# current_time:  2.27
# iter: 1, error: 7955.312
# iter: 2, error: 73.563
# current_time:  2.2800000000000002
# iter: 1, error: 8108.452
# iter: 2, error: 76.565
# current_time:  2.29
# iter: 1, error: 8207.855
# iter: 2, error: 78.531
# current_time:  2.3000000000000003
# iter: 1, error: 8252.820
# iter: 2, error: 79.404
# current_time:  2.31
# iter: 1, error: 8242.997
# iter: 2, error: 79.158
# current_time:  2.32
# iter: 1, error: 8178.394
# iter: 2, error: 77.800
# current_time:  2.33
# iter: 1, error: 8059.375
# iter: 2, error: 75.372
# current_time:  2.34
# iter: 1, error: 7886.661
# iter: 2, error: 71.948
# current_time:  2.35
# iter: 1, error: 7661.326
# iter: 2, error: 67.630
# current_time:  2.36
# iter: 1, error: 7384.793
# iter: 2, error: 62.546
# current_time:  2.37
# iter: 1, error: 7058.826
# iter: 2, error: 56.844
# current_time:  2.38
# iter: 1, error: 6685.522
# iter: 2, error: 50.692
# current_time:  2.39
# iter: 1, error: 6267.295
# iter: 2, error: 44.263
# current_time:  2.4
# iter: 1, error: 5806.868
# iter: 2, error: 37.739
# current_time:  2.41
# iter: 1, error: 5307.250
# iter: 2, error: 31.298
# current_time:  2.42
# iter: 1, error: 4771.724
# iter: 2, error: 25.113
# current_time:  2.43
# iter: 1, error: 4203.823
# iter: 2, error: 19.345
# current_time:  2.44
# iter: 1, error: 3607.306
# iter: 2, error: 14.139
# current_time:  2.45
# iter: 1, error: 2986.136
# iter: 2, error: 9.621
# current_time:  2.46
# iter: 1, error: 2344.456
# current_time:  2.47
# iter: 1, error: 1683.808
# current_time:  2.48
# iter: 1, error: 1015.529
# current_time:  2.49
# iter: 1, error: 339.347
# current_time:  2.5
# iter: 1, error: 339.999
# current_time:  2.5100000000000002
# iter: 1, error: 1017.917
# current_time:  2.52
# iter: 1, error: 1689.839
# current_time:  2.5300000000000002
# iter: 1, error: 2351.247
# current_time:  2.54
# iter: 1, error: 2997.686
# iter: 2, error: 8.864
# current_time:  2.5500000000000003
# iter: 1, error: 3620.287
# iter: 2, error: 12.850
# current_time:  2.56
# iter: 1, error: 4221.378
# iter: 2, error: 17.359
# current_time:  2.57
# iter: 1, error: 4794.285
# iter: 2, error: 22.209
# current_time:  2.58
# iter: 1, error: 5335.148
# iter: 2, error: 27.300
# current_time:  2.59
# iter: 1, error: 5840.309
# iter: 2, error: 32.529
# current_time:  2.6
# iter: 1, error: 6306.328
# iter: 2, error: 37.768
# current_time:  2.61
# iter: 1, error: 6730.030
# iter: 2, error: 42.877
# current_time:  2.62
# iter: 1, error: 7108.531
# iter: 2, error: 47.715
# current_time:  2.63
# iter: 1, error: 7439.271
# iter: 2, error: 52.148
# current_time:  2.64
# iter: 1, error: 7720.028
# iter: 2, error: 56.061
# current_time:  2.65
# iter: 1, error: 7948.930
# iter: 2, error: 59.361
# current_time:  2.66
# iter: 1, error: 8124.463
# iter: 2, error: 61.968
# current_time:  2.67
# iter: 1, error: 8245.478
# iter: 2, error: 63.822
# current_time:  2.68
# iter: 1, error: 8311.201
# iter: 2, error: 64.880
# current_time:  2.69
# iter: 1, error: 8321.236
# iter: 2, error: 65.115
# current_time:  2.7
# iter: 1, error: 8275.568
# iter: 2, error: 64.519
# current_time:  2.71
# iter: 1, error: 8174.565
# iter: 2, error: 63.107
# current_time:  2.72
# iter: 1, error: 8018.970
# iter: 2, error: 60.910
# current_time:  2.73
# iter: 1, error: 7809.897
# iter: 2, error: 57.983
# current_time:  2.74
# iter: 1, error: 7548.819
# iter: 2, error: 54.396
# current_time:  2.75
# iter: 1, error: 7237.559
# iter: 2, error: 50.239
# current_time:  2.7600000000000002
# iter: 1, error: 6878.270
# iter: 2, error: 45.615
# current_time:  2.77
# iter: 1, error: 6473.425
# iter: 2, error: 40.639
# current_time:  2.7800000000000002
# iter: 1, error: 6025.795
# iter: 2, error: 35.438
# current_time:  2.79
# iter: 1, error: 5538.427
# iter: 2, error: 30.144
# current_time:  2.8000000000000003
# iter: 1, error: 5014.627
# iter: 2, error: 24.897
# current_time:  2.81
# iter: 1, error: 4457.931
# iter: 2, error: 19.834
# current_time:  2.82
# iter: 1, error: 3872.085
# iter: 2, error: 15.094
# current_time:  2.83
# iter: 1, error: 3261.015
# iter: 2, error: 10.807
# current_time:  2.84
# iter: 1, error: 2628.804
# current_time:  2.85
# iter: 1, error: 1983.028
# current_time:  2.86
# iter: 1, error: 1319.985
# current_time:  2.87
# iter: 1, error: 648.843
# current_time:  2.88
# iter: 1, error: 25.696
# current_time:  2.89
# iter: 1, error: 699.135
# current_time:  2.9
# iter: 1, error: 1367.056
# current_time:  2.91
# iter: 1, error: 2025.112
# current_time:  2.92
# iter: 1, error: 2669.055
# iter: 2, error: 7.610
# current_time:  2.93
# iter: 1, error: 3298.004
# iter: 2, error: 11.760
# current_time:  2.94
# iter: 1, error: 3902.878
# iter: 2, error: 16.633
# current_time:  2.95
# iter: 1, error: 4481.700
# iter: 2, error: 22.170
# current_time:  2.96
# iter: 1, error: 5030.709
# iter: 2, error: 28.214
# current_time:  2.97
# iter: 1, error: 5546.329
# iter: 2, error: 34.589
# current_time:  2.98
# iter: 1, error: 6025.182
# iter: 2, error: 41.113
# current_time:  2.99
# iter: 1, error: 6464.122
# iter: 2, error: 47.611
# current_time:  3.0
# iter: 1, error: 6860.255
# iter: 2, error: 53.911
# current_time:  3.0100000000000002
# iter: 1, error: 7210.972
# iter: 2, error: 59.844
# current_time:  3.02
# iter: 1, error: 7513.957
# iter: 2, error: 65.244
# current_time:  3.0300000000000002
# iter: 1, error: 7767.204
# iter: 2, error: 69.952
# current_time:  3.04
# iter: 1, error: 7969.027
# iter: 2, error: 73.828
# current_time:  3.0500000000000003
# iter: 1, error: 8118.066
# iter: 2, error: 76.753
# current_time:  3.06
# iter: 1, error: 8213.302
# iter: 2, error: 78.637
# current_time:  3.0700000000000003
# iter: 1, error: 8254.061
# iter: 2, error: 79.425
# current_time:  3.08
# iter: 1, error: 8240.020
# iter: 2, error: 79.092
# current_time:  3.09
# iter: 1, error: 8171.213
# iter: 2, error: 77.650
# current_time:  3.1
# iter: 1, error: 8048.033
# iter: 2, error: 75.143
# current_time:  3.11
# iter: 1, error: 7871.227
# iter: 2, error: 71.646
# current_time:  3.12
# iter: 1, error: 7641.897
# iter: 2, error: 67.264
# current_time:  3.13
# iter: 1, error: 7361.493
# iter: 2, error: 62.127
# current_time:  3.14
# iter: 1, error: 7031.805
# iter: 2, error: 56.385
# current_time:  3.15
# iter: 1, error: 6654.953
# iter: 2, error: 50.205
# current_time:  3.16
# iter: 1, error: 6233.377
# iter: 2, error: 43.762
# current_time:  3.17
# iter: 1, error: 5769.822
# iter: 2, error: 37.238
# current_time:  3.18
# iter: 1, error: 5267.319
# iter: 2, error: 30.811
# current_time:  3.19
# iter: 1, error: 4729.171
# iter: 2, error: 24.653
# current_time:  3.2
# iter: 1, error: 4158.929
# iter: 2, error: 18.923
# current_time:  3.21
# iter: 1, error: 3560.368
# iter: 2, error: 13.766
# current_time:  3.22
# iter: 1, error: 2937.468
# iter: 2, error: 9.305
# current_time:  3.23
# iter: 1, error: 2294.382
# current_time:  3.24
# iter: 1, error: 1632.779
# current_time:  3.25
# iter: 1, error: 963.734
# current_time:  3.2600000000000002
# iter: 1, error: 287.144
# current_time:  3.27
# iter: 1, error: 392.258
# current_time:  3.2800000000000002
# iter: 1, error: 1069.881
# current_time:  3.29
# iter: 1, error: 1741.158
# current_time:  3.3000000000000003
# iter: 1, error: 2401.576
# current_time:  3.31
# iter: 1, error: 3046.685
# iter: 2, error: 9.157
# current_time:  3.3200000000000003
# iter: 1, error: 3667.467
# iter: 2, error: 13.187
# current_time:  3.33
# iter: 1, error: 4266.533
# iter: 2, error: 17.730
# current_time:  3.34
# iter: 1, error: 4837.108
# iter: 2, error: 22.600
# current_time:  3.35
# iter: 1, error: 5375.350
# iter: 2, error: 27.702
# current_time:  3.36
# iter: 1, error: 5877.619
# iter: 2, error: 32.932
# current_time:  3.37
# iter: 1, error: 6340.496
# iter: 2, error: 38.165
# current_time:  3.38
# iter: 1, error: 6760.823
# iter: 2, error: 43.258
# current_time:  3.39
# iter: 1, error: 7135.741
# iter: 2, error: 48.070
# current_time:  3.4
# iter: 1, error: 7462.713
# iter: 2, error: 52.468
# current_time:  3.41
# iter: 1, error: 7739.545
# iter: 2, error: 56.339
# current_time:  3.42
# iter: 1, error: 7964.392
# iter: 2, error: 59.587
# current_time:  3.43
# iter: 1, error: 8135.768
# iter: 2, error: 62.138
# current_time:  3.44
# iter: 1, error: 8252.553
# iter: 2, error: 63.932
# current_time:  3.45
# iter: 1, error: 8314.002
# iter: 2, error: 64.927
# current_time:  3.46
# iter: 1, error: 8319.747
# iter: 2, error: 65.098
# current_time:  3.47
# iter: 1, error: 8269.805
# iter: 2, error: 64.439
# current_time:  3.48
# iter: 1, error: 8164.570
# iter: 2, error: 62.965
# current_time:  3.49
# iter: 1, error: 8004.817
# iter: 2, error: 60.710
# current_time:  3.5
# iter: 1, error: 7791.685
# iter: 2, error: 57.729
# current_time:  3.5100000000000002
# iter: 1, error: 7526.677
# iter: 2, error: 54.095
# current_time:  3.52
# iter: 1, error: 7211.639
# iter: 2, error: 49.898
# current_time:  3.5300000000000002
# iter: 1, error: 6848.753
# iter: 2, error: 45.243
# current_time:  3.54
# iter: 1, error: 6440.512
# iter: 2, error: 40.245
# current_time:  3.5500000000000003
# iter: 1, error: 5989.711
# iter: 2, error: 35.032
# current_time:  3.56
# iter: 1, error: 5499.417
# iter: 2, error: 29.737
# current_time:  3.5700000000000003
# iter: 1, error: 4972.955
# iter: 2, error: 24.499
# current_time:  3.58
# iter: 1, error: 4413.878
# iter: 2, error: 19.456
# current_time:  3.59
# iter: 1, error: 3825.947
# iter: 2, error: 14.746
# current_time:  3.6
# iter: 1, error: 3213.100
# iter: 2, error: 10.500
# current_time:  3.61
# iter: 1, error: 2579.432
# current_time:  3.62
# iter: 1, error: 1932.403
# current_time:  3.63
# iter: 1, error: 1268.584
# current_time:  3.64
# iter: 1, error: 597.020
# current_time:  3.65
# iter: 1, error: 77.594
# current_time:  3.66
# iter: 1, error: 750.771
# current_time:  3.67
# iter: 1, error: 1418.090
# current_time:  3.68
# iter: 1, error: 2075.215
# current_time:  3.69
# iter: 1, error: 2717.902
# iter: 2, error: 7.893
# current_time:  3.7
# iter: 1, error: 3345.397
# iter: 2, error: 12.104
# current_time:  3.71
# iter: 1, error: 3948.407
# iter: 2, error: 17.031
# current_time:  3.72
# iter: 1, error: 4525.066
# iter: 2, error: 22.613
# current_time:  3.73
# iter: 1, error: 5071.631
# iter: 2, error: 28.693
# current_time:  3.74
# iter: 1, error: 5584.541
# iter: 2, error: 35.088
# current_time:  3.75
# iter: 1, error: 6060.436
# iter: 2, error: 41.618
# current_time:  3.7600000000000002
# iter: 1, error: 6496.186
# iter: 2, error: 48.107
# current_time:  3.77
# iter: 1, error: 6888.919
# iter: 2, error: 54.384
# current_time:  3.7800000000000002
# iter: 1, error: 7236.045
# iter: 2, error: 60.281
# current_time:  3.79
# iter: 1, error: 7535.273
# iter: 2, error: 65.632
# current_time:  3.8000000000000003
# iter: 1, error: 7784.622
# iter: 2, error: 70.281
# current_time:  3.81
# iter: 1, error: 7982.429
# iter: 2, error: 74.087
# current_time:  3.8200000000000003
# iter: 1, error: 8127.362
# iter: 2, error: 76.935
# current_time:  3.83
# iter: 1, error: 8218.428
# iter: 2, error: 78.737
# current_time:  3.84
# iter: 1, error: 8254.978
# iter: 2, error: 79.439
# current_time:  3.85
# iter: 1, error: 8236.718
# iter: 2, error: 79.020
# current_time:  3.86
# iter: 1, error: 8163.711
# iter: 2, error: 77.494
# current_time:  3.87
# iter: 1, error: 8036.373
# iter: 2, error: 74.908
# current_time:  3.88
# iter: 1, error: 7855.482
# iter: 2, error: 71.339
# current_time:  3.89
# iter: 1, error: 7622.167
# iter: 2, error: 66.894
# current_time:  3.9
# iter: 1, error: 7337.902
# iter: 2, error: 61.704
# current_time:  3.91
# iter: 1, error: 7004.504
# iter: 2, error: 55.923
# current_time:  3.92
# iter: 1, error: 6624.119
# iter: 2, error: 49.716
# current_time:  3.93
# iter: 1, error: 6199.210
# iter: 2, error: 43.261
# current_time:  3.94
# iter: 1, error: 5732.544
# iter: 2, error: 36.738
# current_time:  3.95
# iter: 1, error: 5227.176
# iter: 2, error: 30.326
# current_time:  3.96
# iter: 1, error: 4686.427
# iter: 2, error: 24.195
# current_time:  3.97
# iter: 1, error: 4113.866
# iter: 2, error: 18.504
# current_time:  3.98
# iter: 1, error: 3513.286
# iter: 2, error: 13.396
# current_time:  3.99
# iter: 1, error: 2888.680
# iter: 2, error: 8.994
# current_time:  4.0
# iter: 1, error: 2244.214
# current_time:  4.01
# iter: 1, error: 1581.680
# current_time:  4.0200000000000005
# iter: 1, error: 911.895
# current_time:  4.03
# iter: 1, error: 234.924
# current_time:  4.04
# iter: 1, error: 444.507
# current_time:  4.05
# iter: 1, error: 1121.808
# current_time:  4.0600000000000005
# iter: 1, error: 1792.414
# current_time:  4.07
# iter: 1, error: 2451.815
# current_time:  4.08
# iter: 1, error: 3095.568
# iter: 2, error: 9.455
# current_time:  4.09
# iter: 1, error: 3714.504
# iter: 2, error: 13.528
# current_time:  4.1
# iter: 1, error: 4311.520
# iter: 2, error: 18.103
# current_time:  4.11
# iter: 1, error: 4879.740
# iter: 2, error: 22.993
# current_time:  4.12
# iter: 1, error: 5415.340
# iter: 2, error: 28.105
# current_time:  4.13
# iter: 1, error: 5914.697
# iter: 2, error: 33.335
# current_time:  4.14
# iter: 1, error: 6374.412
# iter: 2, error: 38.560
# current_time:  4.15
# iter: 1, error: 6791.348
# iter: 2, error: 43.637
# current_time:  4.16
# iter: 1, error: 7162.667
# iter: 2, error: 48.423
# current_time:  4.17
# iter: 1, error: 7485.859
# iter: 2, error: 52.786
# current_time:  4.18
# iter: 1, error: 7758.755
# iter: 2, error: 56.612
# current_time:  4.19
# iter: 1, error: 7979.538
# iter: 2, error: 59.810
# current_time:  4.2
# iter: 1, error: 8146.750
# iter: 2, error: 62.304
# current_time:  4.21
# iter: 1, error: 8259.300
# iter: 2, error: 64.037
# current_time:  4.22
# iter: 1, error: 8316.472
# iter: 2, error: 64.969
# current_time:  4.23
# iter: 1, error: 8317.929
# iter: 2, error: 65.076
# current_time:  4.24
# iter: 1, error: 8263.714
# iter: 2, error: 64.354
# current_time:  4.25
# iter: 1, error: 8154.253
# iter: 2, error: 62.818
# current_time:  4.26
# iter: 1, error: 7990.347
# iter: 2, error: 60.505
# current_time:  4.2700000000000005
# iter: 1, error: 7773.166
# iter: 2, error: 57.471
# current_time:  4.28
# iter: 1, error: 7504.238
# iter: 2, error: 53.791
# current_time:  4.29
# iter: 1, error: 7185.436
# iter: 2, error: 49.555
# current_time:  4.3
# iter: 1, error: 6818.966
# iter: 2, error: 44.869
# current_time:  4.3100000000000005
# iter: 1, error: 6407.347
# iter: 2, error: 39.850
# current_time:  4.32
# iter: 1, error: 5953.392
# iter: 2, error: 34.626
# current_time:  4.33
# iter: 1, error: 5460.192
# iter: 2, error: 29.330
# current_time:  4.34
# iter: 1, error: 4931.089
# iter: 2, error: 24.102
# current_time:  4.3500000000000005
# iter: 1, error: 4369.654
# iter: 2, error: 19.080
# current_time:  4.36
# iter: 1, error: 3779.660
# iter: 2, error: 14.401
# current_time:  4.37
# iter: 1, error: 3165.062
# iter: 2, error: 10.196
# current_time:  4.38
# iter: 1, error: 2529.961
# current_time:  4.39
# iter: 1, error: 1881.706
# current_time:  4.4
# iter: 1, error: 1217.137
# current_time:  4.41
# iter: 1, error: 545.178
# current_time:  4.42
# iter: 1, error: 129.485
# current_time:  4.43
# iter: 1, error: 802.372
# current_time:  4.44
# iter: 1, error: 1469.065
# current_time:  4.45
# iter: 1, error: 2125.232
# current_time:  4.46
# iter: 1, error: 2766.640
# iter: 2, error: 8.180
# current_time:  4.47
# iter: 1, error: 3392.659
# iter: 2, error: 12.453
# current_time:  4.48
# iter: 1, error: 3993.780
# iter: 2, error: 17.432
# current_time:  4.49
# iter: 1, error: 4568.255
# iter: 2, error: 23.059
# current_time:  4.5
# iter: 1, error: 5112.355
# iter: 2, error: 29.173
# current_time:  4.51
# iter: 1, error: 5622.535
# iter: 2, error: 35.588
# current_time:  4.5200000000000005
# iter: 1, error: 6095.453
# iter: 2, error: 42.123
# current_time:  4.53
# iter: 1, error: 6527.996
# iter: 2, error: 48.602
# current_time:  4.54
# iter: 1, error: 6917.313
# iter: 2, error: 54.854
# current_time:  4.55
# iter: 1, error: 7260.835
# iter: 2, error: 60.714
# current_time:  4.5600000000000005
# iter: 1, error: 7556.295
# iter: 2, error: 66.016
# current_time:  4.57
# iter: 1, error: 7801.734
# iter: 2, error: 70.604
# current_time:  4.58
# iter: 1, error: 7995.518
# iter: 2, error: 74.341
# current_time:  4.59
# iter: 1, error: 8136.339
# iter: 2, error: 77.112
# current_time:  4.6000000000000005
# iter: 1, error: 8223.230
# iter: 2, error: 78.831
# current_time:  4.61
# iter: 1, error: 8255.571
# iter: 2, error: 79.447
# current_time:  4.62
# iter: 1, error: 8233.093
# iter: 2, error: 78.942
# current_time:  4.63
# iter: 1, error: 8155.886
# iter: 2, error: 77.332
# current_time:  4.64
# iter: 1, error: 8024.396
# iter: 2, error: 74.667
# current_time:  4.65
# iter: 1, error: 7839.427
# iter: 2, error: 71.026
# current_time:  4.66
# iter: 1, error: 7602.134
# iter: 2, error: 66.519
# current_time:  4.67
# iter: 1, error: 7314.019
# iter: 2, error: 61.278
# current_time:  4.68
# iter: 1, error: 6976.924
# iter: 2, error: 55.458
# current_time:  4.69
# iter: 1, error: 6593.021
# iter: 2, error: 49.226
# current_time:  4.7
# iter: 1, error: 6164.795
# iter: 2, error: 42.759
# current_time:  4.71
# iter: 1, error: 5695.038
# iter: 2, error: 36.239
# current_time:  4.72
# iter: 1, error: 5186.824
# iter: 2, error: 29.842
# current_time:  4.73
# iter: 1, error: 4643.495
# iter: 2, error: 23.739
# current_time:  4.74
# iter: 1, error: 4068.637
# iter: 2, error: 18.089
# current_time:  4.75
# iter: 1, error: 3466.062
# iter: 2, error: 13.031
# current_time:  4.76
# iter: 1, error: 2839.774
# iter: 2, error: 8.688
# current_time:  4.7700000000000005
# iter: 1, error: 2193.953
# current_time:  4.78
# iter: 1, error: 1530.511
# current_time:  4.79
# iter: 1, error: 860.014
# current_time:  4.8
# iter: 1, error: 182.689
# current_time:  4.8100000000000005
# iter: 1, error: 496.745
# current_time:  4.82
# iter: 1, error: 1173.696
# current_time:  4.83
# iter: 1, error: 1843.604
# current_time:  4.84
# iter: 1, error: 2501.963
# current_time:  4.8500000000000005
# iter: 1, error: 3144.333
# iter: 2, error: 9.756
# current_time:  4.86
# iter: 1, error: 3761.395
# iter: 2, error: 13.871
# current_time:  4.87
# iter: 1, error: 4356.337
# iter: 2, error: 18.478
# current_time:  4.88
# iter: 1, error: 4922.178
# iter: 2, error: 23.387
# current_time:  4.89
# iter: 1, error: 5455.115
# iter: 2, error: 28.508
# current_time:  4.9
# iter: 1, error: 5951.540
# iter: 2, error: 33.738
# current_time:  4.91
# iter: 1, error: 6408.075
# iter: 2, error: 38.955
# current_time:  4.92
# iter: 1, error: 6821.603
# iter: 2, error: 44.014
# current_time:  4.93
# iter: 1, error: 7189.309
# iter: 2, error: 48.773
# current_time:  4.94
# iter: 1, error: 7508.708
# iter: 2, error: 53.100
# current_time:  4.95
# iter: 1, error: 7777.657
# iter: 2, error: 56.882
# current_time:  4.96
# iter: 1, error: 7994.367
# iter: 2, error: 60.028
# current_time:  4.97
# iter: 1, error: 8157.408
# iter: 2, error: 62.465
# current_time:  4.98
# iter: 1, error: 8265.720
# iter: 2, error: 64.138
# current_time:  4.99
# iter: 1, error: 8318.613
# iter: 2, error: 65.007
# current_time:  5.0

# %% [markdown]
# ### Plotting

# %%
t = np.arange(robot.sim_params.total_time, step=robot.sim_params.dt)
options = dismech.AnimationOptions(title='Tomato2', plot_step=10)

fig = dismech.get_interactive_animation_plotly(robot, t, qs , options)
fig.show()

# %%
# # save gif
# ani = dismech.get_animation(robot, t, qs, options)
# save_path = os.path.join("tomato_results", f"{plant_name}_{position}.gif")
# ani.save(save_path)

# %%
# plot the trajectory of the flower location
flower_node = 73  # pick a node at the flower

import matplotlib.pyplot as plt

# Extract the DOF indices (x, y, z) of the node you want to track
flower_node_dofs = robot.map_node_to_dof(flower_node)  # e.g., [ix, iy, iz]

# Extract position of that node across all timesteps
logged = qs[:, flower_node_dofs].squeeze()  # shape (n_timesteps, 3)

# remove value at t=0
logged -= robot.nodes[flower_node]

# Plot x, y, z over time
t = np.arange(qs.shape[0]) * robot.sim_params.dt

plt.figure(figsize=(10, 4))
plt.plot(t, logged[:, 0], label='x')
plt.plot(t, logged[:, 1], label='y')
plt.plot(t, logged[:, 2], label='z')
plt.xlabel('Time (s)')
plt.ylabel('Position')
plt.title(f'Position of Node {flower_node} Over Time')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Save data for rendering

# %%
# from dismech.logging import logDataForRendering
# from dismech.logging import export_parachute_data

# rod_data, shell_data = logDataForRendering(qs, t.reshape(-1, 1), robot, len(t), robot.sim_params.static_sim, robot.map_node_to_dof)

# js_file = os.path.join("tomato_results", f"{plant_name}_{position}.js")
# export_parachute_data(qs, geo.rod_edges, robot,
#                           rod_js=js_file,
#                           scaleFactor=100)

# %%
import numpy as np
from scipy.signal import hilbert, detrend, find_peaks

def avg_cycle_amplitude_hilbert(x: np.ndarray) -> float:
    """
    Robust average oscillation amplitude using the analytic-signal envelope.
    Returns the median envelope value (less sensitive to outliers).
    """
    x = np.asarray(x).ravel()
    x = detrend(x)  # remove slow drift
    envelope = np.abs(hilbert(x))
    # Use median to resist occasional spikes; mean is also fine.
    return float(np.median(envelope))

# %%
# amplitude of flower node motion
amp_x_flower_hilbert = avg_cycle_amplitude_hilbert(logged[:, 0]) # hilbert-based amplitude
amp_x_flower_peak = (np.max(logged[:, 0]) - np.min(logged[:, 0])) / 2.0 # peak-to-peak amplitude
print(f"Amplitude of flower node {flower_node} motion in x (peak-to-peak): {amp_x_flower_peak:.4f} m")
print(f"Amplitude of flower node {flower_node} motion in x (hilbert): {amp_x_flower_hilbert:.4f} m")
# Out:
# Amplitude of flower node 73 motion in x (peak-to-peak): 0.0039 m
# Amplitude of flower node 73 motion in x (hilbert): 0.0039 m

# %% [markdown]
# #### Estimate frequency

# %%
import numpy as np

def estimate_frequency(signal, dt):
    """
    Estimate dominant frequency of a periodic signal using FFT.
    
    Parameters
    ----------
    signal : 1D np.ndarray
        The time-varying signal (samples).
    dt : float
        Time step between samples.
    
    Returns
    -------
    freq : float
        Dominant frequency (Hz).
    """
    n = len(signal)
    # Remove mean to avoid 0 Hz dominance
    signal = signal - np.mean(signal)

    # FFT
    freqs = np.fft.rfftfreq(n, d=dt)       # frequency bins (Hz)
    fft_vals = np.fft.rfft(signal)         # FFT coefficients
    magnitude = np.abs(fft_vals)

    # Find the peak frequency (excluding DC = 0 Hz)
    peak_idx = np.argmax(magnitude[1:]) + 1
    freq = freqs[peak_idx]
    return freq


# Example: make a sine wave of 5 Hz, sample at 100 Hz

f_est = estimate_frequency(logged[:, 0], robot.sim_params.dt)
print(f"Estimated frequency: {f_est:.2f} Hz")   # ~5.00 Hz
# Out:
# Estimated frequency: 1.20 Hz
