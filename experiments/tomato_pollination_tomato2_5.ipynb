# %% [markdown]
# ## Tomato Pollination: Tomato 2

# %%
import numpy as np
import dismech
import os

plant_name = "tomato2"

position = "5"

geom = dismech.GeomParams(
    rod_r0=0.03,
    shell_h=0.0,
)

material = dismech.Material(density=1100,
                            youngs_rod=2.16e7,
                            youngs_shell=0,
                            poisson_rod=0.5,
                            poisson_shell=0)

dyn_sim = dismech.SimParams(static_sim=False,
                                  two_d_sim=True,   # no twisting
                                  use_mid_edge=False,
                                  use_line_search=False,
                                  show_floor=False,
                                  log_data=True,
                                  log_step=1,
                                  dt=1e-2,
                                  max_iter=50,
                                  total_time=5,
                                  plot_step=10,
                                  tol=1e-4,
                                  ftol=1e-4,
                                  dtol=1e-2
                                  )

env = dismech.Environment()
env.add_force('gravity', g=np.array([0.0, 0.0, -9.81]))
env.add_force('damping', eta=100)

input_txt = os.path.join('../tests/resources/tomato_pollination/plants/', f"{plant_name}.txt")
geo = dismech.Geometry.from_txt(input_txt)

robot = dismech.SoftRobot(geom, material, geo, dyn_sim, env)

# %% [markdown]
# ### Move the stem: Moving BC

# %%
# # --- pick the main grip node robustly ---
# grasping_point = np.array([
#       1.1154284,
#       0.0092739,
#       0.4896594
#     ])
# xyz = robot.state.q[robot.node_dof_indices].reshape(-1, 3)

main_grip = 39  # node at the main grip

print("Main grip node:", main_grip)

other_grip_nodes_below = np.array(range(main_grip-4, main_grip), dtype=int)
other_grip_nodes_above = np.arange(main_grip+4, main_grip, -1, dtype=int)

print("Other grip nodes below:", other_grip_nodes_below)
print("Other grip nodes above:", other_grip_nodes_above)
# Out:
# Main grip node: 39
# Other grip nodes below: [35 36 37 38]
# Other grip nodes above: [43 42 41 40]

# %%
base_nodes = np.where((robot.state.q[robot.node_dof_indices].reshape(-1, 3)[:, 2]) < 0.22)[0] # fixed base
# Fix only main_grip and base nodes
robot = robot.fix_nodes(np.unique(np.r_[main_grip, base_nodes]))

# %%
# ----- once, before simulation -----

all_grip_nodes = np.r_[main_grip, other_grip_nodes_below, other_grip_nodes_above].astype(int)

xyz0 = robot.state.q[robot.node_dof_indices].reshape(-1, 3).copy()
x0 = xyz0[all_grip_nodes, 0].copy()          # initial x of all prescribed nodes
prev_target_x = x0.copy()                     # last absolute target (starts at initial)

# (Optional) precompute amplitude scalings from *initial* geometry
def build_amps_from_xyz0(xyz0, main_grip, all_grip_nodes, A_main):
    amps = np.empty(all_grip_nodes.size, float)
    amps[0] = A_main  # main_grip
    # below group
    below = np.array(other_grip_nodes_below, dtype=int)
    if below.size:
        ref = below[0]
        L = max(np.linalg.norm(xyz0[main_grip]-xyz0[ref]), 1e-12)
        for j, node in enumerate(below, start=1):  # start=1 because 0 is main_grip
            amps[j] = A_main * (np.linalg.norm(xyz0[ref]-xyz0[node]) / L)
    # above group
    above = np.array(other_grip_nodes_above, dtype=int)
    if above.size:
        ref = above[0]
        offset = 1 + below.size
        L = max(np.linalg.norm(xyz0[main_grip]-xyz0[ref]), 1e-12)
        for j, node in enumerate(above, start=offset):
            amps[j] = A_main * (np.linalg.norm(xyz0[ref]-xyz0[node]) / L)
    return amps

A_main = 0.340670063e-2   # m at main_grip
freq   = 1.3    # Hz
amps   = build_amps_from_xyz0(xyz0, main_grip, all_grip_nodes, A_main)

def shake_distributed(robot, t: float):
    # absolute target centered at initial pose
    target_x = x0 + amps * np.sin(2*np.pi*freq*t)

    # INCREMENT ONLY: avoids velocity spikes and keeps symmetry
    delta_x = target_x - prev_target_x
    prev_target_x[:] = target_x

    return robot.move_nodes(all_grip_nodes, delta_x.reshape(-1,1).flatten(), axis=0)

print("grasping points:", all_grip_nodes)
# Out:
# grasping points: [39 35 36 37 38 43 42 41 40]

# %%
stepper = dismech.ImplicitEulerTimeStepper(robot)
stepper.before_step = shake_distributed

# %% [markdown]
# ### Simulate

# %%
# simulate
robots = stepper.simulate()

qs = np.stack([robot.state.q for robot in robots])
# Out:
# iter: 1, error: 10112.667
# iter: 2, error: 214.436
# current_time:  0.01
# iter: 1, error: 10041.887
# iter: 2, error: 77.706
# current_time:  0.02
# iter: 1, error: 9904.059
# iter: 2, error: 79.500
# current_time:  0.03
# iter: 1, error: 9698.788
# iter: 2, error: 69.752
# current_time:  0.04
# iter: 1, error: 9429.810
# iter: 2, error: 66.052
# current_time:  0.05
# iter: 1, error: 9099.419
# iter: 2, error: 61.553
# current_time:  0.06
# iter: 1, error: 8709.286
# iter: 2, error: 56.089
# current_time:  0.07
# iter: 1, error: 8261.501
# iter: 2, error: 50.057
# current_time:  0.08
# iter: 1, error: 7758.898
# iter: 2, error: 43.785
# current_time:  0.09
# iter: 1, error: 7204.883
# iter: 2, error: 37.463
# current_time:  0.1
# iter: 1, error: 6603.214
# iter: 2, error: 31.229
# current_time:  0.11
# iter: 1, error: 5957.895
# iter: 2, error: 25.223
# current_time:  0.12
# iter: 1, error: 5273.162
# iter: 2, error: 19.594
# current_time:  0.13
# iter: 1, error: 4553.497
# iter: 2, error: 14.486
# current_time:  0.14
# iter: 1, error: 3803.608
# iter: 2, error: 10.020
# current_time:  0.15
# iter: 1, error: 3028.410
# current_time:  0.16
# iter: 1, error: 2230.549
# current_time:  0.17
# iter: 1, error: 1421.488
# current_time:  0.18
# iter: 1, error: 601.977
# current_time:  0.19
# iter: 1, error: 222.162
# current_time:  0.2
# iter: 1, error: 1045.495
# current_time:  0.21
# iter: 1, error: 1862.657
# current_time:  0.22
# iter: 1, error: 2668.328
# current_time:  0.23
# iter: 1, error: 3457.242
# iter: 2, error: 7.822
# current_time:  0.24
# iter: 1, error: 4220.718
# iter: 2, error: 11.471
# current_time:  0.25
# iter: 1, error: 4958.536
# iter: 2, error: 15.746
# current_time:  0.26
# iter: 1, error: 5664.004
# iter: 2, error: 20.463
# current_time:  0.27
# iter: 1, error: 6332.415
# iter: 2, error: 25.489
# current_time:  0.28
# iter: 1, error: 6959.267
# iter: 2, error: 30.687
# current_time:  0.29
# iter: 1, error: 7540.316
# iter: 2, error: 35.922
# current_time:  0.3
# iter: 1, error: 8071.628
# iter: 2, error: 41.059
# current_time:  0.31
# iter: 1, error: 8549.599
# iter: 2, error: 45.966
# current_time:  0.32
# iter: 1, error: 8970.975
# iter: 2, error: 50.513
# current_time:  0.33
# iter: 1, error: 9332.867
# iter: 2, error: 54.580
# current_time:  0.34
# iter: 1, error: 9632.775
# iter: 2, error: 58.059
# current_time:  0.35000000000000003
# iter: 1, error: 9868.605
# iter: 2, error: 60.856
# current_time:  0.36
# iter: 1, error: 10038.689
# iter: 2, error: 62.897
# current_time:  0.37
# iter: 1, error: 10141.800
# iter: 2, error: 64.128
# current_time:  0.38
# iter: 1, error: 10177.163
# iter: 2, error: 64.515
# current_time:  0.39
# iter: 1, error: 10144.460
# iter: 2, error: 64.047
# current_time:  0.4
# iter: 1, error: 10043.836
# iter: 2, error: 62.739
# current_time:  0.41000000000000003
# iter: 1, error: 9875.897
# iter: 2, error: 60.624
# current_time:  0.42
# iter: 1, error: 9641.713
# iter: 2, error: 57.761
# current_time:  0.43
# iter: 1, error: 9342.806
# iter: 2, error: 54.225
# current_time:  0.44
# iter: 1, error: 8981.146
# iter: 2, error: 50.112
# current_time:  0.45
# iter: 1, error: 8559.135
# iter: 2, error: 45.531
# current_time:  0.46
# iter: 1, error: 8079.591
# iter: 2, error: 40.601
# current_time:  0.47000000000000003
# iter: 1, error: 7545.733
# iter: 2, error: 35.454
# current_time:  0.48
# iter: 1, error: 6961.153
# iter: 2, error: 30.222
# current_time:  0.49
# iter: 1, error: 6329.796
# iter: 2, error: 25.042
# current_time:  0.5
# iter: 1, error: 5655.928
# iter: 2, error: 20.048
# current_time:  0.51
# iter: 1, error: 4944.112
# iter: 2, error: 15.371
# current_time:  0.52
# iter: 1, error: 4199.170
# iter: 2, error: 11.133
# current_time:  0.53
# iter: 1, error: 3426.149
# iter: 2, error: 7.446
# current_time:  0.54
# iter: 1, error: 2630.291
# current_time:  0.55
# iter: 1, error: 1818.608
# current_time:  0.56
# iter: 1, error: 992.681
# current_time:  0.5700000000000001
# iter: 1, error: 160.461
# current_time:  0.58
# iter: 1, error: 672.115
# current_time:  0.59
# iter: 1, error: 1499.411
# current_time:  0.6
# iter: 1, error: 2315.902
# current_time:  0.61
# iter: 1, error: 3116.169
# current_time:  0.62
# iter: 1, error: 3894.908
# iter: 2, error: 10.041
# current_time:  0.63
# iter: 1, error: 4650.015
# iter: 2, error: 14.728
# current_time:  0.64
# iter: 1, error: 5371.149
# iter: 2, error: 19.915
# current_time:  0.65
# iter: 1, error: 6055.902
# iter: 2, error: 25.611
# current_time:  0.66
# iter: 1, error: 6699.716
# iter: 2, error: 31.665
# current_time:  0.67
# iter: 1, error: 7298.279
# iter: 2, error: 37.921
# current_time:  0.68
# iter: 1, error: 7847.597
# iter: 2, error: 44.224
# current_time:  0.6900000000000001
# iter: 1, error: 8344.043
# iter: 2, error: 50.409
# current_time:  0.7000000000000001
# iter: 1, error: 8784.377
# iter: 2, error: 56.302
# current_time:  0.71
# iter: 1, error: 9165.745
# iter: 2, error: 61.727
# current_time:  0.72
# iter: 1, error: 9485.693
# iter: 2, error: 66.517
# current_time:  0.73
# iter: 1, error: 9742.175
# iter: 2, error: 70.524
# current_time:  0.74
# iter: 1, error: 9933.570
# iter: 2, error: 73.622
# current_time:  0.75
# iter: 1, error: 10058.695
# iter: 2, error: 75.716
# current_time:  0.76
# iter: 1, error: 10116.806
# iter: 2, error: 76.737
# current_time:  0.77
# iter: 1, error: 10107.603
# iter: 2, error: 76.655
# current_time:  0.78
# iter: 1, error: 10031.228
# iter: 2, error: 75.472
# current_time:  0.79
# iter: 1, error: 9888.264
# iter: 2, error: 73.225
# current_time:  0.8
# iter: 1, error: 9679.725
# iter: 2, error: 69.988
# current_time:  0.81
# iter: 1, error: 9407.050
# iter: 2, error: 65.861
# current_time:  0.8200000000000001
# iter: 1, error: 9072.092
# iter: 2, error: 60.974
# current_time:  0.8300000000000001
# iter: 1, error: 8677.106
# iter: 2, error: 55.477
# current_time:  0.84
# iter: 1, error: 8224.730
# iter: 2, error: 49.533
# current_time:  0.85
# iter: 1, error: 7717.974
# iter: 2, error: 43.316
# current_time:  0.86
# iter: 1, error: 7160.191
# iter: 2, error: 37.003
# current_time:  0.87
# iter: 1, error: 6555.065
# iter: 2, error: 30.767
# current_time:  0.88
# iter: 1, error: 5906.579
# iter: 2, error: 24.775
# current_time:  0.89
# iter: 1, error: 5218.997
# iter: 2, error: 19.179
# current_time:  0.9
# iter: 1, error: 4496.831
# iter: 2, error: 14.116
# current_time:  0.91
# iter: 1, error: 3744.815
# iter: 2, error: 9.706
# current_time:  0.92
# iter: 1, error: 2967.877
# current_time:  0.93
# iter: 1, error: 2168.769
# current_time:  0.9400000000000001
# iter: 1, error: 1358.729
# current_time:  0.9500000000000001
# iter: 1, error: 538.674
# current_time:  0.96
# iter: 1, error: 285.593
# current_time:  0.97
# iter: 1, error: 1108.642
# current_time:  0.98
# iter: 1, error: 1925.109
# current_time:  0.99
# iter: 1, error: 2729.677
# current_time:  1.0
# iter: 1, error: 3517.086
# iter: 2, error: 8.094
# current_time:  1.01
# iter: 1, error: 4278.530
# iter: 2, error: 11.783
# current_time:  1.02
# iter: 1, error: 5014.022
# iter: 2, error: 16.095
# current_time:  1.03
# iter: 1, error: 5716.797
# iter: 2, error: 20.841
# current_time:  1.04
# iter: 1, error: 6382.166
# iter: 2, error: 25.885
# current_time:  1.05
# iter: 1, error: 7005.643
# iter: 2, error: 31.091
# current_time:  1.06
# iter: 1, error: 7583.004
# iter: 2, error: 36.323
# current_time:  1.07
# iter: 1, error: 8110.338
# iter: 2, error: 41.447
# current_time:  1.08
# iter: 1, error: 8584.066
# iter: 2, error: 46.330
# current_time:  1.09
# iter: 1, error: 9000.964
# iter: 2, error: 50.845
# current_time:  1.1
# iter: 1, error: 9358.173
# iter: 2, error: 54.870
# current_time:  1.11
# iter: 1, error: 9653.221
# iter: 2, error: 58.299
# current_time:  1.12
# iter: 1, error: 9884.047
# iter: 2, error: 61.041
# current_time:  1.1300000000000001
# iter: 1, error: 10049.017
# iter: 2, error: 63.021
# current_time:  1.1400000000000001
# iter: 1, error: 10146.939
# iter: 2, error: 64.188
# current_time:  1.1500000000000001
# iter: 1, error: 10177.071
# iter: 2, error: 64.509
# current_time:  1.16
# iter: 1, error: 10139.132
# iter: 2, error: 63.976
# current_time:  1.17
# iter: 1, error: 10033.302
# iter: 2, error: 62.604
# current_time:  1.18
# iter: 1, error: 9860.224
# iter: 2, error: 60.430
# current_time:  1.19
# iter: 1, error: 9621.001
# iter: 2, error: 57.511
# current_time:  1.2
# iter: 1, error: 9317.192
# iter: 2, error: 53.928
# current_time:  1.21
# iter: 1, error: 8950.799
# iter: 2, error: 49.775
# current_time:  1.22
# iter: 1, error: 8524.256
# iter: 2, error: 45.162
# current_time:  1.23
# iter: 1, error: 8040.415
# iter: 2, error: 40.211
# current_time:  1.24
# iter: 1, error: 7502.523
# iter: 2, error: 35.053
# current_time:  1.25
# iter: 1, error: 6914.200
# iter: 2, error: 29.820
# current_time:  1.26
# iter: 1, error: 6279.416
# iter: 2, error: 24.649
# current_time:  1.27
# iter: 1, error: 5602.464
# iter: 2, error: 19.676
# current_time:  1.28
# iter: 1, error: 4887.925
# iter: 2, error: 15.028
# current_time:  1.29
# iter: 1, error: 4140.640
# iter: 2, error: 10.828
# current_time:  1.3
# iter: 1, error: 3365.674
# iter: 2, error: 7.189
# current_time:  1.31
# iter: 1, error: 2568.280
# current_time:  1.32
# iter: 1, error: 1755.406
# current_time:  1.33
# iter: 1, error: 928.802
# current_time:  1.34
# iter: 1, error: 96.356
# current_time:  1.35
# iter: 1, error: 736.013
# current_time:  1.36
# iter: 1, error: 1562.673
# current_time:  1.37
# iter: 1, error: 2378.108
# current_time:  1.3800000000000001
# iter: 1, error: 3176.906
# current_time:  1.3900000000000001
# iter: 1, error: 3953.772
# iter: 2, error: 10.348
# current_time:  1.4000000000000001
# iter: 1, error: 4706.698
# iter: 2, error: 15.098
# current_time:  1.41
# iter: 1, error: 5425.186
# iter: 2, error: 20.332
# current_time:  1.42
# iter: 1, error: 6106.939
# iter: 2, error: 26.065
# current_time:  1.43
# iter: 1, error: 6747.418
# iter: 2, error: 32.142
# current_time:  1.44
# iter: 1, error: 7342.332
# iter: 2, error: 38.408
# current_time:  1.45
# iter: 1, error: 7887.709
# iter: 2, error: 44.707
# current_time:  1.46
# iter: 1, error: 8379.952
# iter: 2, error: 50.875
# current_time:  1.47
# iter: 1, error: 8815.847
# iter: 2, error: 56.738
# current_time:  1.48
# iter: 1, error: 9192.572
# iter: 2, error: 62.119
# current_time:  1.49
# iter: 1, error: 9507.705
# iter: 2, error: 66.854
# current_time:  1.5
# iter: 1, error: 9759.232
# iter: 2, error: 70.796
# current_time:  1.51
# iter: 1, error: 9945.566
# iter: 2, error: 73.820
# current_time:  1.52
# iter: 1, error: 10065.557
# iter: 2, error: 75.833
# current_time:  1.53
# iter: 1, error: 10118.495
# iter: 2, error: 76.770
# current_time:  1.54
# iter: 1, error: 10104.114
# iter: 2, error: 76.603
# current_time:  1.55
# iter: 1, error: 10022.591
# iter: 2, error: 75.336
# current_time:  1.56
# iter: 1, error: 9874.541
# iter: 2, error: 73.010
# current_time:  1.57
# iter: 1, error: 9661.012
# iter: 2, error: 69.700
# current_time:  1.58
# iter: 1, error: 9383.475
# iter: 2, error: 65.510
# current_time:  1.59
# iter: 1, error: 9043.814
# iter: 2, error: 60.571
# current_time:  1.6
# iter: 1, error: 8644.314
# iter: 2, error: 55.033
# current_time:  1.61
# iter: 1, error: 8187.644
# iter: 2, error: 49.062
# current_time:  1.62
# iter: 1, error: 7676.839
# iter: 2, error: 42.831
# current_time:  1.6300000000000001
# iter: 1, error: 7115.279
# iter: 2, error: 36.518
# current_time:  1.6400000000000001
# iter: 1, error: 6506.672
# iter: 2, error: 30.296
# current_time:  1.6500000000000001
# iter: 1, error: 5855.024
# iter: 2, error: 24.328
# current_time:  1.6600000000000001
# iter: 1, error: 5164.618
# iter: 2, error: 18.769
# current_time:  1.67
# iter: 1, error: 4439.984
# iter: 2, error: 13.753
# current_time:  1.68
# iter: 1, error: 3685.873
# iter: 2, error: 9.397
# current_time:  1.69
# iter: 1, error: 2907.227
# current_time:  1.7
# iter: 1, error: 2106.902
# current_time:  1.71
# iter: 1, error: 1295.915
# current_time:  1.72
# iter: 1, error: 475.347
# current_time:  1.73
# iter: 1, error: 349.017
# current_time:  1.74
# iter: 1, error: 1171.750
# current_time:  1.75
# iter: 1, error: 1987.490
# current_time:  1.76
# iter: 1, error: 2790.925
# current_time:  1.77
# iter: 1, error: 3576.798
# iter: 2, error: 8.371
# current_time:  1.78
# iter: 1, error: 4336.177
# iter: 2, error: 12.099
# current_time:  1.79
# iter: 1, error: 5069.313
# iter: 2, error: 16.446
# current_time:  1.8
# iter: 1, error: 5769.369
# iter: 2, error: 21.219
# current_time:  1.81
# iter: 1, error: 6431.669
# iter: 2, error: 26.281
# current_time:  1.82
# iter: 1, error: 7051.746
# iter: 2, error: 31.494
# current_time:  1.83
# iter: 1, error: 7625.396
# iter: 2, error: 36.722
# current_time:  1.84
# iter: 1, error: 8148.730
# iter: 2, error: 41.833
# current_time:  1.85
# iter: 1, error: 8618.198
# iter: 2, error: 46.692
# current_time:  1.86
# iter: 1, error: 9030.601
# iter: 2, error: 51.173
# current_time:  1.87
# iter: 1, error: 9383.110
# iter: 2, error: 55.156
# current_time:  1.8800000000000001
# iter: 1, error: 9673.286
# iter: 2, error: 58.535
# current_time:  1.8900000000000001
# iter: 1, error: 9899.099
# iter: 2, error: 61.221
# current_time:  1.9000000000000001
# iter: 1, error: 10058.948
# iter: 2, error: 63.140
# current_time:  1.9100000000000001
# iter: 1, error: 10151.676
# iter: 2, error: 64.243
# current_time:  1.92
# iter: 1, error: 10176.576
# iter: 2, error: 64.498
# current_time:  1.93
# iter: 1, error: 10133.403
# iter: 2, error: 63.900
# current_time:  1.94
# iter: 1, error: 10022.371
# iter: 2, error: 62.465
# current_time:  1.95
# iter: 1, error: 9844.159
# iter: 2, error: 60.231
# current_time:  1.96
# iter: 1, error: 9599.907
# iter: 2, error: 57.258
# current_time:  1.97
# iter: 1, error: 9291.207
# iter: 2, error: 53.627
# current_time:  1.98
# iter: 1, error: 8920.095
# iter: 2, error: 49.435
# current_time:  1.99
# iter: 1, error: 8489.038
# iter: 2, error: 44.792
# current_time:  2.0
# iter: 1, error: 8000.919
# iter: 2, error: 39.820
# current_time:  2.0100000000000002
# iter: 1, error: 7459.013
# iter: 2, error: 34.651
# current_time:  2.02
# iter: 1, error: 6866.971
# iter: 2, error: 29.418
# current_time:  2.0300000000000002
# iter: 1, error: 6228.787
# iter: 2, error: 24.258
# current_time:  2.04
# iter: 1, error: 5548.777
# iter: 2, error: 19.305
# current_time:  2.05
# iter: 1, error: 4831.544
# iter: 2, error: 14.687
# current_time:  2.06
# iter: 1, error: 4081.947
# iter: 2, error: 10.527
# current_time:  2.07
# iter: 1, error: 3305.066
# iter: 2, error: 6.935
# current_time:  2.08
# iter: 1, error: 2506.169
# current_time:  2.09
# iter: 1, error: 1692.138
# current_time:  2.1
# iter: 1, error: 864.890
# current_time:  2.11
# iter: 1, error: 32.254
# current_time:  2.12
# iter: 1, error: 799.876
# current_time:  2.13
# iter: 1, error: 1625.869
# current_time:  2.14
# iter: 1, error: 2440.215
# current_time:  2.15
# iter: 1, error: 3237.512
# current_time:  2.16
# iter: 1, error: 4012.477
# iter: 2, error: 10.658
# current_time:  2.17
# iter: 1, error: 4763.191
# iter: 2, error: 15.472
# current_time:  2.18
# iter: 1, error: 5479.006
# iter: 2, error: 20.752
# current_time:  2.19
# iter: 1, error: 6157.732
# iter: 2, error: 26.520
# current_time:  2.2
# iter: 1, error: 6794.850
# iter: 2, error: 32.620
# current_time:  2.21
# iter: 1, error: 7386.092
# iter: 2, error: 38.895
# current_time:  2.22
# iter: 1, error: 7927.508
# iter: 2, error: 45.190
# current_time:  2.23
# iter: 1, error: 8415.527
# iter: 2, error: 51.340
# current_time:  2.24
# iter: 1, error: 8846.966
# iter: 2, error: 57.171
# current_time:  2.25
# iter: 1, error: 9219.034
# iter: 2, error: 62.508
# current_time:  2.2600000000000002
# iter: 1, error: 9529.340
# iter: 2, error: 67.187
# current_time:  2.27
# iter: 1, error: 9775.903
# iter: 2, error: 71.062
# current_time:  2.2800000000000002
# iter: 1, error: 9957.170
# iter: 2, error: 74.012
# current_time:  2.29
# iter: 1, error: 10072.022
# iter: 2, error: 75.944
# current_time:  2.3000000000000003
# iter: 1, error: 10119.786
# iter: 2, error: 76.797
# current_time:  2.31
# iter: 1, error: 10100.228
# iter: 2, error: 76.544
# current_time:  2.32
# iter: 1, error: 10013.560
# iter: 2, error: 75.194
# current_time:  2.33
# iter: 1, error: 9860.431
# iter: 2, error: 72.789
# current_time:  2.34
# iter: 1, error: 9641.920
# iter: 2, error: 69.408
# current_time:  2.35
# iter: 1, error: 9359.532
# iter: 2, error: 65.155
# current_time:  2.36
# iter: 1, error: 9015.181
# iter: 2, error: 60.164
# current_time:  2.37
# iter: 1, error: 8611.184
# iter: 2, error: 54.587
# current_time:  2.38
# iter: 1, error: 8150.237
# iter: 2, error: 48.590
# current_time:  2.39
# iter: 1, error: 7635.403
# iter: 2, error: 42.346
# current_time:  2.4
# iter: 1, error: 7070.089
# iter: 2, error: 36.034
# current_time:  2.41
# iter: 1, error: 6458.024
# iter: 2, error: 29.825
# current_time:  2.42
# iter: 1, error: 5803.239
# iter: 2, error: 23.884
# current_time:  2.43
# iter: 1, error: 5110.036
# iter: 2, error: 18.362
# current_time:  2.44
# iter: 1, error: 4382.963
# iter: 2, error: 13.393
# current_time:  2.45
# iter: 1, error: 3626.787
# iter: 2, error: 9.092
# current_time:  2.46
# iter: 1, error: 2846.462
# current_time:  2.47
# iter: 1, error: 2044.949
# current_time:  2.48
# iter: 1, error: 1233.047
# current_time:  2.49
# iter: 1, error: 411.998
# current_time:  2.5
# iter: 1, error: 412.432
# current_time:  2.5100000000000002
# iter: 1, error: 1234.817
# current_time:  2.52
# iter: 1, error: 2049.799
# current_time:  2.5300000000000002
# iter: 1, error: 2852.069
# current_time:  2.54
# iter: 1, error: 3636.375
# iter: 2, error: 8.652
# current_time:  2.5500000000000003
# iter: 1, error: 4393.658
# iter: 2, error: 12.417
# current_time:  2.56
# iter: 1, error: 5124.409
# iter: 2, error: 16.800
# current_time:  2.57
# iter: 1, error: 5821.716
# iter: 2, error: 21.600
# current_time:  2.58
# iter: 1, error: 6480.922
# iter: 2, error: 26.679
# current_time:  2.59
# iter: 1, error: 7097.574
# iter: 2, error: 31.898
# current_time:  2.6
# iter: 1, error: 7667.490
# iter: 2, error: 37.122
# current_time:  2.61
# iter: 1, error: 8186.804
# iter: 2, error: 42.217
# current_time:  2.62
# iter: 1, error: 8651.991
# iter: 2, error: 47.052
# current_time:  2.63
# iter: 1, error: 9059.883
# iter: 2, error: 51.498
# current_time:  2.64
# iter: 1, error: 9407.678
# iter: 2, error: 55.439
# current_time:  2.65
# iter: 1, error: 9692.970
# iter: 2, error: 58.768
# current_time:  2.66
# iter: 1, error: 9913.760
# iter: 2, error: 61.396
# current_time:  2.67
# iter: 1, error: 10068.482
# iter: 2, error: 63.255
# current_time:  2.68
# iter: 1, error: 10156.011
# iter: 2, error: 64.293
# current_time:  2.69
# iter: 1, error: 10175.678
# iter: 2, error: 64.482
# current_time:  2.7
# iter: 1, error: 10127.271
# iter: 2, error: 63.819
# current_time:  2.71
# iter: 1, error: 10011.042
# iter: 2, error: 62.321
# current_time:  2.72
# iter: 1, error: 9827.704
# iter: 2, error: 60.027
# current_time:  2.73
# iter: 1, error: 9578.432
# iter: 2, error: 57.001
# current_time:  2.74
# iter: 1, error: 9264.852
# iter: 2, error: 53.323
# current_time:  2.75
# iter: 1, error: 8889.036
# iter: 2, error: 49.092
# current_time:  2.7600000000000002
# iter: 1, error: 8453.482
# iter: 2, error: 44.419
# current_time:  2.77
# iter: 1, error: 7961.104
# iter: 2, error: 39.428
# current_time:  2.7800000000000002
# iter: 1, error: 7415.207
# iter: 2, error: 34.249
# current_time:  2.79
# iter: 1, error: 6819.469
# iter: 2, error: 29.017
# current_time:  2.8000000000000003
# iter: 1, error: 6177.911
# iter: 2, error: 23.868
# current_time:  2.81
# iter: 1, error: 5494.870
# iter: 2, error: 18.936
# current_time:  2.82
# iter: 1, error: 4774.971
# iter: 2, error: 14.349
# current_time:  2.83
# iter: 1, error: 4023.092
# iter: 2, error: 10.229
# current_time:  2.84
# iter: 1, error: 3244.328
# current_time:  2.85
# iter: 1, error: 2446.427
# current_time:  2.86
# iter: 1, error: 1629.135
# current_time:  2.87
# iter: 1, error: 801.004
# current_time:  2.88
# iter: 1, error: 31.842
# current_time:  2.89
# iter: 1, error: 863.698
# current_time:  2.9
# iter: 1, error: 1688.986
# current_time:  2.91
# iter: 1, error: 2502.215
# current_time:  2.92
# iter: 1, error: 3297.987
# current_time:  2.93
# iter: 1, error: 4071.022
# iter: 2, error: 10.971
# current_time:  2.94
# iter: 1, error: 4819.494
# iter: 2, error: 15.848
# current_time:  2.95
# iter: 1, error: 5532.604
# iter: 2, error: 21.175
# current_time:  2.96
# iter: 1, error: 6208.276
# iter: 2, error: 26.978
# current_time:  2.97
# iter: 1, error: 6842.010
# iter: 2, error: 33.100
# current_time:  2.98
# iter: 1, error: 7429.556
# iter: 2, error: 39.382
# current_time:  2.99
# iter: 1, error: 7966.991
# iter: 2, error: 45.671
# current_time:  3.0
# iter: 1, error: 8450.768
# iter: 2, error: 51.802
# current_time:  3.0100000000000002
# iter: 1, error: 8877.734
# iter: 2, error: 57.601
# current_time:  3.02
# iter: 1, error: 9245.131
# iter: 2, error: 62.893
# current_time:  3.0300000000000002
# iter: 1, error: 9550.598
# iter: 2, error: 67.516
# current_time:  3.04
# iter: 1, error: 9792.188
# iter: 2, error: 71.323
# current_time:  3.0500000000000003
# iter: 1, error: 9968.380
# iter: 2, error: 74.198
# current_time:  3.06
# iter: 1, error: 10078.090
# iter: 2, error: 76.048
# current_time:  3.0700000000000003
# iter: 1, error: 10120.678
# iter: 2, error: 76.817
# current_time:  3.08
# iter: 1, error: 10095.945
# iter: 2, error: 76.479
# current_time:  3.09
# iter: 1, error: 10004.136
# iter: 2, error: 75.045
# current_time:  3.1
# iter: 1, error: 9845.933
# iter: 2, error: 72.563
# current_time:  3.11
# iter: 1, error: 9622.450
# iter: 2, error: 69.110
# current_time:  3.12
# iter: 1, error: 9335.222
# iter: 2, error: 64.796
# current_time:  3.13
# iter: 1, error: 8986.196
# iter: 2, error: 59.754
# current_time:  3.14
# iter: 1, error: 8577.717
# iter: 2, error: 54.138
# current_time:  3.15
# iter: 1, error: 8112.511
# iter: 2, error: 48.116
# current_time:  3.16
# iter: 1, error: 7593.669
# iter: 2, error: 41.861
# current_time:  3.17
# iter: 1, error: 7024.621
# iter: 2, error: 35.551
# current_time:  3.18
# iter: 1, error: 6409.124
# iter: 2, error: 29.357
# current_time:  3.19
# iter: 1, error: 5751.227
# iter: 2, error: 23.443
# current_time:  3.2
# iter: 1, error: 5055.253
# iter: 2, error: 17.958
# current_time:  3.21
# iter: 1, error: 4325.769
# iter: 2, error: 13.037
# current_time:  3.22
# iter: 1, error: 3567.557
# iter: 2, error: 8.792
# current_time:  3.23
# iter: 1, error: 2785.584
# current_time:  3.24
# iter: 1, error: 1982.913
# current_time:  3.25
# iter: 1, error: 1170.127
# current_time:  3.2600000000000002
# iter: 1, error: 348.629
# current_time:  3.27
# iter: 1, error: 475.834
# current_time:  3.2800000000000002
# iter: 1, error: 1297.840
# current_time:  3.29
# iter: 1, error: 2112.032
# current_time:  3.3000000000000003
# iter: 1, error: 2913.106
# current_time:  3.31
# iter: 1, error: 3695.815
# iter: 2, error: 8.936
# current_time:  3.3200000000000003
# iter: 1, error: 4450.969
# iter: 2, error: 12.739
# current_time:  3.33
# iter: 1, error: 5179.306
# iter: 2, error: 17.156
# current_time:  3.34
# iter: 1, error: 5873.838
# iter: 2, error: 21.982
# current_time:  3.35
# iter: 1, error: 6529.923
# iter: 2, error: 27.077
# current_time:  3.36
# iter: 1, error: 7143.126
# iter: 2, error: 32.301
# current_time:  3.37
# iter: 1, error: 7709.285
# iter: 2, error: 37.520
# current_time:  3.38
# iter: 1, error: 8224.557
# iter: 2, error: 42.600
# current_time:  3.39
# iter: 1, error: 8685.446
# iter: 2, error: 47.409
# current_time:  3.4
# iter: 1, error: 9088.809
# iter: 2, error: 51.821
# current_time:  3.41
# iter: 1, error: 9431.877
# iter: 2, error: 55.718
# current_time:  3.42
# iter: 1, error: 9712.272
# iter: 2, error: 58.996
# current_time:  3.43
# iter: 1, error: 9928.030
# iter: 2, error: 61.567
# current_time:  3.44
# iter: 1, error: 10077.618
# iter: 2, error: 63.364
# current_time:  3.45
# iter: 1, error: 10159.945
# iter: 2, error: 64.338
# current_time:  3.46
# iter: 1, error: 10174.377
# iter: 2, error: 64.462
# current_time:  3.47
# iter: 1, error: 10120.738
# iter: 2, error: 63.733
# current_time:  3.48
# iter: 1, error: 9999.315
# iter: 2, error: 62.172
# current_time:  3.49
# iter: 1, error: 9810.858
# iter: 2, error: 59.820
# current_time:  3.5
# iter: 1, error: 9556.575
# iter: 2, error: 56.740
# current_time:  3.5100000000000002
# iter: 1, error: 9238.129
# iter: 2, error: 53.016
# current_time:  3.52
# iter: 1, error: 8857.623
# iter: 2, error: 48.747
# current_time:  3.5300000000000002
# iter: 1, error: 8417.589
# iter: 2, error: 44.045
# current_time:  3.54
# iter: 1, error: 7920.972
# iter: 2, error: 39.035
# current_time:  3.5500000000000003
# iter: 1, error: 7371.106
# iter: 2, error: 33.847
# current_time:  3.56
# iter: 1, error: 6771.696
# iter: 2, error: 28.616
# current_time:  3.5700000000000003
# iter: 1, error: 6126.788
# iter: 2, error: 23.479
# current_time:  3.58
# iter: 1, error: 5440.744
# iter: 2, error: 18.569
# current_time:  3.59
# iter: 1, error: 4718.209
# iter: 2, error: 14.014
# current_time:  3.6
# iter: 1, error: 3964.077
# iter: 2, error: 9.935
# current_time:  3.61
# iter: 1, error: 3183.462
# current_time:  3.62
# iter: 1, error: 2384.030
# current_time:  3.63
# iter: 1, error: 1565.721
# current_time:  3.64
# iter: 1, error: 737.031
# current_time:  3.65
# iter: 1, error: 95.936
# current_time:  3.66
# iter: 1, error: 927.487
# current_time:  3.67
# iter: 1, error: 1752.042
# current_time:  3.68
# iter: 1, error: 2564.118
# current_time:  3.69
# iter: 1, error: 3358.326
# current_time:  3.7
# iter: 1, error: 4129.399
# iter: 2, error: 11.289
# current_time:  3.71
# iter: 1, error: 4875.602
# iter: 2, error: 16.229
# current_time:  3.72
# iter: 1, error: 5585.981
# iter: 2, error: 21.601
# current_time:  3.73
# iter: 1, error: 6258.573
# iter: 2, error: 27.438
# current_time:  3.74
# iter: 1, error: 6888.897
# iter: 2, error: 33.580
# current_time:  3.75
# iter: 1, error: 7472.725
# iter: 2, error: 39.869
# current_time:  3.7600000000000002
# iter: 1, error: 8006.156
# iter: 2, error: 46.151
# current_time:  3.77
# iter: 1, error: 8485.672
# iter: 2, error: 52.262
# current_time:  3.7800000000000002
# iter: 1, error: 8908.150
# iter: 2, error: 58.028
# current_time:  3.79
# iter: 1, error: 9270.861
# iter: 2, error: 63.274
# current_time:  3.8000000000000003
# iter: 1, error: 9571.478
# iter: 2, error: 67.839
# current_time:  3.81
# iter: 1, error: 9808.085
# iter: 2, error: 71.579
# current_time:  3.8200000000000003
# iter: 1, error: 9979.196
# iter: 2, error: 74.377
# current_time:  3.83
# iter: 1, error: 10083.761
# iter: 2, error: 76.146
# current_time:  3.84
# iter: 1, error: 10121.171
# iter: 2, error: 76.830
# current_time:  3.85
# iter: 1, error: 10091.264
# iter: 2, error: 76.407
# current_time:  3.86
# iter: 1, error: 9994.318
# iter: 2, error: 74.891
# current_time:  3.87
# iter: 1, error: 9831.049
# iter: 2, error: 72.330
# current_time:  3.88
# iter: 1, error: 9602.602
# iter: 2, error: 68.807
# current_time:  3.89
# iter: 1, error: 9310.546
# iter: 2, error: 64.432
# current_time:  3.9
# iter: 1, error: 8956.858
# iter: 2, error: 59.340
# current_time:  3.91
# iter: 1, error: 8543.914
# iter: 2, error: 53.687
# current_time:  3.92
# iter: 1, error: 8074.468
# iter: 2, error: 47.641
# current_time:  3.93
# iter: 1, error: 7551.637
# iter: 2, error: 41.375
# current_time:  3.94
# iter: 1, error: 6978.879
# iter: 2, error: 35.068
# current_time:  3.95
# iter: 1, error: 6359.972
# iter: 2, error: 28.890
# current_time:  3.96
# iter: 1, error: 5698.989
# iter: 2, error: 23.004
# current_time:  3.97
# iter: 1, error: 5000.272
# iter: 2, error: 17.558
# current_time:  3.98
# iter: 1, error: 4268.405
# iter: 2, error: 12.685
# current_time:  3.99
# iter: 1, error: 3508.186
# iter: 2, error: 8.496
# current_time:  4.0
# iter: 1, error: 2724.596
# current_time:  4.01
# iter: 1, error: 1920.796
# current_time:  4.0200000000000005
# iter: 1, error: 1107.159
# current_time:  4.03
# iter: 1, error: 285.243
# current_time:  4.04
# iter: 1, error: 539.222
# current_time:  4.05
# iter: 1, error: 1360.817
# current_time:  4.0600000000000005
# iter: 1, error: 2174.188
# current_time:  4.07
# iter: 1, error: 2974.035
# current_time:  4.08
# iter: 1, error: 3755.116
# iter: 2, error: 9.224
# current_time:  4.09
# iter: 1, error: 4508.109
# iter: 2, error: 13.063
# current_time:  4.1
# iter: 1, error: 5234.003
# iter: 2, error: 17.515
# current_time:  4.11
# iter: 1, error: 5925.732
# iter: 2, error: 22.366
# current_time:  4.12
# iter: 1, error: 6578.670
# iter: 2, error: 27.476
# current_time:  4.13
# iter: 1, error: 7188.399
# iter: 2, error: 32.705
# current_time:  4.14
# iter: 1, error: 7750.778
# iter: 2, error: 37.918
# current_time:  4.15
# iter: 1, error: 8261.989
# iter: 2, error: 42.981
# current_time:  4.16
# iter: 1, error: 8718.559
# iter: 2, error: 47.764
# current_time:  4.17
# iter: 1, error: 9117.378
# iter: 2, error: 52.140
# current_time:  4.18
# iter: 1, error: 9455.704
# iter: 2, error: 55.993
# current_time:  4.19
# iter: 1, error: 9731.191
# iter: 2, error: 59.220
# current_time:  4.2
# iter: 1, error: 9941.909
# iter: 2, error: 61.734
# current_time:  4.21
# iter: 1, error: 10086.355
# iter: 2, error: 63.469
# current_time:  4.22
# iter: 1, error: 10163.477
# iter: 2, error: 64.377
# current_time:  4.23
# iter: 1, error: 10172.673
# iter: 2, error: 64.436
# current_time:  4.24
# iter: 1, error: 10113.804
# iter: 2, error: 63.642
# current_time:  4.25
# iter: 1, error: 9987.192
# iter: 2, error: 62.018
# current_time:  4.26
# iter: 1, error: 9793.622
# iter: 2, error: 59.608
# current_time:  4.2700000000000005
# iter: 1, error: 9534.339
# iter: 2, error: 56.476
# current_time:  4.28
# iter: 1, error: 9211.039
# iter: 2, error: 52.706
# current_time:  4.29
# iter: 1, error: 8825.858
# iter: 2, error: 48.399
# current_time:  4.3
# iter: 1, error: 8381.362
# iter: 2, error: 43.669
# current_time:  4.3100000000000005
# iter: 1, error: 7880.525
# iter: 2, error: 38.640
# current_time:  4.32
# iter: 1, error: 7326.712
# iter: 2, error: 33.444
# current_time:  4.33
# iter: 1, error: 6723.653
# iter: 2, error: 28.216
# current_time:  4.34
# iter: 1, error: 6075.422
# iter: 2, error: 23.092
# current_time:  4.3500000000000005
# iter: 1, error: 5386.403
# iter: 2, error: 18.205
# current_time:  4.36
# iter: 1, error: 4661.259
# iter: 2, error: 13.682
# current_time:  4.37
# iter: 1, error: 3904.906
# iter: 2, error: 9.644
# current_time:  4.38
# iter: 1, error: 3122.470
# current_time:  4.39
# iter: 1, error: 2321.540
# current_time:  4.4
# iter: 1, error: 1502.249
# current_time:  4.41
# iter: 1, error: 673.032
# current_time:  4.42
# iter: 1, error: 160.024
# current_time:  4.43
# iter: 1, error: 991.234
# current_time:  4.44
# iter: 1, error: 1815.023
# current_time:  4.45
# iter: 1, error: 2625.915
# current_time:  4.46
# iter: 1, error: 3418.529
# current_time:  4.47
# iter: 1, error: 4187.609
# iter: 2, error: 11.610
# current_time:  4.48
# iter: 1, error: 4931.514
# iter: 2, error: 16.613
# current_time:  4.49
# iter: 1, error: 5639.134
# iter: 2, error: 22.030
# current_time:  4.5
# iter: 1, error: 6308.619
# iter: 2, error: 27.900
# current_time:  4.51
# iter: 1, error: 6935.508
# iter: 2, error: 34.062
# current_time:  4.5200000000000005
# iter: 1, error: 7515.595
# iter: 2, error: 40.357
# current_time:  4.53
# iter: 1, error: 8045.002
# iter: 2, error: 46.631
# current_time:  4.54
# iter: 1, error: 8520.238
# iter: 2, error: 52.720
# current_time:  4.55
# iter: 1, error: 8938.211
# iter: 2, error: 58.451
# current_time:  4.5600000000000005
# iter: 1, error: 9296.223
# iter: 2, error: 63.651
# current_time:  4.57
# iter: 1, error: 9591.978
# iter: 2, error: 68.157
# current_time:  4.58
# iter: 1, error: 9823.595
# iter: 2, error: 71.829
# current_time:  4.59
# iter: 1, error: 9989.619
# iter: 2, error: 74.551
# current_time:  4.6000000000000005
# iter: 1, error: 10089.034
# iter: 2, error: 76.238
# current_time:  4.61
# iter: 1, error: 10121.266
# iter: 2, error: 76.837
# current_time:  4.62
# iter: 1, error: 10086.187
# iter: 2, error: 76.329
# current_time:  4.63
# iter: 1, error: 9984.108
# iter: 2, error: 74.730
# current_time:  4.64
# iter: 1, error: 9815.779
# iter: 2, error: 72.092
# current_time:  4.65
# iter: 1, error: 9582.378
# iter: 2, error: 68.499
# current_time:  4.66
# iter: 1, error: 9285.505
# iter: 2, error: 64.064
# current_time:  4.67
# iter: 1, error: 8927.170
# iter: 2, error: 58.923
# current_time:  4.68
# iter: 1, error: 8509.777
# iter: 2, error: 53.234
# current_time:  4.69
# iter: 1, error: 8036.109
# iter: 2, error: 47.164
# current_time:  4.7
# iter: 1, error: 7509.309
# iter: 2, error: 40.889
# current_time:  4.71
# iter: 1, error: 6932.863
# iter: 2, error: 34.586
# current_time:  4.72
# iter: 1, error: 6310.571
# iter: 2, error: 28.425
# current_time:  4.73
# iter: 1, error: 5646.528
# iter: 2, error: 22.567
# current_time:  4.74
# iter: 1, error: 4945.095
# iter: 2, error: 17.161
# current_time:  4.75
# iter: 1, error: 4210.874
# iter: 2, error: 12.337
# current_time:  4.76
# iter: 1, error: 3448.677
# current_time:  4.7700000000000005
# iter: 1, error: 2660.347
# current_time:  4.78
# iter: 1, error: 1859.036
# current_time:  4.79
# iter: 1, error: 1044.214
# current_time:  4.8
# iter: 1, error: 221.857
# current_time:  4.8100000000000005
# iter: 1, error: 602.588
# current_time:  4.82
# iter: 1, error: 1423.738
# current_time:  4.83
# iter: 1, error: 2236.259
# current_time:  4.84
# iter: 1, error: 3034.853
# current_time:  4.8500000000000005
# iter: 1, error: 3814.280
# iter: 2, error: 9.517
# current_time:  4.86
# iter: 1, error: 4565.076
# iter: 2, error: 13.391
# current_time:  4.87
# iter: 1, error: 5288.497
# iter: 2, error: 17.875
# current_time:  4.88
# iter: 1, error: 5977.395
# iter: 2, error: 22.751
# current_time:  4.89
# iter: 1, error: 6627.160
# iter: 2, error: 27.876
# current_time:  4.9
# iter: 1, error: 7233.392
# iter: 2, error: 33.109
# current_time:  4.91
# iter: 1, error: 7791.969
# iter: 2, error: 38.314
# current_time:  4.92
# iter: 1, error: 8299.097
# iter: 2, error: 43.361
# current_time:  4.93
# iter: 1, error: 8751.332
# iter: 2, error: 48.116
# current_time:  4.94
# iter: 1, error: 9145.589
# iter: 2, error: 52.456
# current_time:  4.95
# iter: 1, error: 9479.159
# iter: 2, error: 56.265
# current_time:  4.96
# iter: 1, error: 9749.727
# iter: 2, error: 59.439
# current_time:  4.97
# iter: 1, error: 9955.395
# iter: 2, error: 61.896
# current_time:  4.98
# iter: 1, error: 10094.695
# iter: 2, error: 63.568
# current_time:  4.99
# iter: 1, error: 10166.607
# iter: 2, error: 64.412
# current_time:  5.0

# %% [markdown]
# ### Plotting

# %%
t = np.arange(robot.sim_params.total_time, step=robot.sim_params.dt)
options = dismech.AnimationOptions(title='Tomato2', plot_step=10)

fig = dismech.get_interactive_animation_plotly(robot, t, qs , options)
fig.show()

# %%
# save gif
ani = dismech.get_animation(robot, t, qs, options)
save_path = os.path.join("tomato_results", f"{plant_name}_{position}.gif")
ani.save(save_path)
# Out:
# 51

# %%
# plot the trajectory of the flower location
flower_node = 73  # pick a node at the flower

import matplotlib.pyplot as plt

# Extract the DOF indices (x, y, z) of the node you want to track
flower_node_dofs = robot.map_node_to_dof(flower_node)  # e.g., [ix, iy, iz]

# Extract position of that node across all timesteps
logged = qs[:, flower_node_dofs].squeeze()  # shape (n_timesteps, 3)

# remove value at t=0
logged -= robot.nodes[flower_node]

# Plot x, y, z over time
t = np.arange(qs.shape[0]) * robot.sim_params.dt

plt.figure(figsize=(10, 4))
plt.plot(t, logged[:, 0], label='x')
plt.plot(t, logged[:, 1], label='y')
plt.plot(t, logged[:, 2], label='z')
plt.xlabel('Time (s)')
plt.ylabel('Position')
plt.title(f'Position of Node {flower_node} Over Time')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Save data for rendering

# %%
from dismech.logging import logDataForRendering
from dismech.logging import export_parachute_data

rod_data, shell_data = logDataForRendering(qs, t.reshape(-1, 1), robot, len(t), robot.sim_params.static_sim, robot.map_node_to_dof)

js_file = os.path.join("tomato_results", f"{plant_name}_{position}.js")
export_parachute_data(qs, geo.rod_edges, robot,
                          rod_js=js_file,
                          scaleFactor=100)
# Out:
# /Users/radha/GitRepos/dismech-python/src/dismech/logging.py:176: UserWarning:
#
# loadtxt: input contained no data: "rawDataShell.txt"

# %%
import numpy as np
from scipy.signal import hilbert, detrend, find_peaks

def avg_cycle_amplitude_hilbert(x: np.ndarray) -> float:
    """
    Robust average oscillation amplitude using the analytic-signal envelope.
    Returns the median envelope value (less sensitive to outliers).
    """
    x = np.asarray(x).ravel()
    x = detrend(x)  # remove slow drift
    envelope = np.abs(hilbert(x))
    # Use median to resist occasional spikes; mean is also fine.
    return float(np.median(envelope))

# %%
# amplitude of flower node motion
amp_x_flower_hilbert = avg_cycle_amplitude_hilbert(logged[:, 0]) # hilbert-based amplitude
amp_x_flower_peak = (np.max(logged[:, 0]) - np.min(logged[:, 0])) / 2.0 # peak-to-peak amplitude
print(f"Amplitude of flower node {flower_node} motion in x (peak-to-peak): {amp_x_flower_peak:.4f} m")
print(f"Amplitude of flower node {flower_node} motion in x (hilbert): {amp_x_flower_hilbert:.4f} m")
# Out:
# Amplitude of flower node 73 motion in x (peak-to-peak): 0.0036 m
# Amplitude of flower node 73 motion in x (hilbert): 0.0036 m

# %%
# plot the amplitudes of the above nodes in a plot against the distance of the node's z-coordinate from the highest base_node
# get the z-coordinate of the highest base node
nodes_to_plot = [15, 21, 27, 33, 39]
base_node_z = robot.state.q[robot.node_dof_indices].reshape(-1, 3)[base_nodes, 2]
highest_base_node_z = np.max(base_node_z)
distances = []
amplitudes = []
for node in nodes_to_plot:
    node_dofs = robot.map_node_to_dof(node)
    node_z = robot.state.q[node_dofs[2]]
    distance = node_z - highest_base_node_z
    distances.append(distance)
    node_x = qs[:, node_dofs[0]].squeeze()  # x-coordinate
    # amplitude = (node_x.max() - node_x.min()) / 2
    amplitude = avg_cycle_amplitude_hilbert(node_x)     # averaged over time amplitude
    amplitudes.append(amplitude)    
plt.figure(figsize=(6, 4))
plt.scatter(distances, amplitudes)
plt.xlabel('distance (m)')
plt.ylabel('amplitude (m)')
plt.title('x amplitude vs distance from base')
# plt.grid(True)
plt.tight_layout()
plt.show()
print("amplitudes:", amplitudes)
# Out:
# amplitudes: [0.0020488631406080206, 0.0024909742030393475, 0.002854654452387453, 0.003179755510125985, 0.0034212913928413887]

# %% [markdown]
# #### Estimate frequency

# %%
import numpy as np

def estimate_frequency(signal, dt):
    """
    Estimate dominant frequency of a periodic signal using FFT.
    
    Parameters
    ----------
    signal : 1D np.ndarray
        The time-varying signal (samples).
    dt : float
        Time step between samples.
    
    Returns
    -------
    freq : float
        Dominant frequency (Hz).
    """
    n = len(signal)
    # Remove mean to avoid 0 Hz dominance
    signal = signal - np.mean(signal)

    # FFT
    freqs = np.fft.rfftfreq(n, d=dt)       # frequency bins (Hz)
    fft_vals = np.fft.rfft(signal)         # FFT coefficients
    magnitude = np.abs(fft_vals)

    # Find the peak frequency (excluding DC = 0 Hz)
    peak_idx = np.argmax(magnitude[1:]) + 1
    freq = freqs[peak_idx]
    return freq


# Example: make a sine wave of 5 Hz, sample at 100 Hz

f_est = estimate_frequency(logged[:, 0], robot.sim_params.dt)
print(f"Estimated frequency: {f_est:.2f} Hz")   # ~5.00 Hz
# Out:
# Estimated frequency: 1.20 Hz
